# %% [markdown]
# # Métodos Computacionales

# %% [markdown]
# ## Unidad 1: Python básico
#
#
# - Repaso breve del Python
# - Estructura básica de un programa en Python.
# - Numpy y rutinas de graficación.
# - Operaciones aritméticas con reales y complejos.
# - Números aleatorios, método del congruente lineal y problemas.
# - Errores: redondeo, truncamiento, sustracción cancelativa, precisiónde la máquina.
# - Algoritmos

# %% [markdown]
# ## Repaso breve de python: Hello World Python

# %% [markdown]
# ##  Tipos de variables en python:
#
# Lenguaje Interpretado

# %%
#Asignación de variables. 
x =  20  #Entero 
y =  3.   #punto flotante
v = 3    #Entero 
z0 = 300000000000000000000000 #Entero 
z1 = 3e10   #Flotante
f = "Hello World " #String
h = "Python"        #String
z = 1 + 9j

# %%
w1 = "Hello "
w2 = " World"

# %%
w1+w2
# Out:
# 'Hello  World'

# %%
w = x + y

# %%
a = f + h  
print(a)
# Out:
# Hello World Python

# %%
print(w1, a)
# Out:
# Hello  Hello World Python

# %%
#mostrando las variables y el tipo de variable
print("x es de tipo", type(x),  "x =", x)
print("y es de tipo", type(y),  "y =", y)
print("v es de tipo", type(z0), "v =", v)
print("z0 es de tipo", type(z0), "z0 =", z0)
print("z1 es de tipo", type(z1), "z1 =", z1)
print("f es de tipo", type(f),  "f =", f)
print("h es de tipo", type(h),  "h =", h)
# Out:
# x es de tipo <class 'int'> x = 20
# y es de tipo <class 'float'> y = 3.0
# v es de tipo <class 'int'> v = 3
# z0 es de tipo <class 'int'> z0 = 300000000000000000000000
# z1 es de tipo <class 'float'> z1 = 30000000000.0
# f es de tipo <class 'str'> f = Hello World
# h es de tipo <class 'str'> h = Python

# %% [markdown]
# ## Tipos de operaciones
# - ### Operadores aritméticos
#
# Operadores  | Descripcion | Ejemplo
# -- | -- | --
# + | Suma | R = 4 + 4 = 8
# - | Resta | R = 7-4  = 3
# - | Negacion| R = - 4  = -4
# * | Multiplicacion |  R =  4*4=16
# ** | Exponente | R = 2**3 = 8
# / | Division | R = 4/2 = 2
# % | Modulo | R = 10 % 4 = 2
# // | Division entera | 10.5/2 = 5

# %%
11/2
# Out:
# 5.5

# %%
11%2
3
# Out:
# 3

# %%
print("x:", x)
print("y:", y)
print("v:", v)
#Division entre tipos de variables
#En la version de python3.0, se puede realizar la división sin inconvenientes.
print("x/y = ", x / y ) , #En python 3 no hay problema con la división, en otro lenguaje puede generar problemas. 
print("x/v = ", x / v )
# Out:
# x: 20
# y: 3.0
# v: 3
# x/y =  6.666666666666667
# x/v =  6.666666666666667

# %%
# Numeros complejos 
z = 1 + 9j  

print("Z es un número complejo", type(z))
print(z.conjugate())
print(z.real)
print(z.imag)
# Out:
# Z es un número complejo <class 'complex'>
# (1-9j)
# 1.0
# 9.0

# %%
z = 1 + 4j

# %%
#Division entera
r1 = 10.5 // 2
r2 = 10.5 / 2
r3 = 10.% 2
print("División entera", r1)
print("División usual ", r2)
print("Modulo",   r3)
# Out:
# División entera 5.0
# División usual  5.25
# Modulo 0.0

# %% [markdown]
# - Operadores a nivel de bit
#
#
# Operadores  | Descripcion              | Ejemplo
# ----------- | -----------              | -------
# &           | and                      | R = 3 & 2 , R= 2
# \|           | or                       | R = 3 \| 2 , R = 3
# ^           | xor                      | R = 3^2  , R=1
# ~           | not                      |  R =  ~3, R=-4
# <<          | desplazamiento izquierda | R = 3<<1, R  = 6
# >>          | desplazamiento derecha   | R = 3>>1 , R = 1

# %%
# ¿Que pasa en la siguiente operacion?,¿como se explica el resultado?
3&2
# Out:
# 2

# %%
10&9
# Out:
# 8

# %%
4&3
# Out:
# 0

# %%
2&2
# Out:
# 2

# %%
a = 1
b = 2
r1 = (a << b) 
print("a<<b =" , r1)
r2 = (a >> b) 
print("a>>b =" , r2)
r3 = ~r1
print("r3 = ~r1=" , r3)
r4 = (a ^ b)
print("a ^ b=", r4)
r5 = (a | b)
print("a | b=", r5)
r6 = (a & b)
print("a & b=", r6)

## ¿Porqué estos valores?.
# Out:
# a<<b = 4
# a>>b = 0
# r3 = ~r1= -5
# a ^ b= 3
# a | b= 3
# a & b= 0

# %% [markdown]
# - Operadores Boolenanos
#
# Operadores  | Descripcion | Ejemplo
# ----------- | ----------- | --------
# and | ¿Se cumple a y b?   | R = True and False # R = False
# or  | ¿Se cumple a o b?   | R = True and False # R = True
# not | No a                | R = Not  True      # R = False

# %%
a = True 
b = False
print(a and b)
print(a & b)
# Out:
# False
# False

# %% [markdown]
# - Valores booleanos
#
# Operadores  | Descripcion               | Ejemplo
# ----------- | -----------               | -------
# ==          | ¿a es igual a b?          | R = 7 == 3 , R = False
# !=          | ¿a es diferente de b?     | R = 5 != 3 , R = True
# <           | ¿a es menor que b?        | R = 3 < 2  , R = False
# >           | ¿a es mayor o igual que b? |  R = 3 > 2  , R = True
# <=          | ¿a es menor o igual que b ? | R = 3 <= 2  , R = False
# >=          | ¿a es mayor o igual que b ?| R = 3 >= 3  , R = True

# %%
a = True
b = False
print(a or b, a & b, not a)
# Out:
# True False False

# %% [markdown]
# #Escribir un codigo en el que entrados dos numeros, muestre cual es el mayo de los numeros.
# 1. Ingrese un numero
#
# 2. a <- Lea el numero
#
# 3. Ingreso el segundo
#
# 4. b<- Lea el numero
#
# 5. Si (a<b):
#     Muestre el numero mayor es b
#
#   Si no
#
#   Muestre el numero mayor es a

# %%
def mayor_de(l,o):
  l=1
  o=2
  l = float(input("primer número "))
  o = float(input("segundo número "))
  if l<o: print(o,"es mayor")
  elif l>o:
   print(l,"es mayor")
  else:
   print("los sumeros son iguales")
  return

# %%
mayor_de(0,0)
# Out:
# primer número 1965
# segundo número 45326
# 45326.0 es mayor

# %%
def numero_mayor(a, b):


  print("Ingrese el primer número:" )
  a=input()
  a=float(a)

  print("Ingreso el segundo número:" )
  b=input()
  b=float(b)


  if(a<b):
    
    print("El numero mayor es :",b )

  elif(a>b) :

    print("El numero mayor es :", a)
  else: 
    print("Los numeros son iguales")

  return

# %%
numero_mayor(3,5)
# Out:
# Ingrese el primer número:
# 7.6
# Ingreso el segundo número:
# 6.2
# El numero mayor es : 7.6

# %%
numero_mayor(a=3, b=3)
# Out:
# Ingrese el primer número:
# 2
# Ingreso el segundo número:
# 2
# Los numeros son iguales

# %%
numero_mayor(3, 5)
# Out:
# Ingrese el primer número:
# 2
# Ingreso el segundo número:
# 2
# Los numeros son iguales

# %%
a=True 
b=True
if( a and b ):
  print("operacion ", a, "and" ,b)
# Out:
# operacion  True and True

# %%
a&b
# Out:
# True

# %%
a=2
b=4

# %%
a and b
# Out:
# 4

# %%
a&b
# Out:
# 0

# %%
print("")
# Out:
# 4
# '4'

# %% [markdown]
# # Listas

# %%
#Definir una lista entre []
a = [3, 4, 4, 5, 6, 9, 10, "hello", "world", [2, 34, 5], 20 ]


print(type(a)) #Tipo de variable
n = len(a)  #Elementos de a
print(n)
#Crear una lista vacia 
b = []
# Out:
# <class 'list'>
# 11

# %%
a[0]="metodos computacionales"

# %%
print(a)
type (a[0])
# Out:
# ['metodos computacionales', 4, 4, 5, 6, 9, 10, 'hello', 'world', [2, 34, 5], 20]
# str

# %%
a[9][0]
# Out:
# 2

# %%
for i in range(0, len(a)):
    print("Indice: ", i,"---------> Elemento", a[i])
# Out:
# Indice:  0 ---------> Elemento 3
# Indice:  1 ---------> Elemento 4
# Indice:  2 ---------> Elemento 4
# Indice:  3 ---------> Elemento 5
# Indice:  4 ---------> Elemento 6
# Indice:  5 ---------> Elemento 9
# Indice:  6 ---------> Elemento 10
# Indice:  7 ---------> Elemento hello
# Indice:  8 ---------> Elemento world
# Indice:  9 ---------> Elemento [2, 34, 5]
# Indice:  10 ---------> Elemento 20

# %%
for i in a:
  print(i)
# Out:
# 3
# 4
# 4
# 5
# 6
# 9
# 10
# hello
# world
# [2, 34, 5]
# 20

# %%
[print(i) for i in a]
# Out:
# 3
# 4
# 4
# 5
# 6
# 9
# 10
# hello
# world
# [2, 34, 5]
# 20
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
elementos = ["prueba", "valor", "estudiante", "hello", "world", [2, 34, 5], 20 ]
q=print(i), for i in elementos

#j = 0
#for ele in elementos:
#  j=j+1perfecto
#  print(ele, j)
# Out:
#   File "<ipython-input-101-1b2bae64350e>", line 2
#     q=print(i). for i in elementos
#                   ^
# SyntaxError: invalid syntax

# %%
for j, ele in enumerate(elementos):
  print(j, ele)
# Out:
# 0 prueba
# 1 valor
# 2 estudiante
# 3 hello
# 4 world
# 5 [2, 34, 5]
# 6 20

# %% [markdown]
# ## Recorrido de listas

# %%
a
# Out:
# ['metodos computacionales',
#  4,
#  4,
#  5,
#  6,
#  9,
#  10,
#  'hello',
#  'world',
#  [2, 34, 5],
#  20]

# %%
print(a[0]) #Primer elementos de la lista
print(a[-1]) #ultimo elementos de la lista
print(a[-2]) #antepenultimo elemtnos de la lista
# Out:
# metodos computacionales
# 20
# [2, 34, 5]

# %%
a
# Out:
# ['metodos computacionales',
#  4,
#  4,
#  5,
#  6,
#  9,
#  10,
#  'hello',
#  'world',
#  [2, 34, 5],
#  20]

# %%
a[0:5] #Mostrar elementos del 0 en adelante
# Out:
# ['metodos computacionales', 4, 4, 5, 6]

# %%
a[2:5] #Mostrar los elementos en el intervalo de 2 al 4
# Out:
# [4, 5, 6]

# %%
a[7][2:]
# Out:
# 'llo'

# %% [markdown]
# ## Tuplas
# las tuplas son más “ligeras” que las listas, por lo que si el uso que le vamos a dar a una colección es muy básico, puedes utilizar tuplas en lugar de listas y ahorrar memoria

# %%
tupla = 1, 2, False, "hello"  
lista = [1, 2, False, "hello"]

# %%
print(tupla[2])
print(lista[2])
# Out:
# False
# False

# %%
lista[0] = True
print(lista)
# Out:
# [True, 2, False, 'hello']

# %% [markdown]
# ¿Qué sucede si se intenta lo mismo de la linea anterior,  pero con una  tupla?

# %%
lista = [3, 4,1, 45, 20, 50]

# %%
f

# %% [markdown]
# ## Operaciones hexagesimal

# %%
r = 0xB3AD  #Hexagesimal

# %%
print(r)
# Out:
# 45997

# %%
13*16**0 + 10*16**1 + 3*16**2 + 11*16**3
# Out:
# 45997

# %% [markdown]
# ## Diccionarios

# %%
d = { "Memento": "Cristopher Nolan", "0" : 2, 2:234, "Fight Club": "David Fincher"}

# %%
d.keys()
# Out:
# dict_keys(['Memento', '0', 2, 'Fight Club'])

# %%
d["Fight Club"]
# Out:
# 'David Fincher'

# %%
for i in d.keys():
    print("La clave ", i,"Tiene el valor de " , d[i])
# Out:
# La clave  Memento Tiene el valor de  Cristopher Nolan
# La clave  0 Tiene el valor de  2
# La clave  2 Tiene el valor de  234
# La clave  Fight Club Tiene el valor de  David Fincher

# %% [markdown]
# ## Expresiones compactas

# %%
a = 15
s = ("mayor que 10 ") if a > 10 else "menor que 10"

# %%
print(s)
# Out:
# mayor que 10

# %%
s = 1 if a > 10 else 20  
print(s)
# Out:
# 1

# %% [markdown]
# ### La anterior expresión, de la forma larga es:

# %%
a = 2
if (a > 10):
    s = "mayor que 10"
else: 
    s = "menor que 10"
print (s)
# Out:
# menor que 10

# %% [markdown]
# # Librerias
# import numpy as np
#
# import scipy as sc
#
# import matplotlib.pylab as plt

# %%
#Ejercicio 1:
#Construrir un algoritmo en el que dado un numero natural lo pase a binario: 

def dec2bin(num):
 
  
  return b

# %% [markdown]
# ## REFERENCIAS.
# [1] Scripts de un curso de python. [Raul Pollan](https://github.com/rramosp/20182.pcomp)
#
# [2] [Fundamenteos de programación](https://sites.google.com/site/funpropoli/ejercicios-practicos)
#
# [3] Scripts de un curso de python. [Fernando Perez](https://github.com/fperez)
