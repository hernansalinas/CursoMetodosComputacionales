# %%
n = 2
i=1
lista = []
while i <= n:
  lista.append(i)
  if i == n:
    break

factorial = 1
for i in lista:
  factorial = factorial * i 
print(factorial)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e6f9e5876bda> in <module>()
#       3 lista = []
#       4 while i <= n:
# ----> 5   lista.append(i)
#       6   if i == n:
#       7     break
#
# KeyboardInterrupt:

# %%
5<=3
# Out:
# False

# %%
n = 3
i=1
lista = []
Fact=1
while i <= n+1:
  lista.append(i)
  i==n+1
  break
for i in lista:
  Fact = Fact *i 
print(lista)
# Out:
# range(0, 3)
# [1]

# %%
# Out:
# []
# 1
# 1
# [1]

# %%
# Out:
# 2
