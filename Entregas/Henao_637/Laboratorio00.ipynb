# %%
import numpy as np
import math as mt
import matplotlib.pyplot as plt

# %% [markdown]
# ##1.Factorial

# %%
def factorial(H):
  """
  Cálulo de factorial de un entero x
    Input:
      p : entero a calcular
    Returns:
      f : factorial de p 
  """
  p = H
  j=p
  fact=1

  for i in range(1,p):
    fact=fact*(j)
    j=j-1
  print(f"{p}! = {fact:.2f}")

# %%
factorial(5)
# Out:
# 5! = 120.00
