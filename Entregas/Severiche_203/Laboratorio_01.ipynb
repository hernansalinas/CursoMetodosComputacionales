# %% [markdown]
# # Laboratorio 01 del taller de MC

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def Mapalogistico(ini,r,canti):
    """
    Calcula los valores de la funcion X(n+1) = rXn(1-Xn)
        Input: valor inicial y r flotantes, canti = cantidad de veces que se repite valor entero 
        Output: lista con canti valores de la funcion
    """
    resultado = np.zeros(canti)
    resultado[0] = ini
    for i in range(1,canti):
        resultado[i] = r*resultado[i-1]*(1-resultado[i-1])
    return resultado

# %% [markdown]
# ## 1) Mapa logistico y grafica de $X_n$ en función de n

# %%
p1_xini = 0.8
p1_valr = 3.3
p1_itera = 100
p1_valx = np.linspace(0,p1_itera,p1_itera)
p1_valy = Mapalogistico(p1_xini,p1_valr,p1_itera)

# %%
plt.figure(figsize=(14,8))
plt.title("Mapa logistico con Xn=0.8 y r=3.3")
plt.ylabel("Mapa logistico")
plt.xlabel("Valores de n")
plt.plot(p1_valx,Mapalogistico(p1_xini,p1_valr,p1_itera))
plt.show()

# %% [markdown]
# # 2) Pruebas para $X_n = 0.5$ y distintos valores de r

# %%
def graficadorEjes(r):
    titulo = "Mapa logistico con Xn=0.5 y r=" + str(r)
    plt.title(titulo)
    plt.ylabel("Mapa logistico")
    plt.xlabel("Valores de n")

# %%
p2_xini = 0.5
p2_valr =  np.array([1.9, 2.9, 3.1, 3.5, 3.9,4.0])
p2_itera = 100
p2_valx = np.linspace(0,p2_itera,p2_itera)
p2_valy_r0 = Mapalogistico(p2_xini,p2_valr[0],p2_itera)
p2_valy_r1 = Mapalogistico(p2_xini,p2_valr[1],p2_itera)
p2_valy_r2 = Mapalogistico(p2_xini,p2_valr[2],p2_itera)
p2_valy_r3 = Mapalogistico(p2_xini,p2_valr[3],p2_itera)
p2_valy_r4 = Mapalogistico(p2_xini,p2_valr[4],p2_itera)
p2_valy_r5 = Mapalogistico(p2_xini,p2_valr[5],p2_itera)

# %%
plt.figure(figsize=(20,12))
plt.subplot(231)
graficadorEjes(p2_valr[0])
plt.plot(p2_valx,p2_valy_r0)

plt.subplot(232)
graficadorEjes(p2_valr[1])
plt.plot(p2_valx,p2_valy_r1)

plt.subplot(233)
graficadorEjes(p2_valr[2])
plt.plot(p2_valx,p2_valy_r2)

plt.subplot(234)
graficadorEjes(p2_valr[3])
plt.plot(p2_valx,p2_valy_r3)

plt.subplot(235)
graficadorEjes(p2_valr[4])
plt.plot(p2_valx,p2_valy_r4)

plt.subplot(236)
graficadorEjes(p2_valr[5])
plt.plot(p2_valx,p2_valy_r5)

plt.show()

# %% [markdown]
# ## 3) Construye una rutina llamada logist_map y probar el codigo:
# Np = 1000
#
# xf = np.zeros(Np)
#
# r  = np.linspace(2.5, 4, Np)
#
# for i in range(0, Np):
#
# xini = np.random.random()
#
# x_i = logist_map(r = r[i], xi = xini, N = 1000)
#
# xf[i] = x_i

# %%
def logist_map():
    pass

# %%
Np = 1000
xf = np.zeros(Np)
r  = np.linspace(2.5, 4, Np)
for i in range(0, Np):
    xini = np.random.random()
    x_i = logist_map(r = r[i], xi = xini, N = 1000)
    xf[i] = x_i

# %% [markdown]
# ## 4) Realiza un gráfico de: plt.plot((r-1/r), xf,  ".", markersize = 0.5)

# %%
plt.figure(figsize=(14,8))
plt.plot((r-1/r), xf,  ".", markersize = 0.5)
plt.show()

# %% [markdown]
# ## 5) Encuentra 2 formas más de expresar $f(x)$
# En este caso se espera que los resultados varien. ¿A que se debe esto?

# %% [markdown]
# ### Caso 1)

# %% [markdown]
# ### Caso 2)
