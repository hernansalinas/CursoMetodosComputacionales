# %% [markdown]
# <a href="https://colab.research.google.com/github/Elizajr/CursoMetodosComputacionales/blob/main/Students/Jim%C3%A9nez_814/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para los siguientes datos de temperatura media como función del tiempo de los últimos años de Bogotá y Barcelona ( [Temperature_Bogota_Barcelona](https://raw.githubusercontent.com/hernansalinas/autogradesMetodosComputacionales/main/Dataset/Temperature_Bogota_Barcelona.csv)) realice lo siguiente:
#
# 1. Leer el dataset desde la url, con el comando pd.read_csv.
# 2. Adicionar una nueva columna AvgTempCelcius con la temperatura en grados celcius. $ C=(F-32)/1.8$
# 3. Realizar un gráfico de AvgTempCelcius como función del año para la ciudad de Bogotá.
# 4. Realizar un gráfico de AvgTempCelcius como función del año para la ciudad de Barcelona.
# 5. Determine la mayor temperatura para Bogotá y Barcelona.

# %%
import pandas as pd
import pylab as plt

# %%
url = "https://raw.githubusercontent.com/hernansalinas/autogradesMetodosComputacionales/main/Dataset/Temperature_Bogota_Barcelona.csv"
df = pd.read_csv(url)

# %%
df = df.drop("Unnamed: 0",axis = 1)
df.head()
# Out:
#    Year       City     Month        Day  AvgTemperature
# 0  1995  Barcelona  6.526027  15.720548       62.019178
# 1  1995     Bogota  6.526027  15.720548       54.963014
# 2  1996  Barcelona  6.513661  15.756831       61.125956
# 3  1996     Bogota  6.513661  15.756831       55.083333
# 4  1997  Barcelona  6.526027  15.720548       62.612329

# %%
df["AvgTempCelcius"] = (df["AvgTemperature"]-32)/1.8
df.head()
# Out:
#    Year       City     Month        Day  AvgTemperature  AvgTempCelcius
# 0  1995  Barcelona  6.526027  15.720548       62.019178       16.677321
# 1  1995     Bogota  6.526027  15.720548       54.963014       12.757230
# 2  1996  Barcelona  6.513661  15.756831       61.125956       16.181087
# 3  1996     Bogota  6.513661  15.756831       55.083333       12.824074
# 4  1997  Barcelona  6.526027  15.720548       62.612329       17.006849

# %%
maxbog = bog['AvgTempCelcius'].max()
maxbar = bar['AvgTempCelcius'].max()
max = df['AvgTempCelcius'].max()
print(f"La máxima temperatura en Bogotá fue de {maxbog:.4}°C")
print(f"La máxima temperatura en Barcelona fue de {maxbar:.4}°C")
print(f"La máxima temperatura general fue de {max:.4}°C")
# Out:
# La máxima temperatura en Bogotá fue de 14.48°C
# La máxima temperatura en Barcelona fue de 17.3°C
# La máxima temperatura general fue de 17.3°C

# %%
bog = df[df["City"]=="Bogota"]
bog.head()
# Out:
#    Year    City     Month        Day  AvgTemperature  AvgTempCelcius
# 1  1995  Bogota  6.526027  15.720548       54.963014       12.757230
# 3  1996  Bogota  6.513661  15.756831       55.083333       12.824074
# 5  1997  Bogota  6.526027  15.720548       56.231507       13.461948
# 7  1998  Bogota  6.526027  15.720548       49.642466        9.801370
# 9  1999  Bogota  6.526027  15.720548       52.231781       11.239878

# %%
plt.figure()
plt.plot(bog["Year"],bog['AvgTempCelcius'], c = "coral",label = "Temperatura")
plt.hlines(maxbog,df["Year"].min(),df["Year"].max(), linestyles= ":", color ="aquamarine", label = "Temperatura máxima")
plt.xlabel("Año")
plt.ylabel("Promedio de temperatura (C°)")
plt.title("Temperatura en el tiempo-Bogotá")
plt.legend()
plt.grid()
plt.show()

# %%
bar = df[df["City"]=="Barcelona"]
bar.head()
# Out:
#    Year       City     Month        Day  AvgTemperature  AvgTempCelcius
# 0  1995  Barcelona  6.526027  15.720548       62.019178       16.677321
# 2  1996  Barcelona  6.513661  15.756831       61.125956       16.181087
# 4  1997  Barcelona  6.526027  15.720548       62.612329       17.006849
# 6  1998  Barcelona  6.526027  15.720548       60.273973       15.707763
# 8  1999  Barcelona  6.526027  15.720548       61.204658       16.224810

# %%
plt.figure()
plt.plot(bar["Year"],bar['AvgTempCelcius'], c = "turquoise",label = "Temperatura")
plt.hlines(maxbar,df["Year"].min(),df["Year"].max(), linestyles= ":", color ="salmon", label = "Temperatura máxima")
plt.xlabel("Año")
plt.ylabel("Promedio de temperatura (C°)")
plt.title("Temperatura en el tiempo - Barcelona")
plt.legend()
plt.grid()
plt.show()
