# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab06_ceros_funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Codigo Markdown:
# Los numeras a, b, c y d tiene que ver con escritura en código Markdown y comandos de latex:
#
# a. Escriba en pseudocódigo los pasos para aplicar el método de la bisección.
#
# b. Realice la deducción del metodo de Newton-Rapshon, se recomienda escribir las ecuaciones en formato latex, para ello puede emplear las siguientes expresiones:
#
# c. ¿Cuál es la diferencia del metodo de Newton-Rapson con respecto al de la secante?
#
#
# d. Escriba en pseudocódigo los pasos para aplicar el método Punto Fijo.
#
#
#
# Comentarios para escribir en latex
#
# *   Entre simbolos \$ \$, puedes porner expresiones  puede poner expresiones, ejemplo:  $y = a_0 x^2 + b_1$
#
# *  Las funciones pueden ser definidas entre \\$,  poniendo un \\, antes de la funcion ejemplo: \\$ \\sinx \\$,   asi las funciones quedarian de esta manera :
#
# > $\sin x$, $\tan x$, $\sec x$, $\sqrt{a} $, $\frac{a}{b}, \frac{df}{dt}$
#
# * Puedes generar tambien escribir ecuaciones con la instrucción:
#
#   \\begin{equation}
#
#     \\sin x
#
#   \\end{equation}
#
# Ejemplo:
#
#   \begin{equation}
#     \frac{df}{dx} = \sin x
#   \end{equation}

# %% [markdown]
# Solución
#
# **a)Método de la bisección**
#
# A continuación, se muestra un ejemplo de pseudocódigo para el método de la bisección, que se utiliza para encontrar una raíz de una función:
# 1. Inicio del programa
# 2. Se define la función $f(x)$ para la que se quiere encontrar la raíz
# 3. Definición de los valores de a y b, que indican el intervalo en el que se buscará la raíz, y la tolerancia T, que indica la  precisión deseada.
# 4. Definición del número máximo de iteraciones N para evitar que el programa se ejecute infinitamente.
# 5. Se abre un ciclo que se ejecutará mientras el contador de iteraciones (definido anteriormente)  sea menor o igual al número máximo de iteraciones N.
# Se calcula el punto medio c del intervalo (a, b) a través de la siguiente fórmula:
# $$c=\frac{a+b}{2}$$
#
# 6. Si la función $f(c)=0$, entonces se ha encontrado una raíz exacta, por lo que el programa sale del bucle. De lo contrario, si la distancia entre a y b es menor que la tolerancia T, entonces se considera que se ha encontrado una buena aproximación de la raíz, y el programa también sale del bucle.
# 7. Si el signo de $f(c)$ es igual al signo de $f(a)$, entonces la raíz se encuentra en el intervalo $(a, c)$, por lo que se redefine $a=c$. De lo contrario, la raíz se encuentra en el intervalo $(c, b)$, por lo que se redefine $b=c$.
# Se incrementa el contador de iteraciones en 1.
#
# 8. Fin del bucle de iteración.
# 9. Se imprime el valor de c, que es la aproximación de la raíz de la función $f(x)$.
# 10. Fin del programa.

# %% [markdown]
# **b)Deducción del método de Newton-Rapshon**
#
# Primero es importante recalcar que el método d**e Newton-Raphson** converge rápidamente a la raiz de la función si se cumplen ciertas condiciones ,como que la función sea **continuamente diferenciable** y que la derivada no se anule en la vecindad de la raiz.
#
# El método de Newton-Raphson es un algoritmo **iterativo** utilizado para encontrar  las raíces de una función con errores relativamente pequeños .
# Supongamos que tenemos una función  $f(x)$  que es diferenciable en un intervalo  [𝑎,𝑏] . Queremos encontrar una aproximación de la raíz de la función en este intervalo, es decir, un valor  $x_0$  tal que  $f(x_0)=0$ .
#
# Empezamos con una aproximación inicial  $𝑥_1$  y trazamos la tangente a la curva de la función  $f(x)$  en el punto  $(𝑥_1,𝑓(𝑥_1))$ . La ecuación de esta tangente es:
#
# **$$𝑦−𝑓(𝑥1)=𝑓′(𝑥1)(𝑥−𝑥1)$$**
#
# Donde  $f′(x_1)$  es la derivada de la función  $f(x)$  evaluada en  $x_1$ .
#
# Ahora, se debe encontrar el punto en el eje  $x$  donde esta tangente cruza el eje  x . Es decir, buscamos el valor de  x_2  tal que  y=0  en la ecuación anterior:
#
# $$0−f(x_1)=f′(x_1)(x_2−x_1)$$
#
# Despejando  x_2 , obtenemos:
#
# $$x_2=x_1−f(x_1)f′(x_1)$$
#
# Este es el paso iterativo del método de Newton-Raphson. A partir de la aproximación inicial  x_1 , podemos obtener la siguiente aproximación  x_2 mediante la fórmula anterior. Repitiendo este proceso con  x_2  , podemos obtener una mejor aproximación  x_3 , y así sucesivamente.
# En general, la fórmula de iteración del método de Newton-Raphson es:
# $$x_{n+1}=x_n−f(x_n)f′(x_n)$$
# Donde  x_n es la aproximación  n-ésima de la raíz de la función.

# %% [markdown]
# **c)¿Cuál es la diferencia del metodo de Newton-Rapson con respecto al de la secante?**
#
# De manera general la principal diferencia entre estos dos métodos es que el primero utiliza la información de la derivada de la funcion para llegar a la raiz y el segundo utiliza sólo la información de dos aproximaciones dadas.
#
# por tanto el método de Newton-Raphson es más preciso que el método de la secante, ya que utiliza una mejor aproximación de la raíz en cada iteración. Sin embargo, la precisión del método de la secante puede mejorarse aumentando el número de iteraciones.

# %% [markdown]
# **d. Escriba en pseudocódigo los pasos para aplicar el método Punto Fijo.**
#
# Dado una función $f(x)$ y una aproximación inicial $x_0$:
# 1. Establecer una tolerancia $e$ y un máximo número de iteraciones $N$.
#
# 2. Establecer $i=0$
# 3. Mientras $i<N$ entonces :
# 4. Calcular la aproximación $$x_{i+1} = g(x_i)$$
#
# donde $g(x)$ es la función de punto fijo
# $$g(x) = x - f(x)$$
#
# 5. Si $|x_{i+1} - x_i| < e$, detener el proceso y retornar $x_{i+1}$ como la solución.
#
# 6. si no establecer $$i = i + 1$$
#
# 7. Si el número máximo de iteraciones se alcanza sin converger, mostrar un mensaje de error y retornar el valor más reciente de $x_i$ como la solución aproximada.

# %% [markdown]
# # 2. Ceros de funciones
# *Encontrar* los ceros de $e^{x}-2= \cos(e^x-2)$ por diferentes metodos, bisection, newton-rapshon, punto fijo.

# %%
import numpy as np 
import scipy.optimize as opt
import scipy as sc
import matplotlib.pylab as plt 
opt.bisect
# Out:
# <function scipy.optimize._zeros_py.bisect(f, a, b, args=(), xtol=2e-12, rtol=8.881784197001252e-16, maxiter=100, full_output=False, disp=True)>

# %%
def func(x):
  return  np.exp(x)-2-np.cos(np.exp(x)-2)

# %%
#Hallando el cero por medio del método de Bisección
root=sc.optimize.bisect(func,-1,2)

# %%
#Hallando el cero por medio del método Newthon-Rapshon
import sympy as sp
x=sp.symbols("x")
def f1(x):
   return  sp.exp(x)-2-sp.cos(sp.exp(x)-2)

# %%
#calculando la derivada con sympy
d=sp.diff(f1(x),x)
funcion1 =sp.lambdify([x],f1(x),"numpy")
fderivate=sp.lambdify([x],d,"numpy")
#finalmente ya se puede aplicar el opt.newton
root1= opt.newton(funcion1,1.5, fderivate)

# %%
#Punto fijo
def g(x):
  g=x-funcion1(x)
  return(g)

# %%
sol = opt.fixed_point(g, 0.5);sol
# Out:
# array(1.00762397)

# %%
#Gráfica de la función con su raíz
x=np.linspace(-1,4,100000)
plt.figure(figsize=(10,10))
plt.plot(x,func(x),color='r')
plt.plot(root,func(root),marker="o",color='blue',label="Raíz")
plt.xlabel("$x$",size=14)
plt.ylabel("$f(x)$",size=14)
plt.legend(loc=2) 
plt.title("Gráfica de $e^x - \cos(e^x - 2)-2 $",size=15)
plt.grid(True)

# %%
print(f'Las raices encontradas por los diferentes métodos fueron {root},{root1},{sol }')
# Out:
# Las raices encontradas por los diferentes métodos fueron 1.0076239716586315,1.0076239716581368,1.0076239716581368

# %% [markdown]
# #3. Partícula en reposo
# Una particula parte del reposo sobre un plano inclinado uniforme, cuyo ángulo
# $\theta$ cambia con una rapidez constante de :
#
# \begin{equation}
# \frac{\mathrm{d}\theta}{\mathrm{d} t} = \omega < 0
# \end{equation}
#
# Al final de t segundos, la posición del objeto esta dada por:
#
#
# \begin{equation}
# x(t) = -\frac{g}{2\omega^2} \left( \frac{e^{\omega t}-e^{-\omega t}}{2}-\sin\omega t\right)
# \end{equation}
#
#
# Suponga que la particula se desplazo 0.51m en 1s. Encuentre, con exactitud de  10−5  la rapidez  𝜔  con que cambia  𝜃 . Supoga  𝑔=9.76 m/s

# %%
#Datos 
g=9.76
x=0.51 #m
t=1  # s
exac=10e-05 #rapidez con que cambia 𝜃
def funcion(w):
  a=(g/(2*w**2))
  b=(np.exp(w)-np.exp(-w))/2
  c=np.sin(w)
  return 0.51+a*(b-c)

# %%
def funci(w):
  a=(g/(2*w**2))
  b=(np.exp(w)-np.exp(-w))/2
  c=np.sin(w)
  return -a*(b-c)

# %%
#El problema se trata de encontrar la raiz de la funcion definida anteriormente
#primero usaré una variante del método de Newton -Raphson teniendo en cuenta el valor de precision 
r1=opt.newton(funcion,1,tol=exac)
#Comprobando la respuesta en la función original 
def x(w):
  a=(g/(2*w**2))
  b=(np.exp(w)-np.exp(-w))/2
  c=np.sin(w)
  return -a*(b-c)

#
print('El valor de w es',r1 )
# Out:
# El valor de w es -0.3135209839399444

# %%
#Se puede ver que x corresponde al dado 0.51 m 
x(r1)
# Out:
# 0.5100000000217875

# %% [markdown]
# La rapidez 𝜔 con que cambia 𝜃 con exactitud de 10−5 es de aproximadamente
# $$w=-0.314 \,rad/s $$
#
# \begin{equation}
# \frac{\mathrm{d}\theta}{\mathrm{d} t} = \omega < 0
# \end{equation}

# %% [markdown]
# #3.  Area
# Hallar el área de un segmento circular cuya area sea igual a una cuarta parte del área del circulo. Para la solución se sugiere lo siguiente:
#
# a) Encontrar la ecuacion trascendental.
#
# b) Con la ecuación anterior, definir una funcion $f(\theta)=0$. Emplee la funcion labmda de python.
#
# c) Construir una data frame de pandas con la columna "theta" con 1000 registros(filas) entre $[-2\pi, 2\pi]$. Sugerencia, para construir el data frame emplee la función linspace como sigue : np.linspace(-2*np.pi, 2*np.pi, 1000 )
#
# d) Construir una segunda columna titulada "F_theta" con los registros f(theta)
#
# f) Realice un gráfico de  "F_theta" vs "theta". Identifique el intervalo de la raiz.
#
# Estime el valor del ángulo empleando los siguientes metodos(Emplee  la documentacion):
#
# g) [Bisección](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.bisect.html)
#
# h) [Newton-Rapshon](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.newton.html)
#
# i) [Secante](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.newton.html)
#
# j) [Punto Fijo](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.fixed_point.html)

# %%
# Función Lambda para calcular el Área de un segmento circular 
circle_segment= lambda 𝜃: 𝜃-np.sin(𝜃)-np.pi/2

# %%
import pandas as pd 
thetaa=np.linspace(-2*np.pi, 2*np.pi, 1000 )
ftheta=np.array([circle_segment(i) for i in thetaa])
df=pd.DataFrame({'Theta':thetaa,'F_theta':ftheta})
df
# Out:
#         Theta   F_theta
# 0   -6.283185 -7.853982
# 1   -6.270606 -7.853981
# 2   -6.258027 -7.853979
# 3   -6.245448 -7.853973
# 4   -6.232870 -7.853960
# ..        ...       ...
# 995  6.232870  4.712368
# 996  6.245448  4.712380
# 997  6.258027  4.712386
# 998  6.270606  4.712389
# 999  6.283185  4.712389
#
# [1000 rows x 2 columns]

# %%
#El intervalo de la raiz se puede definir entre [1.5,3]
#por el método de la bisección 
opt.bisect
sol=opt.bisect(circle_segment,1.5,3)
print("La raíz encontrada con el método de bisección fue ", sol)
# Out:
# La raíz encontrada con el método de bisección fue  2.3098814600093647

# %%
#Newton-Raphson
theta=sp.symbols("theta")
circl_segment= theta-sp.sin(theta)-sp.pi/2
d=sp.diff(circl_segment,theta)
funcion1 =sp.lambdify([theta],circl_segment,"numpy")
fderivate=sp.lambdify([theta],d,"numpy")
#finalmente ya se puede aplicar el opt.newton
root= opt.newton(funcion1,1.5, fderivate)
print("La raíz encontrada con el método de Newton-Raphson fue ", root)
# Out:
# La raíz encontrada con el método de Newton-Raphson fue  2.309881460010057

# %%
#Método de la Secante
root1= opt.newton(funcion1,x0=1.5,x1=2)
print("La raíz encontrada con el método de la secante fue ", root1)
# Out:
# La raíz encontrada con el método de la secante fue  2.309881460010057

# %%
#Método del punto fijo 
def g(theta):
  return theta-funcion1(theta)

# %%
sol1= opt.fixed_point(g, 2)
print("La raíz encontrada con el método del punto fijo  fue ", sol1)
# Out:
# La raíz encontrada con el método del punto fijo  fue  2.3098814600100575

# %%
#primera intuicion
plt.figure(figsize=(10,8))
plt.plot(thetaa,ftheta,color="b")
plt.title("Gráfico de $𝜃-\sin(𝜃)-\frac{\pi}{2}$",size=15)
plt.plot(sol,circle_segment(sol),marker='o',color='red',label="Cero de la función")
plt.xlabel("$𝜃$",size=14)
plt.ylabel("$f(𝜃)$",size=14)
plt.legend()
plt.grid(True)

# %% [markdown]
# # 3. Movimiento de proyectiles en presencia de viento.
#
# Supongamos que un proyectil es lanzado desde el origen con una rapidez $v=vo( \cos \theta , \sin \theta $. Supongamos además que el efecto del viento sobre el proyectil es el de una fuerza proporcional a la velocidad relativa entre el viento y el proyectil. Teniendo presente que si u es la velocidad del viento y $\alpha$ el ángulo que hace dirección de esta velocidad con el eje x, se puede entrontrar las siguientes ecuaciones diferenciales, asociada al estado de movimiento del [proyectil](https://iopscience.iop.org/article/10.1088/0143-0807/36/2/025016/meta):
#
#
# \begin{equation}
# m\frac{dv_x}{dt} = -mb(v_x-u\cos \alpha )
# \end{equation}
#
# \begin{equation}
# m\frac{dv_y}{dt} = -mg-mb(v_x-u\sin \alpha ),
# \end{equation}
#
# donde b es el párametro de rozamiento. La soluciones a las ecuaciones anteriores vienen dadas por:
#
# Posición en x
# \begin{equation}
# x=(u\cos \alpha) t + \frac{1}{b} (v_0\cos \theta_0 -u \cos\alpha)(1-\mathrm{exp}(-bt))
# \end{equation}
#
# Posicion en y
# \begin{equation}
# y= \frac{1}{b}\left(\frac{g}{b}+v_0 \sin \theta_0 -u\sin\alpha \right)(1-\mathrm{exp}(-bt))-\left( \frac{g}{b}-u\sin\alpha\right)t
# \end{equation}
#
# Ver imagen:  http://www.sc.ehu.es/sbweb/fisica3/fluidos/viento/parabolico.html
#
#
# 0. Establezca las siguietnes condiciones inciales.
#
# ```
# #Parametros iniciales
#
# v0 = 60 #Velocidad en m/s
# alpha = np.pi #Angulo del viento
# theta = np.deg2rad(45) #Angulo de lanzamiento
# u = v0/2             #rapidez del viento
# b = 0.05             #Parametro de friccion
# g = 9.8                #Aceleracion de la gravedad m/s2
#
# Params = (alpha, v0, b, u,g)  #Parametros en tupla.
#
# ```
#
#
#
# 1. Defina dos funciones, una para x y otra para y.
#
# ```
#
# #Posicion en x
# def pos_x(t, theta, alpha, v0, b, u,g):
#   x = #escriba aca la expresión
#   return x
#
# #Posicion en y
# def pos_y(t, theta, alpha, v0, b, u,g):
#
#
#   y = #escriba aca la expresión
#   return y
#
# ```
#
# 2. Construya un diccionario con las claves "X", "Y", "Tiempo"
#
# 3. Con el diccionario construya un data frame de pandas llamado df con los nombres de columnas "X", "Y", "Tiempo"  https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.from_dict.html. Defina 1000 regitros para el intervalo de tiempo elegido.
#
#
# 4. Realice un gráfico de x como función del tiempo, de y como función del tiempo y la trayectoria de la partícula (df["X"], df["tiempo"], df["Y"]).
#
#
# 5. Determine el alcance máximo de la partícula, para ello tome  la solucion teórica con $y=0$, solucione numéricamente la ecuación para t y remplace este valor en la ecuación para x. Resuelvalo para $\theta=45^{o}$.
#
# 6. Construya una  grafica del alcance máximo R como función de $\theta$, varie $\theta$  entre 10 y 80 grados cada 5 grados.

# %%
# Parametros iniciales
import math 
import scipy.optimize as opt
v0 = 60 #Velocidad en m/s
alpha = np.pi #Angulo del viento
theta = np.deg2rad(45) #Angulo de lanzamiento en radianes
u = v0/2             #rapidez del viento
b = 0.05             #Parametro de friccion 
g = 9.8              #Aceleracion de la gravedad m/s2

params = (alpha, v0, b, u,g)  #Parametros en tupla.

# %%
#Se define dos funciones, una para x y otra para y.
# Posicion en x
def pos_x(t, theta, alpha, v0, b, u,g):
  
  t1=u*np.cos(alpha)*t
  t2=(1/b)*(v0*np.cos(theta)-u*np.cos(alpha))*(1-np.exp(-b*t))
  x = t1+t2
  return x

# Posicion en y
def pos_y(t, theta, alpha, v0, b, u,g):
  
  t1=(1/b)*(g/b+v0*np.sin(theta)-u*np.sin(alpha))*(1-np.exp(-b*t))
  t2=-(g/b-u*np.sin(alpha))*t
  y = t1+t2
  return y

# %%
def time(t, theta, alpha, v0, b, u, g=9.8):
    h = t - pos_y(t, theta, alpha, v0, b, u, g)
    return h

# %%
#se usa métoodo del punto fijo para encontrar el tiempo cuando y=0
t_vuelo = opt.fixed_point(time, x0=9.0, args=(theta, alpha, v0, b, u))
t = np.linspace(0, t_vuelo, 1000)
x = pos_x(t,theta, alpha, v0, b, u, g=9.8)
y = pos_y(t,theta, alpha, v0, b, u, g=9.8)

# %%
#Construya un diccionario con las claves "X", "Y", "Tiempo"
dic={'X':x,'Y':y,'Tiempo':t}
#Con el diccionario construya un data frame de pandas llamado df con los nombres de columnas "X", "Y", "Tiempo" 
import pandas as pd 
pd=pd.DataFrame.from_dict(dic)

# %%
#Realice un gráfico de x como función del tiempo, de y como función del tiempo y
plt.figure(figsize=(15,18))
plt.subplots(2,1, figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(t, pd['X'], label='Posición en x',color='b')
plt.xlabel('Tiempo (s)')
plt.ylabel('Posición (m)')
plt.legend()
plt.grid(True )
plt.subplot(2,1,2)
plt.plot(t, pd['Y'], label='Posición en y',color='green')
plt.plot(t_vuelo,pos_y(t_vuelo,theta, alpha, v0, b, u,g),marker='o',color='r')
plt.xlabel('Tiempo (s)')
plt.ylabel('Posición (m)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# la trayectoria de la partícula (df["X"], df["tiempo"], df["Y"])
plt.figure(figsize=(10,10))
plt.plot(pd['X'],pd['Y'], label='Trayectoria',color='b')
plt.xlabel('posición en x (m)',size=12)
plt.ylabel('Posición en y (m)',size=12)
plt.legend()
plt.title('Trayectoria de una particula en Movimiento Parabólico en presencia de viento ',size = 14)
plt.grid(True )

# %%
#Determine el alcance máximo de la partícula, para ello tome la solucion teórica con  𝑦=0 , 
#solucione numéricamente la ecuación para t y remplace este valor en la ecuación para x. Resuelvalo para  𝜃=45𝑜 

#Anteriormente se obtuvo t_vuelo cuando y=0 ahora se busca el alcance con pos_x
AlcanceM=pos_x(t_vuelo, theta, alpha, v0, b, u,g)

# %%
def time(t, theta, alpha, v0, b, u, g=9.8):
    h = t - pos_y(t, theta, alpha, v0, b, u, g)
    return h

# %%
#Construya una grafica del alcance máximo R como función de  𝜃 , varie  𝜃  entre 10 y 80 grados cada 5 grados.
plt.figure(figsize=(8,8))
for theta in range(10, 80, 5):

    theta = theta*np.pi/180 #A radianes
    # encuentra tiempo de vuelo
    t_v = opt.fixed_point(time, x0=9.0, args=(theta, alpha, v0, b, u,g),maxiter=100000)
    Time=np.linspace(0,t_v,1000)
    y=pos_y(Time,theta, alpha, v0, b, u,g)
    x=pos_x(Time,theta, alpha, v0, b, u,g)
    plt.plot(x,y)

plt.grid(True)
plt.title('Trayectoria de una partícula con  $𝜃$  entre 10 y 80 grados')
plt.xlabel('Alcance Horizontal (m)',size=12)
plt.ylabel('Altura (m)',size=12)
# Out:
# Text(0, 0.5, 'Altura (m)')

# %% [markdown]
# # 4. Construir un fractal empleando el metodo de Newton-Raphson,
# (Reproducir código y entender)
# \begin{equation}
# z_{n+1} = z_n -a \frac{f(z)}{f'(z)}
# \end{equation}
#
#
#
# \begin{equation}
# f'(z) = \frac{ f(z+h)+f(z) }{h}
# \end{equation}

# %% [markdown]
# ```
# import numpy as np
# import matplotlib.pylab as plt
# from PIL import Image
#
# Npx_X = 80 #Numero de pixeles en x
# Npx_Y = 80 #Numero de pixeles en y
#
# image = Image.new("RGB", (Npx_X, Npx_Y)) #Creacion de la imagen inicial
#
# npx = np.arange(0, Npx_X)
# npy = np.arange(0, Npx_Y)
#
# xmin = -1
# xmax = 1
# ymin = -1
# ymax = 1
# #Transformación al plano complejo en un rectangulo (xmin, xmax), (ymin, ymax)
# zx = npx * (xmax - xmin) / (Npx_X - 1)   + xmin
# zy = npy * (ymax-ymin) / (Npx_Y - 1) + ymin
#
# #Definicion  la funcion y las derivada
# def f(z):
#   return z**3 - 1
#
# def fp(z):
#   return 3*z**2
#
# h = 1E-4
# def fpn(z, h):
#   return (f(z+h)-f(z))/h
#
#
# a = 0.2
# Niteraciones = 120
# eps = 1E-8
#
# x = - 1
# for zx_ in zx:
#   x = x + 1
#   y = -1
#   for zy_ in zy:
#       y = y + 1
#       Z_0 = complex(zx_, zy_)
#
#       for i in range(0, Niteraciones):
#         Z = Z_0 - a * f(Z_0)/fp(Z_0)
#         if( abs(Z-Z_0)<= eps):
#           break
#         Z_0 = Z
#       #print(i)
#       #print(i)
#       r, g, b = i % 4 *64 , i % 8 *16, i% 16* 16
#       image.putpixel((x,y), (r,g,b) )
#
# plt.imshow(image)
# #plt.xlim(400, 600)
# #plt.ylim(400, 523)
# ```

# %%
import numpy as np
import matplotlib.pylab as plt
from PIL import Image

Npx_X = 80 #Numero de pixeles en x
Npx_Y = 80 #Numero de pixeles en y

image = Image.new("RGB", (Npx_X, Npx_Y)) #Creacion de la imagen inicial
#Image.new crea una imagen con el modo y tamaño dados

npx = np.arange(0, Npx_X)
npy = np.arange(0, Npx_Y)

xmin = -1
xmax = 1
ymin = -1
ymax = 1
# Transformación al plano complejo en un rectangulo (xmin, xmax), (ymin, ymax)
zx = npx * (xmax - xmin) / (Npx_X - 1)   + xmin
zy = npy * (ymax-ymin) / (Npx_Y - 1) + ymin

# Definicion  la funcion y las derivada 
def f(z): 
  return z**3 - 1

def fp(z): 
  return 3*z**2

h = 1E-4
def fpn(z, h): 
  return (f(z+h)-f(z))/h


a = 0.2
Niteraciones = 120
eps = 1E-8

x = - 1
for zx_ in zx:
  x = x + 1 
  y = -1
  for zy_ in zy: 
      y = y + 1
      Z_0 = complex(zx_, zy_)

      for i in range(0, Niteraciones): 
        Z = Z_0 - a * f(Z_0)/fp(Z_0)
        if( abs(Z-Z_0)<= eps):
          break           
        Z_0 = Z
      #print(i)
      #print(i)
      r, g, b = i % 4 *64 , i % 8 *16, i% 16* 16      
      image.putpixel((x,y), (r,g,b) )

plt.imshow(image)
#plt.xlim(400, 600)
#plt.ylim(400, 523)
