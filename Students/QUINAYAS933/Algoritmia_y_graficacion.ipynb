# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab03_Algoritmia_y_graficacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.0 Caos numérico en un mapa logístico y errores de punto flotante (Errores de redondeo)
#
# > Un ejemplo clásico de caos,  es el comportamiento no lineal en las interaciones de un mapa logístico
#
# \begin{equation}
# x_{n+1}=f(x_n)=rx_n(1-x_n)
# \end{equation}
#
# > con $x\in (0,1)$ y $r\in(0,4)$ se pueden producir varios comportamientos sorprendentes.
#
# Para este problema, será extremadamente útil  ver sus resultados gráficamente; construya listas de números y llame la libreria matplotlib.
#
#
# #Problema:
# ## 1. Programar la ecuación para el mapa logístico, y  realizar una grafica del valor de xn como funcion de n.

# %%
import numpy as np
n=100
xn=0.6 #poblacion inicial
r=3.5 #tasa a la que crece la poblacion
Arr=np.zeros(n) #arrays de ceros donde cada elemento tiene informacion de cada n

# %%
def func(xn):
  x=r*xn*(1-xn)
  return x

# %%
for i in range(0,len(Arr)):
   x=func(xn)
   Arr[i]=x
   xn=x

# %%
#Graficando 
import matplotlib.pylab as plt
import numpy as np 
time=np.arange(1,len(Arr)+1)
plt.figure(figsize=(30,10))
plt.plot(time,Arr,color='purple')
plt.xlabel("Tiempo",fontsize=16)
plt.ylabel("Población ",fontsize=16) 
plt.tick_params(axis='both', which='major', labelsize=18)
plt.grid(True)
plt.title(label="Mapa logístico de $xn$ con respecto a $n$",fontsize=26)
# Out:
# Text(0.5, 1.0, 'Mapa logístico de $xn$ con respecto a $n$')

# %% [markdown]
# # 2. Realizar pruebas para un $x_0=0.5$, con valores de r
#
# ```
#   r = np.array([1.9, 2.9, 3.1, 3.5, 3.9,4.0])
#   numpoints = 100, # Numero sugerido de iteraciones
#   x0 = 0.5
# ```
#
# Organizar las gráficas [multiples plot](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html)

# %%
#De manera general 
def logist_map(r,x,N):
   Ar=np.zeros(N)
   for i in range(0,N):
     j=r*x*(1-x)
     Ar[i]=j
     x=j
   return Ar

# %%
array=np.arange(6)
lista=[]
time2=np.arange(100)
r1 = np.array([1.9, 2.9, 3.1, 3.5, 3.9,4.0])
for i in r1:
  a=logist_map(i,0.5,100)
  lista.append(a)

# %%
#Graficando 
#falta agregar labels y grid 
import matplotlib.pylab as plt
import numpy as np 
time=np.arange(1,len(Arr)+1)
plt.figure(figsize=(15,18))
plt.subplot(3,2,1)
plt.title('$r=1.9$')
plt.grid(True)
plt.xlabel("Tiempo",fontsize=12)
plt.ylabel("Población ",fontsize=12) 
plt.plot(time2,lista[0],color='r')
plt.subplot(3,2,2)
plt.title('$r=2.9$')
plt.grid(True)
plt.xlabel("Tiempo",fontsize=12)
plt.ylabel("Población ",fontsize=12) 
plt.plot(time2,lista[1],color='b')
plt.subplot(3,2,3)
plt.title('$r=3.1$')
plt.grid(True)
plt.xlabel("Tiempo",fontsize=12)
plt.ylabel("Población ",fontsize=12) 
plt.plot(time2,lista[2])
plt.subplot(3,2,4)
plt.title('$r=3.5$')
plt.grid(True)
plt.xlabel("Tiempo",fontsize=12)
plt.ylabel("Población ",fontsize=12) 
plt.plot(time2,lista[3],color='g')
plt.subplot(3,2,5)
plt.title('$r=3.9$')
plt.grid(True)
plt.xlabel("Tiempo",fontsize=12)
plt.ylabel("Población ",fontsize=12) 
plt.plot(time2,lista[4],color='c')
plt.subplot(3,2,6)
plt.title('$r=4$')
plt.plot(time2,lista[5],color='orange')
plt.xlabel("Tiempo",fontsize=12)
plt.ylabel("Población ",fontsize=12) 
plt.grid(True)

# %% [markdown]
# # 3. Construye una rutina llamada logist_map en que entrada el valor de r, la condiciones inicial xi y el número de puntos determine la evolución en el punto N.  Prueba implementado las siguientes lineas.
#
# ```
# Np = 1000
# xf = np.zeros(Np)
# r  = np.linspace(2.5, 4, Np)
#
# for i in range(0, Np):
#   xini = np.random.random()
#   x_i = logist_map(r = r[i], xi = xini, N = 1000)
#   xf[i] = x_i
# ```
#
#
# 4. Realiza un gráfico de:
# ```
#   plt.plot((r-1/r), xf,  ".", markersize = 0.5)
# ```

# %%
def logist_map2(r,x,N):
   Ar=np.zeros(N)
   for i in range(0,N):
     j=r*x*(1-x)
     Ar[i]=j
     x=j
   return x

# %%
Np = 1000
xf = np.zeros(Np)
r2  = np.linspace(2.5, 4, Np)
for i in range(0, Np): 
  xini = np.random.random()
  x_i = logist_map2(r = r2[i], x = xini, N = 1000) 
  xf[i] = x_i

# %%
plt.plot((r2-1/r2), xf,".",color='green', markersize = 0.5)
plt.grid(True)
plt.figure(figsize=(26,18))

# %% [markdown]
# # 5. Encontrar dos formas adicionales de expresar $f(x)$, para estos valores funcionales determinar las mismas gráficas del numeral 3 para cada uno de las formas de escribir la expresión. En este caso se espera que los resultados varien. ¿A que se debe esto?. La respuesta no es inmediata, constulta algunas fuentes para sacar tu propia conclusión.

# %% [markdown]
# Otras dos formas de encontrar 𝑓(𝑥) es
#
# \begin{equation}
# x_{n+1}=f(x_n)=rx_n-rx_n^2
# \end{equation}
#
# y
#
# \begin{equation}
# x_{n+1}=f(x_n)=r(x_n-x_n^2)
# \end{equation}

# %%
def logist_map3(r,x,N):
   Ar=np.zeros(N)
   for i in range(0,N):
     j=(r*x)-(r*x**2)
     Ar[i]=j
     x=j
   return x

# %%
Np = 1000
xf2 = np.zeros(Np)
r2  = np.linspace(2.5, 4, Np)

for i in range(0, Np): 
  xini = np.random.random()
  x_i = logist_map3(r = r2[i], x = xini, N = 1000) 
  xf2[i] = x_i

# %%
plt.plot((r2-1/r2), xf2,".",color="purple",markersize = 0.5)
plt.grid(True)
plt.figure(figsize=(26,18))

# %%
def logist_map4(r,x,N):
   Ar=np.zeros(N)
   for i in range(0,N):
     j=r*(x-x**2)
     Ar[i]=j
     x=j
   return x

# %%
Np = 1000
xf3 = np.zeros(Np)
r2  = np.linspace(2.5, 4, Np)

for i in range(0, Np): 
  xini = np.random.random()
  x_i = logist_map4(r = r2[i], x = xini, N = 1000) 
  xf3[i] = x_i

# %%
plt.plot((r2-1/r2), xf3,".",color="blue", markersize = 0.5)
plt.grid(True)
plt.figure(figsize=(14,18))

# %% [markdown]
# Cómo se puede ver la función varía (sin embargo las gráficas a simple vista son muy similares ) debido a que la función del mapa logistico tiene comportamientos caóticos que dependen de las condiciones iniciales y del proceso de la evaluación de f(x) y por tanto se pudo ver la diferencia en los resultados.

# %% [markdown]
# # 2.0 El algoritmo de gradiente descendente permite encontrar el minimo de funciones en espacios multidimensionales proponiendo puntos en la direccion en la que el gradiente desciende. Para el caso de una dimensión, podemos encontrar el mínimo realizando iteraciones y multiplicando su derivada en cada nuevo punto por una constante $\alpha$
#
# \begin{equation}
# x_{i+1}=x_i - \alpha \frac{\mathrm{d}f}{\mathrm{d}x}(x_i)
# \end{equation}

# %% [markdown]
# Ejemplo:
#
# Sea $f(\omega) = (\omega-1)^2$ , con $\omega \in \mathbb{R} $. El minimo de esta función esta determinado por
# \begin{equation}
# \frac{\mathrm{d}f}{\mathrm{d}\omega} = 0
# \end{equation}
#
# \begin{equation}
# \omega = 1
# \end{equation}
#
#
# Para determinar el minimo,  a través del gradiente descendente puede ser aplicada el siguiente algoritmo:
# 1. Proponer un número aleatorios inicial $\omega_i$
# 2. Para descender al mínimo de la función, encontremos un  valor para el cual
# la derivada de la función descenciende, asi:
# \begin{equation}
# \omega_{i+1} = \omega_{i} - \alpha \frac{\mathrm{d}f(\omega_i)}{\mathrm{d}\omega}
# \end{equation}
#
# donde, $\alpha$ es conocido como la tasa de aprendizaje del algoritmo.
#
# 3. Evaluar $f(\omega_{i+1})$
#
# 4. Iterar hasta encontrar el minimo de la función
#
#
# En el caso de la funcion propuesta, asumiendo un valor de $\alpha=1$, tenemos que:
#
# 1. Supongamos que $\omega_{0} = 2$, luego :
# 2. $\omega_{0+1} = 2 - 1 f'(\omega_{0}) =  = 0$
# 3. $f(0) = 1$
# 4. $\omega_{1+1} = 0 - 1 f'(\omega_{1}) = 0-1(2(0-1)) =  2$
#
# El valor del $\omega$  despues de un par de iteraciones, no es el esperado, por que no minimiza la función, se debe proponer un tasa de aprendizaje  **$\alpha$** de tal forma que permita descender suavemente para encontrar el minimo.
#
#
#
# **Su tarea será**:
#
# ## 1. Diseñar un programa, en el que entrada la función y su derivada, definidas como funciones lambda de python, se determine el valor mínimo de esa función.
# Prueba tu algoritmo para  la función $f(x) = x^2$

# %%
f=lambda x: x**2
f_derivada=lambda x: 2*x

# %%
import random
W=[]
FW=[]
Der=[]
def gradesc(f,f_derivada,α):
    w=random.random()
    while abs(f_derivada(w))> 0.001:
       wn=w-α*f_derivada(w)
       W.append(wn)
       v=f(wn)
       FW.append(v)
       x=f_derivada(wn)
       Der.append(x)
       w=wn
    return "El mínimo de la función está en ",round(w,2)

# %%
gradesc(f,f_derivada,0.01)
# Out:
# ('El mínimo de la función está en ', 0.0)

# %% [markdown]
# ## 2. Realiza el grafico de la funcion y la derivada, especifica la leyenda de cada curva empleando el metodo legend() de matplotlib.

# %%
x = np.linspace(-5, 5, num=100)
fx=f(x)
df=f_derivada(x)
import matplotlib.pylab as plt
import numpy as np 
plt.figure(figsize=(10,10))
plt.plot(x,fx,label="$f(x)=x^2$",color="red")
plt.plot(x,df,label="$df(x)/dx$",color="blue")
plt.xlabel("$x$",fontsize=12)
plt.ylabel("$y$",fontsize=12)
plt.grid(True)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.title('Gráfico de la funcion y su derivada',fontsize=20)
plt.xlim(-5,5)
plt.legend()

# %% [markdown]
# ## 3. Analiza como se minimiza la función, gráficando de la funcion en cada punto a iterar,  como funcion del numero de iteraciones. Para dos valores diferentes de la constante alpha (prueba con $\alpha=0.1$, $\alpha=0.01$)

# %%
gradesc(f,f_derivada,0.1)
import matplotlib.pylab as plt
import numpy as np 
plt.figure(figsize=(10,10))
plt.plot(FW,label="$F(w)$",color='r')
plt.xlabel("Número de iteraciones",fontsize=14)
plt.ylabel("$f(w)$",fontsize=14)
plt.legend(loc=1)
plt.grid(True)
plt.title("Grafica de cómo se minimiza $x^2$",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Grafica de cómo se minimiza $x^2$')

# %%
gradesc(f,f_derivada,0.01)
import matplotlib.pylab as plt
import numpy as np 
plt.figure(figsize=(10,10))

plt.plot(FW,label="$F(w)$",color='yellow')
plt.xlabel("Número de iteraciones",fontsize=14)
plt.ylabel("$f(w)$",fontsize=14)
plt.legend(loc=1)

plt.grid(True)
plt.title("Grafica de cómo se minimiza $x^2$",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Grafica de cómo se minimiza $x^2$')
