# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab04_pandas_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# >>>[Pandas y chat gpt](#scrollTo=TVI5i4Vbf_Hh)
#
# >>>[Problema 1](#scrollTo=TVI5i4Vbf_Hh)
#
# >>>[Problema 2.](#scrollTo=TVI5i4Vbf_Hh)
#
# >>>[Problema 3](#scrollTo=TVI5i4Vbf_Hh)
#
# >>>[Problema 4](#scrollTo=TVI5i4Vbf_Hh)
#
# >[Trabajo en clase](#scrollTo=YeWda0wX8Ypo)
#
# >[solucion](#scrollTo=evIEuW2-8VZg)
#
# >>[Problema 1](#scrollTo=ubjhDNstxMS0)
#
# >>[Problema 2.](#scrollTo=Y1gWRaNCOPiq)

# %% [markdown]
# ### Pandas y chat gpt
#
# Comandos basicos de pandas:
#
#
# | Function | Description |
# | --- | --- |
# | `fillna()` | Replace NaN values in a DataFrame or Series with a specified value. |
# | `dropna()` | Remove rows or columns containing NaN values from a DataFrame. |
# | `loc[]` | Select rows and columns from a DataFrame by label-based indexing. |
# | `iloc[]` | Select rows and columns from a DataFrame by integer-based indexing. |
# | `[]` | Select a single column from a DataFrame using dot notation or bracket notation. |
# | `shape` | Get the number of rows and columns in a DataFrame. |
# | `dtypes` | Get the data types of the columns in a DataFrame. |
# | `head()` | Get the first n rows of a DataFrame. |
# | `tail()` | Get the last n rows of a DataFrame. |
# | `describe()` | Get summary statistics for the columns in a DataFrame. |
# | `groupby()` | Group a DataFrame by one or more columns and perform an aggregation. |
# | `sort_values()` | Sort a DataFrame by one or more columns. |
# | `merge()` | Merge two DataFrames on a common column. |
# | `pivot_table()` | Create a pivot table from a DataFrame. |
# | `to_csv()` | Save a DataFrame to a CSV file. |
# | `read_csv()` | Read a CSV file into a DataFrame. |
#
#
#
#
#
# ### Problema 1
# 1. a) Generar un diccionario con CHATGPT con los premios nobel de fisica de la decada que tu elijas.  El diccionario debe tener la siguiente estructura:
#
# clave: Nombre del cientifico, el nombre del cientifico se debe llamar de la siguiente forma: Inicial del nombre del cientifico y Apellido, ejemplo: A. Einstein., R. Feyman.
#
# Valor: diccionario con el año y el motivo por que el gano el premio nobel resumido maximo 10 palabras.
#
#
# b). Con el diccionario construir un dataframe de pandas y almacenarlo como un archivo csv. Las columnas del data frame se deberán llamar Cientifico, AnoNobel, Motivo.
#
#
#
#
# ### Problema 2.
#
# Usando el dataset `PS4_1.csv`, convertir la serie `Date` en el indice (serie de tiempo) y eliminar la serie `Unnamed: 1` (generado por pandas), retornar un  diccionario con en el siguiente orden:
#
# * cantidad de columnas
# * Nombre de las columnas
# * número de registros no NaN de cada columna
# * cantidad total de memoria usada para cargar el dataset en el computador ,( df.memory_usage() )
# * Estadistica basica para cada columna, media, desviacion estandar, maximo
# * Remplazar los NaN por None
#
#
# ```
# import pandas as pd
#
# df = pd.read_excel("dataset/PS4_1.xlsx")
# for d in df.Date:
#     if(type(d)==str):
#         df["Date_"] = datetime.strptime(d, "%d/%m/%Y")
#     else:
#         df["Date_"]=d
# df=df.set_index("Date_")
# df=df.drop(columns=["Date","Unnamed: 1"])
#
# ```
#
#
# ### Problema 3
#
# Realizar la lectura del data frame "Crimes_-_2019.csv" asociado a los crimenes que se presentaron en Chicago en el 2019.
#
#
# 1. Ver la estadistica general del data frame.
# 2. Elimnar  las columnas PrimaryType, y Date.
# 3. Transformar la columna Date que es tipo string en una tipo Fecha, use el siguiente metodo de pandas pd.to_datetime(df.Date,format="%m/%d/%Y %I:%M:%S %p")
# 4. Mostrar los casos totales para cada tipo de crimen de forma ascendente, emplee:
#    df.groupby(columna).Date.count()
#
#    sort_values()
# 5. Ordenar los valores por orden alfabetico de Primary type
# 6. Mostrar de la fila 100 a la 120
# 6. Realizar una visualización de los datos anteriores.Emplee la libreria  seaborn con un grafico tipo barplot. Ej.
#    ax = sns.barplot(x = "contador", y="Primary Type", data = datos)
#
#
#
#
# ### Problema 4
#
# 1. Leer el dataset country_vaccinations.csv  y filtrar los datos para Colombia
# 2. Crear un csv con los datos para colombia
# 3. Realizar una comparacion con los paises latinoamericanos de la cantidad de vacunados.
# 4. A traves de mascaras determinar el numero de vacunados en el intervalo  [1.5E6, 2.0E6]
#
#
#
#
# Referencias: Puedes consultar la pagina kaggle para estudiar mas acerca de pandas

# %% [markdown]
# #Trabajo en clase

# %%
#recomendación: generar un diccionario de python con clave, valor, donde la clave son los nombre de los fisicos que ganaron el premio novel entre 1980 y 1990, incluir en el valor del diccinario
#un diccionario con el año en que ganó y 10 plabras con el motivo

#por ejemplo dicc={"A.Einstein": {1905:'efecto fotoelectrico'}}

#el nomre escribirlo en la siguiente notacion: Iniciales del nombre. apellido


#se puede resumir un poco mas

# %%
import pandas as pd

# %%
dic= {'Exactas':'astronomia', 'Humanas':'sociologia', 'ingeniería':'alimentos', 'artes':'canto'}

# %%
#mostrar las claves

dic.keys()
# Out:
# dict_keys(['Exactas', 'Humanas', 'ingeniería', 'artes'])

# %%
#mostrar los valores

dic.values()
# Out:
# dict_values(['astronomia', 'sociologia', 'alimentos', 'canto'])

# %%
#iterar para mostrar clave, valor

for i,s in enumerate(dic):
  print(i,s, dic[s])       #la i corresponde al cero, uno, dos ; s son las claves;dic[s es el valor ascociado a cada una de las claves
# Out:
# 0 Exactas astronomia
# 1 Humanas sociologia
# 2 ingeniería alimentos
# 3 artes canto

# %%
#crear una serie a partir del diccionario

serie= pd.Series(dic)
serie
# Out:
# Exactas       astronomia
# Humanas       sociologia
# ingeniería     alimentos
# artes              canto
# dtype: object

# %%
#acceder a los indices

serie.loc['Exactas'], serie.iloc[0]
# Out:
# ('astronomia', 'astronomia')

# %%
serie.iloc[:]    #notamos que con iloc se accede por medio de indices, y loc se accede por medio de las claves
# Out:
# Exactas       astronomia
# Humanas       sociologia
# ingeniería     alimentos
# artes              canto
# dtype: object

# %%
juan_class= pd.Series(['a', 'b', 'c'], index= ['letraaaa', '1', '2'])   #otra forma de definirlo sin necesidad de diccionarios --> yo disponog los indices
juan_class
# Out:
# letraaaa    a
# 1           b
# 2           c
# dtype: object

# %%
d1= {'name': 'juan', 'topic': 'fisica mecanica', 'score': 5}
d2= {'name': 'pedro', 'topic': 'fisica cuantica', 'score': 3}
d3= {'name': 'francisco', 'topic': 'astronomia', 'score': 7}

r_1= pd.Series(d1)
r_2= pd.Series(d2)
r_3= pd.Series(d3)

df1= pd.DataFrame([r_1, r_2, r_3])
df1
# Out:
#         name            topic  score
# 0       juan  fisica mecanica      5
# 1      pedro  fisica cuantica      3
# 2  francisco       astronomia      7

# %%
pd.DataFrame([d1,d2,d3])   #se puede llear a lo mismo sin considerar las series, pero es importante tener en cuenta que es otra forma de construirlo
# Out:
#         name            topic  score
# 0       juan  fisica mecanica      5
# 1      pedro  fisica cuantica      3
# 2  francisco       astronomia      7

# %%
df1.name    #forma de acceder a las columnas
# Out:
# 0         juan
# 1        pedro
# 2    francisco
# Name: name, dtype: object

# %%
df1['name']   #otra forma de acceder a las columnas --> con estos elementos ya se puede hacer opeaciones entre las columnas
# Out:
# 0         juan
# 1        pedro
# 2    francisco
# Name: name, dtype: object

# %%
df1.name + ' ' + df1.topic    #una de las operciones que se pueden realizar
# Out:
# 0     juan fisica mecanica
# 1    pedro fisica cuantica
# 2     francisco astronomia
# dtype: object

# %%
df1.iloc[0]     #para ubicar los elementos de la primera fila con sus respectivas categorías
# Out:
# name                juan
# topic    fisica mecanica
# score                  5
# Name: 0, dtype: object

# %%
df2= pd.DataFrame([r_1, r_2, r_3], index= ['udea', 'unal', 'MIT'])   #es una forma de cambiar los indices cero
df2
# Out:
#            name            topic  score
# udea       juan  fisica mecanica      5
# unal      pedro  fisica cuantica      3
# MIT   francisco       astronomia      7

# %%
df2.loc['udea']   #accedo a los elementos de la fila con el indice que definí
# Out:
# name                juan
# topic    fisica mecanica
# score                  5
# Name: udea, dtype: object

# %%
fisicos_nobel = {
    'J. Cronin': {
        'año': 1980,
        'motivo': 'Descubrimiento de la violación de simetría CP en la desintegración de partículas elementales'
    },
    'B. Benacerraf': {
        'año': 1980,
        'motivo': 'Descubrimientos sobre las estructuras genéticas que controlan la respuesta inmunológica y el papel del sistema de histocompatibilidad'
    },
    'N. Cabrera': {
        'año': 1981,
        'motivo': 'Descubrimientos experimentales sobre el efecto túnel en superconductores débiles'
    },
    'K.G. Wilson': {
        'año': 1982,
        'motivo': 'Teoría de la renormalización y su aplicación a la física de la materia condensada, especialmente en relación con los efectos críticos de fenómenos de simetría rota'
    },
    'S. Chandrasekhar': {
        'año': 1983,
        'motivo': 'Estudios teóricos sobre las etapas finales de la evolución de las estrellas y las estructuras y procesos estelares'
    },
    'C. Rubbia': {
        'año': 1984,
        'motivo': 'Descubrimiento de las partículas W y Z que transmiten la fuerza débil'
    },
    'K. von Klitzing': {
        'año': 1985,
        'motivo': 'Descubrimiento del efecto cuántico Hall entero'
    },
    'E. Ruska': {
        'año': 1986,
        'motivo': 'Desarrollo de la microscopía electrónica de alta resolución'
    },
    'J.G. Bednorz': {
        'año': 1987,
        'motivo': 'Descubrimiento de la superconductividad a altas temperaturas en materiales cerámicos'
    },
    'A. Müller': {
        'año': 1987,
        'motivo': 'Descubrimiento de la superconductividad a altas temperaturas en materiales cerámicos'
    },
    'L.M. Lederman': {
        'año': 1988,
        'motivo': 'Descubrimiento del neutrino muonico'
    },
    'M. Schwartz': {
        'año': 1988,
        'motivo': 'Descubrimiento del neutrino muonico'
    },
    'J. Steinberger': {
        'año': 1988,
        'motivo': 'Descubrimiento del neutrino muonico'
    },
    'N. Bloembergen': {
        'año': 1981,
        'motivo': 'Desarrollo de la espectroscopía no lineal'
    },
    'Arthur Schawlow': {
        'año': 1981,
        'motivo': 'Desarrollo de la espectroscopía láser'
    },
    'Karl Alex Müller': {
        'año': 1987,
        'motivo': 'Descubrimiento de la superconductividad a altas temperaturas en materiales cerámicos'
    }
   }

# %%
import pandas as pd

df= pd.DataFrame(fisicos_nobel)
df
# Out:
#                                                 J. Cronin  \
# año                                                  1980
# motivo  Descubrimiento de la violación de simetría CP ...
#
#                                             B. Benacerraf  \
# año                                                  1980
# motivo  Descubrimientos sobre las estructuras genética...
#
#                                                N. Cabrera  \
# año                                                  1981
# motivo  Descubrimientos experimentales sobre el efecto...
#
#                                               K.G. Wilson  \
# año                                                  1982
# motivo  Teoría de la renormalización y su aplicación a...
#
#                                          S. Chandrasekhar  \
# año                                                  1983
# motivo  Estudios teóricos sobre las etapas finales de ...
#
#                                                 C. Rubbia  \
# año                                                  1984
# motivo  Descubrimiento de las partículas W y Z que tra...
#
#                                        K. von Klitzing  \
# año                                               1985
# motivo  Descubrimiento del efecto cuántico Hall entero
#
#                                                  E. Ruska  \
# año                                                  1986
# motivo  Desarrollo de la microscopía electrónica de al...
#
#                                              J.G. Bednorz  \
# año                                                  1987
# motivo  Descubrimiento de la superconductividad a alta...
#
#                                                 A. Müller  \
# año                                                  1987
# motivo  Descubrimiento de la superconductividad a alta...
#
#                               L.M. Lederman  \
# año                                    1988
# motivo  Descubrimiento del neutrino muonico
#
#                                 M. Schwartz  \
# año                                    1988
# motivo  Descubrimiento del neutrino muonico
#
#                              J. Steinberger  \
# año                                    1988
# motivo  Descubrimiento del neutrino muonico
#
#                                    N. Bloembergen  \
# año                                          1981
# motivo  Desarrollo de la espectroscopía no lineal
#
#                               Arthur Schawlow  \
# año                                      1981
# motivo  Desarrollo de la espectroscopía láser
#
#                                          Karl Alex Müller
# año                                                  1987
# motivo  Descubrimiento de la superconductividad a alta...

# %%
df.transpose()  #los nombres han quedado como el indice
# Out:
#                    año                                             motivo
# J. Cronin         1980  Descubrimiento de la violación de simetría CP ...
# B. Benacerraf     1980  Descubrimientos sobre las estructuras genética...
# N. Cabrera        1981  Descubrimientos experimentales sobre el efecto...
# K.G. Wilson       1982  Teoría de la renormalización y su aplicación a...
# S. Chandrasekhar  1983  Estudios teóricos sobre las etapas finales de ...
# C. Rubbia         1984  Descubrimiento de las partículas W y Z que tra...
# K. von Klitzing   1985     Descubrimiento del efecto cuántico Hall entero
# E. Ruska          1986  Desarrollo de la microscopía electrónica de al...
# J.G. Bednorz      1987  Descubrimiento de la superconductividad a alta...
# A. Müller         1987  Descubrimiento de la superconductividad a alta...
# L.M. Lederman     1988                Descubrimiento del neutrino muonico
# M. Schwartz       1988                Descubrimiento del neutrino muonico
# J. Steinberger    1988                Descubrimiento del neutrino muonico
# N. Bloembergen    1981          Desarrollo de la espectroscopía no lineal
# Arthur Schawlow   1981              Desarrollo de la espectroscopía láser
# Karl Alex Müller  1987  Descubrimiento de la superconductividad a alta...

# %%
g= df.transpose().reset_index().copy()   #reset index para que ya el nombre no quede como el indice   --- creo una copia y la almaceno en g para que no se modifique el original

# %%
g.columns
# Out:
# Index(['index', 'año', 'motivo'], dtype='object')

# %%
col=['científico', 'año', 'motivo']

# %%
g= g.rename(columns={'index':'científico', 'año':'año'})   #debo reasignar a g para que los cambios se vean reflejados
g
# Out:
#           científico   año                                             motivo
# 0          J. Cronin  1980  Descubrimiento de la violación de simetría CP ...
# 1      B. Benacerraf  1980  Descubrimientos sobre las estructuras genética...
# 2         N. Cabrera  1981  Descubrimientos experimentales sobre el efecto...
# 3        K.G. Wilson  1982  Teoría de la renormalización y su aplicación a...
# 4   S. Chandrasekhar  1983  Estudios teóricos sobre las etapas finales de ...
# 5          C. Rubbia  1984  Descubrimiento de las partículas W y Z que tra...
# 6    K. von Klitzing  1985     Descubrimiento del efecto cuántico Hall entero
# 7           E. Ruska  1986  Desarrollo de la microscopía electrónica de al...
# 8       J.G. Bednorz  1987  Descubrimiento de la superconductividad a alta...
# 9          A. Müller  1987  Descubrimiento de la superconductividad a alta...
# 10     L.M. Lederman  1988                Descubrimiento del neutrino muonico
# 11       M. Schwartz  1988                Descubrimiento del neutrino muonico
# 12    J. Steinberger  1988                Descubrimiento del neutrino muonico
# 13    N. Bloembergen  1981          Desarrollo de la espectroscopía no lineal
# 14   Arthur Schawlow  1981              Desarrollo de la espectroscopía láser
# 15  Karl Alex Müller  1987  Descubrimiento de la superconductividad a alta...

# %%
g.drop(['científico'], axis= 1)
# Out:
#      año                                             motivo
# 0   1980  Descubrimiento de la violación de simetría CP ...
# 1   1980  Descubrimientos sobre las estructuras genética...
# 2   1981  Descubrimientos experimentales sobre el efecto...
# 3   1982  Teoría de la renormalización y su aplicación a...
# 4   1983  Estudios teóricos sobre las etapas finales de ...
# 5   1984  Descubrimiento de las partículas W y Z que tra...
# 6   1985     Descubrimiento del efecto cuántico Hall entero
# 7   1986  Desarrollo de la microscopía electrónica de al...
# 8   1987  Descubrimiento de la superconductividad a alta...
# 9   1987  Descubrimiento de la superconductividad a alta...
# 10  1988                Descubrimiento del neutrino muonico
# 11  1988                Descubrimiento del neutrino muonico
# 12  1988                Descubrimiento del neutrino muonico
# 13  1981          Desarrollo de la espectroscopía no lineal
# 14  1981              Desarrollo de la espectroscopía láser
# 15  1987  Descubrimiento de la superconductividad a alta...

# %%
#ponemos el enlace del archivo que hemos publicado en la web

url= 'https://docs.google.com/spreadsheets/d/e/2PACX-1vRR6Rko3svpDTswovIyNEcTfTEfhMS8N6lYaYrM78YfHV6PcGkcfFJypP50f_fojA/pub?output=xlsx'

# %%
df= pd.read_excel(url)
df
# Out:
#                     Date Unnamed: 1  Berri1  Maisonneuve_1  Maisonneuve_2  \
# 0    2009-01-01 00:00:00   00:00:00    29.0           20.0           35.0
# 1    2009-02-01 00:00:00   00:00:00    19.0            3.0           22.0
# 2    2009-03-01 00:00:00   00:00:00    24.0           12.0           22.0
# 3    2009-04-01 00:00:00   00:00:00    24.0            8.0           15.0
# 4    2009-05-01 00:00:00   00:00:00   120.0          111.0          141.0
# ..                   ...        ...     ...            ...            ...
# 360           27/12/2009   00:00:00    66.0           29.0           52.0
# 361           28/12/2009   00:00:00    61.0           41.0           99.0
# 362           29/12/2009   00:00:00    89.0           52.0          115.0
# 363           30/12/2009   00:00:00    76.0           43.0          115.0
# 364           31/12/2009   00:00:00    53.0           46.0          112.0
#
#      Brebeuf
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 360      0.0
# 361      0.0
# 362      0.0
# 363      0.0
# 364      0.0
#
# [365 rows x 6 columns]

# %%
import datetime

# %%
df.Date[300],df.Date[0]   #los primeros son datetime, pero el resto no
# Out:
# ('28/10/2009', datetime.datetime(2009, 1, 1, 0, 0))

# %%
for f in df.Date:
  print(type(f))

# %%
a= '27/12/2009'

pd.to_datetime(a)
# Out:
# Timestamp('2009-12-27 00:00:00')

# %% [markdown]
# #solucion

# %% [markdown]
# ## Problema 1
# 1. a) Generar un diccionario con CHATGPT con los premios nobel de fisica de la decada que tu elijas.  El diccionario debe tener la siguiente estructura:
#
# clave: Nombre del cientifico, el nombre del cientifico se debe llamar de la siguiente forma: Inicial del nombre del cientifico y Apellido, ejemplo: A. Einstein., R. Feyman.
#
# Valor: diccionario con el año y el motivo por que el gano el premio nobel resumido maximo 10 palabras.
#
#
# b). Con el diccionario construir un dataframe de pandas y almacenarlo como un archivo csv. Las columnas del data frame se deberán llamar Cientifico, AnoNobel, Motivo.

# %%
#comenzamos por generar el diccionario por medio de chat gpt

dic = {
    'O. Stern': {
        'año': 1943,
        'motivo': 'momento magnético del protón'
    },
    'I. I. Rabi': {
        'año': 1944,
        'motivo': 'resonancia magnética de los núcleos atómicos'
    },
    'W. Pauli': {
        'año': 1945,
        'motivo': 'principio de exclusión para los electrones'
    },
    'P. W. Bridgman': {
        'año': 1946,
        'motivo': 'física de alta presión'
    },
    'E. V. Appleton': {
        'año': 1947,
        'motivo': 'investigaciones en la ionosfera'
    },
    'P. M. S. Blackett': {
        'año': 1948,
        'motivo': 'cámara de burbujas'
    },
    'H. Yukawa': {
        'año': 1949,
        'motivo': 'descubrimiento del mesón'
    },
    'C. F. Powell': {
        'año': 1950,
        'motivo': 'cámara de emulsiones'
    }
}

# %%
import pandas as pd

df = pd.DataFrame(dic)
df
# Out:
#                             O. Stern  \
# año                             1943
# motivo  momento magnético del protón
#
#                                           I. I. Rabi  \
# año                                             1944
# motivo  resonancia magnética de los núcleos atómicos
#
#                                           W. Pauli          P. W. Bridgman  \
# año                                           1945                    1946
# motivo  principio de exclusión para los electrones  física de alta presión
#
#                          E. V. Appleton   P. M. S. Blackett  \
# año                                1947                1948
# motivo  investigaciones en la ionosfera  cámara de burbujas
#
#                        H. Yukawa          C. F. Powell
# año                         1949                  1950
# motivo  descubrimiento del mesón  cámara de emulsiones

# %%
#genero una copia en g, para que el dataframe original no se vea modificado

g= df.transpose().reset_index().copy()                 #quito el indice que por defecto lo generó como el nombre del científico
g
# Out:
#                index   año                                        motivo
# 0           O. Stern  1943                  momento magnético del protón
# 1         I. I. Rabi  1944  resonancia magnética de los núcleos atómicos
# 2           W. Pauli  1945    principio de exclusión para los electrones
# 3     P. W. Bridgman  1946                        física de alta presión
# 4     E. V. Appleton  1947               investigaciones en la ionosfera
# 5  P. M. S. Blackett  1948                            cámara de burbujas
# 6          H. Yukawa  1949                      descubrimiento del mesón
# 7       C. F. Powell  1950                          cámara de emulsiones

# %%
#vamos a cambiar el nombre de las columnas del dataframe anterior

g.columns = ['Científico', 'Año Nobel', 'Motivo']   
g


#esto mismo puedo hacerlo como:
# g= g.rename(columns={'index':'científico', 'año':'año'})       #lo reasigno a g para que los cambios se vean reflejados
# Out:
#           Científico Año Nobel                                        Motivo
# 0           O. Stern      1943                  momento magnético del protón
# 1         I. I. Rabi      1944  resonancia magnética de los núcleos atómicos
# 2           W. Pauli      1945    principio de exclusión para los electrones
# 3     P. W. Bridgman      1946                        física de alta presión
# 4     E. V. Appleton      1947               investigaciones en la ionosfera
# 5  P. M. S. Blackett      1948                            cámara de burbujas
# 6          H. Yukawa      1949                      descubrimiento del mesón
# 7       C. F. Powell      1950                          cámara de emulsiones

# %%
#ahora, vamos a almacenar el anterior DataFrame como un archivo csv

g.to_csv('premios nobel entre 1940 y 1950.csv', index=False)

# %% [markdown]
# ## Problema 2.
#
# Usando el dataset `PS4_1.csv`, convertir la serie `Date` en el indice (serie de tiempo) y eliminar la serie `Unnamed: 1` (generado por pandas), retornar un  diccionario con en el siguiente orden:
#
# * cantidad de columnas
# * Nombre de las columnas
# * número de registros no NaN de cada columna
# * cantidad total de memoria usada para cargar el dataset en el computador ,( df.memory_usage() )
# * Estadistica basica para cada columna, media, desviacion estandar, maximo
# * Remplazar los NaN por None
#
#
# ```
# import pandas as pd
#
# df = pd.read_excel("dataset/PS4_1.xlsx")
# for d in df.Date:
#     if(type(d)==str):
#         df["Date_"] = datetime.strptime(d, "%d/%m/%Y")
#     else:
#         df["Date_"]=d
# df=df.set_index("Date_")
# df=df.drop(columns=["Date","Unnamed: 1"])
#
# ```

# %%
#ponemos el enlace del archivo que hemos publicado en la web

url= 'https://docs.google.com/spreadsheets/d/e/2PACX-1vRR6Rko3svpDTswovIyNEcTfTEfhMS8N6lYaYrM78YfHV6PcGkcfFJypP50f_fojA/pub?output=xlsx'

# %%
import pandas as pd

df= pd.read_excel(url)
df
# Out:
#                     Date Unnamed: 1  Berri1  Maisonneuve_1  Maisonneuve_2  \
# 0    2009-01-01 00:00:00   00:00:00    29.0           20.0           35.0
# 1    2009-02-01 00:00:00   00:00:00    19.0            3.0           22.0
# 2    2009-03-01 00:00:00   00:00:00    24.0           12.0           22.0
# 3    2009-04-01 00:00:00   00:00:00    24.0            8.0           15.0
# 4    2009-05-01 00:00:00   00:00:00   120.0          111.0          141.0
# ..                   ...        ...     ...            ...            ...
# 360           27/12/2009   00:00:00    66.0           29.0           52.0
# 361           28/12/2009   00:00:00    61.0           41.0           99.0
# 362           29/12/2009   00:00:00    89.0           52.0          115.0
# 363           30/12/2009   00:00:00    76.0           43.0          115.0
# 364           31/12/2009   00:00:00    53.0           46.0          112.0
#
#      Brebeuf
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 360      0.0
# 361      0.0
# 362      0.0
# 363      0.0
# 364      0.0
#
# [365 rows x 6 columns]

# %%
#lo primero que vamos a hacer es convertir la columna date a una serie de tiempo --> de modo que quede como un datetime

import datetime

for d in df.Date:
  if type(d) == str:                 #hacemos esto porque algunos de los elementos que hay en la columna se encuentras como str y otros ya están directamnete en el formato apropiado
    df['Date_'] = datetime.datetime.strptime(d, '%d/%m/%Y')
  else:
    df['Date_'] = d

df = df.set_index('Date_')                        #hacemos que la fecha en el formato correcto quede como el indice
df = df.drop(columns = ['Date', 'Unnamed: 1'])    #eliminamos al columna que tiene la fecha en un formato inapropiado, y la columna que nos piden que eliminemos

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df
# Out:
#             Berri1  Maisonneuve_1  Maisonneuve_2  Brebeuf
# Date_
# 2009-12-31    29.0           20.0           35.0      NaN
# 2009-12-31    19.0            3.0           22.0      NaN
# 2009-12-31    24.0           12.0           22.0      NaN
# 2009-12-31    24.0            8.0           15.0      NaN
# 2009-12-31   120.0          111.0          141.0      NaN
# ...            ...            ...            ...      ...
# 2009-12-31    66.0           29.0           52.0      0.0
# 2009-12-31    61.0           41.0           99.0      0.0
# 2009-12-31    89.0           52.0          115.0      0.0
# 2009-12-31    76.0           43.0          115.0      0.0
# 2009-12-31    53.0           46.0          112.0      0.0
#
# [365 rows x 4 columns]

# %% [markdown]
# Comandos basicos de pandas:
#
#
# | Function | Description |
# | --- | --- |
# | `fillna()` | Replace NaN values in a DataFrame or Series with a specified value. |
# | `dropna()` | Remove rows or columns containing NaN values from a DataFrame. |
# | `loc[]` | Select rows and columns from a DataFrame by label-based indexing. |
# | `iloc[]` | Select rows and columns from a DataFrame by integer-based indexing. |
# | `[]` | Select a single column from a DataFrame using dot notation or bracket notation. |
# | `shape` | Get the number of rows and columns in a DataFrame. |
# | `dtypes` | Get the data types of the columns in a DataFrame. |
# | `head()` | Get the first n rows of a DataFrame. |
# | `tail()` | Get the last n rows of a DataFrame. |
# | `describe()` | Get summary statistics for the columns in a DataFrame. |
# | `groupby()` | Group a DataFrame by one or more columns and perform an aggregation. |
# | `sort_values()` | Sort a DataFrame by one or more columns. |
# | `merge()` | Merge two DataFrames on a common column. |
# | `pivot_table()` | Create a pivot table from a DataFrame. |
# | `to_csv()` | Save a DataFrame to a CSV file. |
# | `read_csv()` | Read a CSV file into a DataFrame. |

# %%
#ahora, vamos a retornar diccionario con los elementos que nos piden:
#primero vamos a seleccionar los elementos que nos piden

#cantidad de columnas

columnas= df.shape[1]

#nombre de las columnas

name_cols = df.columns.tolist()           #convierto el nombre de las columnas que el atributo me da

# %%
#vamos ahora un código para ver el numero de registros no NaN de cada columna

no_NaN = []

for d in df.columns:
  numero =df[d].isna().sum()     #isna devuelve una mascarra booleana que indica que valores son NaN, el método sum suma los valores true de la máscara dada
  no_NaN.append(len(df[d]) - numero)   #imprimo 365 que es el numero de filas del dataframe, menos el numero de elemtnos no NaN que tiene cada una de las columnas

# %%
#numero de registros no NAN de cada columna

no_NaN      # notamos que en las tres primeras columnas no hay valores que sean NaN
# Out:
# [365, 365, 365, 178]

# %%
#cantidad total de memoria usada para cargar el dataset en el computador:

memoria = df.memory_usage() 
memo_dic = memoria.to_dict()

# %%
#estadísticas básicas para cada columna

media=[]                               #miramos la media de cada una de las columnas
for i in range(4):
  media_cu= df[name_cols[i]].mean()
  media.append(media_cu)

desv_est =[]
for i in range(4):
  desv= df[name_cols[i]].std()
  desv_est.append(desv)

maximo= []
for i in range(4):
  max= df[name_cols[i]].max()
  maximo.append(max)

# %%
desv_est
# Out:
# [1878.8797986572208, 1079.5330858971347, 1854.368523087829, 2484.004743334495]

# %%
#finalmente construimos el diccionario que contenga toda la información que hemos ido generando

dicc = {'Numero de Columnas' : columnas, 'Nombre de las columnas':name_cols, 
        'Numero de registros no NaN de cada columna':{name_cols[0] : no_NaN[0], name_cols[1] : no_NaN[1], name_cols[2] : no_NaN[2], name_cols[3] : no_NaN[3]},
        'Cantidad total de memoria usada para cargar el dataset en el computador': memo_dic,
        'Estadísticas básicas para cada columna': {name_cols[0]:{'media' : media[0], 'desviacion estándar' : desv_est[0], 'valor máximo' : maximo[0]},
                                                   name_cols[1]:{'media' : media[1], 'desviacion estándar' : desv_est[1], 'valor máximo' : maximo[1]},
                                                   name_cols[2]:{'media' : media[2], 'desviacion estándar' : desv_est[2], 'valor máximo' : maximo[2]},
                                                   name_cols[3]:{'media' : media[3], 'desviacion estándar' : desv_est[3], 'valor máximo' : maximo[3]} } }

# %%
dicc
# Out:
# {'Numero de Columnas': 4,
#  'Nombre de las columnas': ['Berri1',
#   'Maisonneuve_1',
#   'Maisonneuve_2',
#   'Brebeuf'],
#  'Numero de registros no NaN de cada columna': {'Berri1': 365,
#   'Maisonneuve_1': 365,
#   'Maisonneuve_2': 365,
#   'Brebeuf': 178},
#  'Cantidad total de memoria usada para cargar el dataset en el computador': {'Index': 2920,
#   'Berri1': 2920,
#   'Maisonneuve_1': 2920,
#   'Maisonneuve_2': 2920,
#   'Brebeuf': 2920},
#  'Estadísticas básicas para cada columna': {'Berri1': {'media': 2032.2,
#    'desviacion estándar': 1878.8797986572208,
#    'valor máximo': 6626.0},
#   'Maisonneuve_1': {'media': 1060.2520547945205,
#    'desviacion estándar': 1079.5330858971347,
#    'valor máximo': 4242.0},
#   'Maisonneuve_2': {'media': 2093.1698630136984,
#    'desviacion estándar': 1854.368523087829,
#    'valor máximo': 6587.0},
#   'Brebeuf': {'media': 2576.3595505617977,
#    'desviacion estándar': 2484.004743334495,
#    'valor máximo': 7575.0}}}

# %%
#el anterior diccionario fue diseñado por mi, y con la ayuda de chat gpt se ha convertido en un dataframe

# %%
columns = dicc['Nombre de las columnas']
n_non_nan = pd.Series(dicc['Numero de registros no NaN de cada columna'])
mem_usage = pd.Series(dicc['Cantidad total de memoria usada para cargar el dataset en el computador'])
stats = pd.DataFrame(dicc['Estadísticas básicas para cada columna']).transpose()

# Combine data into a single dataframe
df_ = pd.concat([n_non_nan, stats, mem_usage], axis=1)
df_.columns = ['Non-NaN Records', 'Mean', 'Std Dev', 'Max Value', 'Memory Usage']
df_.index.name = 'Column'
df_ = df_.reset_index()
#df['Column'] = df['Column'].apply(lambda x: columns.index(x) + 1)
df_ = df_[['Column', 'Non-NaN Records', 'Mean', 'Std Dev', 'Max Value', 'Memory Usage']]

df_
# Out:
#           Column  Non-NaN Records         Mean      Std Dev  Max Value  \
# 0         Berri1            365.0  2032.200000  1878.879799     6626.0
# 1  Maisonneuve_1            365.0  1060.252055  1079.533086     4242.0
# 2  Maisonneuve_2            365.0  2093.169863  1854.368523     6587.0
# 3        Brebeuf            178.0  2576.359551  2484.004743     7575.0
# 4          Index              NaN          NaN          NaN        NaN
#
#    Memory Usage
# 0          2920
# 1          2920
# 2          2920
# 3          2920
# 4          2920

# %%
#por ultimo, debemos reemplazar los NaN por None

g= df.fillna('None')     #generamos un nuevo DataFrame con la corrección que se pide
g
# Out:
#             Berri1  Maisonneuve_1  Maisonneuve_2 Brebeuf
# Date_
# 2009-12-31    29.0           20.0           35.0    None
# 2009-12-31    19.0            3.0           22.0    None
# 2009-12-31    24.0           12.0           22.0    None
# 2009-12-31    24.0            8.0           15.0    None
# 2009-12-31   120.0          111.0          141.0    None
# ...            ...            ...            ...     ...
# 2009-12-31    66.0           29.0           52.0     0.0
# 2009-12-31    61.0           41.0           99.0     0.0
# 2009-12-31    89.0           52.0          115.0     0.0
# 2009-12-31    76.0           43.0          115.0     0.0
# 2009-12-31    53.0           46.0          112.0     0.0
#
# [365 rows x 4 columns]

# %% [markdown]
# ## Problema 3
#
# Realizar la lectura del data frame "Crimes_-_2019.csv" asociado a los crimenes que se presentaron en Chicago en el 2019.
#
#
# 1. Ver la estadistica general del data frame.
# 2. Elimnar  las columnas PrimaryType, y Date.
# 3. Transformar la columna Date que es tipo string en una tipo Fecha, use el siguiente metodo de pandas pd.to_datetime(df.Date,format="%m/%d/%Y %I:%M:%S %p")
# 4. Mostrar los casos totales para cada tipo de crimen de forma ascendente, emplee:
#    df.groupby(columna).Date.count()
#
#    sort_values()
# 5. Ordenar los valores por orden alfabetico de Primary type
# 6. Mostrar de la fila 100 a la 120
# 6. Realizar una visualización de los datos anteriores.Emplee la libreria  seaborn con un grafico tipo barplot. Ej.
#    ax = sns.barplot(x = "contador", y="Primary Type", data = datos)

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hernansalinas/autogrades/main/Laboratorios_Taller/dataset/Crimes_-_2019.csv')
df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1,2,3,4,5,6,7,8,9,14,18,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                ID Case Number              Date                 Block  IUCR  \
# 0      11864018.0    JC476123    9/24/2019 8:00  022XX S MICHIGAN AVE  1154
# 1      11859805.0    JC471592  10/13/2019 20:30   024XX W CHICAGO AVE   860
# 2      11863808.0    JC476236   10/5/2019 18:30     0000X N LOOMIS ST   810
# 3      11859727.0    JC471542  10/13/2019 19:00    016XX W ADDISON ST  1320
# 4      11859656.0    JC471240  10/13/2019 14:10      051XX N BROADWAY   560
# ...           ...         ...               ...                   ...   ...
# 70990         NaN         NaN               NaN                   NaN   NaN
# 70991         NaN         NaN               NaN                   NaN   NaN
# 70992         NaN         NaN               NaN                   NaN   NaN
# 70993         NaN         NaN               NaN                   NaN   NaN
# 70994         NaN         NaN               NaN                   NaN   NaN
#
#              Primary Type                              Description  \
# 0      DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 1                   THEFT                             RETAIL THEFT
# 2                   THEFT                                OVER $500
# 3         CRIMINAL DAMAGE                               TO VEHICLE
# 4                 ASSAULT                                   SIMPLE
# ...                   ...                                      ...
# 70990                 NaN                                      NaN
# 70991                 NaN                                      NaN
# 70992                 NaN                                      NaN
# 70993                 NaN                                      NaN
# 70994                 NaN                                      NaN
#
#                Location Description Arrest Domestic  ...  Ward  \
# 0      COMMERCIAL / BUSINESS OFFICE  False    False  ...   3.0
# 1                GROCERY FOOD STORE  False    False  ...  26.0
# 2                         RESIDENCE  False    False  ...  27.0
# 3                            STREET  False    False  ...  47.0
# 4                       GAS STATION  False    False  ...  47.0
# ...                             ...    ...      ...  ...   ...
# 70990                           NaN    NaN      NaN  ...   NaN
# 70991                           NaN    NaN      NaN  ...   NaN
# 70992                           NaN    NaN      NaN  ...   NaN
# 70993                           NaN    NaN      NaN  ...   NaN
# 70994                           NaN    NaN      NaN  ...   NaN
#
#        Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0                33.0        11     1177560.0    1889548.0  2019.0
# 1                24.0         6     1160005.0    1905256.0  2019.0
# 2                28.0         6     1166986.0    1900306.0  2019.0
# 3                 6.0        14     1164930.0    1923972.0  2019.0
# 4                 3.0       08A     1167380.0    1934505.0  2019.0
# ...               ...       ...           ...          ...     ...
# 70990             NaN       NaN           NaN          NaN     NaN
# 70991             NaN       NaN           NaN          NaN     NaN
# 70992             NaN       NaN           NaN          NaN     NaN
# 70993             NaN       NaN           NaN          NaN     NaN
# 70994             NaN       NaN           NaN          NaN     NaN
#
#              Updated On   Latitude  Longitude                       Location
# 0      10/20/2019 15:56  41.852248 -87.623786  (41.852248185, -87.623786256)
# 1      10/20/2019 16:03  41.895732 -87.687784  (41.895732399, -87.687784384)
# 2      10/20/2019 15:56  41.882002 -87.662287   (41.88200224, -87.662286977)
# 3      10/20/2019 16:03  41.946987 -87.669164  (41.946987144, -87.669163602)
# 4      10/20/2019 16:03  41.975838 -87.659854  (41.975837637, -87.659853835)
# ...                 ...        ...        ...                            ...
# 70990               NaN        NaN        NaN                            NaN
# 70991               NaN        NaN        NaN                            NaN
# 70992               NaN        NaN        NaN                            NaN
# 70993               NaN        NaN        NaN                            NaN
# 70994               NaN        NaN        NaN                            NaN
#
# [70995 rows x 22 columns]

# %% [markdown]
# Ver la estadistica general del data frame.

# %%
#estadísticas generales del dataframe

estadísticas = df.describe()
estadísticas    #usamos el método describe para obtener los datos generales de las columnas que van a ser de tipo numérico
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  5.040100e+04  50401.000000  50401.000000  50401.000000    50401.000000
# mean   1.162834e+07   1133.670542     11.108530     23.298764       36.573461
# std    1.531569e+05    697.737805      6.967977     13.895214       21.277600
# min    2.456800e+04    111.000000      1.000000      1.000000        1.000000
# 25%    1.157392e+07    533.000000      5.000000     10.000000       23.000000
# 50%    1.159453e+07   1023.000000     10.000000     24.000000       32.000000
# 75%    1.161480e+07   1713.000000     17.000000     34.000000       53.000000
# max    1.224939e+07   2535.000000     25.000000     50.000000       77.000000
#
#        X Coordinate  Y Coordinate     Year      Latitude     Longitude
# count  5.020100e+04  5.020100e+04  50401.0  50201.000000  50201.000000
# mean   1.165086e+06  1.886367e+06   2019.0     41.843779    -87.669699
# std    1.604124e+04  3.096797e+04      0.0      0.085163      0.058401
# min    1.098012e+06  1.813914e+06   2019.0     41.644604    -87.915105
# 25%    1.153206e+06  1.859276e+06   2019.0     41.769138    -87.712751
# 50%    1.166927e+06  1.894060e+06   2019.0     41.865140    -87.663220
# 75%    1.176526e+06  1.908116e+06   2019.0     41.903497    -87.627722
# max    1.205114e+06  1.951495e+06   2019.0     42.022535    -87.524616

# %%
info_gral = df.info()   #obtenemos informacion de los datos que contiene cada una de las columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70995 entries, 0 to 70994
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    50401 non-null  float64
#  1   Case Number           50401 non-null  object
#  2   Date                  50401 non-null  object
#  3   Block                 50401 non-null  object
#  4   IUCR                  50401 non-null  object
#  5   Primary Type          50401 non-null  object
#  6   Description           50401 non-null  object
#  7   Location Description  50211 non-null  object
#  8   Arrest                50401 non-null  object
#  9   Domestic              50401 non-null  object
#  10  Beat                  50401 non-null  float64
#  11  District              50401 non-null  float64
#  12  Ward                  50401 non-null  float64
#  13  Community Area        50401 non-null  float64
#  14  FBI Code              50401 non-null  object
#  15  X Coordinate          50201 non-null  float64
#  16  Y Coordinate          50201 non-null  float64
#  17  Year                  50401 non-null  float64
#  18  Updated On            50401 non-null  object
#  19  Latitude              50201 non-null  float64
#  20  Longitude             50201 non-null  float64
#  21  Location              50201 non-null  object
# dtypes: float64(10), object(12)
# memory usage: 11.9+ MB

# %% [markdown]
# Elimnar las columnas PrimaryType, y Date.

# %%
#ahora, debemos eliminar las columnas  PrimaryType, y Date.

g= df.drop(columns=['Date', 'Primary Type']).copy()     #asigno mi dataframe a una nueva variable, tal que df quede sin los cambios que estoy realizando a partir de acá
g.info()       

#notamos que en efecto ya no se encuentran las columnas que hemos eliminado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70995 entries, 0 to 70994
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    50401 non-null  float64
#  1   Case Number           50401 non-null  object
#  2   Block                 50401 non-null  object
#  3   IUCR                  50401 non-null  object
#  4   Description           50401 non-null  object
#  5   Location Description  50211 non-null  object
#  6   Arrest                50401 non-null  object
#  7   Domestic              50401 non-null  object
#  8   Beat                  50401 non-null  float64
#  9   District              50401 non-null  float64
#  10  Ward                  50401 non-null  float64
#  11  Community Area        50401 non-null  float64
#  12  FBI Code              50401 non-null  object
#  13  X Coordinate          50201 non-null  float64
#  14  Y Coordinate          50201 non-null  float64
#  15  Year                  50401 non-null  float64
#  16  Updated On            50401 non-null  object
#  17  Latitude              50201 non-null  float64
#  18  Longitude             50201 non-null  float64
#  19  Location              50201 non-null  object
# dtypes: float64(10), object(10)
# memory usage: 10.8+ MB

# %% [markdown]
# Transformar la columna Date que es tipo string en una tipo Fecha, use el siguiente metodo de pandas pd.to_datetime(df.Date,format="%m/%d/%Y %I:%M:%S %p")

# %%
#en este caso, regresamos el df sin la eliminacion de las columnas que habiamos realizado, para hacer el cambio que se pide:

df.Date    #notamos que en efecto hay elementos que vienen de tipo str
# Out:
# 0          9/24/2019 8:00
# 1        10/13/2019 20:30
# 2         10/5/2019 18:30
# 3        10/13/2019 19:00
# 4        10/13/2019 14:10
#                ...
# 70990                 NaN
# 70991                 NaN
# 70992                 NaN
# 70993                 NaN
# 70994                 NaN
# Name: Date, Length: 70995, dtype: object

# %%
df['Date']= pd.to_datetime(df['Date'],format="%m/%d/%Y %H:%M")
df['Date']
# Out:
# 0       2019-09-24 08:00:00
# 1       2019-10-13 20:30:00
# 2       2019-10-05 18:30:00
# 3       2019-10-13 19:00:00
# 4       2019-10-13 14:10:00
#                 ...
# 70990                   NaT
# 70991                   NaT
# 70992                   NaT
# 70993                   NaT
# 70994                   NaT
# Name: Date, Length: 70995, dtype: datetime64[ns]

# %% [markdown]
# Mostrar los casos totales para cada tipo de crimen de forma ascendente, emplee: df.groupby(columna).Date.count()
#
# sort_values()

# %%
crimenes = df['Primary Type'].dropna()    #con esto podemos ver los diferentes trabajos que hay

# %%
tot_cases= df.groupby('Primary Type').Date.count().sort_values()     #aplicando estos métodos podemos determinar las veces que se repite cada uno de los crimenes, y se organiza desde el que menos se repite hasta el que mas se repite
tot_cases
# Out:
# Primary Type
# NON-CRIMINAL                             1
# HUMAN TRAFFICKING                        3
# HOMICIDE                                 7
# OBSCENITY                                8
# GAMBLING                                11
# KIDNAPPING                              32
# CONCEALED CARRY LICENSE VIOLATION       34
# CRIMINAL SEXUAL ASSAULT                 36
# INTIMIDATION                            38
# LIQUOR LAW VIOLATION                    42
# STALKING                                51
# ARSON                                   70
# PROSTITUTION                           131
# SEX OFFENSE                            197
# CRIM SEXUAL ASSAULT                    205
# INTERFERENCE WITH PUBLIC OFFICER       288
# PUBLIC PEACE VIOLATION                 297
# OFFENSE INVOLVING CHILDREN             420
# WEAPONS VIOLATION                     1171
# CRIMINAL TRESPASS                     1425
# ROBBERY                               1596
# MOTOR VEHICLE THEFT                   1836
# BURGLARY                              1948
# NARCOTICS                             3175
# DECEPTIVE PRACTICE                    3277
# OTHER OFFENSE                         3724
# ASSAULT                               3924
# CRIMINAL DAMAGE                       5040
# BATTERY                               9538
# THEFT                                11876
# Name: Date, dtype: int64

# %% [markdown]
# Ordenar los valores por orden alfabetico de Primary type

# %%
#ahora, lo que vamos a hacer es ordenar tot_cases en orden alfabético

tot_cases_ordered= df.groupby('Primary Type').Date.count().sort_index()         #en este caso en lugar de usar el método sort index, vamos a usar el sort value
tot_cases_ordered
# Out:
# Primary Type
# ARSON                                   70
# ASSAULT                               3924
# BATTERY                               9538
# 119  11863969.0    JC476397 2019-10-12 22:20:00         035XX W 60TH PL  1152
# 120  11859066.0    JC470706 2019-10-13 00:45:00   066XX N NORTHWEST HWY   460
#
#                          Primary Type  \
# 100  INTERFERENCE WITH PUBLIC OFFICER
# 101                     OTHER OFFENSE
# 102                           BATTERY
# 103                             THEFT
# 104                           BATTERY
# 105                DECEPTIVE PRACTICE
# 106                DECEPTIVE PRACTICE
# 107                           BATTERY
# 108                             THEFT
# 109                           BATTERY
# 110                             THEFT
# 111                          BURGLARY
# 112                   CRIMINAL DAMAGE
# 113                           BATTERY
# 114                           BATTERY
# 115                             THEFT
# 116                             THEFT
# 117                           BATTERY
# 118                             THEFT
# 119                DECEPTIVE PRACTICE
# 120                           BATTERY
#
#                                  Description  \
# 100           RESIST/OBSTRUCT/DISARM OFFICER
# 101           HARASSMENT BY ELECTRONIC MEANS
# 102                                   SIMPLE
# 103                           $500 AND UNDER
# 104                                   SIMPLE
# 105  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 106                        CREDIT CARD FRAUD
# 107                  DOMESTIC BATTERY SIMPLE
# 108                           $500 AND UNDER
# 109                  DOMESTIC BATTERY SIMPLE
# 110                           $500 AND UNDER
# 111                           UNLAWFUL ENTRY
# 112                              TO PROPERTY
# 113                                   SIMPLE
# 114                                   SIMPLE
# 115                                OVER $500
# 116                            FROM BUILDING
# 117                  DOMESTIC BATTERY SIMPLE
# 118                            ATTEMPT THEFT
# 119                    ILLEGAL USE CASH CARD
# 120                                   SIMPLE
#
#                                   Location Description Arrest Domestic  ...  \
# 100                                             STREET   True    False  ...
# 101                                          RESIDENCE  False     True  ...
# 102                                 SMALL RETAIL STORE  False    False  ...
# 103                                          RESIDENCE  False    False  ...
# 104                                        HOTEL/MOTEL  False    False  ...
# 105                                              OTHER  False    False  ...
# 106                                   DEPARTMENT STORE  False    False  ...
# 107                                          RESIDENCE  False     True  ...
# 108  VEHICLE - OTHER RIDE SHARE SERVICE (E.G., UBER...  False    False  ...
# 109                                          APARTMENT   True     True  ...
# 110                                   RESIDENCE-GARAGE  False    False  ...
# 111                                              OTHER  False    False  ...
# 112                                          RESIDENCE  False    False  ...
# 113                                           SIDEWALK  False    False  ...
# 114                                          RESIDENCE  False    False  ...
# 115                                   DEPARTMENT STORE  False    False  ...
# 116                                         RESTAURANT  False    False  ...
# 117                                             STREET  False    False  ...
# 118                                   DEPARTMENT STORE  False    False  ...
# 119                                          RESIDENCE  False    False  ...
# 120                                          APARTMENT  False    False  ...
#
#      Ward  Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 100  34.0            72.0        24     1168979.0    1835673.0  2019.0
# 101  21.0            71.0        26     1171392.0    1850870.0  2019.0
# 102  34.0            75.0       08B     1167473.0    1827487.0  2019.0
# 103   6.0            44.0         6           NaN          NaN  2019.0
# 104  27.0             8.0       08B     1173880.0    1906252.0  2019.0
# 105  40.0             4.0        11     1162499.0    1933758.0  2019.0
# 106   4.0            32.0        11     1176576.0    1895067.0  2019.0
# 107  23.0            62.0       08B     1152454.0    1866221.0  2019.0
# 108  30.0            21.0         6     1151321.0    1919701.0  2019.0
# 109  22.0            29.0       08B     1148292.0    1888804.0  2019.0
# 7             CRIMINAL SEXUAL ASSAULT               36
# 8                   CRIMINAL TRESPASS             1425
# 9                  DECEPTIVE PRACTICE             3277
# 10                           GAMBLING               11
# 11                           HOMICIDE                7
# 12                  HUMAN TRAFFICKING                3
# 13   INTERFERENCE WITH PUBLIC OFFICER              288
# 14                       INTIMIDATION               38
# 15                         KIDNAPPING               32
# 16               LIQUOR LAW VIOLATION               42
# 17                MOTOR VEHICLE THEFT             1836
# 18                          NARCOTICS             3175
# 19                       NON-CRIMINAL                1
# 20                          OBSCENITY                8
# 21         OFFENSE INVOLVING CHILDREN              420
# 22                      OTHER OFFENSE             3724
# 23                       PROSTITUTION              131
# 24             PUBLIC PEACE VIOLATION              297
# 25                            ROBBERY             1596
# 26                        SEX OFFENSE              197
# 27                           STALKING               51
# 28                              THEFT            11876
# 29                  WEAPONS VIOLATION             1171

# %%
x , y  = df['Primary Type'] ,  df['Número de casos']
len(x), len(y)
# Out:
# (30, 30)

# %%
#vamos a hacer un gráfico de tot_cases

import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(15,10))
ax = sns.barplot(x,y)
plt.title('Tipos de crímenes')
plt.xticks(rotation = 90)    #esto lo hago para rotar las etiquetas del eje x
ax.set_xticklabels(x)


plt.show
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##Problema 4
# - Leer el dataset country_vaccinations.csv y filtrar los datos para Colombia
# - Crear un csv con los datos para colombia
# - Realizar una comparacion con los paises latinoamericanos de la cantidad de vacunados.
# - A traves de mascaras determinar el numero de vacunados en el intervalo [1.5E6, 2.0E6]

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/hernansalinas/autogrades/main/Laboratorios_Taller/dataset/country_vaccinations.csv')
df
# Out:
#           country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1     Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2     Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3     Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4     Afghanistan      AFG  2021-02-26                 NaN                NaN
# ...           ...      ...         ...                 ...                ...
# 9571     Zimbabwe      ZWE  2021-03-29             81610.0            69751.0
# 9572     Zimbabwe      ZWE  2021-03-30             85866.0            72944.0
# 9573     Zimbabwe      ZWE  2021-03-31             91880.0            76995.0
# 9574     Zimbabwe      ZWE  2021-04-01            105307.0            87791.0
# 9575     Zimbabwe      ZWE  2021-04-02            124753.0           103815.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN              1367.0
# 2                         NaN                     NaN              1367.0
# 3                         NaN                     NaN              1367.0
# 4                         NaN                     NaN              1367.0
# ...                       ...                     ...                 ...
# 9571                  11859.0                  2471.0              5434.0
# 9572                  12922.0                  4256.0              5810.0
# 9573                  14885.0                  6014.0              5712.0
# 9574                  17516.0                 13427.0              6617.0
# 9575                  20938.0                 19446.0              8156.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                           0.00
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 9571                            0.55                           0.47
# 9572                            0.58                           0.49
# 9573                            0.62                           0.52
# 9574                            0.71                           0.59
# 9575                            0.84                           0.70
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                            35.0
# 2                                     NaN                            35.0
# 3                                     NaN                            35.0
# 4                                     NaN                            35.0
# ...                                   ...                             ...
# 9571                                 0.08                           366.0
# 9572                                 0.09                           391.0
# 9573                                 0.10                           384.0
# 9574                                 0.12                           445.0
# 9575                                 0.14                           549.0
#
#                 vaccines                source_name  \
# 0     Oxford/AstraZeneca  Government of Afghanistan
# 1     Oxford/AstraZeneca  Government of Afghanistan
# 2     Oxford/AstraZeneca  Government of Afghanistan
# 3     Oxford/AstraZeneca  Government of Afghanistan
# 1876  Ministry of Health via Universidad de La Sabana
# 1877  Ministry of Health via Universidad de La Sabana
# 1878  Ministry of Health via Universidad de La Sabana
# 1879  Ministry of Health via Universidad de La Sabana
# 1880  Ministry of Health via Universidad de La Sabana
# 1881  Ministry of Health via Universidad de La Sabana
# 1882  Ministry of Health via Universidad de La Sabana
# 1883  Ministry of Health via Universidad de La Sabana
# 1884  Ministry of Health via Universidad de La Sabana
# 1885  Ministry of Health via Universidad de La Sabana
#
#                                          source_website
# 1841  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1842  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1843  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1844  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1845  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1846  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1847  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1848  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1849  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1850  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1851  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1852  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1853  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1854  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1855  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1856  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1857  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1858  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1859  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1860  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1861  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1862  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1863  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1864  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1865  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1866  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1867  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1868  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1869  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1870  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1871  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1872  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1873  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1874  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1875  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1876  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1877  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1878  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1879  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1880  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1881  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1882  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1883  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1884  https://www.minsalud.gov.co/salud/publica/Vacu...
# 1885  https://www.minsalud.gov.co/salud/publica/Vacu...

# %%
#ahora, vamos a crear un csv con los datos para colombia

col_csv = col.to_csv()            #por medio de este método podemos convertir archivos de pandas a csv
col_csv
# Out:
# ',country,iso_code,date,total_vaccinations,people_vaccinated,people_fully_vaccinated,daily_vaccinations_raw,daily_vaccinations,total_vaccinations_per_hundred,people_vaccinated_per_hundred,people_fully_vaccinated_per_hundred,daily_vaccinations_per_million,vaccines,source_name,source_website\n1841,Colombia,COL,2021-02-17,18.0,,,,,0.0,,,,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1842,Colombia,COL,2021-02-18,9935.0,,,9917.0,9917.0,0.02,,,195.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1843,Colombia,COL,2021-02-19,21307.0,,,11372.0,10644.0,0.04,,,209.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1844,Colombia,COL,2021-02-20,33140.0,,,11833.0,11041.0,0.07,,,217.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1845,Colombia,COL,2021-02-21,39827.0,,,6687.0,9952.0,0.08,,,196.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1846,Colombia,COL,2021-02-22,45166.0,,,5339.0,9030.0,0.09,,,177.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1847,Colombia,COL,2021-02-23,48150.0,,,2984.0,8022.0,0.09,,,158.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1848,Colombia,COL,2021-02-24,50524.0,,,2374.0,7215.0,0.1,,,142.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1849,Colombia,COL,2021-02-25,66157.0,,,15633.0,8032.0,0.13,,,158.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1850,Colombia,COL,2021-02-26,81333.0,,,15176.0,8575.0,0.16,,,169.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1851,Colombia,COL,2021-02-27,114042.0,,,32709.0,11557.0,0.22,,,227.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1852,Colombia,COL,2021-02-28,130578.0,,,16536.0,12964.0,0.26,,,255.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1853,Colombia,COL,2021-03-01,149133.0,,,18555.0,14852.0,0.29,,,292.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1854,Colombia,COL,2021-03-02,169619.0,,,20486.0,17353.0,0.33,,,341.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1855,Colombia,COL,2021-03-03,191480.0,,,21861.0,20137.0,0.38,,,396.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1856,Colombia,COL,2021-03-04,206475.0,,,14995.0,20045.0,0.41,,,394.0,"Pfizer/BioNTech, Sinovac",Ministry of Health via Universidad de La Sabana,https://www.minsalud.gov.co/salud/publica/Vacunacion/Paginas/Vacunacion-covid-19.aspx\n1857,Colombia,COL,2021-03-05,239851.0,,,33376.0,22645.0,0.4 ...

# %% [markdown]
# Realizar una comparacion con los paises latinoamericanos de la cantidad de vacunados.

# %%
lat = df[df['country'].isin(['Colombia', 'Brazil', 'México', 'Ecuador', 'Bolivia', 'Paraguay', 'Nicaragua',
                             'Cuba', 'Argentina', 'Venezuela', 'Uruguay', 'Costa Rica', 'Honduras', 'El Salvador',
                             'Haiti', 'Peru', 'Chile', 'Guatemala', 'República Dominicana', 'Panamá', 'Puerto Rico'])]  
lat
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 293   Argentina      ARG  2020-12-29               700.0                NaN
# 294   Argentina      ARG  2020-12-30                 NaN                NaN
# 295   Argentina      ARG  2020-12-31             32013.0                NaN
# 296   Argentina      ARG  2021-01-01                 NaN                NaN
# 297   Argentina      ARG  2021-01-02                 NaN                NaN
# ...         ...      ...         ...                 ...                ...
# 9388  Venezuela      VEN  2021-03-22                 NaN                NaN
# 9389  Venezuela      VEN  2021-03-23                 NaN                NaN
# 9390  Venezuela      VEN  2021-03-24                 NaN                NaN
# 9391  Venezuela      VEN  2021-03-25                 NaN                NaN
# 9392  Venezuela      VEN  2021-03-26             14223.0            14223.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 293                       NaN                     NaN                 NaN
# 294                       NaN                     NaN             15656.0
# 295                       NaN                     NaN             15656.0
# 296                       NaN                     NaN             11070.0
# 297                       NaN                     NaN              8776.0
# ...                       ...                     ...                 ...
# 9388                      NaN                     NaN                92.0
# 9389                      NaN                     NaN                92.0
# 9390                      NaN                     NaN                92.0
# 9391                      NaN                     NaN                92.0
# 9392                      NaN                     NaN                92.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 293                             0.00                            NaN
# 294                              NaN                            NaN
# 295                             0.07                            NaN
# 296                              NaN                            NaN
# 297                              NaN                            NaN
# ...                              ...                            ...
# 9388                             NaN                            NaN
# 9389                             NaN                            NaN
# 9390                             NaN                            NaN
# 9391                             NaN                            NaN
# 9392                            0.05                           0.05
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 293                                   NaN                             NaN
# 294                                   NaN                           346.0
# 295                                   NaN                           346.0
# 296                                   NaN                           245.0
# 297                                   NaN                           194.0
# ...                                   ...                             ...
# 9388                                  NaN                             3.0
# 9389                                  NaN                             3.0
# 9390                                  NaN                             3.0
# 9391                                  NaN                             3.0
# 9392                                  NaN                             3.0
#
#                                               vaccines  \
# 293   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 294   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 295   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 296   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 297   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# ...                                                ...
# 9388                                         Sputnik V
# 9389                                         Sputnik V
# 9390                                         Sputnik V
# 9391                                         Sputnik V
# 9392                                         Sputnik V
#
#                   source_name  \
# 293        Ministry of Health
# 294        Ministry of Health
# 295        Ministry of Health
# 296        Ministry of Health
# 297        Ministry of Health
# ...                       ...
# 9388  Government of Venezuela
# 9389  Government of Venezuela
# 9390  Government of Venezuela
# 9391  Government of Venezuela
# 9392  Government of Venezuela
#
#                                          source_website
# 293   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 294   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 295   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 296   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 297   http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...                                                 ...
# 9388  https://cronica.uno/cinco-semanas-de-vacunacio...
# 9389  https://cronica.uno/cinco-semanas-de-vacunacio...
# 9390  https://cronica.uno/cinco-semanas-de-vacunacio...
# 9391  https://cronica.uno/cinco-semanas-de-vacunacio...
# 9392  https://cronica.uno/cinco-semanas-de-vacunacio...
#
# [821 rows x 15 columns]

# %%
filtro= lat [['country', 'people_vaccinated']]
filtro
# Out:
#         country  people_vaccinated
# 293   Argentina                NaN
# 294   Argentina                NaN
# 295   Argentina                NaN
# 296   Argentina                NaN
# 297   Argentina                NaN
# ...         ...                ...
# 9388  Venezuela                NaN
# 9389  Venezuela                NaN
# 9390  Venezuela                NaN
# 9391  Venezuela                NaN
# 9392  Venezuela            14223.0
#
# [821 rows x 2 columns]

# %%
vacunados= (filtro.groupby('country').sum()).reset_index()
vacunados

#df.groupby('país')['vacunados', 'natalidad'].sum()   #en caso de que quiera sumar los elementos de cada país correspondiente a varias columnas
# Out:
#         country  people_vaccinated
# 0     Argentina         85033946.0
# 1       Bolivia          3991965.0
# 2        Brazil        456495120.0
# 3         Chile        235239384.0
# 4      Colombia         27906580.0
# 5    Costa Rica          1581082.0
# 6       Ecuador          1945600.0
# 7   El Salvador           463843.0
# 8     Guatemala          1660173.0
# 9      Honduras           118744.0
# 10     Paraguay           485329.0
# 11         Peru         18486372.0
# 12      Uruguay         10389390.0
# 13    Venezuela            26574.0

# %%
x= vacunados['country']
y= vacunados['people_vaccinated']


import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(15,10))
ax = sns.barplot(x,y)
plt.title('Personas vacunadas', fontsize = 17)
plt.xticks(rotation = 90, fontsize= 14)    #esto lo hago para rotar las etiquetas del eje x
plt.yticks(fontsize=14)
ax.set_xlabel('country', fontsize= 15)
ax.set_ylabel('Personas vacunadas' ,fontsize= 15)
ax.set_xticklabels(x)


plt.show
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# A traves de mascaras determinar el numero de vacunados en el intervalo [1.5E6, 2.0E6]

# %%
#tenemos en cuenta el siguiente dataframe
tabla_gral= df[['country', 'people_vaccinated']].fillna(0)
gral_sum= tabla_gral.groupby('country').sum().copy()                #necesitamos hacer una copia para que los cambios se vean reflejados
gral_sum
# Out:
#              people_vaccinated
# country
# Afghanistan            62200.0
# Albania                14501.0
# Algeria                    0.0
# Andorra                22243.0
# Angola                272941.0
# ...                        ...
# Uruguay             10389390.0
# Venezuela              26574.0
# Vietnam               805226.0
# Wales               64886323.0
# Zimbabwe             1605837.0
#
# [166 rows x 1 columns]

# %%
#vamos a determinar el numero de vacunados en el intervalo dado

mask = gral_sum['people_vaccinated'].between(1.5e6, 2.0e6)
mask
# Out:
# country
# Afghanistan    False
# Albania        False
# Algeria        False
# Andorra        False
# Angola         False
#                ...
# Uruguay        False
# Venezuela      False
# Vietnam        False
# Wales          False
# Zimbabwe        True
# Name: people_vaccinated, Length: 166, dtype: bool

# %%
#para saber el numero de personas en el rango, usamos el metodo sum

mask.sum()
# Out:
# 10

# %%
#notamos que 10 paises se encuentran entre el rango de vacunados que es pedido

# %%
rango = gral_sum[mask]   #si indexamos el nombre de nuestro dataframe con la mascara que hemos generado, podemos saber los paises que se encuentran en el rango de vacunados que nos piden
rango
# Out:
#             people_vaccinated
# country
# Barbados            1871867.0
# Cambodia            1776455.0
# Costa Rica          1581082.0
# Ecuador             1945600.0
# Gibraltar           1537270.0
# Guatemala           1660173.0
# Luxembourg          1570767.0
# Oman                1870438.0
# Seychelles          1676570.0
# Zimbabwe            1605837.0

# %%
rango['people_vaccinated'].max(), rango[rango['people_vaccinated'] == 1945600.0]
# Out:
# (1945600.0,          people_vaccinated
#  country
#  Ecuador          1945600.0)
