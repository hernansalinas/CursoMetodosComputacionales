# %%
import pandas as pd
import numpy as np

# %%
url="https://docs.google.com/spreadsheets/d/e/2PACX-1vReSbUmOSDL2nSZidldXi-8tQosW1ide_IcYiXwc89L6FVrj5KGKCsuIq5R0lUa9xD83fwZ4TqldEM0/pub?output=csv"

# %%
df=pd.read_csv(url)

# %%
df
# Out:
#      Año                 Nombre  \
# 0   2003    Alexei A. Abrikosov
# 1   2003     Vitaly L. Ginzburg
# 2   2003     Anthony J. Leggett
# 3   2004         David J. Gross
# 4   2004      H. David Politzer
# 5   2004          Frank Wilczek
# 6   2005         Roy J. Glauber
# 7   2005           John L. Hall
# 8   2005      Theodor W. Hänsch
# 9   2006         John C. Mather
# 10  2006        George F. Smoot
# 11  2007            Albert Fert
# 12  2007         Peter Grünberg
# 13  2008         Yoichiro Nambu
# 14  2008       Makoto Kobayashi
# 15  2008      Toshihide Maskawa
# 16  2009         Charles K. Kao
# 17  2009       Willard S. Boyle
# 18  2009        George E. Smith
# 19  2010             Andre Geim
# 20  2010   Konstantin Novoselov
# 21  2011        Saul Perlmutter
# 22  2011       Brian P. Schmidt
# 23  2011          Adam G. Riess
# 24  2012          Serge Haroche
# 25  2012      David J. Wineland
# 26  2013       François Englert
# 27  2013         Peter W. Higgs
# ...

# %%
df=df.rename(columns={"Año":"ano"})

# %%
df.head()
# Out:
#     ano               Nombre  \
# 0  2003  Alexei A. Abrikosov
# 1  2003   Vitaly L. Ginzburg
# 2  2003   Anthony J. Leggett
# 3  2004       David J. Gross
# 4  2004    H. David Politzer
#
#                                               Motivo
# 0  Por sus contribuciones pioneras a la teoría de...
# 1  Por sus contribuciones pioneras a la teoría de...
# 2  Por sus contribuciones pioneras a la teoría de...
# 3  Por el descubrimiento de la libertad asintótic...
# 4  Por el descubrimiento de la libertad asintótic...

# %%
tf=df.ano>2010
df[tf]
# Out:
#      ano                 Nombre  \
# 21  2011        Saul Perlmutter
# 22  2011       Brian P. Schmidt
# 23  2011          Adam G. Riess
# 24  2012          Serge Haroche
# 25  2012      David J. Wineland
# 26  2013       François Englert
# 27  2013         Peter W. Higgs
# 28  2014          Isamu Akasaki
# 29  2014          Hiroshi Amano
# 30  2014         Shuji Nakamura
# 31  2015         Takaaki Kajita
# 32  2015     Arthur B. McDonald
# 33  2016      David J. Thouless
# 34  2016   F. Duncan M. Haldane
# 35  2016  J. Michael Kosterlitz
# 36  2017           Rainer Weiss
# 37  2017        Barry C. Barish
# 38  2017          Kip S. Thorne
# 39  2018          Arthur Ashkin
# 40  2018          Gérard Mourou
# 41  2018       Donna Strickland
# 42  2019          James Peebles
# 43  2019           Michel Mayor
# 44  2019          Didier Queloz
# 45  2020          Roger Penrose
# 46  2020        Reinhard Genzel
# 47  2020         Andrea M. Ghez
# 48  2021         Syukuro Manabe
# ...

# %%
tf=((df.ano>2010) & (df.ano<2015))
df1=df[tf].copy()
df1.reset_index()
# Out:
#    index   ano             Nombre  \
# 0     21  2011    Saul Perlmutter
# 1     22  2011   Brian P. Schmidt
# 2     23  2011      Adam G. Riess
# 3     24  2012      Serge Haroche
# 4     25  2012  David J. Wineland
# 5     26  2013   François Englert
# 6     27  2013     Peter W. Higgs
# 7     28  2014      Isamu Akasaki
# 8     29  2014      Hiroshi Amano
# 9     30  2014     Shuji Nakamura
#
#                                               Motivo
# 0  Por el descubrimiento de la expansión acelerad...
# 1  Por el descubrimiento de la expansión acelerad...
# 2  Por el descubrimiento de la expansión acelerad...
# 3  Por métodos experimentales innovadores que per...
# 4  Por métodos experimentales innovadores que per...
# 5  Por el descubrimiento teórico del mecanismo qu...
# 6  Por el descubrimiento teórico del mecanismo qu...
# 7  Por la invención de los diodos emisores de luz...
# 8  Por la invención de los diodos emisores de luz...
# ...

# %%
df1.ano.unique()
# Out:
# array([2011, 2012, 2013, 2014])

# %%
df1.to_excel("premiosNobeldesde2010.xlsx")
# !pwd
# Out:
# /content

# %%
x=np.random.random(100)
y=np.random.random(100)

# %%
x=np.random.normal(5, 0.2, 1000)
y=np.random.normal(5, 0.2, 1000)
dicc={"x":x, "y":y}
df=pd.DataFrame(dicc)

# %%
df
# Out:
#             x         y
# 0    5.057830  5.213914
# 1    4.983712  4.958858
# 2    4.959564  4.943346
# 3    5.303917  4.828782
# 4    5.027319  4.821007
# ..        ...       ...
# 995  4.781423  4.974218
# 996  5.155646  4.933328
# 997  4.858090  4.874126
# 998  4.953942  4.973508
# 999  5.033128  5.067230
#
# [1000 rows x 2 columns]

# %%
df["suma"]=df.x+df.y

# %%
df["diff_y"]=df.y.diff(4)

# %%
df
# Out:
#             x         y       suma    diff_y
# 0    5.057830  5.213914  10.271745       NaN
# 1    4.983712  4.958858   9.942570       NaN
# 2    4.959564  4.943346   9.902909       NaN
# 3    5.303917  4.828782  10.132699       NaN
# 4    5.027319  4.821007   9.848326 -0.392907
# ..        ...       ...        ...       ...
# 995  4.781423  4.974218   9.755641  0.335487
# 996  5.155646  4.933328  10.088974  0.159956
# 997  4.858090  4.874126   9.732216 -0.217549
# 998  4.953942  4.973508   9.927450 -0.266327
# 999  5.033128  5.067230  10.100359  0.093012
#
# [1000 rows x 4 columns]

# %%
df.x.sum()
# Out:
# 4988.861085904261

# %%
df.x.mean()
# Out:
# 4.988861085904261

# %%
df.x.std()
# Out:
# 0.20212939992111972
