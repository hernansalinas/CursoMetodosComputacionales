# %%
import numpy as np
import math
R=float(input("rapidez inicial: "))
theta=float(input("ángulo en radianes: "))
x0= float(input("distancia donde tira el jugador: "))

g=-9.8
rx=0
ry0=2
v0x= R *np.cos(theta)
v0y= R * np.sin(theta)


def balonY(t):
  return  ry0 + v0y*t+(g*(t**2))/2

def balonX(t):
  return  x0 + v0x*t
# Out:
# rapidez inicial: 19.98
# ángulo en radianes: 1
# distancia donde tira el jugador: -36

# %%
import matplotlib.pyplot  as plt
import numpy as np

tiempos = np.linspace(0,5,10)


x = balonX(tiempos)
y = balonY(tiempos)

x1=0
y1=3.01

plt.plot(x1,y1)
plt.scatter(x1, y1, color='blue', label='Punto')
# Graficar el punto
plt.scatter(x, y, label='Punto')

plt.plot(x,y)

plt.xlabel("balon en eje x [m]")
plt.ylabel("balon en eje y [m]")
for i in distancias_lista:
  if (abs(i-3)<0.05).any():
    print("Encestó")
  else: print("No encestó")
# Out:
# Text(0, 0.5, 'balon en eje y [m]')

# %%
import matplotlib.pyplot  as plt
import numpy as np
distancias_lista=[]
def balonY(distancias):
    t=distancias/v0x
    altura = ry0 + v0y*t+(g*(t**2))/2
    distancias_lista.append(altura)
    return altura
x0= -36.05

R=19.89

theta=1
g=-9.8
rx=0
ry0=2
v0x= R *np.cos(theta)
v0y= R * np.sin(theta)
x1=0
y1=3.01

plt.plot(x1,y1)
plt.scatter(x1, y1, color='blue', label='Punto')

x0s= np.linspace(-60,60, 100)
y = balonY(x0s)

plt.plot(x0s,y)

plt.xlabel("balon en eje x [m]")
plt.ylabel("balon en eje y [m]")
e=1
for i in distancias_lista:
  if (abs(i-3)<0.05).any():
    print("Encestó")
  else: print("No encestó")
# Out:
# no encestó

# %%
# Out:
# no

# %%
D= 997 #densidad del agua kg/m³
g= -9.8 #m/s2
Pa =  101.325
def presion(y):
    return Pa + (D*g*y)
print(presion(-30))
y= np.linspace(0,-30, 10)
presion = presion(y)

plt.figure(figsize=(20,4))
plt.plot(y,presion,"o-", label="presión atmosferica en la distancia maxima es 2.9atm")
plt.xlabel("", fontsize=15)
plt.ylabel("presion", fontsize=10)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title("presiones")
plt.legend()
plt.show()
# Out:
# 293219.325
