# %% [markdown]
# #Actividad 2 : Librerías y modelamiento básico#

# %% [markdown]
# # Actividad 02: Librerias y modelamiento básico
#
# ### Profesor: Juan Marcos Marín Ramírez
# #### Métodos Computacionales 2024-2
# ---
# 1. Una persona conduce una moto con rapidez constante $v_m$, mientras que un policia lo hace con aceleración constante $a_p$ (iniciando desde el reposo). Suponga que ambos movimientos inician en $t=0$, haga una gráfica para el movimiento de la moto y del policia, donde el usuario ingrese la velocidad (moto) y aceleración (policia). Además determine el instante $t$ en el cual se encuentran ambos. Ambos movimientos iniciarán en $x_i = 0$
#
# **Pruebe**: para $v_m$ = 15m/s y $a_p$ = 3 m/s², el tiempo deberia ser 10 s
#
#
# $$x_f = x_i + v_m\cdot t$$
# $$x_f = x_i + v_o\cdot t + \frac{1}{2}a_p\cdot t^2$$
# ---
#
# 2. El potencial Lennard-Jones es un modelo simple que aproxima la interacción entre un par de moléculas neutras. Este está definido como:
#
# $$
# V(r) = 4\epsilon \left[ \left( \frac{\sigma}{r} \right)^{12} - \left( \frac{\sigma}{r} \right)^{6} \right]
# $$
#
# Donde:
# - $ V(r) $ es el potencial en función de la distancia interatómica $ r $.
# - $ \epsilon $ es la profundidad del pozo de potencial, es decir, la energía mínima que describe la interacción entre dos partículas.
# - $ \sigma $ es la distancia a la cual el potencial es cero, también conocido como el parámetro de distancia.
# - $ r $ es la distancia entre las dos partículas.
#
# a. Escriba una función para encontrar modelar el potencial LJ.
#
#
# b. Usando $\sigma = \epsilon = 1$ demuestre que la distancia de equilibrio $r_m$ es aproximadamente $r_m = 2^{2/16}\sigma$. Para esto realice un gráfico del potencial, especificando los ejes. Trunque la serie en $r_c = 2.5\sigma$.
#
#
# c. Verifique que $r_m = 2^{2/16}\sigma$ se cumple para diferentes valores de $\sigma$, dejando $\epsilon$ constante.
#
#
# ---
# 3.  El siguiente código exporta tablas html de sitios web
#
# ```python
# import pandas as pd
#
# # Dataset 1
# # URL of the webpage
# url = "https://worldpopulationreview.com/country-rankings/average-height-by-country"
#
# # Read the HTML content
# html_content = pd.read_html(url)
#
# alturas = html_content[2]
#
# # Dataset 2
# # URL of the webpage
# url = "https://worldpopulationreview.com/country-rankings/average-net-worth-by-country"
#
# # Read the HTML content
# html_content = pd.read_html(url)
#
# income = html_content[0]
# ````
#
# El primer dataset muestra las alturas medias de niñ@s de 5, 10, 15 y 19 años.
#
# a. Limpie los datos, eliminando columnas en *(in)* y cambie todos los nombres al español.
#
#
# b. Realice un gráfico de barras, donde se muestre una comparación de la estatura media para niños y niñas en ambas categorias. Esto para los primeros 10 paises con mayor y menor altura, además agregue a Colombia.
#
# c. ¿Existirá una relación entre la riqueza y la altura? Usando el dataset `income`, haga un merge con el dataset `alturas`. Ahora, empleando los datos de altura para los 10 mayores (19 años) y 10 menores (19 años). Realice un gráfico donde relacione la altura media con el GDP y concluya si existe alguna relación.

# %% [markdown]
# ##1##

# %%
#1#

import matplotlib.pyplot as plt
import numpy as np

v = int(input(print("Ingrese la velocidad de la moto")))
a = int(input(print("Ingrese la aceleración del policía")))
t_encuentro = int((2*v)/a)
t = np.linspace(0,t_encuentro+(0.2*t_encuentro))

#Datos Moto#
xm = v*t

#Datos Policía#
xp = (0.5*a)*(t**2)

#Datos gráfico#
plt.plot(t,xm,'ro-',label="Posición Moto")
plt.plot(t,xp,'bo-',label="Posición Policía")
plt.xlabel("Tiempo (s)")
plt.ylabel("Posición (m)")
plt.legend()
plt.grid()
plt.show()

print("Ambos se encuentran en el segundo ",t_encuentro)
# Out:
# Ingrese la velocidad de la moto
# None5
# Ingrese la aceleración del policía
# None5
# Ambos se encuentran en el segundo  2

# %% [markdown]
# ##2##

# %%
5#2.a#

import numpy as np
import matplotlib.pyplot as plt

def potencial_LJ(r, epsilon, sigma):
  potencial = 4*epsilon*((sigma/r)**12 - (sigma/r)**6)
  return potencial

r = float(input(print("Ingrese un valor para r")))
epsilon = float(input(print("Ingrese un valor para epsilon")))
sigma = float(input(print("Ingrese un valor para sigma")))
respuesta = potencial_LJ(r, epsilon, sigma)
print(respuesta)
# Out:
# Ingrese un valor para r
# Ingrese un valor para epsilon
# Ingrese un valor para sigma
# None0.2
# -0.0032633782272000014

# %%
 #2.b#

sigma = 1.0
epsilon = 1.0
rc = 2.5*sigma
r = np.linspace(0.9*sigma,rc,500)

potencial = potencial_LJ(r, epsilon, sigma)


plt.plot(r,potencial,label='Potencial LJ')
plt.axvline(x=2**(2/16)*sigma, color='red',linestyle='--',label='$r_m = 2^{2/16} \sigma$')
plt.axhline(y=0, color='black',linestyle='--')
plt.title("Potencial Lennard-Jones en función del radio")
plt.xlabel("Distancia interatómica ($\sigma$)")
plt.ylabel("Potencial $V(r)$")
plt.legend()
plt.grid(True)
plt.show()

# %%
#2.c#

epsilon = 1.0
sigmas = [1.0,1.05,1.1,1.15]
rc = 2.5 * max(sigmas)
r = np.linspace(0.9*min(sigmas),rc,500)

for sigma in sigmas:
  potencial = potencial_LJ(r,epsilon,sigma)
  plt.plot(r,potencial, label=f"$\sigma$ = {sigma}")

plt.axvline(x=2**(2/16)*sigma, color='red',linestyle='--',label='$r_m = 2^{2/16} \sigma$')
plt.axhline(y=0, color='black',linestyle='--')
plt.xlabel(r'Distancia interatómica ($\sigma$)')
plt.ylabel(r'Potencial V(r)')
plt.title('Potencial de Lennard-Jones para diferentes valores de $\sigma$', fontsize=14)
plt.legend()
plt.grid(True)

# %% [markdown]
# ##3##

# %%
#3#

import pandas as pd

# Dataset 1
# URL of the webpage
url = "https://worldpopulationreview.com/country-rankings/average-height-by-country"

# Read the HTML content
html_content = pd.read_html(url)

alturas = html_content[2]

# Dataset 2
# URL of the webpage
url = "https://worldpopulationreview.com/country-rankings/average-net-worth-by-country"

# Read the HTML content
html_content = pd.read_html(url)

income = html_content[0]

print(alturas)
# Out:
#                     Country  Average Height, Boys, 19 yo (cm)  Girls 19 (cm)  \
# 0               Netherlands                            183.78         170.36
# 1                Montenegro                            183.30         169.96
# 2                   Estonia                            182.79         168.66
# 3    Bosnia and Herzegovina                            182.47         167.47
# 4                   Iceland                            182.10         168.91
# ..                      ...                               ...            ...
# 191        Papua New Guinea                            163.10         156.89
# 192         Solomon Islands                            163.07         156.79
# 193                    Laos                            162.78         153.10
# 194             Timor Leste                            160.13         152.71
# 195                   Total                            171.37         159.15
#
# ...

# %% [markdown]
# ###3.a###
#
# Limpie los datos, eliminando columnas en (in) y cambie todos los nombres al español

# %%
df = pd.DataFrame(alturas)

datos_limpios = df.drop(columns = ["Boys 19 (in)", "Girls 19 (in)"])

print(datos_limpios)
# Out:
#                     Country  Average Height, Boys, 19 yo (cm)  Girls 19 (cm)  \
# 0               Netherlands                            183.78         170.36
# 1                Montenegro                            183.30         169.96
# 2                   Estonia                            182.79         168.66
# 3    Bosnia and Herzegovina                            182.47         167.47
# 4                   Iceland                            182.10         168.91
# ..                      ...                               ...            ...
# 191        Papua New Guinea                            163.10         156.89
# 192         Solomon Islands                            163.07         156.79
# 193                    Laos                            162.78         153.10
# 194             Timor Leste                            160.13         152.71
# 195                   Total                            171.37         159.15
#
# ...

# %%
datos_limpios
# Out:
#                     Country  Average Height, Boys, 19 yo (cm)  Girls 19 (cm)  \
# 0               Netherlands                            183.78         170.36
# 1                Montenegro                            183.30         169.96
# 2                   Estonia                            182.79         168.66
# 3    Bosnia and Herzegovina                            182.47         167.47
# 4                   Iceland                            182.10         168.91
# ..                      ...                               ...            ...
# 191        Papua New Guinea                            163.10         156.89
# 192         Solomon Islands                            163.07         156.79
# 193                    Laos                            162.78         153.10
# 194             Timor Leste                            160.13         152.71
# 195                   Total                            171.37         159.15
#
# ...

# %%
datos_limpios.rename(columns = {'Country':'País',
                                'Average Height, Boys, 19 yo (cm)': 'Estatura media, niños, 19 años (cm)',
                                'Girls 19 (cm)': 'Niñas, 19 años (cm)',
                                'Boys 15 (cm)': 'Niños, 15 años (cm)',
                                'Girls 15 (cm)': 'Niñas, 15 años (cm)',
                                'Boys 10 (cm)': 'Niños, 10 años (cm)',
                                'Girls 10 (cm)': 'Niñas, 10 años (cm)',
                                'Boys 5 (cm)': 'Niños, 5 años (cm)',
                                'Girls 5 (cm)': 'Niñas, 5 años (cm)'}, inplace = True)

# %%
datos_limpios
# Out:
#                        País  Estatura media, niños, 19 años (cm)  \
# 0               Netherlands                               183.78
# 1                Montenegro                               183.30
# 2                   Estonia                               182.79
# 3    Bosnia and Herzegovina                               182.47
# 4                   Iceland                               182.10
# ..                      ...                                  ...
# 191        Papua New Guinea                               163.10
# 192         Solomon Islands                               163.07
# 193                    Laos                               162.78
# 194             Timor Leste                               160.13
# 195                   Total                               171.37
#
#      Niñas, 19 años (cm)  Niños, 15 años (cm)  Niñas, 15 años (cm)  \
# 0                 170.36               177.20               167.45
# ...

# %% [markdown]
# ###3.b###
# Realice un gráfico de barras, donde se muestre una comparación de la estatura media para niños y niñas en ambas categorias. Esto para los primeros 10 paises con mayor y menor altura, además agregue a Colombia.

# %%
colombia = datos_limpios[datos_limpios['País'] == 'Colombia']

muestra1 = pd.concat([datos_limpios.head(10), colombia])
muestra1.plot(kind = 'bar', x='País', y = ['Estatura media, niños, 19 años (cm)','Niñas, 19 años (cm)'])
plt.title('Altura media de niños y niñas en los primeros 10 países + Colombia')
plt.xlabel('País')
plt.ylabel('Altura (cm)')
plt.show()

muestra2 = pd.concat([datos_limpios.tail(10),colombia])
muestra2.plot(kind = 'bar', x='País', y = ['Estatura media, niños, 19 años (cm)','Niñas, 19 años (cm)'])
plt.title('Altura media de niños y niñas en los últimos 10 países + Colombia')
plt.xlabel('País')
plt.ylabel('Altura (cm)')
plt.show()

# %% [markdown]
# ###3.c###
#  ¿Existirá una relación entre la riqueza y la altura? Usando el dataset income, haga un merge con el dataset alturas. Ahora, empleando los datos de altura para los 10 mayores (19 años) y 10 menores (19 años). Realice un gráfico donde relacione la altura media con el GDP y concluya si existe alguna relación.

# %%
df2 = pd.DataFrame(income)
datos_limpios2 = df2.dropna()

datos_limpios2.rename(columns={'Country':'País', 'Total Wealth (billions USD)':'PIB Total (miles de millones de dólares)'}, inplace = True)
# Out:
# <ipython-input-27-063bd57d54f1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_limpios2.rename(columns={'Country':'País', 'Total Wealth (billions USD)':'PIB Total (miles de millones de dólares)'}, inplace = True)

# %%
df_merge = pd.merge(datos_limpios, datos_limpios2, on='País')
df_merge
# Out:
#                        País  Estatura media, niños, 19 años (cm)  \
# 0               Netherlands                               183.78
# 1                Montenegro                               183.30
# 2                   Estonia                               182.79
# 3    Bosnia and Herzegovina                               182.47
# 4                   Iceland                               182.10
# ..                      ...                                  ...
# 161              Mozambique                               164.30
# 162        Papua New Guinea                               163.10
# 163         Solomon Islands                               163.07
# 164                    Laos                               162.78
# 165             Timor Leste                               160.13
#
#      Niñas, 19 años (cm)  Niños, 15 años (cm)  Niñas, 15 años (cm)  \
# 0                 170.36               177.20               167.45
# ...

# %%
top10 = df_merge.head(10)
last10 = df_merge.tail(10)

df_combinados = pd.concat([top10, last10])
df_combinados
# Out:
#                        País  Estatura media, niños, 19 años (cm)  \
# 0               Netherlands                               183.78
# 1                Montenegro                               183.30
# 2                   Estonia                               182.79
# 3    Bosnia and Herzegovina                               182.47
# 4                   Iceland                               182.10
# 5                   Denmark                               181.89
# 6            Czech Republic                               181.19
# 7                    Latvia                               181.17
# 8                  Slovakia                               181.02
# 9                   Ukraine                               180.98
# 156             Philippines                               165.23
# 157              Madagascar                               165.16
# 158              Bangladesh                               165.08
# ...

# %%
plt.scatter(df_combinados['Estatura media, niños, 19 años (cm)'], df_combinados['PIB Total (miles de millones de dólares)'], color='b', label='Niños')
plt.scatter(df_combinados['Niñas, 19 años (cm)'], df_combinados['PIB Total (miles de millones de dólares)'], color='r', label='Niñas')
plt.title("Relación entre altura media a los 19 años y PIB")
plt.xlabel("Altura media (cm)")
plt.ylabel("PIB (miles de millones de dólares)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Se evidencia una clara tendencia de la altura media a aumentar en países con mayores PIB.
