# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab04_pandas_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas y chat gpt
#
# Comandos basicos de pandas:
#
#
# | Function | Description |
# | --- | --- |
# | `fillna()` | Replace NaN values in a DataFrame or Series with a specified value. |
# | `dropna()` | Remove rows or columns containing NaN values from a DataFrame. |
# | `loc[]` | Select rows and columns from a DataFrame by label-based indexing. |
# | `iloc[]` | Select rows and columns from a DataFrame by integer-based indexing. |
# | `[]` | Select a single column from a DataFrame using dot notation or bracket notation. |
# | `shape` | Get the number of rows and columns in a DataFrame. |
# | `dtypes` | Get the data types of the columns in a DataFrame. |
# | `head()` | Get the first n rows of a DataFrame. |
# | `tail()` | Get the last n rows of a DataFrame. |
# | `describe()` | Get summary statistics for the columns in a DataFrame. |
# | `groupby()` | Group a DataFrame by one or more columns and perform an aggregation. |
# | `sort_values()` | Sort a DataFrame by one or more columns. |
# | `merge()` | Merge two DataFrames on a common column. |
# | `pivot_table()` | Create a pivot table from a DataFrame. |
# | `to_csv()` | Save a DataFrame to a CSV file. |
# | `read_csv()` | Read a CSV file into a DataFrame. |
#
#
#
#
#
# # Problema 1
# 1. a) Generar un diccionario con CHATGPT con los premios nobel de fisica de la decada que tu elijas.  El diccionario debe tener la siguiente estructura:
#
# clave: Nombre del cientifico, el nombre del cientifico se debe llamar de la siguiente forma: Inicial del nombre del cientifico y Apellido, ejemplo: A. Einstein., R. Feyman.
#
# Valor: diccionario con el año y el motivo por que el gano el premio nobel resumido maximo 10 palabras.
#
#
# b). Con el diccionario construir un dataframe de pandas y almacenarlo como un archivo csv. Las columnas del data frame se deberán llamar Cientifico, AnoNobel, Motivo.

# %%
#Primer Punto: Generar el diccionario con chatgpt. (Década del 1900)
import pandas as pd
premiosNobel = {
    'W. Röntgen': {
        'año': 1901,
        'motivo': 'Por el descubrimiento de los rayos X, el cual ha sido de gran importancia para el desarrollo de la física y la medicina'
    },
    'H. Lorentz': {
        'año': 1902,
        'motivo': 'Por sus investigaciones sobre la influencia de los campos eléctricos y magnéticos en la radiación, lo que condujo a importantes avances en la teoría electromagnética'
    },
    'P. Zeeman': {
        'año': 1902,
        'motivo': 'Por el descubrimiento del efecto Zeeman, que demuestra la división de ciertas líneas espectrales bajo la influencia de un campo magnético'
    },
    'A. Becquerel': {
        'año': 1903,
        'motivo': 'Por el descubrimiento de la radiactividad natural'
    },
    'M. Curie': {
        'año': 1903,
        'motivo': 'En reconocimiento a sus estudios sobre la radioactividad descubierta por Becquerel, así como por su aislamiento de los elementos radio y polonio'
    },
    'H. Becquerel': {
        'año': 1903,
        'motivo': 'Por su descubrimiento de la radiactividad natural'
    },
    'Lord Rayleigh': {
        'año': 1904,
        'motivo': 'Por su investigación sobre la densidad de los gases y el descubrimiento del gas argón'
    },
    'J. Strutt (Lord Rayleigh)': {
        'año': 1904,
        'motivo': 'Por su investigación sobre la densidad de los gases y el descubrimiento del gas argón'
    },
    'P. Lenard': {
        'año': 1905,
        'motivo': 'Por sus investigaciones sobre los rayos catódicos, que condujeron a importantes avances en la comprensión de la naturaleza de la radiación'
    },
    'J.J. Thomson': {
        'año': 1906,
        'motivo': 'Por sus investigaciones sobre la conducción eléctrica en gases, así como por el descubrimiento del electrón'
    },
    'A.A. Michelson': {
        'año': 1907,
        'motivo': 'Por su precisión en la medición de la velocidad de la luz, lo que condujo a importantes avances en la teoría de la relatividad de Einstein'
    },
    'A. Einstein': {
        'año': 1905,
        'motivo': 'Por sus servicios a la física teórica, y en particular por su descubrimiento de la ley del efecto fotoeléctrico'
    },
    'G.L. Michelson': {
        'año': 1907,
        'motivo': 'Por su precisión en la medición de la velocidad de la luz, lo que condujo a importantes avances en la teoría de la relatividad de Einstein'
    }}

#Construir un dataframe con el diccionario.
df = pd.DataFrame(premiosNobel)
#Ojo al crear un dataframe a partir de otro, ambos apuntan a la misma posicion de memoria.
g = df.transpose().reset_index().copy()
#Cambiamos el nombre de la columna
g = g.rename(columns= {'index':'Cientifico','año':'AnoNobel','motivo':'Motivo'})
g
#EN data science se habla de registros, no de filas.
# Out:
#                    Cientifico AnoNobel  \
# 0                  W. Röntgen     1901
# 1                  H. Lorentz     1902
# 2                   P. Zeeman     1902
# 3                A. Becquerel     1903
# 4                    M. Curie     1903
# 5                H. Becquerel     1903
# 6               Lord Rayleigh     1904
# 7   J. Strutt (Lord Rayleigh)     1904
# 8                   P. Lenard     1905
# 9                J.J. Thomson     1906
# 10             A.A. Michelson     1907
# 11                A. Einstein     1905
# 12             G.L. Michelson     1907
#
#                                                Motivo
# 0   Por el descubrimiento de los rayos X, el cual ...
# 1   Por sus investigaciones sobre la influencia de...
# 2   Por el descubrimiento del efecto Zeeman, que d...
# 3   Por el descubrimiento de la radiactividad natural
# 4   En reconocimiento a sus estudios sobre la radi...
# 5   Por su descubrimiento de la radiactividad natural
# 6   Por su investigación sobre la densidad de los ...
# 7   Por su investigación sobre la densidad de los ...
# 8   Por sus investigaciones sobre los rayos catódi...
# 9   Por sus investigaciones sobre la conducción el...
# 10  Por su precisión en la medición de la velocida...
# 11  Por sus servicios a la física teórica, y en pa...
# 12  Por su precisión en la medición de la velocida...

# %% [markdown]
# #Problema 2.
#
# Usando el dataset `PS4_1.csv`, convertir la serie `Date` en el indice (serie de tiempo) y eliminar la serie `Unnamed: 1` (generado por pandas), retornar un  diccionario con en el siguiente orden:
#
# * cantidad de columnas
# * Nombre de las columnas
# * número de registros no NaN de cada columna
# * cantidad total de memoria usada para cargar el dataset en el computador ,( df.memory_usage() )
# * Estadistica basica para cada columna, media, desviacion estandar, maximo
# * Remplazar los NaN por None
#
#
# ```
# import pandas as pd
#
# df = pd.read_excel("dataset/PS4_1.xlsx")
# for d in df.Date:
#     if(type(d)==str):
#         df["Date_"] = datetime.strptime(d, "%d/%m/%Y")
#     else:
#         df["Date_"]=d
# df=df.set_index("Date_")
# df=df.drop(columns=["Date","Unnamed: 1"])
#
# ```

# %%
#Tomemos el link del excel desde drive.
import pandas as pd
url ='https://docs.google.com/spreadsheets/d/e/2PACX-1vQMfRjGspVzFho_P7HOFHaw0FaePpqM_ZBa5RC8uCwTuJRtPmkJ2uSgRUEpFrP9OQ/pub?output=xlsx'
df = pd.read_excel(url)
#Cambiemos la primera columna a datetime
from datetime import datetime
for d in df.Date:
    if(type(d)==str):
        df["Date_"] = datetime.strptime(d, "%d/%m/%Y")
    else:
        df["Date_"]=d
df=df.set_index("Date_")
#Borremos la columna unnamed
df=df.drop(columns=["Date","Unnamed: 1"])
df
# Out:
#             Berri1  Maisonneuve_1  Maisonneuve_2  Brebeuf
# Date_
# 2009-12-31    29.0           20.0           35.0      NaN
# 2009-12-31    19.0            3.0           22.0      NaN
# 2009-12-31    24.0           12.0           22.0      NaN
# 2009-12-31    24.0            8.0           15.0      NaN
# 2009-12-31   120.0          111.0          141.0      NaN
# ...            ...            ...            ...      ...
# 2009-12-31    66.0           29.0           52.0      0.0
# 2009-12-31    61.0           41.0           99.0      0.0
# 2009-12-31    89.0           52.0          115.0      0.0
# 2009-12-31    76.0           43.0          115.0      0.0
# 2009-12-31    53.0           46.0          112.0      0.0
#
# [365 rows x 4 columns]

# %%
infoDataframe = {}
#Cantidad de columnas.
infoDataframe['Cantidad Columnas'] = df.shape[1]
#Nombre de las columnas.
infoDataframe['Nombre Columnas'] = ', '.join(df.columns)
#Veamos la cantidad de registros no nan por cada columna.
cuentaColumna = []
for col in df.columns:
    nonan = df[col].count()
    col_count_str = f"{col}: {nonan}"
    cuentaColumna.append(col_count_str)
cadena = ", ".join(cuentaColumna)
infoDataframe['Registro no NAN'] = cadena
#Cantidad de memoria usada
infoDataframe['Memoria Usada'] = df.memory_usage()
#Estadistica básica
media = df.mean()
desviacion = df.std()
maximo = df.max(axis=0)
cadenaEst = ''
for i in range(df.shape[1]-1):
  cadenaEst += f' media col {i}: ' + str(media[i]) + f' desviación col {i}: ' + str(desviacion[i]) + f' maximo {i}:  '+ str(maximo[i])
infoDataframe['Estadistica'] =  cadenaEst
#Finalmente reemplazamos todos los valores NAN por un 'None'.
df.fillna(value='None', inplace= True)
#Veamos el diccionario
infoDataframe
# Out:
# {'Cantidad Columnas': 4,
#  'Nombre Columnas': 'Berri1, Maisonneuve_1, Maisonneuve_2, Brebeuf',
#  'Registro no NAN': 'Berri1: 365, Maisonneuve_1: 365, Maisonneuve_2: 365, Brebeuf: 178',
#  'Memoria Usada': Index            2920
#  Berri1           2920
#  Maisonneuve_1    2920
#  Maisonneuve_2    2920
#  Brebeuf          2920
#  dtype: int64,
#  'Estadistica': ' media col 0: 2032.2 desviación col 0: 1878.8797986572208 maximo 0:  6626.0 media col 1: 1060.2520547945205 desviación col 1: 1079.5330858971347 maximo 1:  4242.0 media col 2: 2093.1698630136984 desviación col 2: 1854.368523087829 maximo 2:  6587.0'}

# %% [markdown]
# #Problema 3
#
# Realizar la lectura del data frame "Crimes_-_2019.csv" asociado a los crimenes que se presentaron en Chicago en el 2019.
#
#
# 1. Ver la estadistica general del data frame.
# 2. Elimnar  las columnas PrimaryType, y Date.
# 3. Transformar la columna Date que es tipo string en una tipo Fecha, use el siguiente metodo de pandas pd.to_datetime(df.Date,format="%m/%d/%Y %I:%M:%S %p")
# 4. Mostrar los casos totales para cada tipo de crimen de forma ascendente, emplee:
#    df.groupby(columna).Date.count()
#
#    sort_values()
# 5. Ordenar los valores por orden alfabetico de Primary type
# 6. Mostrar de la fila 100 a la 120
# 6. Realizar una visualización de los datos anteriores.Emplee la libreria  seaborn con un grafico tipo barplot. Ej.
#    ax = sns.barplot(x = "contador", y="Primary Type", data = datos)

# %%
#Leeamos el archivo.
import pandas as pd
url = 'https://raw.githubusercontent.com/hernansalinas/autogrades/main/Laboratorios_Taller/dataset/Crimes_-_2019.csv'
df = pd.read_csv(url)

# %%
#1. Veamos la estadística general del dataframe
media = df.mean();
desviacion = df.std();
maximo = df.max(axis=None);
print(f'media: {media}, desviacion: {desviacion}, máximo: {maximo}');
# Out:
# media: ID                1.162834e+07
# Arrest            2.263646e-01
# Domestic          1.698379e-01
# Beat              1.133671e+03
# District          1.110853e+01
# Ward              2.329876e+01
# Community Area    3.657346e+01
# X Coordinate      1.165086e+06
# Y Coordinate      1.886367e+06
# Year              2.019000e+03
# Latitude          4.184378e+01
# Longitude        -8.766970e+01
# dtype: float64, desviacion: ID                153156.862507
# Arrest                 0.418482
# Domestic               0.375494
# Beat                 697.737805
# District               6.967977
# Ward                  13.895214
# Community Area        21.277600
# X Coordinate       16041.239625
# Y Coordinate       30967.967260
# Year                   0.000000
# Latitude               0.085163
# Longitude              0.058401
# dtype: float64, máximo: ID                12249393.0
# Arrest                  True
# Domestic                True
# Beat                  2535.0
# District                25.0
# Ward                    50.0
# Community Area          77.0
# X Coordinate       1205114.0
# Y Coordinate       1951495.0
# Year                  2019.0
# Latitude           42.022535
# Longitude         -87.524616
# dtype: object
# <ipython-input-152-aee1185875c7>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   media = df.mean();
# <ipython-input-152-aee1185875c7>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   desviacion = df.std();
# <ipython-input-152-aee1185875c7>:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   maximo = df.max(axis=None);

# %%
#2. Eliminar las columnas primary type y date
dfSinDate = df.drop(columns=["Date", "Primary Type"], inplace= False)
dfSinDate
# Out:
#                ID Case Number                 Block  IUCR  \
# 0      11864018.0    JC476123  022XX S MICHIGAN AVE  1154
# 1      11859805.0    JC471592   024XX W CHICAGO AVE   860
# 2      11863808.0    JC476236     0000X N LOOMIS ST   810
# 3      11859727.0    JC471542    016XX W ADDISON ST  1320
# 4      11859656.0    JC471240      051XX N BROADWAY   560
# ...           ...         ...                   ...   ...
# 70990         NaN         NaN                   NaN   NaN
# 70991         NaN         NaN                   NaN   NaN
# 70992         NaN         NaN                   NaN   NaN
# 70993         NaN         NaN                   NaN   NaN
# 70994         NaN         NaN                   NaN   NaN
#
#                                    Description          Location Description  \
# 0      FINANCIAL IDENTITY THEFT $300 AND UNDER  COMMERCIAL / BUSINESS OFFICE
# 1                                 RETAIL THEFT            GROCERY FOOD STORE
# 2                                    OVER $500                     RESIDENCE
# 3                                   TO VEHICLE                        STREET
# 4                                       SIMPLE                   GAS STATION
# ...                                        ...                           ...
# 70990                                      NaN                           NaN
# 70991                                      NaN                           NaN
# 70992                                      NaN                           NaN
# 70993                                      NaN                           NaN
# 70994                                      NaN                           NaN
#
#       Arrest Domestic    Beat  District  Ward  Community Area FBI Code  \
# 0      False    False   132.0       1.0   3.0            33.0       11
# 1      False    False  1221.0      12.0  26.0            24.0        6
# 2      False    False  1224.0      12.0  27.0            28.0        6
# 3      False    False  1922.0      19.0  47.0             6.0       14
# 4      False    False  2033.0      20.0  47.0             3.0      08A
# ...      ...      ...     ...       ...   ...             ...      ...
# 70990    NaN      NaN     NaN       NaN   NaN             NaN      NaN
# 70991    NaN      NaN     NaN       NaN   NaN             NaN      NaN
# 70992    NaN      NaN     NaN       NaN   NaN             NaN      NaN
# 70993    NaN      NaN     NaN       NaN   NaN             NaN      NaN
# 70994    NaN      NaN     NaN       NaN   NaN             NaN      NaN
#
#        X Coordinate  Y Coordinate    Year        Updated On   Latitude  \
# 0         1177560.0     1889548.0  2019.0  10/20/2019 15:56  41.852248
# 1         1160005.0     1905256.0  2019.0  10/20/2019 16:03  41.895732
# 2         1166986.0     1900306.0  2019.0  10/20/2019 15:56  41.882002
# 3         1164930.0     1923972.0  2019.0  10/20/2019 16:03  41.946987
# 4         1167380.0     1934505.0  2019.0  10/20/2019 16:03  41.975838
# ...             ...           ...     ...               ...        ...
# 70990           NaN           NaN     NaN               NaN        NaN
# 70991           NaN           NaN     NaN               NaN        NaN
# 70992           NaN           NaN     NaN               NaN        NaN
# 70993           NaN           NaN     NaN               NaN        NaN
# 70994           NaN           NaN     NaN               NaN        NaN
#
#        Longitude                       Location
# 0     -87.623786  (41.852248185, -87.623786256)
# 1     -87.687784  (41.895732399, -87.687784384)
# 2     -87.662287   (41.88200224, -87.662286977)
# 3     -87.669164  (41.946987144, -87.669163602)
# 4     -87.659854  (41.975837637, -87.659853835)
# ...          ...                            ...
# 70990        NaN                            NaN
# 70991        NaN                            NaN
# 70992        NaN                            NaN
# 70993        NaN                            NaN
# 70994        NaN                            NaN
#
# [70995 rows x 20 columns]

# %%
#3. Transformar la columna Date que es tipo string en una tipo Fecha 
##use el siguiente metodo de pandas pd.to_datetime(df.Date,format="%m/%d/%Y %I:%M:%S %p")
from datetime import datetime
df = pd.to_datetime(df.Date,format='%m/%d/%Y %H:%M')

# %%
#4. Mostrar los casos totales para cada tipo
## de crimen de forma ascendente, emplee: df.groupby(columna).Date.count()
df.groupby('Primary Type').Date.count().sort_values()
# Out:
# Primary Type
# NON-CRIMINAL                             1
# HUMAN TRAFFICKING                        3
# HOMICIDE                                 7
# OBSCENITY                                8
# GAMBLING                                11
# KIDNAPPING                              32
# CONCEALED CARRY LICENSE VIOLATION       34
# CRIMINAL SEXUAL ASSAULT                 36
# INTIMIDATION                            38
# LIQUOR LAW VIOLATION                    42
# STALKING                                51
# ARSON                                   70
# PROSTITUTION                           131
# SEX OFFENSE                            197
# CRIM SEXUAL ASSAULT                    205
# INTERFERENCE WITH PUBLIC OFFICER       288
# PUBLIC PEACE VIOLATION                 297
# OFFENSE INVOLVING CHILDREN             420
# WEAPONS VIOLATION                     1171
# CRIMINAL TRESPASS                     1425
# ROBBERY                               1596
# MOTOR VEHICLE THEFT                   1836
# BURGLARY                              1948
# NARCOTICS                             3175
# DECEPTIVE PRACTICE                    3277
# OTHER OFFENSE                         3724
# ASSAULT                               3924
# CRIMINAL DAMAGE                       5040
# BATTERY                               9538
# THEFT                                11876
# Name: Date, dtype: int64

# %%
#Ordenar los valores por orden alfabetico de Primary type.
df.sort_values(by='Primary Type', inplace=True)
df
# Out:
#                ID Case Number             Date                   Block  IUCR  \
# 18138  11572064.0    JC123114   1/20/2019 0:20  052XX S SACRAMENTO AVE  1020
# 31130  11591850.0    JC147478  2/10/2019 17:01        0000X E 112TH ST  1020
# 30074  11590298.0    JC145620    2/9/2019 2:31    029XX N RIDGEWAY AVE  1020
# 1633   11861121.0    JC473050  10/15/2019 3:30      027XX N LEHMANN CT  1020
# 7346   11554238.0    JC101904   1/2/2019 14:30    010XX N PARKSIDE AVE  1020
# ...           ...         ...              ...                     ...   ...
# 70990         NaN         NaN              NaN                     NaN   NaN
# 70991         NaN         NaN              NaN                     NaN   NaN
# 70992         NaN         NaN              NaN                     NaN   NaN
# 70993         NaN         NaN              NaN                     NaN   NaN
# 70994         NaN         NaN              NaN                     NaN   NaN
#
#       Primary Type Description    Location Description Arrest Domestic  ...  \
# 18138        ARSON     BY FIRE  VEHICLE NON-COMMERCIAL  False    False  ...
# 31130        ARSON     BY FIRE               APARTMENT  False    False  ...
# 30074        ARSON     BY FIRE  DRIVEWAY - RESIDENTIAL  False    False  ...
# 1633         ARSON     BY FIRE                   ALLEY  False    False  ...
# 7346         ARSON     BY FIRE               RESIDENCE  False    False  ...
# ...            ...         ...                     ...    ...      ...  ...
# 70990          NaN         NaN                     NaN    NaN      NaN  ...
# 70991          NaN         NaN                     NaN    NaN      NaN  ...
# 70992          NaN         NaN                     NaN    NaN      NaN  ...
# 70993          NaN         NaN                     NaN    NaN      NaN  ...
# 70994          NaN         NaN                     NaN    NaN      NaN  ...
#
#        Ward  Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 18138  14.0            63.0         9     1157266.0    1869704.0  2019.0
# 31130   9.0            49.0         9     1178436.0    1830713.0  2019.0
# 30074  30.0            21.0         9     1151328.0    1919710.0  2019.0
# 1633   43.0             7.0         9     1171945.0    1918598.0  2019.0
# 7346   29.0            25.0         9     1138496.0    1906312.0  2019.0
# ...     ...             ...       ...           ...          ...     ...
# 70990   NaN             NaN       NaN           NaN          NaN     NaN
# 70991   NaN             NaN       NaN           NaN          NaN     NaN
# 70992   NaN             NaN       NaN           NaN          NaN     NaN
# 70993   NaN             NaN       NaN           NaN          NaN     NaN
# 70994   NaN             NaN       NaN           NaN          NaN     NaN
#
#              Updated On   Latitude  Longitude                       Location
# 18138   3/26/2019 16:07  41.798230 -87.698809  (41.798229812, -87.698808911)
# 31130   2/17/2019 16:05  41.690779 -87.622356  (41.690778821, -87.622356236)
# 30074   2/16/2019 16:06  41.935570 -87.719273   (41.935570221, -87.71927314)
# 1633   10/22/2019 16:09  41.932089 -87.643538  (41.932088625, -87.643537568)
# 7346    1/10/2019 15:16  41.899047 -87.766757  (41.899047116, -87.766757441)
# ...                 ...        ...        ...                            ...
# 70990               NaN        NaN        NaN                            NaN
# 70991               NaN        NaN        NaN                            NaN
# 70992               NaN        NaN        NaN                            NaN
# 70993               NaN        NaN        NaN                            NaN
# 70994               NaN        NaN        NaN                            NaN
#
# [70995 rows x 22 columns]

# %%
#Mostrar de la fila 100 a la 120
df.iloc[100:120]
# Out:
#                ID Case Number              Date                      Block  \
# 26577  11585792.0    JC140314    2/4/2019 18:40  081XX S COTTAGE GROVE AVE
# 24917  11583163.0    JC137242    2/1/2019 16:30         053XX N LOWELL AVE
# 39455  11604873.0    JC163166   2/23/2019 14:15  044XX S COTTAGE GROVE AVE
# 48859  11619971.0    JC181625   3/11/2019 15:30      046XX S FRANCISCO AVE
# 24911  11583153.0    JC133266    1/29/2019 7:50          064XX S MOZART ST
# 1554   11862020.0    JC474121  10/15/2019 20:20          006XX N LAMON AVE
# 10165  11558964.0    JC107615     1/7/2019 8:00        030XX W CARROLL AVE
# 9338   11557706.0    JC106124    1/5/2019 18:57          017XX W GRAND AVE
# 22030  11578375.0    JC131117    1/27/2019 3:18       012XX S LAWNDALE AVE
# 24895  11583131.0    JC136743    2/1/2019 16:25      044XX S FAIRFIELD AVE
# 38657  11603686.0    JC161839   2/22/2019 10:13         036XX S WABASH AVE
# 40210  11606044.0    JC164058   2/24/2019 11:47    009XX N SPRINGFIELD AVE
# 8870   11557000.0    JC105071     1/4/2019 9:45        087XX S CRANDON AVE
# 8869   11556999.0    JC105154    1/4/2019 23:01       042XX W FORD CITY DR
# 40796  11606992.0    JC165883   2/25/2019 22:37         060XX S JUSTINE ST
# 23229  11580406.0    JC133604   1/23/2019 13:00          049XX N AVERS AVE
# 10922  11560296.0    JC109149    1/8/2019 11:50       007XX N MICHIGAN AVE
# 10923  11560297.0    JC109084    1/8/2019 10:20          056XX N MOZART ST
# 10913  11560280.0    JC108924    1/3/2019 11:00         001XX S PAULINA ST
# 24803  11582999.0    JC137070    2/1/2019 23:10        023XX N HARDING AVE
#
#        IUCR Primary Type                     Description  \
# 26577  051A      ASSAULT             AGGRAVATED: HANDGUN
# 24917   560      ASSAULT                          SIMPLE
# 39455   530      ASSAULT   AGGRAVATED: OTHER DANG WEAPON
# 48859   520      ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
# 24911   530      ASSAULT   AGGRAVATED: OTHER DANG WEAPON
# 1554    560      ASSAULT                          SIMPLE
# 10165   530      ASSAULT   AGGRAVATED: OTHER DANG WEAPON
# 9338    560      ASSAULT                          SIMPLE
# 22030   520      ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
# 24895  051A      ASSAULT             AGGRAVATED: HANDGUN
# 38657   558      ASSAULT  AGG PRO.EMP: OTHER DANG WEAPON
# 40210   560      ASSAULT                          SIMPLE
# 8870    560      ASSAULT                          SIMPLE
# 8869    560      ASSAULT                          SIMPLE
# 40796   520      ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
# 23229   560      ASSAULT                          SIMPLE
# 10922   560      ASSAULT                          SIMPLE
# 10923   530      ASSAULT   AGGRAVATED: OTHER DANG WEAPON
# 10913   560      ASSAULT                          SIMPLE
# 24803   520      ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
#
#                Location Description Arrest Domestic  ...  Ward  \
# 26577                        STREET  False    False  ...   8.0
# 24917              RESIDENCE-GARAGE  False    False  ...  39.0
# 39455            SMALL RETAIL STORE  False    False  ...   4.0
# 48859                      SIDEWALK   True    False  ...  15.0
# 24911                        STREET  False    False  ...  17.0
# 1554                      APARTMENT  False     True  ...  37.0
# 10165                        STREET  False     True  ...  27.0
# 9338                     RESTAURANT   True    False  ...   1.0
# 22030                     APARTMENT   True     True  ...  24.0
# 24895                         ALLEY  False    False  ...  15.0
# 38657      SCHOOL, PUBLIC, BUILDING  False    False  ...   3.0
# 40210                     RESIDENCE  False     True  ...  37.0
# 8870                      RESIDENCE  False     True  ...   8.0
# 8869                      APARTMENT  False    False  ...  18.0
# 40796                     APARTMENT  False    False  ...  16.0
# 23229      SCHOOL, PUBLIC, BUILDING  False    False  ...  39.0
# 10922  COMMERCIAL / BUSINESS OFFICE  False    False  ...  42.0
# 10923       SCHOOL, PUBLIC, GROUNDS  False    False  ...  40.0
# 10913                        STREET  False    False  ...  27.0
# 24803                     APARTMENT   True     True  ...  35.0
#
#        Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 26577            44.0       04A     1182974.0    1851151.0  2019.0
# 24917            13.0       08A     1146401.0    1935370.0  2019.0
# 39455            39.0       04A     1182339.0    1875765.0  2019.0
# 48859            58.0       04A     1157815.0    1873744.0  2019.0
# 24911            66.0       04A     1158484.0    1861911.0  2019.0
# 1554             25.0       08A     1143572.0    1903977.0  2019.0
# 10165            27.0       04A     1156114.0    1902253.0  2019.0
# 9338             24.0       08A     1164467.0    1903534.0  2019.0
# 22030            29.0       04A     1151904.0    1894143.0  2019.0
# 24895            58.0       04A     1158778.0    1875031.0  2019.0
# 38657            35.0       04A     1177328.0    1880737.0  2019.0
# 40210            23.0       08A     1150215.0    1906033.0  2019.0
# 8870             48.0       08A     1193020.0    1847386.0  2019.0
# 8869             65.0       08A     1148829.0    1853237.0  2019.0
# 40796            67.0       04A     1167037.0    1864690.0  2019.0
# 23229            14.0       08A     1149820.0    1932619.0  2019.0
# 10922             8.0       08A     1177293.0    1905615.0  2019.0
# 10923             2.0       04A     1156333.0    1937407.0  2019.0
# 10913            28.0       08A     1165095.0    1899450.0  2019.0
# 24803            22.0       04A     1149662.0    1915218.0  2019.0
#
#              Updated On   Latitude  Longitude                       Location
# 26577   2/21/2019 16:06  41.746759 -87.605110  (41.746759188, -87.605109535)
# 24917    2/8/2019 16:14  41.978638 -87.736980  (41.978637926, -87.736979831)
# 39455    3/2/2019 16:09  41.814317 -87.606674  (41.814317008, -87.606674143)
# 48859   3/28/2019 15:59  41.809305 -87.696686    (41.80930497, -87.69668587)
# 24911    2/6/2019 16:03  41.776820 -87.694555  (41.776819976, -87.694554571)
# 1554   10/22/2019 16:09  41.892546 -87.748172  (41.892546106, -87.748171713)
# 10165    1/18/2019 9:37  41.887571 -87.702156  (41.887571335, -87.702156331)
# 9338     1/18/2019 9:37  41.890914 -87.671445  (41.890913805, -87.671445268)
# 22030    2/3/2019 16:01  41.865401 -87.717830   (41.865400546, -87.71783042)
# 24895    2/8/2019 16:14  41.812817 -87.693119  (41.812817031, -87.693118571)
# 38657    3/1/2019 16:09  41.828075 -87.624904    (41.8280754, -87.624904486)
# 40210    3/3/2019 16:04  41.898061 -87.723721    (41.898061071, -87.7237208)
# 8870     1/18/2019 9:37  41.736188 -87.568422  (41.736188496, -87.568421695)
# 8869     1/18/2019 9:37  41.753208 -87.730173  (41.753208408, -87.730172879)
# 40796    3/4/2019 16:05  41.784267 -87.663120  (41.784267283, -87.663120076)
# 23229    2/1/2019 16:12  41.971023 -87.724478  (41.971022998, -87.724478132)
# 10922    1/18/2019 9:37  41.896343 -87.624279  (41.896343018, -87.624279065)
# 10923    1/18/2019 9:37  41.984032 -87.700399  (41.984032004, -87.700398992)
# 10913   1/17/2019 14:26  41.879694 -87.669255   (41.879693672, -87.66925501)
# 24803    2/8/2019 16:14  41.923276 -87.725513  (41.923276362, -87.725512869)
#
# [20 rows x 22 columns]

# %%
#Realizar una visualización de los datos anteriores.
##Emplee la libreria seaborn con un grafico tipo barplot. 
#Ej. ax = sns.barplot(x = "contador", y="Primary Type", data = datos)
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 8));
sns.barplot(data=df, y = df.groupby('Primary Type').Date.count().values, x=df.groupby('Primary Type').Date.count().index);

# %% [markdown]
# #Problema 4
#
# 1. Leer el dataset country_vaccinations.csv  y filtrar los datos para Colombia
# 2. Crear un csv con los datos para colombia
# 3. Realizar una comparacion con los paises latinoamericanos de la cantidad de vacunados.
# 4. A traves de mascaras determinar el numero de vacunados en el intervalo  [1.5E6, 2.0E6]
#
#
#
#
# Referencias: Puedes consultar la pagina kaggle para estudiar mas acerca de pandas

# %%
#1. Leer el dataset 
import pandas as pd
url = 'https://raw.githubusercontent.com/hernansalinas/autogrades/main/Laboratorios_Taller/dataset/country_vaccinations.csv'
df = pd.read_csv(url)
df
# Out:
#           country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1     Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2     Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3     Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4     Afghanistan      AFG  2021-02-26                 NaN                NaN
# ...           ...      ...         ...                 ...                ...
# 9571     Zimbabwe      ZWE  2021-03-29             81610.0            69751.0
# 9572     Zimbabwe      ZWE  2021-03-30             85866.0            72944.0
# 9573     Zimbabwe      ZWE  2021-03-31             91880.0            76995.0
# 9574     Zimbabwe      ZWE  2021-04-01            105307.0            87791.0
# 9575     Zimbabwe      ZWE  2021-04-02            124753.0           103815.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN              1367.0
# 2                         NaN                     NaN              1367.0
# 3                         NaN                     NaN              1367.0
# 4                         NaN                     NaN              1367.0
# ...                       ...                     ...                 ...
# 9571                  11859.0                  2471.0              5434.0
# 9572                  12922.0                  4256.0              5810.0
# 9573                  14885.0                  6014.0              5712.0
# 9574                  17516.0                 13427.0              6617.0
# 9575                  20938.0                 19446.0              8156.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                           0.00
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 9571                            0.55                           0.47
# 9572                            0.58                           0.49
# 9573                            0.62                           0.52
# 9574                            0.71                           0.59
# 9575                            0.84                           0.70
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                            35.0
# 2                                     NaN                            35.0
# 3                                     NaN                            35.0
# 4                                     NaN                            35.0
# ...                                   ...                             ...
# 9571                                 0.08                           366.0
# 9572                                 0.09                           391.0
# 9573                                 0.10                           384.0
# 9574                                 0.12                           445.0
# 9575                                 0.14                           549.0
#
#                 vaccines                source_name  \
# 0     Oxford/AstraZeneca  Government of Afghanistan
# 1     Oxford/AstraZeneca  Government of Afghanistan
# 2     Oxford/AstraZeneca  Government of Afghanistan
# 3     Oxford/AstraZeneca  Government of Afghanistan
# 4     Oxford/AstraZeneca  Government of Afghanistan
# ...                  ...                        ...
# 9571   Sinopharm/Beijing         Ministry of Health
# 9572   Sinopharm/Beijing         Ministry of Health
# 9573   Sinopharm/Beijing         Ministry of Health
# 9574   Sinopharm/Beijing         Ministry of Health
# 9575   Sinopharm/Beijing         Ministry of Health
#
#                                          source_website
# 0     http://www.xinhuanet.com/english/asiapacific/2...
# 1     http://www.xinhuanet.com/english/asiapacific/2...
# 2     http://www.xinhuanet.com/english/asiapacific/2...
# 3     http://www.xinhuanet.com/english/asiapacific/2...
# 4     http://www.xinhuanet.com/english/asiapacific/2...
# ...                                                 ...
# 9571  https://twitter.com/MoHCCZim/status/1378053949...
# 9572  https://twitter.com/MoHCCZim/status/1378053949...
# 9573  https://twitter.com/MoHCCZim/status/1378053949...
# 9574  https://twitter.com/MoHCCZim/status/1378053949...
# 9575  https://twitter.com/MoHCCZim/status/1378053949...
#
# [9576 rows x 15 columns]

# %%
#2. Crear un csv con los datos para Colombia.
dfColombia = df[df['country'] == 'Colombia']
csvColombia = dfColombia.to_csv('csvColombia',index=False)

# %%
#Realizar una comparación con los países latinoamericanos de la cantidad de vacunados
#Le pedimos a chatgpt que nos haga la lista de todos los paises
paises = ['Argentina','Bolivia', 'Brazil', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Dominican Republic', 'Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Puerto Rico', 'Trinidad and Tobago', 'Uruguay', 'Venezuela']
dfLatam = df[df['country'].isin(paises)]
#Hagamos un histograma para comparar los paises
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 8));
sns.barplot(data=df, y = dfLatam.groupby('country').total_vaccinations.count().values, x=dfLatam.groupby('country').total_vaccinations.count().index);

# %%
#A través de mascaras determinar el numero de vacunados en el intervalo [1.5E6, 2.0E6]
cotaInferior = 1.5e6
cotaSuperior = 2.0e6
mascara = (df['people_vaccinated']>= cotaInferior ) & (df['people_vaccinated']<=cotaSuperior)
#Creamos un dataframe con los vacunados en este rango
dfCondicion = df[mascara]
#Agrupamos la cantidad de vacunados por país en este rango
dfCondicion.groupby('country').people_vaccinated.count()
# Out:
# country
# Argentina         5
# Bangladesh        2
# Brazil            2
# Canada            7
# Chile             4
# Colombia          7
# England           1
# France            9
# Germany          11
# Hungary          10
# India             2
# Indonesia         5
# Israel            8
# Italy             9
# Mexico            5
# Netherlands       1
# Poland            9
# Romania          15
# Scotland         21
# Spain             6
# United States     1
# Name: people_vaccinated, dtype: int64
