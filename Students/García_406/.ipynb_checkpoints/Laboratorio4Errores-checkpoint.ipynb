# %%
import numpy as np
from decimal import Decimal
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Escribir un programa que calcule el número

# %%
def invexponencial(x,N):
  e=0
  for i in range(N):
    sing=(-1)**i
    e=e+(sing*(((x)**i)/np.math.factorial(i)))
  return e

# %%
print(np.exp(-1/2))
print(invexponencial(1/2,20))
# Out:
# 0.6065306597126334
# 0.6065306597126333

# %% [markdown]
# ## Comparación

# %%
def comparacion(x,N):
  if abs((-x**(N+1))/(np.math.factorial(N+1)))<=abs(1E-7*invexponencial(x,N)):
    return True
  else:
    return False

# %%
comparacion(0.001,20)
# Out:
# True

# %% [markdown]
# ## Diferencia entre 1/exp(x) y exp(-x) para valores muy grandes

# %%
print(np.exp(-100))
print(1/np.exp(100))
abs(np.exp(-100)-1/np.exp(100))
# Out:
# 3.720075976020836e-44
# 3.7200759760208356e-44
# 4.9784122222889134e-60

# %% [markdown]
# ## Convergencia de la serie dependiendo de x

# %%
for j in range(0,10):
  print(j," ",invexponencial(j,20),"   ",np.exp(-j))
# Out:
# 0   1.0     1.0
# 1   0.36787944117144245     0.36787944117144233
# 2   0.1353352832362194     0.1353352832366127
# 3   0.04978706711474102     0.049787068367863944
# 4   0.018315259717021463     0.01831563888873418
# 5   0.00670634105421557     0.006737946999085467
# 6   0.0013126228039965042     0.0024787521766663585
# 7   -0.0236134818594909     0.0009118819655545162
# 8   -0.3415891012417609     0.00033546262790251185
# 9   -3.4829765179280283     0.00012340980408667956

# %% [markdown]
# desde x=4 la función empieza a perder certeza, y desde x=7 la serie deja de converger

# %% [markdown]
# ## Grafica del error como función de N para distintos valores de x
#
# Para x=1 y N=100

# %%
X=np.arange(1,100)
Y=np.zeros(99)
for h in range(len(X)):
  Y[h]=abs(np.exp(-1)-invexponencial(1,h))
plt.plot(X,Y,"r")
plt.grid()
plt.xlim(0,20)
plt.xlabel("N")
plt.ylabel("Error")
# Out:
# Text(0, 0.5, 'Error')

# %% [markdown]
# Para x=2 y N=100

# %%
for h in range(len(X)):
  Y[h]=abs(np.exp(-2)-invexponencial(2,h))
plt.plot(X,Y,"r")
plt.grid()
plt.xlim(0,20)
plt.xlabel("N")
plt.ylabel("Error")
# Out:
# Text(0, 0.5, 'Error')

# %% [markdown]
# Para x=3 y N=100

# %%
for h in range(len(X)):
  Y[h]=abs(np.exp(-3)-invexponencial(3,h))
plt.plot(X,Y,"r")
plt.grid()
plt.xlim(0,20)
plt.xlabel("N")
plt.ylabel("Error")
# Out:
# Text(0, 0.5, 'Error')

# %% [markdown]
# Para x=4 y N=100

# %%
for h in range(len(X)):
  Y[h]=abs(np.exp(-4)-invexponencial(4,h))
plt.plot(X,Y,"r")
plt.grid()
plt.xlim(0,20)
plt.xlabel("N")
plt.ylabel("Error")
# Out:
# Text(0, 0.5, 'Error')

# %% [markdown]
# ## 2) Cancelación sustractiva

# %% [markdown]
# Escribir un codigo que realice el calculo de las tres series

# %%
def S_1(N):
  s=0
  for i in range(1,N*2+1):
    sing=(-1)**i
    s=s+(sing*(i/(i+1)))
  return s

# %%
def S_2(N):
  s1=0
  s2=0
  for i in range(1,N+1):
    s1=s1+((2*i-1)/(2*i))
  for j in range(1,N+1):
    s2=s2+((2*j)/((2*j)+1))
  s3=-s1+s2
  return s3

# %%
def S_3(N):
  s3=0
  for i in range(1,N):
    s3=s3+(1/((2*i)*(2*i+1)))
  return s3

# %%
for k in range(0,100):
  print(k," ",S_1(k)," ",S_2(k)," ",S_3(k))
# 57   0.3025238962301966   0.30252389623019127   0.3024476185795487
# 58   0.30259757733836046   0.3025975773383536   0.3025238962301971
# 59   0.3026687922650091   0.30266879226500265   0.30259757733836096
# 60   0.30273766278842507   0.30273766278841663   0.3026687922650096
# 61   0.30280430279908743   0.3028043027990819   0.30273766278842557
# 62   0.3028688189281197   0.30286881892811124   0.302804302799088
# 63   0.3029313111165961   0.30293131111658766   0.30286881892812023
# 64   0.30299187313209996   0.3029918731320933   0.30293131111659666
# 65   0.3030505930381481   0.30305059303814375   0.3029918731321005
# 66   0.3031075536214244   0.30310755362142316   0.3030505930381487
# 67   0.30316283278118117   0.30316283278118306   0.30310755362142505
# 68   0.30321650388465904   0.3032165038846557   0.30316283278118183
# 69   0.30326863609193677   0.30326863609192856   0.3032165038846597
# 70   0.3033192946532336   0.30331929465322105   0.3032686360919374
# 71   0.30336854118135337   0.30336854118132806   0.30331929465323426
# 72   0.30341643390165984   0.3034164339016314   0.30336854118135403
# 73   0.30346302788171764   0.30346302788169055   0.30341643390166056
# 74   0.3035083752425013   0.30350837524247254   0.30346302788171836
# 75   0.3035525253528766   0.30355252535284194   0.30350837524250196
# 76   0.3035955250088793   0.3035955250088449   0.30355252535287724
# 77   0.30363741859915994   0.30363741859913773   0.30359552500888
# 78   0.30367824825782397   0.3036782482578104   0.30363741859916066
# 79   0.303718054005774   0.30371805400575624   0.3036782482578247
# 80   0.30375687388155037   0.3037568738815253   0.3037180540057747
# 81   0.3037947440625699   0.30379474406254303   0.3037568738815511
# 82   0.30383169897757356   0.3038316989775467   0.30379474406257057
# 83   0.30386777141101984   0.3038677714109923   0.3038316989775743
# 84   0.30390299260008713   0.30390299260005804   0.30386777141102067
# 85   0.30393739232488926   0.3039373923248547   0.303902992600088
# 86   0.30397099899245206   0.303970998992412   0.3039373923248902
# 87   0.30400383971494804   0.30400383971490896   0.30397099899245306
# 88   0.30403594038264203   0.3040359403826045   0.30400383971494893
# 89   0.30406732573196094   0.3040673257319213   0.3040359403826428
# 90   0.30409801940906345   0.30409801940902526   0.30406732573196177
# 91   0.304128044029252   0.3041280440292127   0.3040980194090643
# 92   0.3041574212325423   0.3041574212325031   0.3041280440292528
# 93   0.3041861717356761   0.3041861717356369   0.3041574212325431
# 94   0.304214315380841   0.3042143153808041   0.30418617173567686
# 95   0.30424187118133705   0.30424187118129   0.30421431538084176
# 96   0.30426885736441134   0.30426885736436304   0.3042418711813378
# 97   0.30429529141146394   0.304295291411421   0.30426885736441206
# 98   0.3043211900958107   0.304321190095763   0.30429529141146466
# 99   0.30434656951817507   0.3043465695181311   0.3043211900958115

# %% [markdown]
# Como podemos observar, pareciera que las tres series convergen, ahora si suponemos que S3 es la solución exacta, entonces:

# %%
def e(x,y):
  e=abs((x-y)/y)
  return e

# %%
X=np.zeros(3000,dtype=float)
Y=np.zeros(3000,dtype=float)
for i in range(2,len(X)):
  X[i]=S_3(i)
  Y[i]=e(S_1(i),S_3(i))
X=np.log10(X)
Y=np.log10(Y)
plt.plot(Y,X,"r.-")
plt.xlabel("Log E")
plt.ylabel("Log N")

# %%
X=np.zeros(3000,dtype=float)
Y=np.zeros(3000,dtype=float)
for i in range(2,len(X)):
  X[i]=S_3(i)
  Y[i]=e(S_2(i),S_3(i))
X=np.log10(X)
Y=np.log10(Y)
plt.plot(Y,X,"b.-")
plt.xlabel("Log E")
plt.ylabel("Log N")
