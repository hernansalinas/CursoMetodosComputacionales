# %%
import scipy as sc
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate

# %%
x = np.random.randint(0,255,(8,8))
x
# Out:
# array([[164, 161,  51, 233, 205, 199, 225, 158],
#        [246, 156,  10,  82,  32,  44, 213, 170],
#        [ 19, 130, 103, 186, 170,  44, 156, 134],
#        [192, 193,  49,  20,  27, 227, 219, 223],
#        [ 74, 216, 149, 133,  41,  53,  32, 131],
#        [233, 146, 228, 205, 242, 105,  89, 125],
#        [241,  68,  96, 167, 155, 169,  31, 104],
#        [126,  64, 133,  97, 105,  50, 164, 188]])

# %%
plt.imshow(x)
x[2:7:2 , 2:7:2]
# Out:
# array([[103, 170, 156],
#        [149,  41,  32],
#        [ 96, 155,  31]])

# %%
plt.imshow(x[2:7:2 , 2:7:2])

# %%
M=np.random.randint(0,200,(4,4))
M
# Out:
# array([[139,  31, 162,  19],
#        [126, 176, 136, 169],
#        [114,  73,  36,   9],
#        [ 40, 136,  50, 152]])

# %%
#dimension de la matriz
dim=np.shape(M)
print(dim)
# Out:
# (4, 4)

# %%
D=np.random.randint(0,200,(4,1))
D
# Out:
# array([[ 73],
#        [136],
#        [175],
#        [141]])

# %%
#multiplicacion por escalar
N=3*M
N
# Out:
# array([[417,  93, 486,  57],
#        [378, 528, 408, 507],
#        [342, 219, 108,  27],
#        [120, 408, 150, 456]])

# %%
#resta
A= M-N
A
# Out:
# array([[-278,  -62, -324,  -38],
#        [-252, -352, -272, -338],
#        [-228, -146,  -72,  -18],
#        [ -80, -272, -100, -304]])

# %%
#transpuesta
T= np.transpose(M)
T
# Out:
# array([[139, 126, 114,  40],
#        [ 31, 176,  73, 136],
#        [162, 136,  36,  50],
#        [ 19, 169,   9, 152]])

# %%
R=np.zeros(np.shape(D))
R
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
#multiplicacion por un vector
R=np.zeros(np.shape(D))

for i in range()
# Out:
# array([[184275],
#        [318675],
#        [121800],
#        [198450]])

# %%
def mul_matriz(A,B):
  dimA=np.shape(A)
  dimB=np.shape(B)
  c=np.zeros(np.shape(A)[1],np.shape(B)[0])
