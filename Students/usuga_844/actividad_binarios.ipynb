# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=40

def mybin(x):
  b=''
  while x!=0:
      oldx=x
      b=str(x%2)+b
      x=x//2
      print(f'x={oldx}/2={x} → b={b}')

  return b
b
# Out:
# ''

# %%
x=40
c=x//2
r=x%2
print(c,r)
# Out:
# 20 0

# %%
x=c
c=x//2
r=x%2
print(c,r)
# Out:
# 10 0

# %%
x=c
c=x//2
r=x%2
print(c,r)
# Out:
# 5 0

# %%
x=c
c=x//2
r=x%2
print(c,r)
# Out:
# 2 1

# %%
x = 40

while x > 1:
    c = x // 2
    r = x % 2
    print(c, r)
    x = c  # Actualizamos el valor de x para la próxima iteración
# Out:
# 20 0
# 10 0
# 5 0
# 2 1
# 1 0
