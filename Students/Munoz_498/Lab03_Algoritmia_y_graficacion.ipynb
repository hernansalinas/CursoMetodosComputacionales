# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab03_Algoritmia_y_graficacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio 03 - Melanie Andrea Muñoz Chavarria
#
#
# ## 1.0 Mapa logístico
# Caos numérico en un mapa logístico y errores de punto flotante (Errores de redondeo)
#
# > Un ejemplo clásico de caos,  es el comportamiento no lineal en las interaciones de un mapa logístico
#
# \begin{equation}
# x_{n+1}=f(x_n)=rx_n(1-x_n)
# \end{equation}
#
#
# > con $x\in (0,1)$ y $r\in(0,4)$ se pueden producir varios comportamientos sorprendentes.
#
# Para este problema, será extremadamente útil  ver sus resultados gráficamente; construya listas de números y llame la libreria matplotlib.
#
#
# > ### Problema:
# a. Programar la ecuación para el mapa logístico, y  realizar una grafica del valor de xn como funcion de n.
#
# b. Realizar pruebas para un $x_0=0.5$, con valores de r
#
# ```
#   r = np.array([1.9, 2.9, 3.1, 3.5, 3.9,4.0])
#   numpoints = 100, # Numero sugerido de iteraciones
#   x0 = 0.5
# ```
#
# Organizar las gráficas [multiples plot](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html)
#
#
#
# c. Construye una rutina llamada logist_map en que entrada el valor de r, la condiciones inicial xi y el número de puntos determine la evolución en el punto N.  Prueba implementado las siguientes lineas.
#
# ```
# Np = 1000
# xf = np.zeros(Np)
# r  = np.linspace(2.5, 4, Np)
#
# for i in range(0, Np):
#   xini = np.random.random()
#   x_i = logist_map(r = r[i], xi = xini, N = 1000)
#   xf[i] = x_i
# ```
#
#
# d. Realiza un gráfico de:
# ```
#   plt.plot((r-1/r), xf,  ".", markersize = 0.5)
# ```
#
#
# e. Encontrar dos formas adicionales de expresar $f(x)$, para estos valores funcionales determinar las mismas gráficas del numeral 3 para cada uno de las formas de escribir la expresión. En este caso se espera que los resultados varien. ¿A que se debe esto?. Consulta algunas fuentes para responder a la pregunta.
#
#
# Ref: https://www.youtube.com/watch?v=EOvLhZPevm0&t=104s

# %%
#Librerías
import numpy as np
import matplotlib.pyplot as plt

# %%
# a . Mapa Logístico
def ecuacion_mapa_logistico(t_crecimineto,poblacion_tiempo): #Para la ecuacion de poblacion
  poblacion=t_crecimineto*poblacion_tiempo*(1-poblacion_tiempo)
  return poblacion

def mapa_logistico(n,r,x0):
  x=np.zeros(n) #Este vector se refifinirá con los valores resultantes de aplicar la ecuación
  x[0]=x0 #Para el valor incial de la población
  for i in range(1,n): #Recursividad
    x1=ecuacion_mapa_logistico(r,x0) #Se aplica la ecuación de mapa logistico para la poblacion
    x0=x1
    x[i]=x1 #Igula las componentes del vector de ceros a los resultados de la iteración
  return x

print(mapa_logistico(4,2.5,0.5))

#Gráfico mapa logístico
eje_x=mapa_logistico(5,1,0.5) #Se fijan los valores en la función de mapa logístico para que retorne el array
plt.figure()
plt.title('Mapa logístico', fontsize=14)
plt.ylabel('${x_n}$', fontsize=14)
plt.xlabel('''n

Figura 1. Mapa logístico para ${x_0=0.5}$, n=3 y r=1''', fontsize=14)
plt.plot(eje_x,'.m-', markersize=18)
plt.grid()
plt.show()
# Out:
# [0.5        0.625      0.5859375  0.60653687]

# %%
#b. Pruebas mapa logístico para valores establecidos de r y x0
r = np.array([1.9, 2.9, 3.1, 3.5, 3.9,4.0])
numpoints = 100
x0 = 0.5
#Pruebas para los valores dados de r, n y x0
poblacion_0=mapa_logistico(numpoints,r[0],x0)
poblacion_1=mapa_logistico(numpoints,r[1],x0)
poblacion_2=mapa_logistico(numpoints,r[2],x0)
poblacion_3=mapa_logistico(numpoints,r[3],x0)
poblacion_4=mapa_logistico(numpoints,r[4],x0)
poblacion_5=mapa_logistico(numpoints,r[5],x0)

#Subplots
fig, axs = plt.subplots(3, 2, figsize=(10,8))

#Para el valor de r[0]
axs[0, 0].plot(poblacion_0, '.r-')
axs[0, 0].set_title(f"Mapa logístico para tasa de crecimiento de: {r[0]}", fontsize=10)
axs[0, 0].set_ylabel('${x_n}$')
axs[0, 0].set_xlabel('n')

#Para el valor de r[1]
axs[0, 1].plot(poblacion_1, '.b-')
axs[0, 1].set_title(f"Mapa logístico para tasa de crecimiento de: {r[1]}",fontsize=10)
axs[0, 1].set_ylabel('${x_n}$')
axs[0, 1].set_xlabel('n')

#Para el valor de r[2]
axs[1, 0].plot(poblacion_2, '.m-')
axs[1, 0].set_title(f"Mapa logístico para tasa de crecimiento de: {r[2]}",fontsize=10)
axs[1, 0].set_ylabel('${x_n}$')
axs[1, 0].set_xlabel('n')

#Para el valor de r[3]
axs[1, 1].plot(poblacion_3, '.c-')
axs[1, 1].set_title(f"Mapa logístico para tasa de crecimiento de: {r[3]}",fontsize=10)
axs[1, 1].set_ylabel('${x_n}$')
axs[1, 1].set_xlabel('n')

#Para el valor de r[4]
axs[2, 0].plot(poblacion_4, '.y-')
axs[2, 0].set_title(f"Mapa logístico para tasa de crecimiento de: {r[4]}",fontsize=10)
axs[2, 0].set_ylabel('${x_n}$')
axs[2, 0].set_xlabel('n')

#Para el valor de r[5]
axs[2, 1].plot(poblacion_5, '.-')
axs[2, 1].set_title(f"Mapa logístico para tasa de crecimiento de: {r[5]}",fontsize=10)
axs[2, 1].set_ylabel('${x_n}$')
axs[2, 1].set_xlabel('n')


fig.tight_layout() #Permite la separación, ajustando el espacio entre los Subplots

# %%
#c.Rutina logist_map

def logist_map(n,r,x0):
  x=np.zeros(n)
  x[0]=x0
  for i in range(1,n):
    x1=ecuacion_mapa_logistico(r,x0)
    x0=x1
    x[i]=x1
  return x[n-1] #Para ver la evolución en punto N

#Prueba
Np = 1000
xf = np.zeros(Np)
r  = np.linspace(2.5, 4, Np)

for i in range(0, Np):
  xini = np.random.random()
  x_i = logist_map(1000,r[i],xini)
  xf[i] = x_i

#d. Grafico para xf
r_operacion=np.zeros(Np)

for j in range(0,Np): #Ya que r es un array, esto permite hacer la operación sobre cada valor, para luego agregarlo nuevamente a un array que antes tenía ceros
  r_j=((r[j]-1)/r[j])
  r_operacion[j]=r_j
   #Figura
plt.figure(figsize=(8,8))
plt.plot(r_operacion,xf,".b", markersize = 0.5)
plt.title('Diagrama de Bifurcación para el mapa logístico', fontsize=14)
plt.xlabel('''(r-1)/r
Figura 2. Diagrama de Bifurcación
para los valores de los vectores xf y r_operacion''',fontsize=14)
plt.ylabel('xf',fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# e. Formas alternativas
#
# Los cambios en los resultados se producen porque las variaciones con las formas alternativas de la función, hacen que el dinámica de la población y otros parámetros del mapa logístico, como la tasa de crecimiento cambien. Obteniendo resultados diferentes de los esperados.
#
# 1) \begin{equation}
# x_{n+1}=f(x_n)=(rx_n-rx_n^2)
# \end{equation}
#
# 2)\begin{equation}
# x_{n+1}=f(x_n)=x_n(r-rx_n)
# \end{equation}

# %%
#Forma alternativa 1
def ecuacion_mapa_logistico1(t_crecimineto,poblacion_tiempo): #Para la ecuacion de poblacion
  poblacion=(t_crecimineto*poblacion_tiempo-t_crecimineto*poblacion_tiempo**2)
  return poblacion

def mapa_logistico1(n,r,x0):
  x=np.zeros(n) #Este vector se redefinirá con los valores resultantes de aplicar la ecuación
  x[0]=x0 #Para el valor incial de la población
  for i in range(1,n): #Recursividad
    x1=ecuacion_mapa_logistico1(r,x0) #Se aplica la ecuación de mapa logistico para la poblacion
    x0=x1
    x[i]=x1 #Igula las componentes del vector de ceros a los resultados de la iteración
  return x

print(mapa_logistico1(4,2.5,0.5))

def logist_map1(n,r,x0): #Para graficar
  x=np.zeros(n)
  x[0]=x0
  for i in range(1,n):
    x1=ecuacion_mapa_logistico1(r,x0)
    x0=x1
    x[i]=x1
  return x[n-1] #Para ver la evolución en punto N

#Prueba
Np = 1000
xf = np.zeros(Np)
r  = np.linspace(2.5, 4, Np)

for i in range(0, Np):
  xini = np.random.random()
  x_i = logist_map1(1000,r[i],xini)
  xf[i] = x_i

r_operacion1=np.zeros(Np)

for j in range(0,Np): #Ya que r es un array, esto permite hacer la operación sobre cada valor, para luego agregarlo nuevamente a un array que antes tenía ceros
  r_j=((r[j]-1)/r[j])
  r_operacion1[j]=r_j
   #Figura
plt.figure(figsize=(8,8))
plt.plot(r_operacion1,xf,".r", markersize = 0.5)
plt.title('Diagrama de Bifurcación para el mapa logístico', fontsize=14)
plt.xlabel('''(r-1)/r
Figura 3. Diagrama de Bifurcación
para los valores de los vectores xf y r_operacion1''',fontsize=14)
plt.ylabel('xf',fontsize=14)
plt.grid()
plt.show()
# Out:
# [0.5        0.625      0.5859375  0.60653687]

# %%
#Forma alternativa 2
def ecuacion_mapa_logistico2(t_crecimineto,poblacion_tiempo): #Para la ecuacion de poblacion
  poblacion=(t_crecimineto-t_crecimineto*poblacion_tiempo)*poblacion_tiempo
  return poblacion

def mapa_logistico2(n,r,x0):
  x=np.zeros(n) #Este vector se redefinirá con los valores resultantes de aplicar la ecuación
  x[0]=x0 #Para el valor incial de la población
  for i in range(1,n): #Recursividad
    x1=ecuacion_mapa_logistico2(r,x0) #Se aplica la ecuación de mapa logistico para la poblacion
    x0=x1
    x[i]=x1 #Igula las componentes del vector de ceros a los resultados de la iteración
  return x

print(mapa_logistico2(4,2.5,0.5))

def logist_map2(n,r,x0): #Para graficar
  x=np.zeros(n)
  x[0]=x0
  for i in range(1,n):
    x1=ecuacion_mapa_logistico2(r,x0)
    x0=x1
    x[i]=x1
  return x[n-1] #Para ver la evolución en punto N

#Prueba
Np = 1000
xf = np.zeros(Np)
r  = np.linspace(2.5, 4, Np)

for i in range(0, Np):
  xini = np.random.random()
  x_i = logist_map2(1000,r[i],xini)
  xf[i] = x_i

#d. Grafico para xf
r_operacion2=np.zeros(Np)

for j in range(0,Np): #Ya que r es un array, esto permite hacer la operación sobre cada valor, para luego agregarlo nuevamente a un array que antes tenía ceros
  r_j=((r[j]-1)/r[j])
  r_operacion2[j]=r_j
   #Figura
plt.figure(figsize=(8,8))
plt.plot(r_operacion2,xf,".g", markersize = 0.5)
plt.title('Diagrama de Bifurcación para el mapa logístico', fontsize=14)
plt.xlabel('''(r-1)/r
Figura 4. Diagrama de Bifurcación
para los valores de los vectores xf y r_operacion2''',fontsize=14)
plt.ylabel('xf',fontsize=14)
plt.grid()
plt.show()
# Out:
# [0.5        0.625      0.5859375  0.60653687]

# %% [markdown]
# ## 2. Mapa de henon
# El mapa de Hénon es un sistema dinámico discreto en el tiempo que se define por las siguientes ecuaciones:
#
# $$x_{n+1} = 1 - ax_n^2 + y_n$$
# $$y_{n+1} = bx_n$$
#
# Donde $x_n$ y $y_n$ son las coordenadas de un punto en el plano, y $a$ y $b$ son dos parámetros que controlan el comportamiento del mapa. El mapa de Hénon es uno de los ejemplos más estudiados de sistemas dinámicos que muestran comportamiento caótico, es decir, una gran sensibilidad a las condiciones iniciales y una estructura fractal.
#
# El mapa de Hénon fue introducido por Michel Hénon como un modelo simplificado de la sección de Poincaré del modelo de Lorenz, que es otro sistema dinámico caótico que describe la convección atmosférica². Para los valores clásicos del mapa de Hénon, que son $a = 1.4$ y $b = 0.3$, un punto inicial del plano se acercará a un conjunto de puntos conocido como el atractor extraño de Hénon, o divergirá al infinito. El atractor de Hénon es una curva suave en una dirección y un conjunto de Cantor en otra.
#
# Su tarea será:
# 1. Construir una gráfica de xn como función de N
# 2. Construir una gráfica de yn como función de N
# 3. Construir una gráfica de xn, yn.
# 4. Para b=0.3, construir una curva de xn como función de a, con a entre 0, 1
#
#
# Reto, con tu codigo, reproducir los fractales mostrados en esta página https://blbadger.github.io/henon-map.html

# %%
#Funciones para el mapa de Henon
def ecuacion_henonx(x0,y,a): #Para la ecuación 1 del mapa
  valor=1-(a*x0**2) + y
  return valor


def mapa_henonx(n,x0,y,a):
  x=np.zeros(n) #Este vector se redifinirá con los valores resultantes de aplicar la ecuación
  x[0]=x0 #Para el valor incial de la población
  for i in range(1,n): #Recursividad
    x1=ecuacion_henonx(x0,y,a) #Se aplica la ecuación del mapa de Henon para x
    x0=x1
    x[i]=x1 #Igula las componentes del vector de ceros a los resultados de la iteración
  return x

def ecuacion_henony(x,b):  #Para la ecuacion 2 del mapa
  valor2=b*x
  return valor2

def mapa_henony(n,x,b,y0):
  y=np.zeros(n) #Este vector se redifinirá con los valores resultantes de aplicar la ecuación
  y[0]=y0 #Para el valor incial de la población
  for i in range(1,n): #Recursividad
    y1=ecuacion_henony(x,b) #Se aplica la ecuación del mapa de Henon para y
    y0=y1
    y[i]=y1 #Igula las componentes del vector de ceros a los resultados de la iteración
  return y

# %%
fig, axs = plt.subplots(2, 2, figsize=(10,10))

#Grafico para xn en función de N.
x=mapa_henonx(100, 0, 0.1, 1.3 )
axs[0, 0].plot(x, '.g-')
axs[0, 0].set_title('Mapa de Henon: ${x_n}$ en función del N ',fontsize=12)
axs[0, 0].set_ylabel('${x_n}$')
axs[0, 0].set_xlabel("""n
Figura 5. Representa el valor de ${x_n}$
en función del N""",fontsize=12)

#Gráfico para yn en funcion de N
y=mapa_henony(100,1,0.3,0.1)
axs[0, 1].plot(y, '.r-')
axs[0, 1].set_title('Mapa de Henon: ${y_n}$ en función del N ',fontsize=12)
axs[0, 1].set_ylabel('${y_n}$')
axs[0, 1].set_xlabel("""n
Figura 6. Representa el valor de ${y_n}$
en función del N""",fontsize=12)

#Grafico para xn,yn
axs[1, 0].plot(x, y, '.b-')
axs[1, 0].set_title('Mapa de Henon:${x_n}$, ${y_n}$ ',fontsize=12)
axs[1, 0].set_ylabel('${y_n}$')
axs[1, 0].set_xlabel("""${x_n}$
Figura 6. Representa el par ordenado (${x_n}$, ${y_n}$)""",fontsize=12)


#Gráfico para xn en función de a, con b=0.3
def ecuacion_henonxa(x0,a,b): #Esto permite hacer la ecuación de Henon para Xn, reemplazando y, por x0*b
  valor=1-(a*x0**2) + x0*b
  return valor

def mapa_henonxa(n,x0,b): #Esta ecuación permitirá la gráficación de los valores
  a=np.linspace(0,1,n) #Esto permite que se generen n a que esten entre 0 y 1
  x=np.zeros(n) #Vector de ceros que luego se reemplazará
  x[0]=x0 #Para tomar el valor inicial
  for i in range(1,n): #Recursividad para producir los distintos valores
    for j in a: #Itera sobre el linspace que esta entre 0 y 1
      x1=ecuacion_henonxa(x0,j,b)
      x0=x1
      x[i]=x1 #Redefine los valores del vector de ceros
  return x

b=0.3
xn=mapa_henonxa(15,1,b)
axs[1, 1].plot(xn, '.m-')
axs[1, 1].set_title('Mapa de Henon:${x_n}$ en función de a ',fontsize=12)
axs[1, 1].set_ylabel('${y_n}$')
axs[1, 1].set_xlabel("""${x_n}$
Figura 7. Representa los valores de ${x_n}$ en función
de a, que está entre valores de (0,1) y para b=0.3""",fontsize=12)

fig.tight_layout()

# %% [markdown]
# ## 3.0  Gradiente descendente
# El algoritmo de gradiente descendente permite encontrar el mínimo de funciones en espacios multidimensionales proponiendo puntos en la dirección en la que el gradiente desciende. Para el caso de una dimensión, podemos encontrar el mínimo realizando iteraciones y multiplicando su derivada en cada nuevo punto por una constante $\alpha$
#
# \begin{equation}
# x_{i+1}=x_i - \alpha \frac{\mathrm{d}f}{\mathrm{d}x}(x_i)
# \end{equation}
#
#
# Ejemplo:
#
# Sea $f(\omega) = (\omega-1)^2$ , con $\omega \in \mathbb{R} $. El minimo de esta función esta determinado por
# \begin{equation}
# \frac{\mathrm{d}f}{\mathrm{d}\omega} = 0
# \end{equation}
#
# \begin{equation}
# \omega = 1
# \end{equation}
#
#
# Para determinar el minimo,  a través del gradiente descendente puede ser aplicada el siguiente algoritmo:
# 1. Proponer un número aleatorios inicial $\omega_i$
# 2. Para descender al mínimo de la función, encontremos un  valor para el cual
# la derivada de la función descenciende, asi:
# \begin{equation}
# \omega_{i+1} = \omega_{i} - \alpha \frac{\mathrm{d}f(\omega_i)}{\mathrm{d}\omega}
# \end{equation}
#
# donde, $\alpha$ es conocido como la tasa de aprendizaje del algoritmo.
#
# 3. Evaluar $f(\omega_{i+1})$
#
# 4. Iterar hasta encontrar el minimo de la función
#
#
# En el caso de la funcion propuesta, asumiendo un valor de $\alpha=1$, tenemos que:
#
# 1. Supongamos que $\omega_{0} = 2$, luego :
# 2. $\omega_{0+1} = 2 - 1 f'(\omega_{0}) =  = 0$
# 3. $f(0) = 1$
# 4. $\omega_{1+1} = 0 - 1 f'(\omega_{1}) = 0-1(2(0-1)) =  2$
#
# El valor del $\omega$  despues de un par de iteraciones, no es el esperado, por que no minimiza la función, se debe proponer un tasa de aprendizaje  **$\alpha$** de tal forma que permita descender suavemente para encontrar el minimo.
#
#
#
# **Su tarea será**:
#
# 1. Disenar un programa, en el que entrada la función y su derivada, definidas como funciones lambda de python, se determine el valor mínimo de esa función.
# Prueba tu algoritmo para  la función $f(x) = x^2$
#
# 2. Realiza el grafico de la funcion y la derivada, especifica la leyenda de cada curva empleando el metodo legend() de matplotlib.
#
#
# 3. Analiza como se minimiza la función, gráficando de la funcion en cada punto a iterar,  como funcion del numero de iteraciones. Para dos valores diferentes de la constante alpha (prueba con $\alpha=0.1$, $\alpha=0.01$)

# %%
#1.Evaluar con while |w1-w2|<epsilon
#Función y su derivada
f=lambda x: x**2
df=lambda x: 2*x

def minimo_funcion(funcion,derivada,w0,alpha,epsilon):
  valores_f=[] #Acá se guardaran los valores de f evaluada en cada wi

  while (abs(derivada(w0))>=epsilon): #Iterará hasta que la derivada (gradiente), para acercarse a un mínimo
    w1=w0-alpha*df(w0)
    valores_f.append(funcion(w1))
    w0=w1 #Permite redefinir los valores y continuar con la iteración hasta cumplir la condicion
  valor_minimo=min(valores_f)

  return valor_minimo

a=minimo_funcion(f,df,2,0.1,1E-12)
a
# Out:
# 1.627933211152311e-25

# %%
#2.
#Valores para x
x=np.linspace(-20,20,70)
plt.figure(figsize=(8,8))
plt.title('Función y su derivada',fontsize=12)
plt.ylabel('f(x)',fontsize=12)
plt.xlabel('''x
Figura 8. La función y su derivada evaluada
para valores de x entre -20 y 20''',fontsize=12)
plt.plot(x,f(x),'m-', label='${x^2}$')
plt.plot(x,df(x),'g-',label='${2x}$')
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %%
#3.
#Se redefine la función para obtener todos los valores de la función evaluada en cada wi

def minimo_funcion_grafico(funcion,derivada,w0,alpha,epsilon):
  valores_f=[]

  while (abs(derivada(w0))>=epsilon):
    w1=w0-alpha*df(w0)
    valores_f.append(funcion(w1))
    w0=w1
  return valores_f


f_01=minimo_funcion_grafico(f,df,2,0.1,1E-12) #Esté sera la lista de valores para alpha de 0.1
f_001=minimo_funcion_grafico(f,df,2,0.01,1E-12) #Esté sera la lista de valores para alpha de 0.01

#Grafico
plt.figure(figsize=(8,8))
plt.title('Minimización de la función',fontsize=12)
plt.ylabel('f(x)',fontsize=12)
plt.xlabel('''Número de Iteraciones

Figura 9. f(x) en función del número de iteraciones''',fontsize=12)
plt.plot(f_01,'r-', label='Para f con ${\\alpha=0.1}$')
plt.plot(f_001,'-', label='Para f con ${\\alpha=0.01}$')
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %% [markdown]
# Para la figura 9, note como la función en particular, decrece más rápido para el valor de ${\alpha=0.1}$
