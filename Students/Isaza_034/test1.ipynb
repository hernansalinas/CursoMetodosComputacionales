# %%
# Initialize Otter
import otter
grader = otter.Notebook("test1.ipynb")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5607b188ec52> in <cell line: 2>()
#       1 # Initialize Otter
# ----> 2 import otter
#       3 grader = otter.Notebook("test1.ipynb")
#
# ModuleNotFoundError: No module named 'otter'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogradesMetodosComputacionales/blob/main/Actividades_clase/actividad03/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import otter
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pylab as plt
#import otter
#grader = otter.Notebook()

# %% [markdown]
# **Question 1:** Escribir una función llamada `promedio` que retorne el promedio de una arrray de numpy

# %%
def promedio(z):
  i=0
  sum=0
  for r in range(len(z)):
    sum=sum+z[r]
    i = i+1
  v=sum/i
  return v
z=[2,5,6, 7, 8, 9, 10]
promedio(z)
# Out:
# 6.714285714285714

# %%
grader.check("q1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e65af2900b1d> in <cell line: 1>()
# ----> 1 grader.check("q1")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# **Question 2:** Create a DataFrame mirroring the table below and assign this to `data`. Then group by the `flavor` column and find the mean price for each flavor; assign this **series** to `price_by_flavor`.
#
# | flavor | scoops | price |
# |-----|-----|-----|
# | chocolate | 1 | 2 |
# | vanilla | 1 | 1.5 |
# | chocolate | 2 | 3 |
# | strawberry | 1 | 2 |
# | strawberry | 3 | 4 |
# | vanilla | 2 | 2 |
# | mint | 1 | 4 |
# | mint | 2 | 5 |
# | chocolate | 3 | 5 |

# %%
data = pd.DataFrame({"flavor":["chocolate","vainilla","chocolate","strawberry","strawberry","vainilla","mint","mint","chocolate"],"scoops":[1,1,2,1,3,2,1,2,3],"price":[2,1.5,3,2,4,2,4,5,5]})
df =pd.DataFrame(data)
df
df= df.set_index(df.flavor)
price_by_flavor = data.groupby("flavor")["price"].mean()
price_by_flavor
# Out:
# flavor
# chocolate     3.333333
# mint          4.500000
# strawberry    3.000000
# vainilla      1.750000
# Name: price, dtype: float64

# %%
grader.check("q2")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 3:** Create a barplot of `price_by_flavor`.

# %%
plt.figure(figsize=(6,4))
plt.bar(price_by_flavor.index,price_by_flavor.values,color="skyblue")
plt.xlabel("Sabor")
plt.ylabel("Precio promedio")
plt.title("Precio promedio por sabor")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **Question 4:** What do you notice about the bar plot?

# %% [markdown]
# Lo que quiere decir la grafica de barras es que la menta es uno de los sabores mas caros del mercado y uno de los mas baratos es la vainilla.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# These are some submission instructions.

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(run_tests=True)
