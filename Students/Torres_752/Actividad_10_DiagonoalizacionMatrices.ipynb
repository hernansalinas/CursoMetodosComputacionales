# %% [markdown]
# # Autovalores, autovectores, polinomio caracteristico, diagonalización

# %% [markdown]
# | Librería | Función | Explicación |
# | --- | --- | --- |
# | numpy | numpy.linalg.eig | Calcula los autovalores y autovectores derechos de una matriz cuadrada |
# | numpy | numpy.linalg.eigh | Calcula los autovalores y autovectores de una matriz hermítica compleja o simétrica real |
# | numpy | numpy.poly | Calcula el polinomio característico de una matriz |
# | sympy | sympy.Matrix.eigenvals | Calcula los autovalores de una matriz simbólica |
# | sympy | sympy.Matrix.eigenvects | Calcula los autovalores y autovectores de una matriz simbólica |
# | sympy | sympy.Matrix.charpoly | Calcula el polinomio característico de una matriz simbólica |

# %% [markdown]
# Calcular el polinomio caracteristico, los  autovalores y autvectores propios de la siguiente matrices, comprobar con la solucion analitica:
#
# 1.
# \begin{bmatrix}
# 1 & -1 & 4 \\
# 3 & 2 & -1 \\
# 2 & 1 & -1
# \end{bmatrix}
#
#
# 2. \begin{bmatrix}
# 3 & -5 \\
# 1 & -1 \\
# \end{bmatrix}

# %%
#@title librerias
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# ##1.
# \begin{equation} A=
# \begin{bmatrix}
# 1 & -1 & 4 \\
# 3 & 2 & -1 \\
# 2 & 1 & -1
# \end{bmatrix}
# \end{equation}

# %%
# 1)
a1=np.array([1,-1,4])
a2=np.array([3,2,-1])
a3=np.array([2,1,-1])

A=np.array([a1,a2,a3])


# Valores propios y vectores propios:

eigenvalues_A, ev_A = np.linalg.eig(A)
eigenvect_A=ev_A.T
print(f'Valores propios de A:{eigenvalues_A}','\n')
print('Vectores propios de A(normalizados):' ,'\n' f'{eigenvect_A}')
# Out:
# Valores propios de A:[ 3. -2.  1.]
#
# Vectores propios de A(normalizados):
# [[ 0.40824829  0.81649658  0.40824829]
#  [ 0.57735027 -0.57735027 -0.57735027]
#  [ 0.23570226 -0.94280904 -0.23570226]]

# %%
v1=eigenvect_A[0]
v2=eigenvect_A[1]
v3=eigenvect_A[2]

# %%
#Polinomio caracteristico de A :
#p_A=np.poly(eigenval_A)

A_s=sp.Matrix([[1,-1,4],[3,2,-1],[2,1,-1]])
A_s

p_A=A_s.charpoly().as_expr()
p_A
# Out:
# lambda**3 - 2*lambda**2 - 5*lambda + 6

# %%
eigvals__S= sp.Matrix.eigenvals(A_s)


eigvals__S # El resultado de este modulo es un diccionario con la siguiente forma ,    Claves:Eigenvalores,  Valores :Multiplicidad del valor propio
# Out:
# {3: 1, 1: 1, -2: 1}

# %%
eigvect_A_s=sp.Matrix.eigenvects(A_s)
eigvect_A_s

#v1_s=eigvect_A_s[2][2]
#v2_s=eigvect_A_s[0][2]
#v3_s=eigvect_A_s[1][2]
# Out:
# [(-2,
#   1,
#   [Matrix([
#    [-1],
#    [ 1],
#    [ 1]])]),
#  (1,
#   1,
#   [Matrix([
#    [-1],
#    [ 4],
#    [ 1]])]),
#  (3,
#   1,
#   [Matrix([
#    [1],
#    [2],
#    [1]])])]

# %%
#Diagonalizacion de la matriz A:
# Construimos una matriz cuyas columnas correspondan a los vectores propios de A:


eigenvalues_A, ev_A = np.linalg.eig(A)
eigenvect_A=ev_A.T


P=ev_A

#Hallamos la inversa de P:

P_inv=np.linalg.inv(P)

# Realizamos el producto matricial: D=(P^-1)(A)(P)

D=((P_inv)@A)@P
D

for i in range(len(D)):
  for j in range(len(D[i])):
    D[i][j]=D[i][j].round()
    
   
print(' D =','\n' f'{D}')
# Out:
#  D =
# [[ 3. -0. -0.]
#  [ 0. -2. -0.]
#  [ 0. -0.  1.]]

# %% [markdown]
# ##2.
# \begin{equation} B=
# \begin{bmatrix}
# 3 & -5 \\
# 1 & -1 \\
# \end{bmatrix}
# \end{equation}

# %%
b1=np.array([3,-5])
b2=np.array([1,-1])
B=np.array([b1,b2])
B
# Out:
# array([[ 3, -5],
#        [ 1, -1]])

# %%
# Valores propios y vectores propios:

eigenvalues_B, ev_B = np.linalg.eig(B)
λ0=eigenvalues_B[0]
λ1=eigenvalues_B[1]

eigenvect_B = ev_B.T
w0=eigenvect_B[0]
w1=eigenvect_B[1]

print(f'Valores propios de A:{eigenvalues_B}','\n')
print('Vectores propios de A(normalizados):' ,'\n' f'{eigenvect_B}')
# Out:
# Valores propios de A:[1.+1.j 1.-1.j]
#
# Vectores propios de A(normalizados):
# [[0.91287093+0.j         0.36514837-0.18257419j]
#  [0.91287093-0.j         0.36514837+0.18257419j]]

# %%
#Polinomio caracteristico de B :
#p_A=np.poly(eigenval_A)

B_s=sp.Matrix([[3,-5],[1,-1]])
B_s

p_B=B_s.charpoly().as_expr()
p_B
# Out:
# lambda**2 - 2*lambda + 2

# %%
#Diagonalizacion de la matriz B:
# Construimos una matriz cuyas columnas correspondan a los vectores propios de A:


eigenvalues_B, ev_B = np.linalg.eig(B)
eigenvect_B = ev_B.T

C=ev_B

#Hallamos la inversa de C:

C_inv=np.linalg.inv(C)

# Realizamos el producto matricial: R=(C^-1)(B)(C), de modo que R sea la una matriz diagonal cuyas entradas no nulas coincidan con los valores propios de B

R=((C_inv)@B)@C
R

for i in range(len(R)):
  for j in range(len(R[i])):
    R[i][j]=R[i][j].round()
    
   
print(' R =','\n' f'{R}')
# Out:
#  R =
# [[ 1.+1.j -0.-0.j]
#  [-0.+0.j  1.-1.j]]

# %% [markdown]
# # Diagonalizacion
# Una matriz cuadrada $A$ es diagonalizable si y solo si cada autovalor $\lambda$ de multiplicidad $m$ produce exactamente $m$ autovectores básicos; es decir, si y solo si la solución general del sistema $(A-I\lambda)\vec{x}=0$ tiene exactamente $m$ parámetros.
#
#
# Para diagonalizar una matriz $A$, se necesita encontrar una matriz invertible $P$ tal que $P^{-1}AP$ sea una matriz diagonal $D$. Esto significa que las columnas de $P$ son los autovectores de $A$ y los elementos de la diagonal de $D$ son los autovalores correspondientes de $A$.
#
# Encuentre la matrix diagnonal para las matrices anteriores.

# %% [markdown]
# Actividad 2.
#
# Considere la ecuación cuadrática $x^2-4xy+3y^2=6$, esta ecuación cuadrática se corresponde a una hiperbola, la cual puede ser escrita en forma matricial como sigue:
#
# $A\vec{v} \cdot \vec{v}=6$, donde $\vec{v}=(x, y)$ y A es una matrix simetrica,
#
# \begin{equation}
# A=\begin{bmatrix}
# 1 & -2 \\
# -2 & 3 \\
# \end{bmatrix}
# \end{equation}
#
# 1. Realice un grafico que represente la hyperbola
#
#
#
#
#
#
#
# - Diagonalice A, para ello construya la matrix Q de autovectores ortoganales
# tal que $D=Q^{T}AQ$, en este caso se dice que A es diagonalizable ortogonalmente, donde $A=QDQ^T$.
#
# - Aplique el resultado de la siguiente demostración para encontrar una nueva hyperbola en una  nueva base
#
# \begin{equation}
# QDQ^T \vec{v} \cdot \vec{v} = d
# \end{equation}
#
#
# \begin{equation}
# Q(DQ^T\vec{v}) \cdot \vec{v} = (DQ^T\vec{v}) \cdot (Q^T\vec{v})=d
# \end{equation}
#
#
# \begin{equation}
# (DQ^T\vec{v}) \cdot (Q^T\vec{v})=d
# \end{equation}
#
#
# Sea $u=Q^T\vec{v}$
#
# Luego :
#
#
# \begin{equation}
# (D\vec{u}) \cdot \vec{u}=d
# \end{equation}
#
# donde $\vec{u}=(x', y')$, tal que $D\vec{u} \cdot \vec{u}=d$ es una nueva hyperbola

# %%
# Grafico de la hiperbola:
x=np.linspace(-20,20,100)
y=np.linspace(-20,20,100)

x,y= np.meshgrid(x,y)
plt.contour(x, y, (x**2-4*x*y+3*y**2-6) , [0])

# %%
A=np.array([[1,-2],[-2,3]])

eigenstuff_A=np.linalg.eig(A)
autovectores_A=eigenstuff_A[1].T
Q=autovectores_A # Matriz cuyas columnas son los vectores propios de A

D=(Q)@(A)@(Q.T) # Matriz diagonal resultante

for i in range(len(D)):
  for j in range(len(D[i])):
    D[i][j]=round(D[i][j], ndigits=3)
    
   
print('D =','\n' f'{D}')
# Out:
# D =
# [[-0.236 -0.   ]
#  [-0.     4.236]]

# %%
c0=D[0][0]
c1=D[1][1]
# Out:
# 4.236

# %%
# Grafico de la hiperbola:
x=np.linspace(-20,20,100)
y=np.linspace(-20,20,100)

x,y= np.meshgrid(x,y)
plt.contour(x, y, (x**2-4*x*y+3*y**2-6) , [0])
plt.contour(x, y, (c0*x**2 + c1*y**2 -6 ) , [0],colors='green')
plt.grid()

# %%
D=((Q)@A)@(Q.T)
D
# Out:
# array([[-2.36067977e-01, -3.46944695e-16],
#        [-2.22044605e-16,  4.23606798e+00]])

# %% [markdown]
# \begin{equation}
# X^TAX  = d \Longrightarrow        Y^TDY  = d
# \end{equation}
#
# \begin{equation}
# X = QY
# \end{equation}
