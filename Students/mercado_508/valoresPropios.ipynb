# %%
import numpy as np
a = np.matrix([[1,2],
               [3,4]])
a
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
valor = a[0,1]
valor
# Out:
# 2

# %%
def determinante2(a):
 det = (a[0,0]*a[1,1])-(a[0,1]*a[1,0])
 return det

# %%
resultado1 = determinante2(a)
resultado1
# Out:
# -2

# %%
b = np.matrix([[1,2,3],
               [4,5,6],
               [7,8,9]])

# %%
b = np.matrix([[1,2,3],
               [4,5,6],
               [7,8,9]])
def determinante3(determinante,b):
  a1 = b[1:3:1,1:3:1]
  a2 = b[1:3:1,0:3:2]
  a3 = b[1:3:1,0:2:1]
  det3 = b[0,0]*determinante(a1)-b[0,1]*determinante(a2)+b[0,2]* determinante(a3)
  return det3
resultado2 = determinante3(determinante,b)
resultado2
# Out:
# 0

# %% [markdown]
# # sympy
