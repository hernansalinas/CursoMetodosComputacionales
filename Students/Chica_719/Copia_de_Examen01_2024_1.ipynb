# %% [markdown]
# # Examen 1: Métodos computacionales.
#
# ## Profesor: Hernán Salinas
# ### Universidad de Antioquia
#
#
# El examen consta de 7 puntos, cada uno de igual valor, el uso de herramientas de IA no esta permitido. Puede usar la documentacion de scipy, numpy, matplotlib.
#
# La entrega se realiza a través del github del curso.
#
#
# #### Examen
#
# Una esfera de masa $m$ es lanzada desde la superficie de la tierra con velocidad $\vec{v_0}$. Las fuerzas que actúan sobre la bolita son: el peso $m\vec{g}$, y la fuerza de rozamiento $\vec{f}=-mb\vec{v}_0$ que el  aire ejerce sobre la bolita. Un digrama de cuerpo libre es esquematizado en la siguiente figura.
#
# ![Movimiento parabolico](http://www.sc.ehu.es/sbweb/fisica/dinamica/stokes2/stokes1.gif)
#
# Para dar solución al movimiento de la bolita, se debe plantear las ecuaciones de movimiento desde la segunda ley de Newton y después solucionarla para encontrar la ecuaciones de posición y velocidad. Su tarea será determinar el valor del alcance máximo para diferentes ángulos de lanzamiento. Para ello lea detenidamente lo siguiente:
#
# Las **ecuaciones de movimiento** de la bolita vienen dadas por:
# \begin{equation}
# m\frac{\mathrm{d}v_x}{\mathrm{d}t} = - mbv_x
# \end{equation}
#
#
# \begin{equation}
# m\frac{\mathrm{d}v_y}{\mathrm{d}t} = - mg-mbv_y
# \end{equation}
#
#
# donde:
#
# $v_{0x}=v_0\cos \theta$,  $v_{0y}=v_0\sin \theta$,  $b$ el coeficiente de rozamiento con el aire, y $g$ la aceleración de la gravedad
#
#
# La solución a las ecuaciones anteriores para la **posición ($x$, $y$) y la velocidad ($v_x$, $v_y$)**  son:
#
#
# \begin{equation}
# x =  \frac{v_{0x}}{b}\left( 1-e^{-bt} \right)
# \end{equation}
#
# \begin{equation}
# y =  \frac{1}{b}\left( \frac{g}{b}+v_{0y}\right)(1-e^{-bt})-\frac{g}{b}t
# \end{equation}
#
#
# \begin{equation}
# v_x = v_{0x}e^{-bt}
# \end{equation}
#
# \begin{equation}
# v_y = \left(\frac{g}{b}+v_{0y} \right) e^{-bt}-\frac{g}{b}
# \end{equation}
#
#
#
# **Alcance máximo**
#
# El tiempo asociado al alcance máximo del proyectil se da cuando $x=R$, despejando de la ecuación para $x$ el tiempo, se tiene que:
#
# \begin{equation}
# t_v=-\frac{1}{b} \ln \left(1-\frac{Rb}{v_{0x}} \right)
# \end{equation}
#
# Reemplanzando en la ecuación para $y$ obtenemos que:
# \begin{equation}
# y =\left(\frac{g}{b} + v_{0y}  \right) \frac{R}{v_{0x}}+\frac{g}{b^2}\ln \left(1-\frac{Rb}{v_{0x}} \right)
# \end{equation}
#
# El alcance máximo R, estará deteminado cuando $y=0$ en la anterior ecuación. Notese que es una ecuación trascendental. Su tarea será determinar el valor de R para diferentes ángulos de lanzamiento, para ello realice lo siguiente:
#
#
#
#
#
# 1. Construir una función de python paramétrica para determinar el valor de R.
# $y = f(R, \theta, v_{ox},v_{oy},b,g)$
#
#
#
# 2. Asumiento que la bolita es lanzada con una rapidez de
# $v_0=55\mathrm{m}/\mathrm{s}$ y un ángulo de $45^{\circ}$ respecto a la horizontal, $b=0.005$ y $g=9.8\mathrm{m}/\mathrm{s^2}$, determine el alcance máximo. Emplee el método que desee.
#
#
# 3. Valide el resutado anterior, con un método diferente al que empleo en el apartado anterior y además, determine el tiempo de vuelo $t_v$.
#
#
# 4. Construya una gráfica de $x$ vs $t$, $y$ vs $t$, $x$ vs $y$. Asegurese de  no superar en las trayectorias los tiempos establecidos por el  tiempo de vuelo $t_v$.
#
# Ahora,  vamos a mostrar la trayectoria para múltiples ángulos de lanzamiento.
#
# 5. Suponiendo,  $b=0.009$, $v_0 = 40\mathrm{m}/\mathrm{s}$ y  $\theta$ entre $0<\theta<90^{\circ}$ en pasos de $5^{\circ}$:
# ```python
# theta=np.arange(0, 90, 5)
# theta=np.deg2rad(theta)
# ```
#
#
# generalice el resultado del punto  número 2  para determinar el conjunto de valores de R asociados a cada ángulo. Con lo anterior determine los tiempos de vuelo.
#
# 6. Realice un gráfico de $R$ vs $t_v$
#
# 7. Finalmente, construya todas las trayectorias ($y$ vs $x$) para cada ángulo $\theta$.

# %% [markdown]
# La solución a las ecuaciones anteriores para la **posición ($x$, $y$) y la velocidad ($v_x$, $v_y$)**  son:
#
#
# \begin{equation}
# x =  \frac{v_{0x}}{b}\left( 1-e^{-bt} \right)
# \end{equation}
#
# \begin{equation}
# y =  \frac{1}{b}\left( \frac{g}{b}+v_{0y}\right)(1-e^{-bt})-\frac{g}{b}t
# \end{equation}
#
#
# \begin{equation}

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import math as m

# %%
#Su tarea será determinar el valor del alcance máximo para diferentes ángulos de lanzamiento.

# %% [markdown]
# 1. Construir una función de python paramétrica para determinar el valor de R.
# $y = f(R, \theta, v_{ox},v_{oy},b,g)$
#
#
#
# 2. Asumiento que la bolita es lanzada con una rapidez de
# $v_0=55\mathrm{m}/\mathrm{s}$ y un ángulo de $45^{\circ}$ respecto a la horizontal, $b=0.005$ y $g=9.8\mathrm{m}/\mathrm{s^2}$, determine el alcance máximo. Emplee el método que desee.
#
#
# 3. Valide el resutado anterior, con un método diferente al que empleo en el apartado anterior y además, determine el tiempo de vuelo $t_v$.
#
#
# 4. Construya una gráfica de $x$ vs $t$, $y$ vs $t$, $x$ vs $y$. Asegurese de  no superar en las trayectorias los tiempos establecidos por el  tiempo de vuelo $t_v$.
#
# Ahora,  vamos a mostrar la trayectoria para múltiples ángulos de lanzamiento.
#
# 5. Suponiendo,  $b=0.009$, $v_0 = 40\mathrm{m}/\mathrm{s}$ y  $\theta$ entre $0<\theta<90^{\circ}$ en pasos de $5^{\circ}$:
# ```python
# theta=np.arange(0, 90, 5)
# theta=np.deg2rad(theta)
# ```

# %% [markdown]
# $v_{0x}=v_0\cos \theta$,  $v_{0y}=v_0\sin \theta$
#
# \begin{equation}
# t_v=-\frac{1}{b} \ln \left(1-\frac{Rb}{v_{0x}} \right)
# \end{equation}
#
# Reemplanzando en la ecuación para $y$ obtenemos que:
# \begin{equation}
# y =\left(\frac{g}{b} + v_{0y}  \right) \frac{R}{v_{0x}}+\frac{g}{b^2}\ln \left(1-\frac{Rb}{v_{0x}} \right)
# \end{equation}

# %% [markdown]
# \begin{equation}
# x =  \frac{v_{0x}}{b}\left( 1-e^{-bt} \right)
# \end{equation}
#
# \begin{equation}
# y =  \frac{1}{b}\left( \frac{g}{b}+v_{0y}\right)(1-e^{-bt})-\frac{g}{b}t
# \end{equation}
#
#
# \begin{equation}

# %%
x0=8

v0=55
theta=45

v0_x=v0*np.sin(theta)
v0_y=v0*np.sin(theta)
t = np.linspace(0,10)
b=0.009
y=lambda t:(1/b)*((g/b)+v0_y)*(1-np.exp(-b*t))-(g/b)*t
x=lambda t:(v0_x/b)*(1-np.exp(-b*t))
root2 = sc.optimize.newton(y,x0)
plt.plot(t,y(t))
plt.plot(root2,y(root2),"ro")
#plt.plot(t,x(t))


plt.legend()

plt.grid()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x0=400
root = sc.optimize.newton(y,x0)

print(f"el alcance maximo es:{x(root)}m")

plt.plot(x(t),y((t)))
plt.plot(x(root), y(root),"ro")

plt.legend()
plt.xlabel('Distancia[m]')
plt.ylabel('altura[m]')
plt.grid()

# %% [markdown]
# En esta parte empieza el parcial corregido respecto a lo que habia subido

# %%
#R = np.linspace(0,400,40)
def fun_para(R, theta, v0, b, g):
  theta = 45
  v0 = 55
  b = 0.005
  g = 9.8

  v0_x = v0 * np.cos(np.radians(theta))
  v0_y = v0 * np.sin(np.radians(theta))
  p1 = ((g / b) + v0_y) * (R/v0_y)
  p2 = (g / (b ** 2)) * np.log(1 - (R * b) / v0_x)
  f = p1 + p2
  return f
y=fun_para(R, theta, v0, b, g)

# %%
x0=300
root = sc.optimize.newton(lambda R: fun_para(R, theta, v0, b, g), x0)
print("Root:", root)
# Out:
# Root: 300.6920766931813

# %%
R = np.linspace(0,400,40)
plt.plot(R,y, label="Función")
plt.plot(root,fun_para(root,theta, v0, b, g),"ro" )
plt.title("Función maximo alcance")
plt.xlabel("Distancia horizontal (m)")
plt.ylabel("Distancia vertical (m)")
#plt.plot(R, max_al(R), label="Función modificada")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# \begin{equation}
# t_v=-\frac{1}{b} \ln \left(1-\frac{Rb}{v_{0x}} \right)
# \end{equation}
# 3. Valide el resutado anterior, con un método diferente al que empleo en el apartado anterior y además, determine el tiempo de vuelo $t_v$.
#
#
# 4. Construya una gráfica de $x$ vs $t$, $y$ vs $t$, $x$ vs $y$. Asegurese de  no superar en las trayectorias los tiempos establecidos por el  tiempo de vuelo $t_v$.
#
# Ahora,  vamos a mostrar la trayectoria para múltiples ángulos de lanzamiento.
#
# 5. Suponiendo,  $b=0.009$, $v_0 = 40\mathrm{m}/\mathrm{s}$ y  $\theta$ entre $0<\theta<90^{\circ}$ en pasos de $5^{\circ}$:
# ```python
# theta=np.arange(0, 90, 5)
# theta=np.deg2rad(theta)
# ```

# %%
def tv(R,v0, theta, b ):

  b = 0.005
  v0 = 55
  v0_x = v0 * np.cos(np.radians(theta))
  t_vu = (-1 / b) * np.log(1 - ((R * b) / v0_x))
  return t_vu
print(f"el tiempo de vuelo corresponde: {tv(root,v0, theta, b)}")
# Out:
# el tiempo de vuelo corresponde: 7.885101833163972

# %%
t = np.linspace(0,tv(R,v0, theta, b ),100)
#y=lambda t:(1/b)*((g/b)+v0_y)*(1-np.exp(-b*t))-(g/b)*t
x=lambda t:(v0_x/b)*(1-np.exp(-b*t))

plt.plot(t,x(t),"r*", )
plt.ylabel("x (m) ")
plt.xlabel("t (s)")
plt.title("Grafica X vs t")
plt.legend()
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
t = np.linspace(0,tv(R,v0, theta, b ),100)
y=lambda t:(1/b)*((g/b)+v0_y)*(1-np.exp(-b*t))-(g/b)*t
plt.plot(t,y(t),"r*", )
plt.ylabel("x (m) ")
plt.xlabel("t (s)")
plt.title("Grafica X vs t")
plt.legend()
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(x(t),y(t),"r*", )
plt.ylabel("x (m) ")
plt.xlabel("t (s)")
plt.title("Grafica X vs t")
plt.legend()
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
"""Intente terminar lo otro pero no medio en el momento que llame la funcion y asi no pude hacer los otros puntos
"""
theta=45
def fun_para(R, theta):
  theta=45
  v0 = 40
  b = 0.009
  g = 9.8

  v0_x = v0 * np.cos(np.radians(theta))
  v0_y = v0 * np.sin(np.radians(theta))
  p1 = ((g / b) + v0_y) * (R/v0_y)
  p2 = (g / (b ** 2)) * np.log(1 - (R * b) / v0_x)
  f = p1 + p2
  return f
fun_para(R, theta)
# Out:
# array([   0.        ,    9.61069202,   17.9242988 ,   24.93228439,
#          30.62602835,   34.99682455,   38.03588007,   39.73431404,
#          40.08315646,   39.07334699,   36.69573375,   32.94107208,
#          27.80002327,   21.2631533 ,   13.32093153,    3.96372934,
#          -6.81818114,  -19.03462847,  -32.69554326,  -47.81095961,
#         -64.39101651,  -82.44595936, -101.98614143, -123.02202539,
#        -145.56418485, -169.62330596, -195.21018898, -222.33574991,
#        -251.01102219, -281.24715835, -313.05543174, -346.44723829,
#        -381.4340983 , -418.02765822, -456.23969256, -496.0821057 ,
#        -537.56693387, -580.70634707, -625.51265107, -671.99828945])

# %%
the=np.arange(0, 90, 5)
the=np.deg2rad(the)
def t3v(R,the):
  b=0.009
  v0=40
  v0_x=v0*np.cos(the)
  t_vu=(-1/b)*np.log(1-((R*b)/(v0_x)))
  return t_vu
F= t3v(root,the)
print(f"el tiempo : {F}")
# Out:
# el tiempo : [  7.78368116   7.814484     7.90813246   8.06847047   8.30234212
#    8.62033833   9.03805403   9.57815458  10.27381402  11.17462144
#   12.35721839  13.94569253  16.15398631  19.38411574  24.49026546
#   33.66677419  54.85148016 166.36454355]

# %%
the=np.arange(0, 90, 5)
the=np.deg2rad(the)
v0_x=v0*np.cos(the)
v0_x
the
# Out:
# array([0.        , 0.08726646, 0.17453293, 0.26179939, 0.34906585,
#        0.43633231, 0.52359878, 0.61086524, 0.6981317 , 0.78539816,
#        0.87266463, 0.95993109, 1.04719755, 1.13446401, 1.22173048,
#        1.30899694, 1.3962634 , 1.48352986])
