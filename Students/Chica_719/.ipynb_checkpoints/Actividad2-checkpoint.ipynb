# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange
import sympy as sp
import scipy as sc
from scipy import optimize

# %%
a=30 #metros
def P(y):
  P=101325+(1027)*(9.8)*y
  return(P)
y=np.linspace(0,a,10)
k=P(a)/(101325)
plt.figure(figsize=(6,4))
plt.plot(y,P(y),"o-", label=str(k)+"Pa")
plt.xlabel("Profundidad [m]",fontsize=10)
plt.ylabel("Presion[Pa]",fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend()
plt.show()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

def cargar_datos_desde_json(archivo):
    with open(archivo, 'r') as archivo_json:
        datos = json.load(archivo_json)
    return datos

def calcular_trayectoria(theta, vo, d):
    g = 9.81  # Aceleración debido a la gravedad en m/s^2
    theta_rad = np.radians(theta)
    vx = vo * np.cos(theta_rad)
    vy = vo * np.sin(theta_rad)

    # Tiempo de vuelo
    t_vuelo = (2 * vy) / g

    # Rango horizontal
    x = vx * t_vuelo

    # Altura máxima alcanzada
    y_max = (vy ** 2) / (2 * g)

    # Altura final
    y = vy * t_vuelo - 0.5 * g * (t_vuelo ** 2)

    return x, y

def graficar_trayectoria(x, y, altura_objetivo):
    plt.plot(x, y, label='Trayectoria de la pelota')
    plt.axhline(y=altura_objetivo, color='r', linestyle='--', label='Altura de la cesta')
    plt.xlabel('Distancia horizontal (m)')
    plt.ylabel('Altura (m)')
    plt.title('Movimiento parabólico del lanzamiento de baloncesto')
    plt.legend()
    plt.grid(True)
    plt.show()

datos = cargar_datos_desde_json('datos.json')
angulo = datos['angulo']
vo = datos['vo']
distancia = datos['distancia']
altura_objetivo = 3  # Altura de la cesta en metros

x, y = calcular_trayectoria(angulo, vo, distancia)
graficar_trayectoria(x, y, altura_objetivo)

# Verificar si la pelota pasa por encima de la altura de la cesta
if y >= altura_objetivo:
    print("El jugador encestó.")
else:
    print("El jugador no encestó.")

graficar_trayectoria(theta, vo, d, tiempo_vuelo, alcance_horizontal)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-f91f81f603e7> in <cell line: 40>()
#      38     plt.show()
#      39
# ---> 40 datos = cargar_datos_desde_json('datos.json')
#      41 angulo = datos['angulo']
#      42 vo = datos['vo']
#
# <ipython-input-7-f91f81f603e7> in cargar_datos_desde_json(archivo)
#       4
#       5 def cargar_datos_desde_json(archivo):
# ----> 6     with open(archivo, 'r') as archivo_json:
#       7         datos = json.load(archivo_json)
#       8     return datos
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datos.json'
