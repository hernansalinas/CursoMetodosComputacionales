# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Actividades_clase/Actividad_04_Binarios_Errores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
#
# # Actividad 4
# ### Métodos computacionales para físicos  y astrónomos
# ### Universidad de Antioquia
# ### Prof: Hernan D. Salinas Jiménez

# %%
# !git clone https://github.com/hernansalinas/autogrades.git
#path="libs"
path="autogrades/Actividades_clase/libs"
# %run -i {path}/libUnitTest.py
# Out:
# Cloning into 'autogrades'...
# remote: Enumerating objects: 642, done.
# remote: Counting objects: 100% (258/258), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 642 (delta 144), reused 153 (delta 82), pack-reused 384
# Receiving objects: 100% (642/642), 38.78 MiB | 39.08 MiB/s, done.
# Resolving deltas: 100% (338/338), done.

# %% [markdown]
# ### Activity 1.0:
#
# Implement a function that get the binary representation of an integer with name mybin, the algorithm should return
# a string with 8 characters, the maximun number that represent the funcition is integer of 8 bit. The name of function is
# mybin
#
# Ejexample :
#
# b=mybin(x)
#
# b='00101000'

# %%
##!/usr/bin/env python3

# Estudiante: Alejandro Rios Yepes. (CC1036966630)

# Definimos la función
def mybin(numero):
    # Inicializar una cadena vacía para guardar el resultado
    binario = ""
    # Repetir mientras el número sea mayor que 0
    while numero > 0:
        # Obtener el residuo de dividir el número entre 2
        residuo = numero % 2
        # Agregar el residuo al inicio de la cadena binaria
        binario = str(residuo) + binario
        # Actualizar el número dividiéndolo entre 2
        numero = numero // 2
    # Repetir mientras la longitud de la cadena binaria sea menor que 8
    while len(binario) < 8:
        # Agregar un cero al inicio de la cadena binaria
        binario = "0" + binario
    # Devolver la cadena binaria como resultado
    return binario

# Pedir el número al usuario como entrada y convertirlo a entero
numero = int(input("Ingresa un número entero: "))
# Mostrar el resultado llamando a la función mybin con el número ingresado
print(mybin(numero))
# Out:
# Ingresa un número entero: 2
# 00000010

# %%
# %run -i {path}/Act_02/test01.py
# Out:
# <style>
#   table { text-align: left; border-collapse: collapse; margin: 1em; caption-side: bottom; font-family: Sans-Serif; font-size: 12px}
#   caption { text-align: left; padding: 5px }
#   th, td { border: 2px solid #BFC9CA; padding: 5px }
#   th { background-color: #BFC9CA }
#   .passed { background-color: #76D7C4 }
#   .failed { background-color: #EC7063 }
#   .skipped { background-color: #EDBB99 }
#   .score { background-color: #7DCEA0 }
#   .results .points { display: none }
#   .results .message { display: block; font-size:smaller; color:#D35400 }
#   .results .note { display: block; font-size:smaller; font-decoration:italics }
#   .results .passed::before  { content: "Passed" }
#   .results .skipped::before  { content: "Skipped" }
#   .results .failed::before  { content: "Failed" }
#   .grade .passed  .message:empty::before { content:"Passed" }
#   .grade .failed  .message:empty::before { content:"Failed" }
#   .grade .skipped .message:empty::before { content:"Skipped" }
# </style>
# <table class='results'>
#   <th class='test'>Test</th><th class='result'>Result</th></tr>
# <tr>
#   <td class='test'>
#     La salida debe ser un string
#     <div class='message'>Done</div>
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='test'>
#     La longitud del string debe ser de 8
#     <div class='message'>Done</div>
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='test'>
#     Para el número 119 su representacion es 01110111
#     <div class='message'>Done</div>
#   </td>
#   <td class='result passed'></td>
# </tr>  <tr><th class='score'>Total Points</th><th class='score'>3</th></tr></table>

# %% [markdown]
# ### Activity 2.0:
#
# With the binary representation please try to implement the formula to recover the number.
#
# Hint: Use as input the binary representation as a string and invert its order
#
# ```
# number32(BIN):
#
# ```
#
# Where BIN is a string with the binary number
#
# Example:
#
#
# Test your solution for the next number:
#
# number32("00111110001000000000001000010000")

# %%
def number32(BIN):
    # Obtener el signo, el exponente y la mantisa
    sign = int(BIN[0])
    exponent = int(BIN[1:9], 2) - 127
    mantissa = 1.0

    # Calcular la parte fraccional
    for i in range(9, len(BIN)):
        mantissa += int(BIN[i]) * 2 ** (-i + 8)

    # Calcular el valor final
    value = ((-1) ** sign) * mantissa * (2 ** exponent)
    return value

resultado = number32("00111110001000000000001000010000")
print(resultado)
# Out:
# 0.15625786781311035

# %%
# %run -i {path}/Act_02/test02.py
# Out:
# <style>
#   table { text-align: left; border-collapse: collapse; margin: 1em; caption-side: bottom; font-family: Sans-Serif; font-size: 12px}
#   caption { text-align: left; padding: 5px }
#   th, td { border: 2px solid #BFC9CA; padding: 5px }
#   th { background-color: #BFC9CA }
#   .passed { background-color: #76D7C4 }
#   .failed { background-color: #EC7063 }
#   .skipped { background-color: #EDBB99 }
#   .score { background-color: #7DCEA0 }
#   .results .points { display: none }
#   .results .message { display: block; font-size:smaller; color:#D35400 }
#   .results .note { display: block; font-size:smaller; font-decoration:italics }
#   .results .passed::before  { content: "Passed" }
#   .results .skipped::before  { content: "Skipped" }
#   .results .failed::before  { content: "Failed" }
#   .grade .passed  .message:empty::before { content:"Passed" }
#   .grade .failed  .message:empty::before { content:"Failed" }
#   .grade .skipped .message:empty::before { content:"Skipped" }
# </style>
# <table class='results'>
#   <th class='test'>Test</th><th class='result'>Result</th></tr>
# <tr>
#   <td class='test'>
#     La salida debe ser un float
#     <div class='message'>Done</div>
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='test'>
#     Realizando prueba para un numero binario
#     <div class='message'>Done</div>
#   </td>
#   <td class='result passed'></td>
# </tr>  <tr><th class='score'>Total Points</th><th class='score'>2</th></tr></table>

# %% [markdown]
# ### Activity 3.0:
# 1. Write a python script that calculates the double precision number represented by a 64-bits binary.
#
# the name of function should be:
# ```
# number64(BIN):
#
# ```
#
# 2. What is the number represented by:
#
# BIN="0 10000000011 1011100100001111111111111111111111111111111111111111"

# %%
def number64(BIN):
    # Obtener el signo, el exponente y la mantisa
    sign = int(BIN[0])
    exponent = int(BIN[1:12], 2) - 1023
    mantissa = 1.0

    # Calcular la parte fraccional
    for i in range(12, len(BIN)):
        mantissa += int(BIN[i]) * 2 ** (-i + 11)

    # Calcular el valor final
    value = ((-1) ** sign) * mantissa * (2 ** exponent)

    # Convertir el valor a formato de punto flotante
    result = "{:.17f}".format(value)

    return result

resultado = number64("0100000000111011100100001111111111111111111111111111111111111111")
print(resultado)
# Out:
# 27.56640624999999645

# %%
# %run -i {path}/Act_02/test03.py
# Out:
#   File "/content/autogrades/Actividades_clase/libs/Act_02/test03.py", line 28
#     True)
#         ^
# SyntaxError: unmatched ')'
