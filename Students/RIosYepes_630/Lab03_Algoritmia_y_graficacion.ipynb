# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab03_Algoritmia_y_graficacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Estudiante:** Alejandro Rios Yepes (CC1036966630)
#
# Métodos computacionales - UdeA.

# %% [markdown]
# # Laboratorio 03
#
#
# ## 1.0 Mapa logístico
# Caos numérico en un mapa logístico y errores de punto flotante (Errores de redondeo)
#
# > Un ejemplo clásico de caos,  es el comportamiento no lineal en las interaciones de un mapa logístico
#
# \begin{equation}
# x_{n+1}=f(x_n)=rx_n(1-x_n)
# \end{equation}
#
# > con $x\in (0,1)$ y $r\in(0,4)$ se pueden producir varios comportamientos sorprendentes.
#
# Para este problema, será extremadamente útil  ver sus resultados gráficamente; construya listas de números y llame la libreria matplotlib.
#
#
# > ### Problema:
# a. Programar la ecuación para el mapa logístico, y  realizar una grafica del valor de xn como funcion de n.
#
# b. Realizar pruebas para un $x_0=0.5$, con valores de r
#
# ```
#   r = np.array([1.9, 2.9, 3.1, 3.5, 3.9,4.0])
#   numpoints = 100, # Numero sugerido de iteraciones
#   x0 = 0.5
# ```
#
# Organizar las gráficas [multiples plot](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html)
#
#
#
# c. Construye una rutina llamada logist_map en que entrada el valor de r, la condiciones inicial xi y el número de puntos determine la evolución en el punto N.  Prueba implementado las siguientes lineas.
#
# ```
# Np = 1000
# xf = np.zeros(Np)
# r  = np.linspace(2.5, 4, Np)
#
# for i in range(0, Np):
#   xini = np.random.random()
#   x_i = logist_map(r = r[i], xi = xini, N = 1000)
#   xf[i] = x_i
# ```
#
#
# d. Realiza un gráfico de:
# ```
#   plt.plot((r-1/r), xf,  ".", markersize = 0.5)
# ```
#
#
# e. Encontrar dos formas adicionales de expresar $f(x)$, para estos valores funcionales determinar las mismas gráficas del numeral 3 para cada uno de las formas de escribir la expresión. En este caso se espera que los resultados varien. ¿A que se debe esto?. Consulta algunas fuentes para responder a la pregunta.
#
#
# Ref: https://www.youtube.com/watch?v=EOvLhZPevm0&t=104s

# %%
# Item a)
# Importar la librería matplotlib
import matplotlib.pyplot as plt

# Definir la función del mapa logístico
def mapa_logistico(x0, r, n):
  # Inicializar una lista vacía para almacenar los valores de x
  x = []
  # Asignar el valor inicial de x
  x.append(x0)
  # Usar un bucle for para iterar n veces
  for i in range(n):
    # Calcular el valor siguiente de x usando la fórmula del mapa logístico
    x_siguiente = r * x[i] * (1 - x[i])
    # Añadir el valor siguiente a la lista de x
    x.append(x_siguiente)
  # Devolver la lista de x
  return x

# Asignar los valores de los parámetros
x0 = 0.5 # Valor inicial de x
r = 3.8 # Valor de r
n = 100 # Número de iteraciones

# Llamar a la función del mapa logístico y guardar el resultado en una variable
x = mapa_logistico(x0, r, n)

# Crear una lista con los valores de n
n = list(range(n+1))

# Graficar x como función de n usando la librería matplotlib
plt.plot(n, x, 'b.')
plt.xlabel('n')
plt.ylabel('x')
plt.title('Mapa logístico')
plt.show()

# %%
# Item b)
# Importar las librería numpy
import numpy as np

# Asignar los valores de los parámetros
numpoints = 100 # Número sugerido de iteraciones
x0 = 0.5 # Valor inicial de x
r = np.array([1.9, 2.9, 3.1, 3.5, 3.9,4.0]) # Array de valores de r

# Crear una figura con 6 subgráficas usando la función subplot
fig, axs = plt.subplots(2, 3)

# Usar un bucle for para iterar sobre el array de r
for i in range(len(r)):
  # Llamar a la función del mapa logístico y guardar el resultado en una variable
  x = mapa_logistico(x0, r[i], numpoints)
  # Crear una lista con los valores de n
  n = list(range(numpoints+1))
  # Graficar x como función de n en la subgráfica correspondiente
  axs[i//3, i%3].plot(n, x, 'b.')
  axs[i//3, i%3].set_xlabel('n')
  axs[i//3, i%3].set_ylabel('x')
  axs[i//3, i%3].set_title('Mapa logístico con r = ' + str(r[i]))


# Ajustar el espacio entre las subgráficas
plt.tight_layout()
plt.subplots_adjust(wspace=2)
# Mostrar la figura
plt.show()

# %%
# Item c)

def logist_map(r, xi, N):
  # Esta función aplica el mapa logístico N veces al valor inicial xi con el parámetro r
  x = xi # Inicializamos x con el valor inicial
  for n in range(N): # Iteramos N veces
    x = r * x * (1 - x) # Aplicamos la fórmula del mapa logístico
  return x # Devolvemos el último valor de x

Np = 1000 # Número de puntos
xf = np.zeros(Np) # Vector para guardar los valores finales
r  = np.linspace(2.5, 4, Np) # Vector de valores de r entre 2.5 y 4

for i in range(0, Np): # Para cada valor de r
  xini = np.random.random() # Generamos un valor inicial aleatorio entre 0 y 1
  x_i = logist_map(r = r[i], xi = xini, N = 1000) # Aplicamos la rutina logist_map
  xf[i] = x_i # Guardamos el valor final en el vector xf

# Aquí puedes hacer lo que quieras con el vector xf, por ejemplo graficarlo

plt.plot(r, xf, ".") # Hacemos un gráfico de puntos con r en el eje x y xf en el eje y
plt.xlabel("r") # Etiquetamos el eje x
plt.ylabel("xf") # Etiquetamos el eje y
plt.title("Mapa logístico") # Ponemos un título al gráfico
plt.show() # Mostramos el gráfico

# %%
# Item d)
plt.plot((r-1/r), xf,  ".", markersize = 0.5)

# %%
# Item e)


# Definimos una nueva función para el mapa logístico con una expresión exponencial
def logist_map_exp(r, xi, N):
    x = xi  # Inicializamos x con el valor inicial
    for n in range(N):  # Iteramos N veces
        x = r * x * np.exp(-x)  # Aplicamos la fórmula del mapa logístico con la expresión exponencial
    return x  # Devolvemos el último valor de x

# Definimos el número de puntos y creamos un vector para guardar los valores finales
Np = 1000
xf_exp = np.zeros(Np)

# Creamos un vector de valores de r entre 2.5 y 4
r = np.linspace(2.5, 4, Np)

# Iteramos a través de cada valor de r
for i in range(Np):
    # Generamos un valor inicial aleatorio entre 0 y 1
    xini = np.random.random()
    # Aplicamos la rutina logist_map_exp con la expresión exponencial
    x_i = logist_map_exp(r=r[i], xi=xini, N=1000)
    # Guardamos el valor final en el vector xf_exp
    xf_exp[i] = x_i

# Hacemos un gráfico de puntos con r en el eje x y xf_exp en el eje y
plt.plot(r, xf_exp, ".")
plt.xlabel("r")  # Etiquetamos el eje x
plt.ylabel("xf (Exp)")  # Etiquetamos el eje y
plt.title("Mapa logístico con Forma Exponencial")  # Ponemos un título al gráfico
plt.show()  # Mostramos el gráfico

# %%
# Definimos una nueva función para el mapa logístico con una expresión trigonométrica
def logist_map_trig(r, xi, N):
    x = xi  # Inicializamos x con el valor inicial
    for n in range(N):  # Iteramos N veces
        x = r * np.sin(np.pi * x)  # Aplicamos la fórmula del mapa logístico con la expresión trigonométrica
    return x  # Devolvemos el último valor de x

# Creamos un vector para guardar los valores finales con la expresión trigonométrica
xf_trig = np.zeros(Np)

# Volvemos a crear un vector de valores de r entre 2.5 y 4
r = np.linspace(2.5, 4, Np)

# Iteramos a través de cada valor de r
for i in range(Np):
    # Generamos un valor inicial aleatorio entre 0 y 1
    xini = np.random.random()
    # Aplicamos la rutina logist_map_trig con la expresión trigonométrica
    x_i = logist_map_trig(r=r[i], xi=xini, N=1000)
    # Guardamos el valor final en el vector xf_trig
    xf_trig[i] = x_i

# Hacemos un gráfico de puntos con r en el eje x y xf_trig en el eje y
plt.plot(r, xf_trig, ".")
plt.xlabel("r")  # Etiquetamos el eje x
plt.ylabel("xf (Trig)")  # Etiquetamos el eje y
plt.title("Mapa logístico con Forma Trigonométrica")  # Ponemos un título al gráfico
plt.show()  # Mostramos el gráfico

# %% [markdown]
# ## 2. Mapa de henon
# El mapa de Hénon es un sistema dinámico discreto en el tiempo que se define por las siguientes ecuaciones:
#
# $$x_{n+1} = 1 - ax_n^2 + y_n$$
# $$y_{n+1} = bx_n$$
#
# Donde $x_n$ y $y_n$ son las coordenadas de un punto en el plano, y $a$ y $b$ son dos parámetros que controlan el comportamiento del mapa. El mapa de Hénon es uno de los ejemplos más estudiados de sistemas dinámicos que muestran comportamiento caótico, es decir, una gran sensibilidad a las condiciones iniciales y una estructura fractal.
#
# El mapa de Hénon fue introducido por Michel Hénon como un modelo simplificado de la sección de Poincaré del modelo de Lorenz, que es otro sistema dinámico caótico que describe la convección atmosférica². Para los valores clásicos del mapa de Hénon, que son $a = 1.4$ y $b = 0.3$, un punto inicial del plano se acercará a un conjunto de puntos conocido como el atractor extraño de Hénon, o divergirá al infinito. El atractor de Hénon es una curva suave en una dirección y un conjunto de Cantor en otra.
#
# Su tarea será:
# 1. Construir una gráfica de xn como función de N
# 2. Construir una gráfica de yn como función de N
# 3. Construir una gráfica de xn, yn.
# 4. Para b=0.3, construir una curva de xn como función de a, con a entre 0, 1
#
#
# Reto, con tu codigo, reproducir los fractales mostrados en esta página https://blbadger.github.io/henon-map.html

# %%
import matplotlib.pyplot as plt  # Importamos la biblioteca matplotlib para trazar gráficos

# Parámetros del mapa de Hénon
a = 1.4
b = 0.3

# Condiciones iniciales
x0 = 0.1
y0 = 0.1

# Número de iteraciones
N = 10000

# Listas para almacenar las coordenadas x e y
xn = []  # Lista para las coordenadas x
yn = []  # Lista para las coordenadas y

# Aplicar el mapa de Hénon iterativamente
for n in range(N):
    # Calculamos xn y yn usando las ecuaciones del mapa de Hénon
    xn.append(y0 + 1 - a * x0 ** 2)
    yn.append(b * x0)

    # Actualizamos las condiciones iniciales para la siguiente iteración
    x0 = xn[-1]
    y0 = yn[-1]

# Creamos las gráficas
plt.figure(figsize=(12, 4))  # Creamos una figura con un tamaño específico

# Gráfica de xn como función de N
plt.subplot(131)  # Dividimos la figura en 1 fila, 3 columnas y seleccionamos la primera subtrama
plt.plot(range(N), xn)  # Trazamos xn en función de N
plt.xlabel('N')  # Etiqueta del eje x
plt.ylabel('xn')  # Etiqueta del eje y
plt.title('xn vs N')  # Título de la gráfica

# Gráfica de yn como función de N
plt.subplot(132)  # Seleccionamos la segunda subtrama
plt.plot(range(N), yn)  # Trazamos yn en función de N
plt.xlabel('N')  # Etiqueta del eje x
plt.ylabel('yn')  # Etiqueta del eje y
plt.title('yn vs N')  # Título de la gráfica

# Gráfica de xn vs yn
plt.subplot(133)  # Seleccionamos la tercera subtrama
plt.plot(xn, yn, '.', markersize=1)  # Trazamos xn vs yn con puntos pequeños
plt.xlabel('xn')  # Etiqueta del eje x
plt.ylabel('yn')  # Etiqueta del eje y
plt.title('xn vs yn')  # Título de la gráfica

plt.tight_layout()  # Ajustamos automáticamente la disposición de las subtramas

# Mostramos las gráficas
plt.show()

# Crear la curva de xn como función de a
a_values = [i / 100 for i in range(101)]  # Valores de a entre 0 y 1 en incrementos de 0.01
xn_a = []  # Lista para almacenar xn para diferentes valores de a

for a in a_values:
    x0 = 0.1  # Restablecemos la condición inicial x0
    xn_temp = []  # Lista temporal para almacenar xn para un valor particular de a
    for n in range(N):
        xn_temp.append(y0 + 1 - a * x0 ** 2)  # Calculamos xn usando el mapa de Hénon
        x0 = xn_temp[-1]  # Actualizamos x0 para la siguiente iteración
    xn_a.append(xn_temp[-1])  # Agregamos el último valor de xn para este valor de a

# Gráfica de xn como función de a
plt.figure()  # Creamos una nueva figura
plt.plot(a_values, xn_a)  # Trazamos xn vs a
plt.xlabel('a')  # Etiqueta del eje x
plt.ylabel('xn')  # Etiqueta del eje y
plt.title('xn vs a')  # Título de la gráfica

plt.show()  # Mostramos la gráfica

# %%
# Parámetros del mapa de Hénon
a = 1.4
b = 0.3

# Condiciones iniciales
x0 = 0.1
y0 = 0.1

# Número de iteraciones
N = 10000

# Listas para almacenar las coordenadas x e y
xn = []
yn = []

# Aplicar el mapa de Hénon iterativamente
for n in range(N):
    xn.append(y0 + 1 - a * x0 ** 2)
    yn.append(b * x0)

    # Actualizar las condiciones iniciales para la siguiente iteración
    x0 = xn[-1]
    y0 = yn[-1]

# Crear la gráfica de xn vs yn
plt.figure(figsize=(8, 6))
plt.plot(xn, yn, '.', markersize=1)
plt.xlabel('xn')
plt.ylabel('yn')
plt.title('Atractor de Hénon con a=1.4 y b=0.3')
plt.show()

# %% [markdown]
# ## 3.0  Gradiente descendente
# El algoritmo de gradiente descendente permite encontrar el mínimo de funciones en espacios multidimensionales proponiendo puntos en la dirección en la que el gradiente desciende. Para el caso de una dimensión, podemos encontrar el mínimo realizando iteraciones y multiplicando su derivada en cada nuevo punto por una constante $\alpha$
#
# \begin{equation}
# x_{i+1}=x_i - \alpha \frac{\mathrm{d}f}{\mathrm{d}x}(x_i)
# \end{equation}
#
#
# Ejemplo:
#
# Sea $f(\omega) = (\omega-1)^2$ , con $\omega \in \mathbb{R} $. El minimo de esta función esta determinado por
# \begin{equation}
# \frac{\mathrm{d}f}{\mathrm{d}\omega} = 0
# \end{equation}
#
# \begin{equation}
# \omega = 1
# \end{equation}
#
#
# Para determinar el minimo,  a través del gradiente descendente puede ser aplicada el siguiente algoritmo:
# 1. Proponer un número aleatorios inicial $\omega_i$
# 2. Para descender al mínimo de la función, encontremos un  valor para el cual
# la derivada de la función descenciende, asi:
# \begin{equation}
# \omega_{i+1} = \omega_{i} - \alpha \frac{\mathrm{d}f(\omega_i)}{\mathrm{d}\omega}
# \end{equation}
#
# donde, $\alpha$ es conocido como la tasa de aprendizaje del algoritmo.
#
# 3. Evaluar $f(\omega_{i+1})$
#
# 4. Iterar hasta encontrar el minimo de la función
#
#
# En el caso de la funcion propuesta, asumiendo un valor de $\alpha=1$, tenemos que:
#
# 1. Supongamos que $\omega_{0} = 2$, luego :
# 2. $\omega_{0+1} = 2 - 1 f'(\omega_{0}) =  = 0$
# 3. $f(0) = 1$
# 4. $\omega_{1+1} = 0 - 1 f'(\omega_{1}) = 0-1(2(0-1)) =  2$
#
# El valor del $\omega$  despues de un par de iteraciones, no es el esperado, por que no minimiza la función, se debe proponer un tasa de aprendizaje  **$\alpha$** de tal forma que permita descender suavemente para encontrar el minimo.
#
#
#
# **Su tarea será**:
#
# 1. Disenar un programa, en el que entrada la función y su derivada, definidas como funciones lambda de python, se determine el valor mínimo de esa función.
# Prueba tu algoritmo para  la función $f(x) = x^2$
#
# 2. Realiza el grafico de la funcion y la derivada, especifica la leyenda de cada curva empleando el metodo legend() de matplotlib.
#
#
# 3. Analiza como se minimiza la función, gráficando de la funcion en cada punto a iterar,  como funcion del numero de iteraciones. Para dos valores diferentes de la constante alpha (prueba con $\alpha=0.1$, $\alpha=0.01$)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para encontrar el mínimo de una función usando el método de descenso de gradiente
def find_minimum(f, df, alpha, max_iterations=1000, tol=1e-6):
    x = np.random.rand()  # Inicialización aleatoria de x
    history = []  # Para almacenar el historial de valores de la función
    for i in range(max_iterations):
        gradient = df(x)  # Calcula el gradiente en el punto actual
        x -= alpha * gradient  # Actualiza x usando el descenso de gradiente
        history.append(f(x))  # Registra el valor de la función en este punto
        if abs(gradient) < tol:  # Comprueba si el gradiente es suficientemente pequeño para detenerse
            break
    return x, history  # Devuelve el valor mínimo encontrado y el historial de la función

# Definir la función y su derivada como funciones lambda de Python
f = lambda x: x**2  # Función cuadrática
df = lambda x: 2 * x  # Derivada de la función cuadrática

# Parámetros de prueba
alphas = [0.1, 0.01]

# Encontrar el mínimo y registrar el historial de valores de la función para cada alpha
minima = {}
history = {}
for alpha in alphas:
    x_min, f_history = find_minimum(f, df, alpha)  # Encuentra el mínimo para el valor de alpha actual
    minima[alpha] = x_min  # Registra el valor mínimo en el diccionario
    history[alpha] = f_history  # Registra el historial de valores de la función en el diccionario

# Graficar la función y su derivada
x = np.linspace(-1, 1, 400)  # Crea puntos x para graficar
y = f(x)  # Calcula los valores de la función en esos puntos
dy = df(x)  # Calcula los valores de la derivada en esos puntos

plt.figure(figsize=(12, 6))
plt.plot(x, y, label='Función $f(x) = x^2$', color='blue')  # Grafica la función cuadrática
plt.plot(x, dy, label='Derivada $f\'(x) = 2x$', color='green')  # Grafica la derivada
plt.xlabel('x')
plt.ylabel('y')
plt.legend()  # Agrega leyendas a las curvas
plt.title('Función y Derivada')
plt.grid(True)
plt.show()

# Graficar la convergencia para diferentes valores de alpha
plt.figure(figsize=(12, 6))
for alpha in alphas:
    plt.plot(range(len(history[alpha])), history[alpha], label=f'α = {alpha}')  # Grafica la convergencia
plt.xlabel('Número de Iteraciones')
plt.ylabel('Valor de la Función')
plt.legend()  # Agrega leyendas a las curvas
plt.title('Convergencia del Descenso de Gradiente')
plt.grid(True)
plt.show()

# Mostrar el valor mínimo encontrado para cada alpha
for alpha in alphas:
    print(f'Mínimo para α = {alpha}: x = {minima[alpha]}, f(x) = {f(minima[alpha])}')
# Out:
# Mínimo para α = 0.1: x = 3.923589196201875e-07, f(x) = 1.5394552180552077e-13
# Mínimo para α = 0.01: x = 4.888963446730115e-07, f(x) = 2.3901963583463205e-13
