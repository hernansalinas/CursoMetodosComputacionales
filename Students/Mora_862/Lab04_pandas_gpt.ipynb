# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab04_pandas_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas y chat gpt
#
# ### Problema 1
# 1. a) Generar un diccionario con CHATGPT con los premios nobel de fisica de la decada que tu elijas.  El diccionario debe tener la siguiente estructura:
#
# clave: Nombre del cientifico, el nombre del cientifico se debe llamar de la siguiente forma: Inicial del nombre del cientifico y Apellido, ejemplo: A. Einstein., R. Feyman.
#
# Valor: diccionario con el año y el motivo por que el gano el premio nobel resumido maximo 10 palabras.
#
#
# b). Con el diccionario construir un dataframe de pandas y almacenarlo como un archivo csv. Las columnas del data frame se deberán llamar Cientifico, AnoNobel, Motivo.
#
#
#
#
# ### Problema 2.
#
# Usando el dataset `PS4_1.csv`, convertir la serie `Date` en el indice (serie de tiempo) y eliminar la serie `Unnamed: 1` (generado por pandas), retornar un  diccionario con en el siguiente orden:
#
# * cantidad de columnas
# * Nombre de las columnas
# * número de registros no NaN de cada columna
# * cantidad total de memoria usada para cargar el dataset en el computador ,( df.memory_usage() )
# * Estadistica basica para cada columna, media, desviacion estandar, maximo
# * Remplazar los NaN por None
#
#
# ### Problema 3
#
# Realizar la lectura del data frame "Crimes_-_2019.csv" asociado a los crimenes que se presentaron en Chicago en el 2019.
#
#
# 1. Ver la estadistica general del data frame.
# 2. Elimnar  las columnas PrimaryType, y Date.
# 3. Transformar la columna Date que es tipo string en una tipo Fecha, use el siguiente metodo de pandas pd.to_datetime(df.Date,format="%m/%d/%Y %I:%M:%S %p")
# 4. Mostrar los casos totales para cada tipo de crimen de forma ascendente, emplee:
#    df.groupby(columna).Date.count()
#
#    sort_values()
# 5. Ordenar los valores por orden alfabetico de Primary type
# 6. Mostrar de la fila 100 a la 120
# 6. Realizar una visualización de los datos anteriores.Emplee la libreria  seaborn con un grafico tipo barplot. Ej.
#    ax = sns.barplot(x = "contador", y="Primary Type", data = datos)
#
#
#
#
# ### Problema 4
#
# 1. Leer el dataset country_vaccinations.csv  y filtrar los datos para Colombia
# 2. Crear un csv con los datos para colombia
# 3. Realizar una comparacion con los paises latinoamericanos de la cantidad de vacunados.
# 4. A traves de mascaras determinar el numero de vacunados en el intervalo  [1.5E6, 2.0E6]
#
#
#
#
# Referencias: Puedes consultar la pagina kaggle para estudiar mas acerca de pandas

# %%
#HACER EN CHAT GPT
#Generar un diccionario de python con clave valor, donde la clave son los nombres de los físicos que ganaron el premio novel entre 1927 a 1937
#Incluir en el valor del diccionario un diccionario con el año ene que ganó y 10 palabras con el motivo.
#Ejemplo: Dicc={"A. Eintein.":{1905: "Efecto fotoeléctrico"}}
#El nombre debe escribirlo en las iniciales del nombre y después el apellido

# %%
fisicos_nobel= {
    "C. Wilson": {
        "año": 1927,
        "motivo":  "Desarrollo de la cámara de niebla y su aplicación a la detección de partículas subatómicas"},
    "O. Richardson": {
        "año": 1928,
        "motivo": "Trabajo sobre la termiónica y descubrimiento del efecto Richardson"},
    "P. Broglie": {
        "año":1929,
        "motivo": "Naturaleza ondulatoria de los electrones"},
    "C. Raman": {
        "año":1930,
        "motivo": "Disperción Raman"},
    "N. N": {
        "año":1931,
        "motivo": "Premio no entregado"},
    "W. Pauli": {
        "año": 1932,
        "motivo": "Formas alotrópicas del hidrógeno"},
    "E. Schrödinger": {
        "año": 1933, 
        "motivo": "Desarrollo de la mecánica ondulatoria y la formulación de la ecuación de Schrödinger"},
    "P. Dirac": {
        "año": 1933,
        "motivo": "Desarrollo de la mecánica cuántica y formulación de la ecuación de Dirac para el electrón"},
    "N. N": {
        "año":1934,
        "motivo": "Premio no entregado"},
    "J. Chadwick": {
        "año": 1935,
        "motivo": "Descubrimiento del neutrón"},
    "V. Hess": {
        "año": 1936,
        "motivo": "Radiación cósmica"},
    "C. Davisson": {
        "año":1937,
        "motivo": "Difracción de los electrones causada por cristales"},
    "G. Thomson": {
        "año":1937,
        "motivo": "Difracción de los electrones causada por cristales"},
}

# %%
import pandas as pd
df=pd.DataFrame(fisicos_nobel)
df.transpose().reset_index() #transponer la tabla y ponerle numeración a las filas
# Out:
#              index   año                                             motivo
# 0        C. Wilson  1927  Desarrollo de la cámara de niebla y su aplicac...
# 1    O. Richardson  1928  Trabajo sobre la termiónica y descubrimiento d...
# 2       P. Broglie  1929           Naturaleza ondulatoria de los electrones
# 3         C. Raman  1930                                   Disperción Raman
# 4             N. N  1934                                Premio no entregado
# 5         W. Pauli  1932                   Formas alotrópicas del hidrógeno
# 6   E. Schrödinger  1933  Desarrollo de la mecánica ondulatoria y la for...
# 7         P. Dirac  1933  Desarrollo de la mecánica cuántica y formulaci...
# 8      J. Chadwick  1935                         Descubrimiento del neutrón
# 9          V. Hess  1936                                  Radiación cósmica
# 10     C. Davisson  1937  Difracción de los electrones causada por crist...
# ...

# %%
g=df.transpose().reset_index().copy() #creamos copia de df

# %%
g.columns
# Out:
# Index(['index', 'año', 'motivo'], dtype='object')

# %%
col=["Científico", "Año","Motivo"] #cambiar nombre col

# %%
g = g.rename(columns={"index":"Científico", "año":"Año", "motivo":"Motivo"})
g
# Out:
#         Científico   Año                                             Motivo
# 0        C. Wilson  1927  Desarrollo de la cámara de niebla y su aplicac...
# 1    O. Richardson  1928  Trabajo sobre la termiónica y descubrimiento d...
# 2       P. Broglie  1929           Naturaleza ondulatoria de los electrones
# 3         C. Raman  1930                                   Disperción Raman
# 4             N. N  1934                                Premio no entregado
# 5         W. Pauli  1932                   Formas alotrópicas del hidrógeno
# 6   E. Schrödinger  1933  Desarrollo de la mecánica ondulatoria y la for...
# 7         P. Dirac  1933  Desarrollo de la mecánica cuántica y formulaci...
# 8      J. Chadwick  1935                         Descubrimiento del neutrón
# 9          V. Hess  1936                                  Radiación cósmica
# 10     C. Davisson  1937  Difracción de los electrones causada por crist...
# ...

# %%
g.to_csv('fisicos_nobel.csv', index=False) #para guardar archos en .cvs, "index=false" es para evitar que se agreguen columnas

# %% [markdown]
# PUNTO2

# %%
url="https://docs.google.com/spreadsheets/d/e/2PACX-1vTGtyNnZH9uCYF60T8K_gA9JG36AB3v00s_iiF3pqUDRWpJEIkFlzhSWGQpYEAR6Q/pub?output=xlsx"

# %%
df = pd.read_excel(url)
df
# Out:
#                     Date Unnamed: 1  Berri1  Maisonneuve_1  Maisonneuve_2  \
# 0    2009-01-01 00:00:00   00:00:00    29.0           20.0           35.0
# 1    2009-02-01 00:00:00   00:00:00    19.0            3.0           22.0
# 2    2009-03-01 00:00:00   00:00:00    24.0           12.0           22.0
# 3    2009-04-01 00:00:00   00:00:00    24.0            8.0           15.0
# 4    2009-05-01 00:00:00   00:00:00   120.0          111.0          141.0
# ..                   ...        ...     ...            ...            ...
# 360           27/12/2009   00:00:00    66.0           29.0           52.0
# 361           28/12/2009   00:00:00    61.0           41.0           99.0
# 362           29/12/2009   00:00:00    89.0           52.0          115.0
# 363           30/12/2009   00:00:00    76.0           43.0          115.0
# 364           31/12/2009   00:00:00    53.0           46.0          112.0
#
#      Brebeuf
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# ...

# %%
from datetime import datetime
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(url)
df2=df.drop(["Unnamed: 1"], axis = 1)
df2
# Out:
#                     Date  Berri1  Maisonneuve_1  Maisonneuve_2  Brebeuf
# 0    2009-01-01 00:00:00    29.0           20.0           35.0      NaN
# 1    2009-02-01 00:00:00    19.0            3.0           22.0      NaN
# 2    2009-03-01 00:00:00    24.0           12.0           22.0      NaN
# 3    2009-04-01 00:00:00    24.0            8.0           15.0      NaN
# 4    2009-05-01 00:00:00   120.0          111.0          141.0      NaN
# ..                   ...     ...            ...            ...      ...
# 360           27/12/2009    66.0           29.0           52.0      0.0
# 361           28/12/2009    61.0           41.0           99.0      0.0
# 362           29/12/2009    89.0           52.0          115.0      0.0
# 363           30/12/2009    76.0           43.0          115.0      0.0
# 364           31/12/2009    53.0           46.0          112.0      0.0
#
# [365 rows x 5 columns]

# %%
descripciones = df2.describe()
descripciones['Berri1'][ [0,1,2,7] ]
# Out:
# count     365.000000
# mean     2032.200000
# std      1878.879799
# max      6626.000000
# Name: Berri1, dtype: float64

# %%
dicc={"Columnas":len(df2.keys()), "Nombre de columna": df2.keys(), "número de registros no NaN de columna Berri1":descripciones['Berri1'][0]-365,
      "número de registros no NaN de columna Maisonneuve_1":descripciones['Maisonneuve_1'][0]-365,
      "número de registros no NaN de columna Maisonneuve_2":descripciones['Maisonneuve_2'][0]-365,
      "número de registros no NaN de columna Brebeuf": 365-descripciones['Brebeuf'][0],
      "Memoria utilizada al cargar el dataset en bytes": df.memory_usage(index=True).sum(),
      #Estadistica basica para cada columna, media, desviacion estandar, maximo
      "Media Berril": descripciones['Berri1'][1], 
      "Media Maisonneve_1": descripciones['Maisonneuve_1'][1],
      "Media Maisonneve_2": descripciones['Maisonneuve_2'][1],
      'Media Brebeuf': descripciones['Brebeuf'][1],
      'Desviación estandar Berril':descripciones['Berri1'][2],
      'Desviación estandar  Maisonneve_1':descripciones['Maisonneuve_1'][2],
      'Desviación estandar  Maisonneve_2':descripciones['Maisonneuve_2'][2],
      'Desviación estandar Brebeuf':descripciones['Brebeuf'][2],
      "Máximo Berril": descripciones['Berri1'][7],
      "Máximo Maisonneuve_1": descripciones['Maisonneuve_1'][7],
      "Máximo Maisonneuve_2": descripciones['Maisonneuve_2'][7],
      "Máximo Brebeuf": descripciones['Brebeuf'][7]}
dicc
# Out:
# {'Columnas': 5,
#  'Nombre de columna': Index(['Date', 'Berri1', 'Maisonneuve_1', 'Maisonneuve_2', 'Brebeuf'], dtype='object'),
#  'número de registros no NaN de columna Berri1': 0.0,
#  'número de registros no NaN de columna Maisonneuve_1': 0.0,
#  'número de registros no NaN de columna Maisonneuve_2': 0.0,
#  'número de registros no NaN de columna Brebeuf': 187.0,
#  'Memoria utilizada al cargar el dataset en bytes': 17648,
#  'Media Berril': 2032.2,
#  'Media Maisonneve_1': 1060.2520547945205,
#  'Media Maisonneve_2': 2093.1698630136984,
#  'Media Brebeuf': 2576.3595505617977,
#  'Desviación estandar Berril': 1878.8797986572208,
#  'Desviación estandar  Maisonneve_1': 1079.5330858971347,
#  'Desviación estandar  Maisonneve_2': 1854.368523087829,
#  'Desviación estandar Brebeuf': 2484.004743334495,
#  'Máximo Berril': 6626.0,
#  'Máximo Maisonneuve_1': 4242.0,
#  'Máximo Maisonneuve_2': 6587.0,
#  'Máximo Brebeuf': 7575.0}

# %%
df2 = df2.replace({np.nan: None})
print(df2)
# Out:
#                     Date Berri1 Maisonneuve_1 Maisonneuve_2 Brebeuf
# 0    2009-01-01 00:00:00   29.0          20.0          35.0    None
# 1    2009-02-01 00:00:00   19.0           3.0          22.0    None
# 2    2009-03-01 00:00:00   24.0          12.0          22.0    None
# 3    2009-04-01 00:00:00   24.0           8.0          15.0    None
# 4    2009-05-01 00:00:00  120.0         111.0         141.0    None
# ..                   ...    ...           ...           ...     ...
# 360           27/12/2009   66.0          29.0          52.0     0.0
# 361           28/12/2009   61.0          41.0          99.0     0.0
# 362           29/12/2009   89.0          52.0         115.0     0.0
# 363           30/12/2009   76.0          43.0         115.0     0.0
# 364           31/12/2009   53.0          46.0         112.0     0.0
#
# [365 rows x 5 columns]

# %% [markdown]
# # Punto 3
# Realizar la lectura del data frame "Crimes_-_2019.csv" asociado a los crimenes que se presentaron en Chicago en el 2019.
#
# Ver la estadistica general del data frame.
#
# Elimnar las columnas PrimaryType, y Date.
#
# Transformar la columna Date que es tipo string en una tipo Fecha, use el siguiente metodo de pandas pd.to_datetime(df.Date,format="%m/%d/%Y %I:%M:%S %p")
#
# Mostrar los casos totales para cada tipo de crimen de forma ascendente, emplee: df.groupby(columna).Date.count()
#
# sort_values()
#
# Ordenar los valores por orden alfabetico de Primary type
#
# Mostrar de la fila 100 a la 120
#
# Realizar una visualización de los datos anteriores.Emplee la libreria seaborn con un grafico tipo barplot. Ej. ax = sns.barplot(x = "contador", y="Primary Type", data = datos)

# %%
import pandas as pd

data = pd.read_csv("Crimes_-_2019.csv")
data
# Out:
#                ID Case Number              Date                 Block  IUCR  \
# 0      11864018.0    JC476123    9/24/2019 8:00  022XX S MICHIGAN AVE  1154
# 1      11859805.0    JC471592  10/13/2019 20:30   024XX W CHICAGO AVE   860
# 2      11863808.0    JC476236   10/5/2019 18:30     0000X N LOOMIS ST   810
# 3      11859727.0    JC471542  10/13/2019 19:00    016XX W ADDISON ST  1320
# 4      11859656.0    JC471240  10/13/2019 14:10      051XX N BROADWAY   560
# ...           ...         ...               ...                   ...   ...
# 70990         NaN         NaN               NaN                   NaN   NaN
# 70991         NaN         NaN               NaN                   NaN   NaN
# 70992         NaN         NaN               NaN                   NaN   NaN
# 70993         NaN         NaN               NaN                   NaN   NaN
# 70994         NaN         NaN               NaN                   NaN   NaN
#
# ...

# %%
#eliminar las columnas
data2=data.drop(['Date', 'Primary Type'], axis=1)
data2
# Out:
#                ID Case Number                 Block  IUCR  \
# 0      11864018.0    JC476123  022XX S MICHIGAN AVE  1154
# 1      11859805.0    JC471592   024XX W CHICAGO AVE   860
# 2      11863808.0    JC476236     0000X N LOOMIS ST   810
# 3      11859727.0    JC471542    016XX W ADDISON ST  1320
# 4      11859656.0    JC471240      051XX N BROADWAY   560
# ...           ...         ...                   ...   ...
# 70990         NaN         NaN                   NaN   NaN
# 70991         NaN         NaN                   NaN   NaN
# 70992         NaN         NaN                   NaN   NaN
# 70993         NaN         NaN                   NaN   NaN
# 70994         NaN         NaN                   NaN   NaN
#
#                                    Description          Location Description  \
# 0      FINANCIAL IDENTITY THEFT $300 AND UNDER  COMMERCIAL / BUSINESS OFFICE
# 1                                 RETAIL THEFT            GROCERY FOOD STORE
# ...

# %%
#Mostrar los casos totales para cada tipo de crimen de forma ascendente, emplee: df.groupby(columna).Date.count()
#sort_values()

crimen = data.groupby('Primary Type').Date.count().sort_values(ascending=True)
crimen
# Out:
# Primary Type
# NON-CRIMINAL                             1
# HUMAN TRAFFICKING                        3
# HOMICIDE                                 7
# OBSCENITY                                8
# GAMBLING                                11
# KIDNAPPING                              32
# CONCEALED CARRY LICENSE VIOLATION       34
# CRIMINAL SEXUAL ASSAULT                 36
# INTIMIDATION                            38
# LIQUOR LAW VIOLATION                    42
# STALKING                                51
# ARSON                                   70
# PROSTITUTION                           131
# SEX OFFENSE                            197
# CRIM SEXUAL ASSAULT                    205
# INTERFERENCE WITH PUBLIC OFFICER       288
# PUBLIC PEACE VIOLATION                 297
# OFFENSE INVOLVING CHILDREN             420
# WEAPONS VIOLATION                     1171
# CRIMINAL TRESPASS                     1425
# ROBBERY                               1596
# ...

# %%
#Ordenar los valores por orden alfabetico de Primary type
data.sort_values(by=["Primary Type"]).groupby('Primary Type').Date.count()
# Out:
# Primary Type
# ARSON                                   70
# ASSAULT                               3924
# BATTERY                               9538
# BURGLARY                              1948
# CONCEALED CARRY LICENSE VIOLATION       34
# CRIM SEXUAL ASSAULT                    205
# CRIMINAL DAMAGE                       5040
# CRIMINAL SEXUAL ASSAULT                 36
# CRIMINAL TRESPASS                     1425
# DECEPTIVE PRACTICE                    3277
# GAMBLING                                11
# HOMICIDE                                 7
# HUMAN TRAFFICKING                        3
# INTERFERENCE WITH PUBLIC OFFICER       288
# INTIMIDATION                            38
# KIDNAPPING                              32
# LIQUOR LAW VIOLATION                    42
# MOTOR VEHICLE THEFT                   1836
# NARCOTICS                             3175
# NON-CRIMINAL                             1
# OBSCENITY                                8
# ...

# %%
#Mostrar de la fila 100 a la 120
de_100_a_120 = data.iloc[100:121]
de_100_a_120
# Out:
#              ID Case Number              Date                   Block  IUCR  \
# 100  11859907.0    JC471683  10/13/2019 22:34   104XX S VINCENNES AVE  3710
# 101  11860374.0    JC472166  10/13/2019 14:02     081XX S SANGAMON ST  2826
# 102  11859476.0    JC471139  10/13/2019 13:21  116XX S MARSHFIELD AVE   460
# 103  11643816.0    JC209931     4/3/2019 9:15     079XX S LANGLEY AVE   820
# 104  11859100.0    JC470700   10/13/2019 0:26     003XX W CHESTNUT ST   460
# 105  11859367.0    JC470937   10/13/2019 9:26  050XX N WINCHESTER AVE  1154
# 106  11860787.0    JC472189  10/13/2019 15:00    0000X E ROOSEVELT RD  1150
# 107  11859148.0    JC470728   10/13/2019 1:50         037XX W 57TH PL   486
# 108  11863828.0    JC476269    10/4/2019 0:56    029XX N RIDGEWAY AVE   820
# 109  11859863.0    JC471634  10/13/2019 21:31     022XX S KILDARE AVE   486
# 110  11860264.0    JC472131  10/13/2019 20:00      094XX S NORMAL AVE   820
# ...

# %%
a
# Out:
# Primary Type
# BATTERY                             8
# BURGLARY                            1
# CRIMINAL DAMAGE                     1
# DECEPTIVE PRACTICE                  3
# INTERFERENCE WITH PUBLIC OFFICER    1
# OTHER OFFENSE                       1
# THEFT                               6
# Name: Date, dtype: int64

# %%
#Realizar una visualización de los datos anteriores.Emplee la libreria seaborn con un grafico tipo barplot.
# Ej. ax = sns.barplot(x = "contador", y="Primary Type", data = datos)

import seaborn as sns
import matplotlib.pyplot as plt


a=de_100_a_120.sort_values(by=["Primary Type"]).groupby('Primary Type').Date.count()
sns.barplot(x=a.values, y=a.index)
sns.set(rc={"figure.figsize":(10, 8)})
plt.title("Conteo de crímenes de la posición 100 a la 120 ")
plt.show()

# %% [markdown]
# # Problema 4
# Leer el dataset country_vaccinations.csv y filtrar los datos para Colombia
#
# Crear un csv con los datos para colombia
#
# Realizar una comparacion con los paises latinoamericanos de la cantidad de vacunados.
#
# A traves de mascaras determinar el numero de vacunados en el intervalo [1.5E6, 2.0E6]

# %%
#leer dataset
datos = pd.read_csv("country_vaccinations.csv")
datos
# Out:
#           country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1     Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2     Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3     Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4     Afghanistan      AFG  2021-02-26                 NaN                NaN
# ...           ...      ...         ...                 ...                ...
# 9571     Zimbabwe      ZWE  2021-03-29             81610.0            69751.0
# 9572     Zimbabwe      ZWE  2021-03-30             85866.0            72944.0
# 9573     Zimbabwe      ZWE  2021-03-31             91880.0            76995.0
# 9574     Zimbabwe      ZWE  2021-04-01            105307.0            87791.0
# 9575     Zimbabwe      ZWE  2021-04-02            124753.0           103815.0
#
# ...

# %%
#filtrar datos para Colombia
datoscolombia = datos.loc[datos['country']=='Colombia']
datoscolombia
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 1841  Colombia      COL  2021-02-17                18.0                NaN
# 1842  Colombia      COL  2021-02-18              9935.0                NaN
# 1843  Colombia      COL  2021-02-19             21307.0                NaN
# 1844  Colombia      COL  2021-02-20             33140.0                NaN
# 1845  Colombia      COL  2021-02-21             39827.0                NaN
# 1846  Colombia      COL  2021-02-22             45166.0                NaN
# 1847  Colombia      COL  2021-02-23             48150.0                NaN
# 1848  Colombia      COL  2021-02-24             50524.0                NaN
# 1849  Colombia      COL  2021-02-25             66157.0                NaN
# 1850  Colombia      COL  2021-02-26             81333.0                NaN
# 1851  Colombia      COL  2021-02-27            114042.0                NaN
# ...

# %%
datoscolombia.to_csv('datoscolombia.csv', index=False)

# %%
#Realizar una comparacion con los paises latinoamericanos de la cantidad de vacunados.
colombia = datoscolombia['total_vaccinations']
sumacol=sum(colombia)
sumacol
# Out:
# 35303248.0

# %%
#Venezuela
datosven = datos.loc[datos['country']=='Venezuela']
venezuela= datosven['total_vaccinations']
venezuela = venezuela.replace({np.nan: 0})
sumaven=sum(venezuela)
sumaven
# Out:
# 26574.0

# %%
#Ecuador
datosecua = datos.loc[datos['country']=='Ecuador']
ecuador= datosecua['total_vaccinations']
ecuador = ecuador.replace({np.nan: 0})
sumaecua=sum(ecuador)
sumaecua
# Out:
# 2410101.0

# %%
#Perú
datosperu = datos.loc[datos['country']=='Peru']
peru= datosperu['total_vaccinations']
peru = peru.replace({np.nan: 0})
sumaperu=sum(peru)
sumaperu
# Out:
# 24434065.0

# %%
#Brasil
datosbrasil = datos.loc[datos['country']=='Brazil']
brasil= datosbrasil['total_vaccinations']
brasil = brasil.replace({np.nan: 0})
sumabrasil=sum(brasil)
sumabrasil
# Out:
# 571024737.0

# %%
#Argentina
datosarg = datos.loc[datos['country']=='Argentina']
argentina= datosarg['total_vaccinations']
argentina = argentina.replace({np.nan: 0})
sumaarg=sum(argentina)
sumaarg
# Out:
# 108616678.0

# %%
#Chile
datoschile = datos.loc[datos['country']=='Chile']
chile= datosven['total_vaccinations']
chile = chile.replace({np.nan: 0})
sumachile=sum(chile)
sumachile
# Out:
# 26574.0

# %%
#Bolivia
datosboliv = datos.loc[datos['country']=='Bolivia']
bolivia= datosboliv['total_vaccinations']
bolivia = bolivia.replace({np.nan: 0})
sumaboliv=sum(bolivia)

#Mexico
datosmex = datos.loc[datos['country']=='Mexico']
mexico= datosmex['total_vaccinations']
mexico = mexico.replace({np.nan: 0})
sumamex=sum(mexico)

#Guatemala
datosguate = datos.loc[datos['country']=='Guatemala']
guatemala= datosguate['total_vaccinations']
guatemala = guatemala.replace({np.nan: 0})
sumaguate=sum(guatemala)

#Panama
datospana = datos.loc[datos['country']=='Panama']
panama= datospana['total_vaccinations']
panama = panama.replace({np.nan: 0})
sumapana=sum(panama)

#Puerto Rico
datospuerto = datos.loc[datos['country']=='Puerto Rico']
puertorico= datospuerto['total_vaccinations']
puertorico = puertorico.replace({np.nan: 0})
sumapuerto=sum(puertorico)

#Cuba
datoscuba = datos.loc[datos['country']=='Cuba']
cuba= datoscuba['total_vaccinations']
cuba = cuba.replace({np.nan: 0})
sumacuba=sum(cuba)

#Nicaragua
datosnica = datos.loc[datos['country']=='Nicaragua']
nicaragua= datosnica['total_vaccinations']
nicaragua = nicaragua.replace({np.nan: 0})
sumanica=sum(nicaragua)

#Honduras
datoshond = datos.loc[datos['country']=='Honduras']
honduras= datoshond['total_vaccinations']
honduras = honduras.replace({np.nan: 0})
sumahond=sum(honduras)

#Creo un diccionario para graficarlo
dicc={'Colombia': sumacol, 'Venezuela':sumaven,'Ecuador':sumaecua, 'Peru':sumaperu,'Brasil':sumabrasil,'Argentina':sumaarg,
      'Chile':sumachile, 'Bolivia':sumaboliv, 'Mexico':sumamex,'Guatemala':sumaguate, 'Panama':sumapana, 'Puerto Rico':sumapuerto, 
      'Cuba':sumacuba,'Nicaragua':sumanica,'Honduras':sumahond}

claves = list(dicc.keys())
valores = list(dicc.values())

sns.barplot(x=valores, y=claves)
sns.set(rc={"figure.figsize":(50, 30)})
plt.title("Vacunados en América Latina")
plt.show()

# %%
#A traves de mascaras determinar el numero de vacunados en el intervalo [1.5E6, 2.0E6]
mask = datos['total_vaccinations']>1.5e6
mask2= datos['total_vaccinations']<2.0e6

maskcombination= mask & mask2

masktotal= datos[maskcombination]
masktotal
# Out:
#         country  iso_code        date  total_vaccinations  people_vaccinated  \
# 361   Argentina       ARG  2021-03-07           1526078.0          1182874.0
# 362   Argentina       ARG  2021-03-08           1546699.0          1202998.0
# 363   Argentina       ARG  2021-03-09           1648957.0          1301787.0
# 364   Argentina       ARG  2021-03-10           1774438.0          1424984.0
# 365   Argentina       ARG  2021-03-11           1919074.0          1564555.0
# ...         ...       ...         ...                 ...                ...
# 9527      Wales  OWID_WLS  2021-03-29           1837726.0          1413710.0
# 9528      Wales  OWID_WLS  2021-03-30           1865120.0          1427183.0
# 9529      Wales  OWID_WLS  2021-03-31           1893423.0          1443885.0
# 9530      Wales  OWID_WLS  2021-04-01           1920657.0          1460880.0
# 9531      Wales  OWID_WLS  2021-04-02           1936088.0          1472643.0
#
# ...

# %% [markdown]
# # **EN CLASE**

# %%
import pandas as pd

dicc={"Antioquia":"Medellín", "Meta":"Villavicencio", "Cundinamarca":"Bogotá", "Vichada":"Puerto Carreño"}
#Construir la serie
S=pd.Series({"Antioquia":"Medellín", "Meta":"Villavicencio", "Cundinamarca":"Bogotá", "Vichada":"Puerto Carreño"})

# %%
S.iloc[0:4]
# Out:
# Antioquia             Medellín
# Meta             Villavicencio
# Cundinamarca            Bogotá
# Vichada         Puerto Carreño
# dtype: object

# %%
from numpy import deg2rad
d1={"Color":"Amarillo", "Número":"45", "Objeto":"Balón"}
d2={"Color":"Azul", "Número":"32", "Objeto": "Flor"}
d3={"Color":"Rojo", "Número":"23", "Objeto":"Computador"}
d4={"Color":"Morado", "Número":"18", "Objeto":"Plana"}

record1=pd.Series(d1)
record2=pd.Series(d2)
record3=pd.Series(d3)
record4=pd.Series(d4)

# %%
df1=pd.DataFrame([record1, record2, record3, record4])
df1
# Out:
#       Color Número      Objeto
# 0  Amarillo     45       Balón
# 1      Azul     32        Flor
# 2      Rojo     23  Computador
# 3    Morado     18       Plana

# %%
df1.Color
# Out:
# 0    Amarillo
# 1        Azul
# 2        Rojo
# 3      Morado
# Name: Color, dtype: object

# %%
df1. Color + " "+ df1.Objeto
# Out:
# 0     Amarillo  Balón
# 1          Azul  Flor
# 2    Rojo  Computador
# 3       Morado  Plana
# dtype: object
