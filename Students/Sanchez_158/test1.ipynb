# %%
# Initialize Otter
#import otter
#grader = otter.Notebook("test1.ipynb")

# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogradesMetodosComputacionales/blob/main/Actividades_clase/actividad03/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import otter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
#import otter
#grader = otter.Notebook()

# %% [markdown]
# **Question 1:** Escribir una función llamada `promedio` que retorne el promedio de una arrray de numpy

# %%
def promedio(x):
  y=np.array([x])

  z=np.mean(y)
  return z
  print(y)

# %%
promedio([2,3,4,5,5,6,7,8,9,4,3])
# Out:
# 5.090909090909091

# %%
#grader.check("q1")

# %% [markdown]
# **Question 2:** Create a DataFrame mirroring the table below and assign this to `data`. Then group by the `flavor` column and find the mean price for each flavor; assign this **series** to `price_by_flavor`.
#
# | flavor | scoops | price |
# |-----|-----|-----|
# | chocolate | 1 | 2 |
# | vanilla | 1 | 1.5 |
# | chocolate | 2 | 3 |
# | strawberry | 1 | 2 |
# | strawberry | 3 | 4 |
# | vanilla | 2 | 2 |
# | mint | 1 | 4 |
# | mint | 2 | 5 |
# | chocolate | 3 | 5 |

# %%
df=pd.DataFrame(data = {
    'flavor': ["chocolate", "vainilla", "chocolate", "strawberry", "strawberry", "vainilla", "mint", "mint", "chocolate"],
    'scoops': [1, 1, 2, 1, 3, 2, 1, 2, 3],
    'price': [2, 1.5, 3, 2, 4, 2, 4, 5, 5]
}
)
df
# Out:
#        flavor  scoops  price
# 0   chocolate       1    2.0
# 1    vainilla       1    1.5
# 2   chocolate       2    3.0
# 3  strawberry       1    2.0
# 4  strawberry       3    4.0
# 5    vainilla       2    2.0
# 6        mint       1    4.0
# 7        mint       2    5.0
# 8   chocolate       3    5.0

# %%
price_by_flavor = df.groupby("flavor")["price"].mean()
print(price_by_flavor)
# Out:
# flavor
# chocolate     3.333333
# mint          4.500000
# strawberry    3.000000
# vainilla      1.750000
# Name: price, dtype: float64

# %%
#grader.check("q2")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 3:** Create a barplot of `price_by_flavor`.

# %%
#plt.bar(df.flavor,df.price)
price_by_flavor.plot.bar("flavor","mean")
plt.xlabel("Flavor")
plt.ylabel("Mean")

plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **Question 4:** What do you notice about the bar plot?

# %% [markdown]
# _Type your answer here, replacing this text._
#
# Que es muy útil para comparar cantidades entre diferentes categorías, en este caso entre las categorias "Flavor": [chocolate, mint, strawberry, vainilla].
#
# > Indented block

# %% [markdown]
# <!-- END QUESTION -->

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# These are some submission instructions.

# %%
# Save your notebook first, then run this cell to export your submission.
#grader.export(run_tests=True)
