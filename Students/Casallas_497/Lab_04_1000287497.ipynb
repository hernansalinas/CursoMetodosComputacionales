# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab04_pandas_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas y chat gpt
#
# ### Problema 1
# 1. a) Generar un diccionario con CHATGPT con los premios nobel de fisica de la decada que tu elijas.  El diccionario debe tener la siguiente estructura:
#
# clave: Nombre del cientifico, el nombre del cientifico se debe llamar de la siguiente forma: Inicial del nombre del cientifico y Apellido, ejemplo: A. Einstein., R. Feyman.
#
# Valor: diccionario con el año y el motivo por que el gano el premio nobel resumido maximo 10 palabras.
#
#
# b). Con el diccionario construir un dataframe de pandas y almacenarlo como un archivo csv. Las columnas del data frame se deberán llamar Cientifico, AnoNobel, Motivo.
#
#
#
#
# ### Problema 2.
#
# Usando el dataset `PS4_1.csv`, convertir la serie `Date` en el indice (serie de tiempo) y eliminar la serie `Unnamed: 1` (generado por pandas), retornar un  diccionario con en el siguiente orden:
#
# * cantidad de columnas
# * Nombre de las columnas
# * número de registros no NaN de cada columna
# * cantidad total de memoria usada para cargar el dataset en el computador ,( df.memory_usage() )
# * Estadistica basica para cada columna, media, desviacion estandar, maximo
# * Remplazar los NaN por None
#
#
# ### Problema 3
#
# Realizar la lectura del data frame "Crimes_-_2019.csv" asociado a los crimenes que se presentaron en Chicago en el 2019.
#
#
# 1. Ver la estadistica general del data frame.
# 2. Elimnar  las columnas PrimaryType, y Date.
# 3. Transformar la columna Date que es tipo string en una tipo Fecha, use el siguiente metodo de pandas pd.to_datetime(df.Date,format="%m/%d/%Y %I:%M:%S %p")
# 4. Mostrar los casos totales para cada tipo de crimen de forma ascendente, emplee:
#    df.groupby(columna).Date.count()
#
#    sort_values()
# 5. Ordenar los valores por orden alfabetico de Primary type
# 6. Mostrar de la fila 100 a la 120
# 6. Realizar una visualización de los datos anteriores.Emplee la libreria  seaborn con un grafico tipo barplot. Ej.
#    ax = sns.barplot(x = "contador", y="Primary Type", data = datos)
#
#
#
#
# ### Problema 4
#
# 1. Leer el dataset country_vaccinations.csv  y filtrar los datos para Colombia
# 2. Crear un csv con los datos para colombia
# 3. Realizar una comparacion con los paises latinoamericanos de la cantidad de vacunados.
# 4. A traves de mascaras determinar el numero de vacunados en el intervalo  [1.5E6, 2.0E6]
#
#
#
#
# Referencias: Puedes consultar la pagina kaggle para estudiar mas acerca de pandas

# %%
#HACER EN CHAT GPT
#Generar un diccionario de python con clave valor, donde la clave son los nombres de los físicos que ganaron el premio novel entre 1970 a 1980
#Incluir en el valor del diccionario un diccionario con el año ene que ganó y 10 palabras con el motivo.
#Ejemplo: Dicc={"A. Eintein.":{1905: "Efecto fotoeléctrico"}}
#El nombre debe escribirlo en las iniciales del nombre y después el apellido

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fisicos_nobel = {
    "Hannes Alfvén": {
        "año": 1970,
        "motivo": ["plasma", "cosmología", "magnetohidrodinámica", "ondas de Alfvén"]
    },
    "Louis Néel": {
        "año": 1970,
        "motivo": ["ferrimagnetismo", "transiciones de fase", "magnetismo"]
    },
    "Dennis Gabor": {
        "año": 1971,
        "motivo": ["holografía", "óptica", "imagen tridimensional"]
    },
    "John Bardeen": {
        "año": 1972,
        "motivo": ["transistor", "superconductividad", "teoría de la conductividad"]
    },
    "Leon N. Cooper": {
        "año": 1972,
        "motivo": ["superconductividad", "teoría BCS"]
    },
    "Robert Schrieffer": {
        "año": 1972,
        "motivo": ["superconductividad", "teoría BCS"]
    },
    "Leo Esaki": {
        "año": 1973,
        "motivo": ["túnel", "dispositivos electrónicos"]
    },
    "Ivar Giaever": {
        "año": 1973,
        "motivo": ["túnel", "efecto Josephson"]
    },
    "Brian Josephson": {
        "año": 1973,
        "motivo": ["túnel", "efecto Josephson"]
    },
    "Anthony Hewish": {
        "año": 1974,
        "motivo": ["radioastronomía", "púlsares"]
    },
    "Martin Ryle": {
        "año": 1974,
        "motivo": ["radioastronomía", "apertura sintética"]
    },
    "Aage Bohr": {
        "año": 1975,
        "motivo": ["física nuclear", "estructura nuclear"]
    },
    "Ben Mottelson": {
        "año": 1975,
        "motivo": ["física nuclear", "estructura nuclear"]
    },
    "James Rainwater": {
        "año": 1975,
        "motivo": ["física nuclear", "estructura nuclear"]
    },
    "Burton Richter": {
        "año": 1976,
        "motivo": ["partículas", "jpsi mesón"]
    },
    "Samuel C.C. Ting": {
        "año": 1976,
        "motivo": ["partículas", "jpsi mesón"]
    },
    "Philip W. Anderson": {
        "año": 1977,
        "motivo": ["materia condensada", "transiciones de fase"]
    },
    "Sir Nevill Mott": {
        "año": 1977,
        "motivo": ["materia condensada", "propiedades eléctricas"]
    }}

# %%
import pandas as pd
df_n=pd.DataFrame(fisicos_nobel)
df_n.transpose().reset_index() #transponer la tabla y ponerle numeración a las filas
# Out:
#                  index   año  \
# 0        Hannes Alfvén  1970
# 1           Louis Néel  1970
# 2         Dennis Gabor  1971
# 3         John Bardeen  1972
# 4       Leon N. Cooper  1972
# 5    Robert Schrieffer  1972
# 6            Leo Esaki  1973
# 7         Ivar Giaever  1973
# 8      Brian Josephson  1973
# 9       Anthony Hewish  1974
# 10         Martin Ryle  1974
# 11           Aage Bohr  1975
# 12       Ben Mottelson  1975
# 13     James Rainwater  1975
# 14      Burton Richter  1976
# 15    Samuel C.C. Ting  1976
# 16  Philip W. Anderson  1977
# 17     Sir Nevill Mott  1977
#
#                                                motivo
# 0   [plasma, cosmología, magnetohidrodinámica, ond...
# 1   [ferrimagnetismo, transiciones de fase, magnet...
# 2         [holografía, óptica, imagen tridimensional]
# 3   [transistor, superconductividad, teoría de la ...
# 4                    [superconductividad, teoría BCS]
# 5                    [superconductividad, teoría BCS]
# 6                  [túnel, dispositivos electrónicos]
# 7                           [túnel, efecto Josephson]
# 8                           [túnel, efecto Josephson]
# 9                         [radioastronomía, púlsares]
# 10              [radioastronomía, apertura sintética]
# 11               [física nuclear, estructura nuclear]
# 12               [física nuclear, estructura nuclear]
# 13               [física nuclear, estructura nuclear]
# 14                           [partículas, jpsi mesón]
# 15                           [partículas, jpsi mesón]
# 16         [materia condensada, transiciones de fase]
# 17       [materia condensada, propiedades eléctricas]

# %%
g=df_n.transpose().reset_index().copy() #creamos copia de df

# %%
g.columns
# Out:
# Index(['index', 'año', 'motivo'], dtype='object')

# %%
col=["Científico", "Año","Motivo"] #cambiar nombre col
col
# Out:
# ['Científico', 'Año', 'Motivo']

# %%
g = g.rename(columns={"index":"Científico", "año":"Año", "motivo":"Motivo"})
g
# Out:
#             Científico   Año  \
# 0        Hannes Alfvén  1970
# 1           Louis Néel  1970
# 2         Dennis Gabor  1971
# 3         John Bardeen  1972
# 4       Leon N. Cooper  1972
# 5    Robert Schrieffer  1972
# 6            Leo Esaki  1973
# 7         Ivar Giaever  1973
# 8      Brian Josephson  1973
# 9       Anthony Hewish  1974
# 10         Martin Ryle  1974
# 11           Aage Bohr  1975
# 12       Ben Mottelson  1975
# 13     James Rainwater  1975
# 14      Burton Richter  1976
# 15    Samuel C.C. Ting  1976
# 16  Philip W. Anderson  1977
# 17     Sir Nevill Mott  1977
#
#                                                Motivo
# 0   [plasma, cosmología, magnetohidrodinámica, ond...
# 1   [ferrimagnetismo, transiciones de fase, magnet...
# 2         [holografía, óptica, imagen tridimensional]
# 3   [transistor, superconductividad, teoría de la ...
# 4                    [superconductividad, teoría BCS]
# 5                    [superconductividad, teoría BCS]
# 6                  [túnel, dispositivos electrónicos]
# 7                           [túnel, efecto Josephson]
# 8                           [túnel, efecto Josephson]
# 9                         [radioastronomía, púlsares]
# 10              [radioastronomía, apertura sintética]
# 11               [física nuclear, estructura nuclear]
# 12               [física nuclear, estructura nuclear]
# 13               [física nuclear, estructura nuclear]
# 14                           [partículas, jpsi mesón]
# 15                           [partículas, jpsi mesón]
# 16         [materia condensada, transiciones de fase]
# 17       [materia condensada, propiedades eléctricas]

# %%
g.to_csv('nobel.csv', header=False, index=False)

# %% [markdown]
# Punto 2:

# %%
url="https://docs.google.com/spreadsheets/d/e/2PACX-1vTGtyNnZH9uCYF60T8K_gA9JG36AB3v00s_iiF3pqUDRWpJEIkFlzhSWGQpYEAR6Q/pub?output=xlsx"

# %%
df_u = pd.read_excel(url)

# %%
from datetime import datetime

# %%
for i in df_u.Date:
  print(type(i)) #hay dos tipo de variable: datatime y str
# Out:
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# Punto 3

# %%
df = pd.read_csv("Crimes_-_2019.csv")

#1
df
print(df.describe())
print(df.info())
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  5.040100e+04  50401.000000  50401.000000  50401.000000    50401.000000
# mean   1.162834e+07   1133.670542     11.108530     23.298764       36.573461
# std    1.531569e+05    697.737805      6.967977     13.895214       21.277600
# min    2.456800e+04    111.000000      1.000000      1.000000        1.000000
# 25%    1.157392e+07    533.000000      5.000000     10.000000       23.000000
# 50%    1.159453e+07   1023.000000     10.000000     24.000000       32.000000
# 75%    1.161480e+07   1713.000000     17.000000     34.000000       53.000000
# max    1.224939e+07   2535.000000     25.000000     50.000000       77.000000
#
#        X Coordinate  Y Coordinate     Year      Latitude     Longitude
# count  5.020100e+04  5.020100e+04  50401.0  50201.000000  50201.000000
# mean   1.165086e+06  1.886367e+06   2019.0     41.843779    -87.669699
# std    1.604124e+04  3.096797e+04      0.0      0.085163      0.058401
# min    1.098012e+06  1.813914e+06   2019.0     41.644604    -87.915105
# 25%    1.153206e+06  1.859276e+06   2019.0     41.769138    -87.712751
# 50%    1.166927e+06  1.894060e+06   2019.0     41.865140    -87.663220
# 75%    1.176526e+06  1.908116e+06   2019.0     41.903497    -87.627722
# max    1.205114e+06  1.951495e+06   2019.0     42.022535    -87.524616
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70995 entries, 0 to 70994
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    50401 non-null  float64
#  1   Case Number           50401 non-null  object
#  2   Date                  50401 non-null  object
#  3   Block                 50401 non-null  object
#  4   IUCR                  50401 non-null  object
#  5   Primary Type          50401 non-null  object
#  6   Description           50401 non-null  object
#  7   Location Description  50211 non-null  object
#  8   Arrest                50401 non-null  object
#  9   Domestic              50401 non-null  object
#  10  Beat                  50401 non-null  float64
#  11  District              50401 non-null  float64
#  12  Ward                  50401 non-null  float64
#  13  Community Area        50401 non-null  float64
#  14  FBI Code              50401 non-null  object
#  15  X Coordinate          50201 non-null  float64
#  16  Y Coordinate          50201 non-null  float64
#  17  Year                  50401 non-null  float64
#  18  Updated On            50401 non-null  object
#  19  Latitude              50201 non-null  float64
#  20  Longitude             50201 non-null  float64
#  21  Location              50201 non-null  object
# dtypes: float64(10), object(12)
# memory usage: 11.9+ MB
# None
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1,2,3,4,5,6,7,8,9,14,18,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#2
df_sin = df.drop(["Primary Type","Date"], axis=1)
df_sin
# Out:
#                ID Case Number                 Block  IUCR  \
# 0      11864018.0    JC476123  022XX S MICHIGAN AVE  1154
# 1      11859805.0    JC471592   024XX W CHICAGO AVE   860
# 2      11863808.0    JC476236     0000X N LOOMIS ST   810
# 3      11859727.0    JC471542    016XX W ADDISON ST  1320
# 4      11859656.0    JC471240      051XX N BROADWAY   560
# ...           ...         ...                   ...   ...
# 70990         NaN         NaN                   NaN   NaN
# 70991         NaN         NaN                   NaN   NaN
# 70992         NaN         NaN                   NaN   NaN
# 70993         NaN         NaN                   NaN   NaN
# 70994         NaN         NaN                   NaN   NaN
#
#                                    Description          Location Description  \
# 0      FINANCIAL IDENTITY THEFT $300 AND UNDER  COMMERCIAL / BUSINESS OFFICE
# 1                                 RETAIL THEFT            GROCERY FOOD STORE
# 2                                    OVER $500                     RESIDENCE
# 3                                   TO VEHICLE                        STREET
# 4                                       SIMPLE                   GAS STATION
# ...                                        ...                           ...
# 70990                                      NaN                           NaN
# 70991                                      NaN                           NaN
# 70992                                      NaN                           NaN
# 70993                                      NaN                           NaN
# 70994                                      NaN                           NaN
#
#       Arrest Domestic    Beat  District  Ward  Community Area FBI Code  \
# 0      False    False   132.0       1.0   3.0            33.0       11
# 1      False    False  1221.0      12.0  26.0            24.0        6
# 2      False    False  1224.0      12.0  27.0            28.0        6
# 3      False    False  1922.0      19.0  47.0             6.0       14
# 4      False    False  2033.0      20.0  47.0             3.0      08A
# ...      ...      ...     ...       ...   ...             ...      ...
# 70990    NaN      NaN     NaN       NaN   NaN             NaN      NaN
# 70991    NaN      NaN     NaN       NaN   NaN             NaN      NaN
# 70992    NaN      NaN     NaN       NaN   NaN             NaN      NaN
# 70993    NaN      NaN     NaN       NaN   NaN             NaN      NaN
# 70994    NaN      NaN     NaN       NaN   NaN             NaN      NaN
#
#        X Coordinate  Y Coordinate    Year        Updated On   Latitude  \
# 0         1177560.0     1889548.0  2019.0  10/20/2019 15:56  41.852248
# 1         1160005.0     1905256.0  2019.0  10/20/2019 16:03  41.895732
# 2         1166986.0     1900306.0  2019.0  10/20/2019 15:56  41.882002
# 3         1164930.0     1923972.0  2019.0  10/20/2019 16:03  41.946987
# 4         1167380.0     1934505.0  2019.0  10/20/2019 16:03  41.975838
# ...             ...           ...     ...               ...        ...
# 70990           NaN           NaN     NaN               NaN        NaN
# 70991           NaN           NaN     NaN               NaN        NaN
# 70992           NaN           NaN     NaN               NaN        NaN
# 70993           NaN           NaN     NaN               NaN        NaN
# 70994           NaN           NaN     NaN               NaN        NaN
#
#        Longitude                       Location
# 0     -87.623786  (41.852248185, -87.623786256)
# 1     -87.687784  (41.895732399, -87.687784384)
# 2     -87.662287   (41.88200224, -87.662286977)
# 3     -87.669164  (41.946987144, -87.669163602)
# 4     -87.659854  (41.975837637, -87.659853835)
# ...          ...                            ...
# 70990        NaN                            NaN
# 70991        NaN                            NaN
# 70992        NaN                            NaN
# 70993        NaN                            NaN
# 70994        NaN                            NaN
#
# [70995 rows x 20 columns]

# %%
#3
df["Date"]= pd.to_datetime(df['Date'], format='%m/%d/%Y %H:%M')
df["Date"]
# Out:
# 0       2019-09-24 08:00:00
# 1       2019-10-13 20:30:00
# 2       2019-10-05 18:30:00
# 3       2019-10-13 19:00:00
# 4       2019-10-13 14:10:00
#                 ...
# 70990                   NaT
# 70991                   NaT
# 70992                   NaT
# 70993                   NaT
# 70994                   NaT
# Name: Date, Length: 70995, dtype: datetime64[ns]

# %%
#4
df.groupby("Primary Type")["Date"].count().sort_values()
# Out:
# Primary Type
# NON-CRIMINAL                             1
# HUMAN TRAFFICKING                        3
# HOMICIDE                                 7
# OBSCENITY                                8
# GAMBLING                                11
# KIDNAPPING                              32
# CONCEALED CARRY LICENSE VIOLATION       34
# CRIMINAL SEXUAL ASSAULT                 36
# INTIMIDATION                            38
# LIQUOR LAW VIOLATION                    42
# STALKING                                51
# ARSON                                   70
# PROSTITUTION                           131
# SEX OFFENSE                            197
# CRIM SEXUAL ASSAULT                    205
# INTERFERENCE WITH PUBLIC OFFICER       288
# PUBLIC PEACE VIOLATION                 297
# OFFENSE INVOLVING CHILDREN             420
# WEAPONS VIOLATION                     1171
# CRIMINAL TRESPASS                     1425
# ROBBERY                               1596
# MOTOR VEHICLE THEFT                   1836
# BURGLARY                              1948
# NARCOTICS                             3175
# DECEPTIVE PRACTICE                    3277
# OTHER OFFENSE                         3724
# ASSAULT                               3924
# CRIMINAL DAMAGE                       5040
# BATTERY                               9538
# THEFT                                11876
# Name: Date, dtype: int64

# %%
#5
df.sort_values("Primary Type")
df
# Out:
#                ID Case Number                Date                 Block  IUCR  \
# 0      11864018.0    JC476123 2019-09-24 08:00:00  022XX S MICHIGAN AVE  1154
# 1      11859805.0    JC471592 2019-10-13 20:30:00   024XX W CHICAGO AVE   860
# 2      11863808.0    JC476236 2019-10-05 18:30:00     0000X N LOOMIS ST   810
# 3      11859727.0    JC471542 2019-10-13 19:00:00    016XX W ADDISON ST  1320
# 4      11859656.0    JC471240 2019-10-13 14:10:00      051XX N BROADWAY   560
# ...           ...         ...                 ...                   ...   ...
# 70990         NaN         NaN                 NaT                   NaN   NaN
# 70991         NaN         NaN                 NaT                   NaN   NaN
# 70992         NaN         NaN                 NaT                   NaN   NaN
# 70993         NaN         NaN                 NaT                   NaN   NaN
# 70994         NaN         NaN                 NaT                   NaN   NaN
#
#              Primary Type                              Description  \
# 0      DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 1                   THEFT                             RETAIL THEFT
# 2                   THEFT                                OVER $500
# 3         CRIMINAL DAMAGE                               TO VEHICLE
# 4                 ASSAULT                                   SIMPLE
# ...                   ...                                      ...
# 70990                 NaN                                      NaN
# 70991                 NaN                                      NaN
# 70992                 NaN                                      NaN
# 70993                 NaN                                      NaN
# 70994                 NaN                                      NaN
#
#                Location Description Arrest Domestic  ...  Ward  \
# 0      COMMERCIAL / BUSINESS OFFICE  False    False  ...   3.0
# 1                GROCERY FOOD STORE  False    False  ...  26.0
# 2                         RESIDENCE  False    False  ...  27.0
# 3                            STREET  False    False  ...  47.0
# 4                       GAS STATION  False    False  ...  47.0
# ...                             ...    ...      ...  ...   ...
# 70990                           NaN    NaN      NaN  ...   NaN
# 70991                           NaN    NaN      NaN  ...   NaN
# 70992                           NaN    NaN      NaN  ...   NaN
# 70993                           NaN    NaN      NaN  ...   NaN
# 70994                           NaN    NaN      NaN  ...   NaN
#
#        Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0                33.0        11     1177560.0    1889548.0  2019.0
# 1                24.0         6     1160005.0    1905256.0  2019.0
# 2                28.0         6     1166986.0    1900306.0  2019.0
# 3                 6.0        14     1164930.0    1923972.0  2019.0
# 4                 3.0       08A     1167380.0    1934505.0  2019.0
# ...               ...       ...           ...          ...     ...
# 70990             NaN       NaN           NaN          NaN     NaN
# 70991             NaN       NaN           NaN          NaN     NaN
# 70992             NaN       NaN           NaN          NaN     NaN
# 70993             NaN       NaN           NaN          NaN     NaN
# 70994             NaN       NaN           NaN          NaN     NaN
#
#              Updated On   Latitude  Longitude                       Location
# 0      10/20/2019 15:56  41.852248 -87.623786  (41.852248185, -87.623786256)
# 1      10/20/2019 16:03  41.895732 -87.687784  (41.895732399, -87.687784384)
# 2      10/20/2019 15:56  41.882002 -87.662287   (41.88200224, -87.662286977)
# 3      10/20/2019 16:03  41.946987 -87.669164  (41.946987144, -87.669163602)
# 4      10/20/2019 16:03  41.975838 -87.659854  (41.975837637, -87.659853835)
# ...                 ...        ...        ...                            ...
# 70990               NaN        NaN        NaN                            NaN
# 70991               NaN        NaN        NaN                            NaN
# 70992               NaN        NaN        NaN                            NaN
# 70993               NaN        NaN        NaN                            NaN
# 70994               NaN        NaN        NaN                            NaN
#
# [70995 rows x 22 columns]

# %%
#6
df.iloc[100:121]
df
# Out:
#                ID Case Number                Date                 Block  IUCR  \
# 0      11864018.0    JC476123 2019-09-24 08:00:00  022XX S MICHIGAN AVE  1154
# 1      11859805.0    JC471592 2019-10-13 20:30:00   024XX W CHICAGO AVE   860
# 2      11863808.0    JC476236 2019-10-05 18:30:00     0000X N LOOMIS ST   810
# 3      11859727.0    JC471542 2019-10-13 19:00:00    016XX W ADDISON ST  1320
# 4      11859656.0    JC471240 2019-10-13 14:10:00      051XX N BROADWAY   560
# ...           ...         ...                 ...                   ...   ...
# 70990         NaN         NaN                 NaT                   NaN   NaN
# 70991         NaN         NaN                 NaT                   NaN   NaN
# 70992         NaN         NaN                 NaT                   NaN   NaN
# 70993         NaN         NaN                 NaT                   NaN   NaN
# 70994         NaN         NaN                 NaT                   NaN   NaN
#
#              Primary Type                              Description  \
# 0      DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 1                   THEFT                             RETAIL THEFT
# 2                   THEFT                                OVER $500
# 3         CRIMINAL DAMAGE                               TO VEHICLE
# 4                 ASSAULT                                   SIMPLE
# ...                   ...                                      ...
# 70990                 NaN                                      NaN
# 70991                 NaN                                      NaN
# 70992                 NaN                                      NaN
# 70993                 NaN                                      NaN
# 70994                 NaN                                      NaN
#
#                Location Description Arrest Domestic  ...  Ward  \
# 0      COMMERCIAL / BUSINESS OFFICE  False    False  ...   3.0
# 1                GROCERY FOOD STORE  False    False  ...  26.0
# 2                         RESIDENCE  False    False  ...  27.0
# 3                            STREET  False    False  ...  47.0
# 4                       GAS STATION  False    False  ...  47.0
# ...                             ...    ...      ...  ...   ...
# 70990                           NaN    NaN      NaN  ...   NaN
# 70991                           NaN    NaN      NaN  ...   NaN
# 70992                           NaN    NaN      NaN  ...   NaN
# 70993                           NaN    NaN      NaN  ...   NaN
# 70994                           NaN    NaN      NaN  ...   NaN
#
#        Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0                33.0        11     1177560.0    1889548.0  2019.0
# 1                24.0         6     1160005.0    1905256.0  2019.0
# 2                28.0         6     1166986.0    1900306.0  2019.0
# 3                 6.0        14     1164930.0    1923972.0  2019.0
# 4                 3.0       08A     1167380.0    1934505.0  2019.0
# ...               ...       ...           ...          ...     ...
# 70990             NaN       NaN           NaN          NaN     NaN
# 70991             NaN       NaN           NaN          NaN     NaN
# 70992             NaN       NaN           NaN          NaN     NaN
# 70993             NaN       NaN           NaN          NaN     NaN
# 70994             NaN       NaN           NaN          NaN     NaN
#
#              Updated On   Latitude  Longitude                       Location
# 0      10/20/2019 15:56  41.852248 -87.623786  (41.852248185, -87.623786256)
# 1      10/20/2019 16:03  41.895732 -87.687784  (41.895732399, -87.687784384)
# 2      10/20/2019 15:56  41.882002 -87.662287   (41.88200224, -87.662286977)
# 3      10/20/2019 16:03  41.946987 -87.669164  (41.946987144, -87.669163602)
# 4      10/20/2019 16:03  41.975838 -87.659854  (41.975837637, -87.659853835)
# ...                 ...        ...        ...                            ...
# 70990               NaN        NaN        NaN                            NaN
# 70991               NaN        NaN        NaN                            NaN
# 70992               NaN        NaN        NaN                            NaN
# 70993               NaN        NaN        NaN                            NaN
# 70994               NaN        NaN        NaN                            NaN
#
# [70995 rows x 22 columns]

# %%
#7
plt.figure(figsize=(24,12))
info = pd.DataFrame(df.groupby("Primary Type")["Date"].count())
info = info.reset_index()
info.columns = ["Primary Type", "contador"]


ax = sns.barplot(x="contador", y="Primary Type", data=info)
ax.set(xlabel="Contador de casos", ylabel="Tipo de crimen")
plt.show()

# %% [markdown]
# Punto 4

# %%
df_v = pd.read_csv("country_vaccinations.csv")
#1
colombia = df_v["country"] == "Colombia"
df_colombia = df_v.loc[colombia]

#2
df_colombia.to_csv("datos_colombia.csv", index=False)

# %%
#extraemos la lista de los paises 
paises = df_v[df_v.duplicated(['country'])]['country'].unique()
paises
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Brazil', 'Brunei', 'Bulgaria', 'Cambodia', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Chile', 'China', 'Colombia',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Estonia',
#        'Faeroe Islands', 'Falkland Islands', 'Finland', 'France', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece',
#        'Greenland', 'Grenada', 'Guatemala', 'Guernsey', 'Guinea',
#        'Guyana', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
#        'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kosovo', 'Kuwait', 'Latvia', 'Lebanon', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Macao', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Malta', 'Mauritania', 'Mauritius', 'Mexico',
#        'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat',
#        'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal',
#        'Netherlands', 'New Zealand', 'Nigeria', 'North Macedonia',
#        'Northern Cyprus', 'Northern Ireland', 'Norway', 'Oman',
#        'Pakistan', 'Palestine', 'Panama', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia',
#        'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka',
#        'Suriname', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Togo',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turks and Caicos Islands', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Venezuela', 'Vietnam', 'Wales', 'Zimbabwe'],
#       dtype=object)

# %%
#3
df_vacunas = df_v.groupby("country")["total_vaccinations"].sum()

latinoamerica= ["Argentina","Bolivia","Brazil","Chile", "Colombia", "Costa Rica","Ecuador","Paraguay","Peru","Uruguay","Venezuela"]
df_latinoamerica = df_vacunas.loc[latinoamerica].sort_values(ascending=False)
df_latinoamerica
# Out:
# country
# Brazil        571024737.0
# Chile         311634144.0
# Argentina     108616678.0
# Colombia       35303248.0
# Peru           24434065.0
# Uruguay        10685446.0
# Bolivia         5115399.0
# Ecuador         2410101.0
# Costa Rica      2334603.0
# Paraguay         509170.0
# Venezuela         26574.0
# Name: total_vaccinations, dtype: float64

# %%
#4
vacunas = (df_v["total_vaccinations"] >= 1.5E6) & (df_v["total_vaccinations"] <= 2.0E6)
df_vacunas_intervalo = df_v.loc[vacunas]
df_vacunas_intervalo
# Out:
#         country  iso_code        date  total_vaccinations  people_vaccinated  \
# 361   Argentina       ARG  2021-03-07           1526078.0          1182874.0
# 362   Argentina       ARG  2021-03-08           1546699.0          1202998.0
# 363   Argentina       ARG  2021-03-09           1648957.0          1301787.0
# 364   Argentina       ARG  2021-03-10           1774438.0          1424984.0
# 365   Argentina       ARG  2021-03-11           1919074.0          1564555.0
# ...         ...       ...         ...                 ...                ...
# 9527      Wales  OWID_WLS  2021-03-29           1837726.0          1413710.0
# 9528      Wales  OWID_WLS  2021-03-30           1865120.0          1427183.0
# 9529      Wales  OWID_WLS  2021-03-31           1893423.0          1443885.0
# 9530      Wales  OWID_WLS  2021-04-01           1920657.0          1460880.0
# 9531      Wales  OWID_WLS  2021-04-02           1936088.0          1472643.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 361                  343204.0                     NaN             71582.0
# 362                  343701.0                 20621.0             71076.0
# 363                  347170.0                102258.0             74693.0
# 364                  349454.0                125481.0             84735.0
# 365                  354519.0                144636.0             95230.0
# ...                       ...                     ...                 ...
# 9527                 424016.0                 20114.0             28018.0
# 9528                 437937.0                 27394.0             27906.0
# 9529                 449538.0                 28303.0             27777.0
# 9530                 459777.0                 27234.0             27053.0
# 9531                 463445.0                 15431.0             24284.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 361                             3.38                           2.62
# 362                             3.42                           2.66
# 363                             3.65                           2.88
# 364                             3.93                           3.15
# 365                             4.25                           3.46
# ...                              ...                            ...
# 9527                           58.29                          44.84
# 9528                           59.16                          45.27
# 9529                           60.05                          45.80
# 9530                           60.92                          46.33
# 9531                           61.41                          46.71
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 361                                  0.76                          1584.0
# 362                                  0.76                          1573.0
# 363                                  0.77                          1653.0
# 364                                  0.77                          1875.0
# 365                                  0.78                          2107.0
# ...                                   ...                             ...
# 9527                                13.45                          8886.0
# 9528                                13.89                          8851.0
# 9529                                14.26                          8810.0
# 9530                                14.58                          8580.0
# 9531                                14.70                          7702.0
#
#                                               vaccines  \
# 361   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 362   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 363   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 364   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 365   Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# ...                                                ...
# 9527               Oxford/AstraZeneca, Pfizer/BioNTech
# 9528               Oxford/AstraZeneca, Pfizer/BioNTech
# 9529               Oxford/AstraZeneca, Pfizer/BioNTech
# 9530               Oxford/AstraZeneca, Pfizer/BioNTech
# 9531               Oxford/AstraZeneca, Pfizer/BioNTech
#
#                            source_name  \
# 361                 Ministry of Health
# 362                 Ministry of Health
# 363                 Ministry of Health
# 364                 Ministry of Health
# 365                 Ministry of Health
# ...                                ...
# 9527  Government of the United Kingdom
# 9528  Government of the United Kingdom
# 9529  Government of the United Kingdom
# 9530  Government of the United Kingdom
# 9531  Government of the United Kingdom
#
#                                          source_website
# 361   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 362   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 363   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 364   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 365   http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...                                                 ...
# 9527  https://coronavirus.data.gov.uk/details/health...
# 9528  https://coronavirus.data.gov.uk/details/health...
# 9529  https://coronavirus.data.gov.uk/details/health...
# 9530  https://coronavirus.data.gov.uk/details/health...
# 9531  https://coronavirus.data.gov.uk/details/health...
#
# [205 rows x 15 columns]

# %% [markdown]
# CLASE:

# %%
import pandas as pd

dicc={"Antioquia":"Medellín", "Meta":"Villavicencio", "Cundinamarca":"Bogotá", "Vichada":"Puerto Carreño"}
#Construir la serie
S=pd.Series({"Antioquia":"Medellín", "Meta":"Villavicencio", "Cundinamarca":"Bogotá", "Vichada":"Puerto Carreño"})

# %%
S.iloc[0:4]
# Out:
# Antioquia             Medellín
# Meta             Villavicencio
# Cundinamarca            Bogotá
# Vichada         Puerto Carreño
# dtype: object

# %%
from numpy import deg2rad
d1={"Color":"Amarillo", "Número":"45", "Objeto":"Balón"}
d2={"Color":"Azul", "Número":"32", "Objeto": "Flor"}
d3={"Color":"Rojo", "Número":"23", "Objeto":"Computador"}
d4={"Color":"Morado", "Número":"18", "Objeto":"Plana"}

record1=pd.Series(d1)
record2=pd.Series(d2)
record3=pd.Series(d3)
record4=pd.Series(d4)

# %%
df1=pd.DataFrame([record1, record2, record3, record4])
df1
# Out:
#       Color Número      Objeto
# 0  Amarillo     45       Balón
# 1      Azul     32        Flor
# 2      Rojo     23  Computador
# 3    Morado     18       Plana

# %%
df1.Color
# Out:
# 0    Amarillo
# 1        Azul
# 2        Rojo
# 3      Morado
# Name: Color, dtype: object

# %%
df1. Color + " "+ df1.Objeto
# Out:
# 0     Amarillo Balón
# 1          Azul Flor
# 2    Rojo Computador
# 3       Morado Plana
# dtype: object
