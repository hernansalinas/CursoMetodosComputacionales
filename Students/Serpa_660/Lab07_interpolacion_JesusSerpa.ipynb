# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab07_interpolacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio metodos computacionales,
# # Interpolacion

# %% [markdown]
# # 1. Movimiento de proyectiles en presencia de viento.
#
# Supongamos que un proyectil es lanzado desde el origen con una rapidez $v=vo( \cos \theta , \sin \theta) $. Supongamos además que el efecto del viento sobre el proyectil es el de una fuerza proporcional a la velocidad relativa entre el viento y el proyectil. Teniendo presente que si $u$ es la velocidad del viento y $\alpha$ el ángulo que hace dirección de esta velocidad con el eje x, se puede entrontrar las siguientes ecuaciones diferenciales, asociada al estado de movimiento del [proyectil](https://iopscience.iop.org/article/10.1088/0143-0807/36/2/025016/meta):
#
#
# \begin{equation}
# m\frac{dv_x}{dt} = -mb(v_x-u\cos \alpha )
# \end{equation}
#
# \begin{equation}
# m\frac{dv_y}{dt} = -mg-mb(v_x-u\sin \alpha ),
# \end{equation}
#
# donde b es el párametro de rozamiento. La soluciones a las ecuaciones anteriores vienen dadas por:
#
# Posición en x
# \begin{equation}
# x=(u\cos \alpha) t + \frac{1}{b} (v_0\cos \theta_0 -u \cos\alpha)(1-\mathrm{exp}(-bt))
# \end{equation}
#
# Posicion en y
# \begin{equation}
# y= \frac{1}{b}\left(\frac{g}{b}+v_0 \sin \theta_0 -u\sin\alpha \right)(1-\mathrm{exp}(-bt))-\left( \frac{g}{b}-u\sin\alpha\right)t
# \end{equation}
#
# Ver imagen:  http://www.sc.ehu.es/sbweb/fisica3/fluidos/viento/parabolico.html
#
#
# 0. Establezca las siguietnes condiciones inciales.
#
# ```
# #Parametros iniciales
#
# v0 = 60 #Velocidad en m/s
# alpha = np.pi #Angulo del viento
# theta = np.deg2rad(45) #Angulo de lanzamiento
# u = v0/2             #rapidez del viento
# b = 0.05             #Parametro de friccion
# g = 9.8                #Aceleracion de la gravedad m/s2
#
# Params = (alpha, v0, b, u,g)  #Parametros en tupla.
#
# ```
#
#
#
# 1. Defina dos funciones, una para x y otra para y.
#
# ```
#
# #Posicion en x
# def pos_x(t, theta, alpha, v0, b, u,g):
#   x = #escriba aca la expresión
#   return x
#
# #Posicion en y
# def pos_y(t, theta, alpha, v0, b, u,g):
#
#
#   y = #escriba aca la expresión
#   return y
#
# ```
#
# 2. Construya un diccionario con las claves "X", "Y", "Tiempo"
#
# 3. Con el diccionario construya un data frame de pandas llamado df con los nombres de columnas "X", "Y", "Tiempo"  https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.from_dict.html. Defina 1000 registros para el intervalo de tiempo elegido.
#
#
# 4. Realice un gráfico de x como función del tiempo, de y como función del tiempo y la trayectoria de la partícula (df["X"], df["tiempo"], df["Y"]).
#
#
# 5. Determine el alcance máximo de la partícula, para ello tome  la solucion teórica con $y=0$, solucione numéricamente la ecuación para t y remplace este valor en la ecuación para x. Resuelvalo para $\theta=45^{o}$.
#
# 6. Construya una  grafica del alcance máximo R como función de $\theta$, varie $\theta$  entre 10 y 90 grados cada 5 grados.
#
# 7. Realice una interpolacion de R como función de theta.

# %% [markdown]
# Posición en x
# \begin{equation}
# x=(u\cos \alpha) t + \frac{1}{b} (v_0\cos \theta_0 -u \cos\alpha)(1-\mathrm{exp}(-bt))
# \end{equation}
#
# Posicion en y
# \begin{equation}
# y= \frac{1}{b}\left(\frac{g}{b}+v_0 \sin \theta_0 -u\sin\alpha \right)(1-\mathrm{exp}(-bt))-\left( \frac{g}{b}-u\sin\alpha\right)t
# \end{equation}

# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
from scipy.optimize import newton
from scipy.interpolate import lagrange
from scipy import interpolate
import sympy as sp
import math as mt

# %%
vo = 60 #Velocidad en m/s
alpha = np.pi #Angulo del viento
theta = np.deg2rad(45) #Angulo de lanzamiento
u = vo/2             #rapidez del viento
b = 0.05             #Parametro de friccion 
g = 9.8                #Aceleracion de la gravedad m/s2

def pos_x(t, vo, theta0, u, alpha, b, g  ):
  t1 = u*np.cos(alpha)*t  
  t2 = 1./b*(vo*np.cos(theta0)-u*np.cos(alpha))  
  t3 = (1-np.exp(-b*t))
  return t1 + t2 * t3


def pos_y(t, vo, theta0, u, alpha, b, g  ):
  t1 = (g/b + vo*np.sin(theta0) - u* np.sin(alpha) )
  t2 = (1-np.exp(-b*t)) 
  t3 = (g/b - u*np.sin(alpha))*t 
  return 1./b * t1 * t2 - t3

# %%
t = np.linspace(0, 8.5, 100)
Params = (vo, theta, u, alpha, b , g)  #Parametros en tupla.
x = pos_x(t, *Params)
y = pos_y(t, *Params)

# %%
dicc = {"x":x,"y":y ,"t":t}
df = pd.DataFrame(dicc)

# %%
plt.plot(df.x, df.y)
plt.xlabel("x")
plt.ylabel("y")
plt.grid()

# %%
plt.plot(df.t, df.y)
plt.xlabel("t")
plt.ylabel("y")
plt.grid()

# %%
tv = newton(pos_y, 6.5, args=Params)
tv
# Out:
# 8.111627022095584

# %%
pos_x(tv, *Params)
# Out:
# 239.60614945520726

# %% [markdown]
# # Generalizacion

# %%
np.arange(5, 85, 5)
# Out:
# array([ 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80])

# %%
theta = np.deg2rad(np.arange(5, 80, 5)) #Angulo de lanzamiento
theta
# Out:
# array([0.08726646, 0.17453293, 0.26179939, 0.34906585, 0.43633231,
#        0.52359878, 0.61086524, 0.6981317 , 0.78539816, 0.87266463,
#        0.95993109, 1.04719755, 1.13446401, 1.22173048, 1.30899694])

# %%
Rmax = np.zeros(len(theta))
for i, te in enumerate(theta):
  Params = (vo, te, u, alpha, b , g)  #Parametros en tupla.
  tv = newton(pos_y, 6.5, args = Params)
  Rmax[i] = pos_x(tv, *Params)
  #print(tv,pos_x(tv, *Params))

# %%
# Alcance maximo como funcion de theta
plt.plot(theta, Rmax,"ro" )

# %%
#interpolar 
x = theta
y = Rmax
f  = interpolate.CubicSpline(x,y)

# %%
plt.plot(x,f(x))
plt.plot(x,y,"ro")

# %% [markdown]
# # 2.0  Interpolación lagrange
#
# Consideremos la función:
# \begin{equation*}
#      f(x) = \frac{1}{1+25x^2}
# \end{equation*}
# en el intervalo $[-1, 1]$, definamos un conjunto de puntos $n+1$  equiespaciados en $[-1,1]$.
#
#  1. Representar gráficamente la función junto al polinomio de interpolación de Lagrange, $p_n(x)$, para $n=\{ 4, 8, 12, 16, 20 \}$.
#  2. Comprobar gráficamente cómo el error aumenta con $n$. Emplee la libreria, simbolica de sympy y encuente el error en la interpolación.
#
#  Para este numeral, emplee que:
#
#
# La cota del  error , viene dado por:
# \begin{equation}
# f(x) - P(x) = \epsilon = \frac{1}{(n+1)!} f^{(n+1)}(\xi)(x - x_0)(x - x_1) ... (x - x_n)
# \end{equation}, emplee la libreria simbolica para realizar la estimación de dicha cuota, sólo para n = 4, en el punto 0.5

# %%
#Ayuda: 

import sympy as sp # Cargamos sympy como sp
import numpy as np
import matplotlib.pylab as plt

f_s = lambda x: 1/(1+25*x**2)
sp.init_printing() # Usar LaTeX para dibujar ecuaciones

x = sp.symbols("x") # x será una variable simbólica
f_s(x)
print(sp.diff(f_s(x),x))
print(sp.diff(f_s(x),x, 1))
print(sp.diff(f_s(x),x, 2))
print(sp.diff(f_s(x),x, 3))
print(sp.diff(f_s(x),x, 4))
print(sp.diff(f_s(x),x, 5))
f5 = sp.diff(f_s(x),x, 5)
fxn5 = sp.lambdify(x,f5,'numpy') #numpy funcion

x_ = np.linspace(-1, 1, 100)

plt.figure()
plt.plot(x_, fxn5(x_) )
plt.show()
# Out:
# -50*x/(25*x**2 + 1)**2
# -50*x/(25*x**2 + 1)**2
# 50*(100*x**2/(25*x**2 + 1) - 1)/(25*x**2 + 1)**2
# 15000*x*(-50*x**2/(25*x**2 + 1) + 1)/(25*x**2 + 1)**3
# 15000*(10000*x**4/(25*x**2 + 1)**2 - 300*x**2/(25*x**2 + 1) + 1)/(25*x**2 + 1)**3
# 3750000*x*(-10000*x**4/(25*x**2 + 1)**2 + 400*x**2/(25*x**2 + 1) - 3)/(25*x**2 + 1)**4

# %%
f_s = lambda x: 1/(1+25*x**2)

#puntos
N=5
x_=np.linspace(-1,1,N) #puntos equiespaciados

x= np.linspace(-1,1,100)

#lagrange
xx=np.linspace(np.min(x_),np.max(x_))
p=lagrange(x_,f_s(x_))


#grafica
plt.plot(x,f_s(x),"o-")
plt.plot(x_,f_s(x_),"ro")
plt.plot(xx,p(xx),"k-")

# %%
def interpolacion(N):
  n=N+1
  x_=np.linspace(-1,1,n) #puntos equiespaciados
  #lagrange
  xx=np.linspace(np.min(x_),np.max(x_))
  p=lagrange(x_,f_s(x_))
  return xx,p

# %%
#grafica
NN=[4,8,12,16,20]

fig, axs = plt.subplots(figsize=(12,8), nrows=2,ncols=3)
x= np.linspace(-1,1,100)
f_s = lambda x: 1/(1+25*x**2)
i=0
for n_ in NN:
  ax= axs.flatten()
  ax[i].plot(x,f_s(x),"o-")
  ax[i].plot(x_,f_s(x_),"ro")

  N=n_

  xx, p= interpolacion(N)
  ax[i].plot(xx,p(xx),"k-")
  ax[i].set_xlabel("x")
  ax[i].set_ylabel("y")
  i=i+1
fig.subplots_adjust(wspace=0.3)
fig.subplots_adjust(hspace=0.2)

# %% [markdown]
# La cota del  error , viene dado por:
# \begin{equation}
# f(x) - P(x) = \epsilon = \frac{1}{(n+1)!} f^{(n+1)}(\xi)(x - x_0)(x - x_1) ... (x - x_n)
# \end{equation}, emplee la libreria simbolica para realizar la estimación de dicha cuota, sólo para n = 4, en el punto 0.5

# %%
N=4
xx,p =interpolacion(N)

# %%
x= np.linspace(-1,1,100)
f_s = lambda x: 1/(1+25*x**2)
x = sp.symbols("x") # x será una variable simbólica
f5 = sp.diff(f_s(x),x, N+1)
print(f5)
fxn5 = sp.lambdify(x,f5,'numpy') #numpy funcion
# Out:
# 3750000*x*(-10000*x**4/(25*x**2 + 1)**2 + 400*x**2/(25*x**2 + 1) - 3)/(25*x**2 + 1)**4

# %%
plt.plot(xx, abs(fxn5(xx)))
print(np.max(abs(fxn5(xx))))
# Out:
# 280238.95743385755

# %%
x_ = np.linspace(-1,1,N+1) #Puntos de interpolacion

# %%
plt.figure()
plt.plot(x_,f_s(x_),"o",label="f(x)")
plt.plot(xx,280238.95743385755*((xx-x_[0])*(xx-x_[1])*(xx-x_[2])*(xx-x_[3])*(xx-x_[4]))/mt.factorial(N+1))
plt.xlabel("x")
plt.ylabel("Error")
plt.legend()
plt.show()

# %% [markdown]
# # 3.  Interpolación Hermite
#
# Consideremos la función:
# \begin{equation*}
#      f(x) = \frac{1}{1+25x^2}
# \end{equation*}
# en el intervalo $[-1, 1]$, definamos un conjunto de puntos $n+1$  equiespaciados en $[-1,1]$.
#
#  1. Representar gráficamente la función junto al polinomio de interpolación de Lagrange, $p_n(x)$, para $n=\{ 4, 8, 12, 16, 20 \}$.
#  2. Comprobar gráficamente cómo el error aumenta con $n$. Emplee la libreria, simbolica de sympy y encuente el error en la interpolación.
#
#  Para este numeral, emplee que:
#
#
# La cota del  error , viene dado por:
#
# $$
#   f(x)-p_{2n+1}(x)
#   = \frac{f^{2n+2}(\xi)}{(2n+2)!} (x-x_0)^2(x-x_1)^2(x-x_2)^2,
# $$
#
#
#
#
#
# emplee la libreria simbolica para realizar la estimación de dicha cuota, sólo para n = 4, en el punto 0.5

# %%
x = np.linspace(-1, 1, 100)
f_s = lambda x: 1/(1+25*x**2)

# %%
#calculamos derivada
def f_pp(x):
   return 1/(1+25*x**2)

x=sp.Symbol("x")

df= sp.diff(f_pp(x),x)
df
# Out:
#    -50⋅x
# ────────────
#            2
# ⎛    2    ⎞
# ⎝25⋅x  + 1⎠

# %%
#funcion
f_s = lambda x: 1/(1+25*x**2)

#funcion derivada 
def f_p(x):
  return -(50*x)/(25*x**2 +1)**2

#puntos
N=5
x_=np.linspace(-1,1,N)
x = np.linspace(-1, 1, 100)


#hermite
xx=np.linspace(np.min(x_),np.max(x_))
H=interpolate.CubicHermiteSpline(x_,f_s(x_),f_p(x_))


#grafica
plt.figure(figsize=(10,5))

plt.plot(xx,H(xx),"k-", label="Interpolacion")
plt.plot(x,f_s(x),"o-")
plt.plot(x_,f_s(x_),"ro")
plt.legend()

# %%
def Hermite(N):
  n=N+1
  x_=np.linspace(-1,1,n) #puntos equiespaciados
  #lagrange
  xx=np.linspace(np.min(x_),np.max(x_))
  H=interpolate.CubicHermiteSpline(x_,f_s(x_),f_p(x_))
  return xx,H

# %%
#grafica
NN=[4,8,12,16,20]

fig, axs = plt.subplots(figsize=(19,8), nrows=2,ncols=3)
x= np.linspace(-1,1,100)
f_s = lambda x: 1/(1+25*x**2)
i=0
for n_ in NN:
  ax= axs.flatten()
  ax[i].plot(x,f_s(x),"o-")
  ax[i].plot(x_,f_s(x_),"ro")

  N=n_

  xx, H= Hermite(N)
  ax[i].plot(xx,H(xx),"k-")
  ax[i].set_xlabel("x")
  ax[i].set_ylabel("y")
  i=i+1
fig.subplots_adjust(wspace=0.3)
fig.subplots_adjust(hspace=0.2)

# %% [markdown]
#
# La cota del  error , viene dado por:
#
# $$
#   f(x)-p_{2n+1}(x)
#   = \frac{f^{2n+2}(\xi)}{(2n+2)!} (x-x_0)^2(x-x_1)^2(x-x_2)^2,
# $$

# %%
f_s = lambda x: 1/(1+25*x**2)
x=sp.Symbol("x")
f_p = sp.diff(f_s(x), x, 10)
funP_Error = sp.lambdify(x,f_p,'numpy') #numpy funcion
plt.plot(xx,funP_Error(xx))
m=np.max(abs(funP_Error(xx)))
print(m)
# Out:
# 21480092132498.223

# %%
xx
# Out:
# array([-1.        , -0.95918367, -0.91836735, -0.87755102, -0.83673469,
#        -0.79591837, -0.75510204, -0.71428571, -0.67346939, -0.63265306,
#        -0.59183673, -0.55102041, -0.51020408, -0.46938776, -0.42857143,
#        -0.3877551 , -0.34693878, -0.30612245, -0.26530612, -0.2244898 ,
#        -0.18367347, -0.14285714, -0.10204082, -0.06122449, -0.02040816,
#         0.02040816,  0.06122449,  0.10204082,  0.14285714,  0.18367347,
#         0.2244898 ,  0.26530612,  0.30612245,  0.34693878,  0.3877551 ,
#         0.42857143,  0.46938776,  0.51020408,  0.55102041,  0.59183673,
#         0.63265306,  0.67346939,  0.71428571,  0.75510204,  0.79591837,
#         0.83673469,  0.87755102,  0.91836735,  0.95918367,  1.        ])

# %%
x_ = np.linspace(-1,1,N) #Puntos de interpolacion
x_
# Out:
# array([-1.        , -0.89473684, -0.78947368, -0.68421053, -0.57894737,
#        -0.47368421, -0.36842105, -0.26315789, -0.15789474, -0.05263158,
#         0.05263158,  0.15789474,  0.26315789,  0.36842105,  0.47368421,
#         0.57894737,  0.68421053,  0.78947368,  0.89473684,  1.        ])

# %%
fun = sp.lambdify(x,f_s(x),'numpy') #numpy funcion
funp = sp.lambdify(x,f_p,'numpy') #numpy funcion

xx=np.linspace(-1,1,100)

#INterpolacion
N=4
x_= np.linspace(-1,1,N+1)


h = interpolate.CubicHermiteSpline(x_,fun(x_),funp(x_))

f_s = lambda x: 1/(1+25*x**2)
x=sp.Symbol("x")
f_p = sp.diff(f_s(x), x, 10)
funP_Error = sp.lambdify(x,f_p,'numpy') #numpy funcion

E=(m/(mt.factorial(10)))*(xx-x_[0])**2*(xx-x_[1])**2*(xx-x_[2])**2*(xx-x_[3])**2*(xx-x_[4])**2

# %%
plt.plot(xx,E)

# %% [markdown]
# # 4. Spline Cúbico
#
# Consideremos la imagen ![paloma](https://github.com/hernansalinas/autogrades/blob/main/Laboratorios_Taller/img/paloma.png?raw=true).
#
#
#
#
# Con los datos dados en la tabla:
#
# 1. Representar gráficamente la imagen, usando las órdenes `imread` e `imshow` de python (estas órdenes están contenidas en el paquete `matplotlib`)
#
# 2. Definir una lista de puntos, $x_i$,$y_i$ de la paloma.
#
# 3. Representar el polinomio de interpolación de Lagrange en estos puntos, para aproximar el dibujo.
#
# 4. Repetir el proceso de interpolación mediante *splines* cúbicos. Para ello, utilizar la función `CubicSpline` (contenida en `scipy.interpolate`),
#
#
# 5. Comparar los resultados. ¿Alguna de las interpolaciones presenta oscilaciones? ¿A qué se debe este fenómeno?
#
# Ref: Metodos numericos, Burden.

# %%
# definimos los puntos 

x2 = ([0.9, 1.3, 1.9, 2.1, 2.6, 3.0, 3.9, 4.4, 4.7,5.0,6.0,7.0,8.0,9.2,10.5, 11.3, 11.6,12.0,  12.6, 13.0,13.3 ])
y2 = ([1.3,1.5,1.85,2.1,2.6,2.7,2.4,2.15,2.05,2.1,2.25,2.3, 2.25, 1.95,1.4,0.9,0.7,0.6,0.5,0.4,0.25])
plt.figure(figsize=(16,5))
plt.plot(x2,y2,"ro")

# %%
#interpolacion por lagrange
plt.figure(figsize=(16,5))
f1  = interpolate.interp1d(x2,y2,kind="cubic")
x  = np.linspace(np.min(x2),np.max(x2))
plt.plot(x,f1(x))
plt.plot(x2,y2,"ro")

# %%
#interpolando por por cubicSpline
plt.figure(figsize=(16,5))
f3 = interpolate.lagrange(x2,y2)
x  = np.linspace(np.min(x2),np.max(x2))
plt.plot(x,f3(x))
plt.plot(x2,y2,"ro")

# %% [markdown]
# # 5.0 Ejercicios de Repaso

# %% [markdown]
#  En la teoria de campo medio, La magnetización como función de la temperatura de un material magnético  puede ser calculada como:
#
# \begin{equation}
# m(T) = \tanh\left( \frac{m(T)}{T} \right)
# \end{equation}
#
# donde m y T son la magnetizacion y temperatura reducida respectivamente
#
# Para T = 0.5, determine:
#
# a. La magnetización reducida empleando el metodo de la secante(Muestre su resultado con 4 cifras)
#
# b. Valide su respuestado con el metodo de punto fijo.
# (Muestre su resultado con 4 cifras)
#
# d. Defina T = np.linspace(0.1,0.99,100), y emple el metodo de la secante para construir un gráfico de magnetización reducida como función de la temperatura para los  100 valores  de T.
#
#
# e. Para los 100 puntos anteriores, emplee el metodo de interpolación de lagrange y cubic-spline. Realizar una gráfica mostrando los puntos y el polinomio de interpolación para cada unos de los metodos. ¿Que puede concluir de los metodos?

# %%
import numpy as np
from scipy.optimize import root_scalar
from scipy.optimize import fixed_point

T = 0.5

# a) Método de la secante
def f(m, T):
    return np.tanh(m/T) - m

sol = root_scalar(f, x0=0.4, x1=0.5, method='secant', args=(T,))

print(f"La magnetización reducida en T = {T} es para el metodo secante: {sol.root:.4f}")

# b) Método de punto fijo
def g(m, T):
    return np.tanh(m/T)

sol2 = fixed_point(g, x0=0.5, args=(T,))

print(f"La magnetización reducida en T = {T} con el método de punto fijo es: {sol2:.4f}")
# Out:
# La magnetización reducida en T = 0.5 es para el metodo secante: 0.9575
# La magnetización reducida en T = 0.5 con el método de punto fijo es: 0.9575

# %%
T = np.linspace(0.1,0.99,100)
magnetization = np.zeros(len(T))

for i in range(len(T)):
    sol = root_scalar(f, x0=0.4, x1=0.5, method='secant', args=(T[i],))
    magnetization[i] = sol.root

plt.plot(T, magnetization)
plt.xlabel('Temperatura reducida')
plt.ylabel('Magnetización reducida')
plt.show()

# %%
import matplotlib.pyplot as plt

T = np.linspace(0.1, 0.99, 100)
m = np.zeros_like(T)
cubic= interpolate.CubicSpline(T, g(m,T))
plt.plot(T,g(m,T),"ro")
plt.plot(T,cubic(T))
plt.grid()

# %%
lagrange_poly = lagrange(T, m)
T = np.linspace(0.1, 0.99, 100)
m = np.zeros_like(T)
cubic= interpolate.CubicSpline(T, g(m,T))
plt.plot(T,g(m,T),"ro")
plt.plot(T,lagrange_poly(T))
plt.grid()

# %%
m = np.zeros_like(T)
for i in range(len(T)):
    bracket = [0, 0.5]  # Intervalo inicial para la raíz
    x0 = np.mean(bracket)  # Valor inicial para la aproximación de la raíz
    sol = root_scalar(f, x0=0.4, x1=0.5, method='secant', args=(T[i],))
    m[i] = sol.root

# Interpolación con Lagrange
lagrange_poly = lagrange(T, m)

# Interpolación con cubic spline
spline = CubicSpline(T, m)

# Crear la figura
fig, ax = plt.subplots(figsize=(8, 6))

# Graficar los puntos de la magnetización reducida
ax.plot(T, m, 'o', label='Datos')

# Graficar el polinomio de Lagrange
T_interp = np.linspace(0.1, 0.99, 1000)
m_interp_lagrange = lagrange_poly(T_interp)
ax.plot(T_interp, m_interp_lagrange, '-', label='Interpolación Lagrange')

# Graficar el spline cúbico
m_interp_spline = spline(T_interp)
ax.plot(T_interp, m_interp_spline, '--', label='Cubic Spline')

# Etiquetas de los ejes y título
ax.set_xlabel('Temperatura')
ax.set_ylabel('Magnetización reducida')
ax.set_title('Interpolación de magnetización reducida')

# Leyenda
ax.legend()

# Mostrar la figura
plt.show()
