# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Laboratorios_Taller/Lab06_ceros_funciones_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
from scipy import optimize

# %% [markdown]
# # Codigo Markdown:
# Los numeras a, b, c y d tiene que ver con escritura en código Markdown y comandos de latex:
#
# a. Escriba en pseudocódigo los pasos para aplicar el método de la bisección.
#
# b. Realice la deducción del metodo de Newton-Rapshon, se recomienda escribir las ecuaciones en formato latex, para ello puede emplear las siguientes expresiones:
#
# c. ¿Cuál es la diferencia del metodo de Newton-Rapson con respecto al de la secante?
#
#
# d. Escriba en pseudocódigo los pasos para aplicar el método Punto Fijo.
#
#
#
# Comentarios para escribir en latex
#
# *   Entre simbolos \$ \$, puedes porner expresiones  puede poner expresiones, ejemplo:  $y = a_0 x^2 + b_1$
#
# *  Las funciones pueden ser definidas entre \\$,  poniendo un \\, antes de la funcion ejemplo: \\$ \\sinx \\$,   asi las funciones quedarian de esta manera :
#
# > $\sin x$, $\tan x$, $\sec x$, $\sqrt{a} $, $\frac{a}{b}, \frac{df}{dt}$
#
# * Puedes generar tambien escribir ecuaciones con la instrucción:
#
#   \\begin{equation}
#
#     \\sin x
#
#   \\end{equation}
#
# Ejemplo:
#
#   \begin{equation}
#     \frac{df}{dx} = \sin x
#   \end{equation}
#
#
#
# # 2. Ceros de funciones
# *Encontrar* los ceros de $e^{x}-2= \cos(e^x-2)$ por diferentes metodos, bisection, newton-rapshon, punto fijo.
#
#
#
#
#
# # 3. Movimiento de proyectiles en presencia de viento.
#
# Supongamos que un proyectil es lanzado desde el origen con una rapidez $v=vo( \cos \theta , \sin \theta $. Supongamos además que el efecto del viento sobre el proyectil es el de una fuerza proporcional a la velocidad relativa entre el viento y el proyectil. Teniendo presente que si u es la velocidad del viento y $\alpha$ el ángulo que hace dirección de esta velocidad con el eje x, se puede entrontrar las siguientes ecuaciones diferenciales, asociada al estado de movimiento del [proyectil](https://iopscience.iop.org/article/10.1088/0143-0807/36/2/025016/meta):
#
#
# \begin{equation}
# m\frac{dv_x}{dt} = -mb(v_x-u\cos \alpha )
# \end{equation}
#
# \begin{equation}
# m\frac{dv_y}{dt} = -mg-mb(v_x-u\sin \alpha ),
# \end{equation}
#
# donde b es el párametro de rozamiento. La soluciones a las ecuaciones anteriores vienen dadas por:
#
# Posición en x
# \begin{equation}
# x=(u\cos \alpha) t + \frac{1}{b} (v_0\cos \theta_0 -u \cos\alpha)(1-\mathrm{exp}(-bt))
# \end{equation}
#
# Posicion en y
# \begin{equation}
# y= \frac{1}{b}\left(\frac{g}{b}+v_0 \sin \theta_0 -u\sin\alpha \right)(1-\mathrm{exp}(-bt))-\left( \frac{g}{b}-u\sin\alpha\right)t
# \end{equation}
#
# Ver imagen:  http://www.sc.ehu.es/sbweb/fisica3/fluidos/viento/parabolico.html
#
#
# 0. Establezca las siguientes condiciones inciales.
#
# ```
# #Parametros iniciales
#
# v0 = 60 #Velocidad en m/s
# alpha = np.pi #Angulo del viento
# theta = np.deg2rad(45) #Angulo de lanzamiento
# u = v0/2             #rapidez del viento
# b = 0.05             #Parametro de friccion
# g = 9.8                #Aceleracion de la gravedad m/s2
#
# Params = (alpha, v0, b, u,g)  #Parametros en tupla.
#
# ```
#
#
#
# 1. Defina dos funciones, una para x y otra para y.
#
# ```
#
# #Posicion en x
# def pos_x(t, theta, alpha, v0, b, u,g):
#   x = #escriba aca la expresión
#   return x
#
# #Posicion en y
# def pos_y(t, theta, alpha, v0, b, u,g):
#
#
#   y = #escriba aca la expresión
#   return y
#
# ```
#
# 2. Construya un diccionario con las claves "X", "Y", "Tiempo"
#
# 3. Con el diccionario construya un data frame de pandas llamado df con los nombres de columnas "X", "Y", "Tiempo"  https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.from_dict.html. Defina 1000 regitros para el intervalo de tiempo elegido.
#
#
# 4. Realice un gráfico de x como función del tiempo, de y como función del tiempo y la trayectoria de la partícula (df["X"], df["tiempo"], df["Y"]).
#
#
# 5. Determine el alcance máximo de la partícula, para ello tome  la solucion teórica con $y=0$, solucione numéricamente la ecuación para t y remplace este valor en la ecuación para x. Resuelvalo para $\theta=45^{o}$.
#
# 6. Construya una  grafica del alcance máximo R como función de $\theta$, varie $\theta$  entre 10 y 80 grados cada 5 grados.

# %% [markdown]
# # **1. Código Markdown**

# %% [markdown]
# a. Pseudocódigo método de bisección

# %% [markdown]
# ```
# # Inicio
#
# Función bisección (funcion, numero real a, numero real b, numero real tolerancia, número máximo de iteraciones):
#
#    c=a
#    iteraciones=0
#
#    Mientras |f(c)| >= numero real tolerancia y f(a)*f(b)>0 y iteraciones< número máximo de iteraciones:
#
#      c=a+b/2
#      f(c)
#
#      Si f(c)>0:
#        b=c
#      Sino:
#        a=c
#      FinSi
#
#      Si iteraciones= número máximo de iteraciones:
#
#       Escribir "No se alcanza la posición deseada, número máximo de iteraciones superado N=", N
#
#      Devolver c
#
#   # Fin
# ```

# %% [markdown]
# b. Deducción método Newton-Rapshon

# %% [markdown]
# Supongamos que se desea calcular la raíz de una función $\\f(x)$ aproximándonos desde algún $\\x_0$. Se quiere encontrar una mejor aproximación $\\x_1$ de la raíz y para ello asumimos que $\\x_1$ está lo suficientemente cerca de la raíz para que $\\f(x_1)$ se acerque a 0.
#
# Consideremos el primer polinomio de Taylor para $\\f(x)$ expandido alrededor de $\\x_0$

# %% [markdown]
# \begin{equation}
#   \\f(x)\approx f(x_0)+f'(x_0)(x-x_0)
# \end{equation}
#
# Como se desea encontrar el valor para el cual $\\f(x)=0$ entonces sustituyendo en la ecuación anterior se tiene:
#
# \begin{equation}
#   \\0= f(x_0)+f'(x_0)(x-x_0)
# \end{equation}
#
# Y despejando a $\\x$ de la ecuación
#
# \begin{equation}
#   \\x=x_0-\frac{f(x_0)}{f'(x_0)}
# \end{equation}

# %% [markdown]
# De esta manera se puede iterar para encontrar la raíz y se genera la sucesión:
#
#
# \begin{equation}
#   \\x_{n+1}=x_n-\frac{f(x_n)}{f'(x_n)}
# \end{equation}

# %% [markdown]
# **Nota:** El método se deriva de suponer que como $\\|x-x_0|$ es pequeño, los términos relacionados con $\\(x-x_0)^n$ son mucho más pequeños y por esa razón se considera el primer polinomio de Taylor.

# %% [markdown]
# c. ¿Cuál es la diferencia del metodo de Newton-Rapson con respecto al de la secante?

# %% [markdown]
# El método de la secante empieza con dos aproximaciones iniciales $\\x_0$ y $\\x_1$  de modo que la aproximación $\\x_2$ es la intersección en en el eje $\\x$  de la recta que une los puntos $\\(x_0,f(x_0))$ y $\\(x_1,f(x_1))$. Luego la aproximación $\\x_3$ es nuevamente la intersección en $\\x$ de la recta que une los puntos $\\(x_1,f(x_1))$ y$\\(x_2,f(x_2))$ y así sucesivamente.

# %% [markdown]
# En este método solo es necesario evaluar la función una vez por cada iteración, pues en contraste con el método de Newton-Rapshon, también se necesita evaluar la derivada de la función.

# %% [markdown]
# d.  Escriba en pseudocódigo los pasos para aplicar el método Punto Fijo.

# %% [markdown]
# ```
# # Inicio
#
#
# Función punto fijo (función,función de punto fijo (g(x)),aproximación inicial, número máximo de iteraciones,tolerancia):
#
#    punto inicial= g(aproximación incial)
#
#    Mientras |p0-g(p_inicial)|>=epsilon y numero máximo de iteraciones<=100
#     punto incial= g(aproximación inicial)
#     aproximación inicial = punto inicial
#     número maximo iteraciones =número máximo iteraciones+1
#    Fin Mientras
#
#    Devolver g(aproximación inicial)
#
#
#
#
# ```

# %% [markdown]
# # **2. Ceros de funciones**

# %% [markdown]
# *Encontrar* los ceros de $e^{x}-2= \cos(e^x-2)$ por diferentes metodos, bisection, newton-rapshon, punto fijo.

# %%
f=lambda x: np.exp(x)-2-np.cos(np.exp(x)-2)
f_=lambda x: np.exp(x)+np.sin(np.exp(x)-2)*np.exp(x)

# %%
x=np.linspace(-1,2,1000)

# %%
plt.plot(x,f(x),c="b")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gráfica de la función")
plt.grid()

# %%
plt.plot(x,f_(x),c="b")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gráfica de la derivada de la función")
plt.grid()

# %%
# Se hace cero en x=1

# %%
# Raiz método Newton-Rhapson

raizn= sp.optimize.newton(f,4,f_)
raizn
# Out:
# 1.0076239716581368

# %%
# Raíz método bisección

raizb= sp.optimize.bisect(f,0.5,2)
raizb
# Out:
# 1.0076239716586315

# %%
# Raíz método secante

raizs=sp.optimize.newton(f,4) # no se pasa la derivada de f
raizs
# Out:
# 1.0076239716581368

# %% [markdown]
# # **3. Movimiento de proyectiles en presencia de viento**

# %% [markdown]
# \begin{equation}
# m\frac{dv_x}{dt} = -mb(v_x-u\cos \alpha )
# \end{equation}
#
# \begin{equation}
# m\frac{dv_y}{dt} = -mg-mb(v_x-u\sin \alpha ),
# \end{equation}
#
# donde b es el párametro de rozamiento. La soluciones a las ecuaciones anteriores vienen dadas por:
#
# Posición en x
# \begin{equation}
# x=(u\cos \alpha) t + \frac{1}{b} (v_0\cos \theta_0 -u \cos\alpha)(1-\mathrm{exp}(-bt))
# \end{equation}
#
# Posicion en y
# \begin{equation}
# y= \frac{1}{b}\left(\frac{g}{b}+v_0 \sin \theta_0 -u\sin\alpha \right)(1-\mathrm{exp}(-bt))-\left( \frac{g}{b}-u\sin\alpha\right)t
# \end{equation}

# %%
# Parametros iniciales

v0 = 60 # Velocidad en m/s
alpha = np.pi/4 # Angulo del viento
theta = np.deg2rad(45) # Angulo de lanzamiento
u = v0/2             # rapidez del viento
b = 0.05             # Parametro de friccion
g = 9.8                # Aceleracion de la gravedad m/s2

Params = (theta,alpha, v0, b, u,g)  #Parametros en tupla.

# %%
# Posicion en x
def pos_x(t, theta, alpha, v0, b, u,g):

  x =(u*np.cos(alpha))*t +1/b*(v0*np.cos(theta)-u*np.cos(alpha))*(1-np.exp(-b*t))

  return x

# Posicion en y
def pos_y(t, theta, alpha, v0, b, u,g):

  y= 1/b*(g/b+v0*np.sin(theta)-u*np.sin(alpha))*(1-np.exp(-b*t))-(g/b-u*np.sin(alpha))*t
  return y

# %%
y= lambda t,*Params: 1/b*(g/b+v0*np.sin(theta)-u*np.sin(alpha))*(1-np.exp(-b*t))-(g/b-u*np.sin(alpha))*t

# %%
tv = optimize.bisect(pos_y, 0.1, 10, args=Params)
tv  # cuando y=0
# Out:
# 9.031812367278818

# %%
t = np.linspace(0,tv,1000)
x = pos_x(t, theta, alpha, v0, b, u,g)
y = pos_y(t, theta, alpha, v0, b, u,g)

# %%
# Prueba para b= 0.1 fricción muy pequeña
plt.plot(x,y,color="red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trayectoria de un Proyectil con Fricción")
plt.grid()

# %%
dicc={"X":x,"Y":y,"Tiempo":t}

# %%
# 1000 registros para el tiempo

df=pd.DataFrame(dicc)
df
# Out:
#               X             Y    Tiempo
# 0      0.000000  0.000000e+00  0.000000
# 1      0.383528  3.831271e-01  0.009041
# 2      0.766968  7.653669e-01  0.018082
# 3      1.150323  1.146720e+00  0.027123
# 4      1.533591  1.527186e+00  0.036163
# ..          ...           ...       ...
# 995  344.509027  1.315646e+00  8.995649
# 996  344.823099  9.875830e-01  9.004690
# 997  345.137116  6.589542e-01  9.013731
# 998  345.451078  3.297598e-01  9.022772
# 999  345.764984  2.228262e-11  9.031812
#
# [1000 rows x 3 columns]

# %% [markdown]
# 4. Realice un gráfico de x como función del tiempo, de y como función del tiempo y la trayectoria de la partícula (df["X"], df["tiempo"], df["Y"]).

# %%
plt.plot(df["Tiempo"],df["X"],color="deeppink",label="Parábola",linewidth="2")
plt.xlabel("Tiempo")
plt.ylabel("X")
plt.title("Posición x en función del tiempo")
plt.grid() # movimiento rectilíneo uniforme a lo largo del eje x

# %%
plt.plot(df["Tiempo"],df["Y"],color="royalblue",label="y(t)",linewidth="2")
plt.xlabel("Tiempo")
plt.ylabel("y")
plt.title("Posición y en función del tiempo")
plt.grid()

# %%
plt.plot(df["X"],df["Y"],color="limegreen",label="Parábola",linewidth="2")
plt.ylabel("Posiciones")
plt.title("x(t),y(t)")
plt.grid()

# %% [markdown]
#  5. Determine el alcance máximo de la partícula, para ello tome  la solucion teórica con $y=0$, solucione numéricamente la ecuación para t y remplace este valor en la ecuación para x. Resuelvalo para $\theta=45^{o}$.

# %%
x= lambda t, theta, alpha, v0, b, u,g: (u*np.cos(alpha))*t+1/b*(v0*np.cos(theta)-u*np.cos(alpha))*(1-np.exp(-b*t))

# %%
x(tv,*Params) # valor esperado del alcance máximo en el tiro parabólico
# Out:
# 345.764984276583

# %% [markdown]
# 6. Construya una  grafica del alcance máximo R como función de $\theta$, varie $\theta$  entre 10 y 80 grados cada 5 grados.

# %%
theta1= np.deg2rad( np.arange(10, 85, 5))

# %%
for i in theta1:

  Params1=(i,alpha, v0, b, u,g)
  valor= optimize.bisect(pos_y, 0.1, 15, args=Params1) # 15 raíces, ya que hay 15 ángulos
  t_nuevo = np.linspace(0,valor,1000)
  y_nuevo= pos_y(t_nuevo, *Params1)
  x_nuevo= pos_x(t_nuevo, *Params1)
  plt.plot(x_nuevo, y_nuevo)

plt.xlabel("Álcance máximo(R)")
plt.ylabel("Altura")
plt.title("Álcance máximo R(θ)")
plt.grid()

# %% [markdown]
# # 4. Fixed point methods.
#
# When a new planet is discovered, there are different methods to estimate its physical properties. Many times is only possible to estimate either the planet mass or the planet radius and the other property has to be predicted through computer modelling.
#
# If one has the planet mass, a very rough way to estimate its radius is to assume certain composition (mean density) and a homogeneous distribution (a very bad assumption!). For example, for the planet [Gliese 832c](http://es.wikipedia.org/wiki/Gliese_832_c) with a mass $M= 5.40 M_{\oplus}$, if we assume an earth-like composition, i.e. $\bar \rho_{\oplus} = 5520\ kg/m^3$, we obtain:
#
# $$R_{g832c} = \left( \frac{3 M_{g832c}}{ 4 \pi \bar\rho_{\oplus} } \right)^{1/3} \approx 1.75 R_{\oplus}$$
#
# That would be the planet radius if the composition where exactly equal to earth's.
#
# A more realistic approach is assuming an internal one-layer density profile like:
#
# $$\rho(r) = \rho_0 \exp\left( -\frac{r}{L} \right)$$
#
# where $\rho_0$ is the density at planet centre and $L$ is a characteristic lenght depending on the composition. From numerical models of planet interiors, the estimated parameters for a planet of are $M= 5.40 M_{\oplus}$ are approximately $\rho_0 = 18000\ kg/m^3$ and $L = 6500\ km$.
#
# Integrating over the planet volume, we obtain the total mass as
#
# $$M = 4\pi \int_0^R \rho(r)r^2dr$$
#
# This is a function of the mass in terms of the planet radius.
#
# Solving the equation $M(R) = M_{g832c}$ it would be possible to find a more realistic planet radius. However when using numerical models, it is not possible to approach the solution from the left side as a negative mass makes no sense.

# %%
# radio 1,69

# %%
# normalizar respecto a las masas terrestres

# %%
import sympy as sp

# %%
r= sp.Symbol("r")
L= sp.Symbol("L")
rho0= sp.Symbol("rho0") # simbólicamente

R= sp.Symbol("R")

# %%
rho= lambda r: rho0*sp.exp(-r/L)

# %%
rho(r)
# Out:
# rho0*exp(-r/L)

# %%
integral= sp.integrate(r**2*rho(r),(r,0,R))
integral
# Out:
# 2*L**3*rho0 + (-2*L**3*rho0 - 2*L**2*R*rho0 - L*R**2*rho0)*exp(-R/L)

# %%
p_0= 18000  # en kg/m^3
L= 6500/6.371   # normalizado respecto al radio de la tierra en km
M_g= 5.40/5.972 *10**24 # normalizado respecto a la masa de la tierra
radio_inicial= 1.0  # km

# %%
M = lambda R: 4*np.pi* (2*L**3*p_0 + np.exp(-R/L)*(-2*L**3*p_0 - 2*L**2*R*p_0 - L*R**2*p_0 )) - (M_g)

# %%
G = lambda R: R-M(R)
I = lambda R: R # función identidad

# %%
R=np.linspace(0,2)

# %%
plt.plot(R,M(R),label="M(R)",c="b")
plt.plot(R,G(R),label="G(R)",c="r")
plt.plot(R,I(R),label="I(R)",c="green")
plt.title("Gráfica de las funciones")
plt.legend()
plt.grid()

# %%
radio= optimize.fixed_point(G,radio_inicial,)
radio
# Out:
# array(1.70183849e+33)

# %% [markdown]
# # 5. Construir un fractal empleando el metodo de Newton-Raphson,
# (Reproducir código y entender)
# \begin{equation}
# z_{n+1} = z_n -a \frac{f(z)}{f'(z)}
# \end{equation}
#
#
#
# \begin{equation}
# f'(z) = \frac{ f(z+h)+f(z) }{h}
# \end{equation}
#
#
#
# ```
# import numpy as np
# import matplotlib.pylab as plt
# from PIL import Image
#
# Npx_X = 80 #Numero de pixeles en x
# Npx_Y = 80 #Numero de pixeles en y
#
# image = Image.new("RGB", (Npx_X, Npx_Y)) #Creacion de la imagen inicial
#
# npx = np.arange(0, Npx_X)
# npy = np.arange(0, Npx_Y)
#
# xmin = -1
# xmax = 1
# ymin = -1
# ymax = 1
# #Transformación al plano complejo en un rectangulo (xmin, xmax), (ymin, ymax)
# zx = npx * (xmax - xmin) / (Npx_X - 1)   + xmin
# zy = npy * (ymax-ymin) / (Npx_Y - 1) + ymin
#
# #Definicion  la funcion y las derivada
# def f(z):
#   return z**3 - 1
#
# def fp(z):
#   return 3*z**2
#
# h = 1E-4
# def fpn(z, h):
#   return (f(z+h)-f(z))/h
#
#
# a = 0.2
# Niteraciones = 120
# eps = 1E-8
#
# x = - 1
# for zx_ in zx:
#   x = x + 1
#   y = -1
#   for zy_ in zy:
#       y = y + 1
#       Z_0 = complex(zx_, zy_)
#
#       for i in range(0, Niteraciones):
#         Z = Z_0 - a * f(Z_0)/fp(Z_0)
#         if( abs(Z-Z_0)<= eps):
#           break
#         Z_0 = Z
#       #print(i)
#       #print(i)
#       r, g, b = i % 4 *64 , i % 8 *16, i% 16* 16
#       image.putpixel((x,y), (r,g,b) )
#
# plt.imshow(image)
# #plt.xlim(400, 600)
# #plt.ylim(400, 523)
# ```

# %%
import numpy as np
import matplotlib.pylab as plt
from PIL import Image

Npx_X = 80 #Numero de pixeles en x
Npx_Y = 80 #Numero de pixeles en y

image = Image.new("RGB", (Npx_X, Npx_Y)) #Creacion de la imagen inicial

npx = np.arange(0, Npx_X)
npy = np.arange(0, Npx_Y)

xmin = -1
xmax = 1
ymin = -1
ymax = 1
# Transformación al plano complejo en un rectangulo (xmin, xmax), (ymin, ymax)
zx = npx * (xmax - xmin) / (Npx_X - 1)   + xmin
zy = npy * (ymax-ymin) / (Npx_Y - 1) + ymin

# Definicion  la funcion y las derivada
def f(z):
  return z**3 - 1

def fp(z):
  return 3*z**2

h = 1E-4

def fpn(z, h): # derivada con el valor de h
  return (f(z+h)-f(z))/h


a = 0.2 # punto inicial de aproximación
Niteraciones = 120
eps = 1E-8

x = - 1
for zx_ in zx:
  x = x + 1
  y = -1
  for zy_ in zy:
      y = y + 1
      Z_0 = complex(zx_, zy_)

      for i in range(0, Niteraciones): # Newton-Rapshon
        Z = Z_0 - a * f(Z_0)/fp(Z_0)
        if( abs(Z-Z_0)<= eps):
          break
        Z_0 = Z
      #print(i)
      #print(i)
      r, g, b = i % 4 *64 , i % 8 *16, i% 16* 16
      image.putpixel((x,y), (r,g,b) )

plt.imshow(image)
# plt.xlim(400, 600)
# plt.ylim(400, 523)
