# %% [markdown]
# <a href="https://colab.research.google.com/github/hernansalinas/autogrades/blob/main/Actividades_clase/Actividad_05_06_ZerosFunciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
#
# # Actividad 5
# ### Métodos computacionales para físicos  y astrónomos
# ### Universidad de Antioquia
# ### Prof: Hernan D. Salinas Jiménez
# Ref: https://github.com/restrepo/ComputationalMethods

# %% [markdown]
# 1. Implementar el metodo de la bisección para determinar las raices de una función.
# 2. Implementar el metodo de la newton para determinar las raices de una función.
#
# Prueba tu resultado para:

# %% [markdown]
#
#  2. $a e^{x}-2= b\cos(e^x-2)$

# %%
import numpy as np
import matplotlib.pyplot as plt
#funcion definida para a
f_a = lambda b,x: 2/np.exp(x) + (b*np.cos(np.exp(x) -  2))/np.exp(x)
b = np.pi
x = np.linspace(1,2,100)
plt.figure()
plt.plot(x,f_a(b,x), label= f_a)
plt.legend()

# %%
def biseccion(f,a,b,N,eps):
  for i in range(N):
    if f(a)*f(b)>0:
      print("cambie los valores del intervalo")
      break

  i = 0
  while i !=N:

      p = (a+b)/2
      print (i, p, f(p))
      if f(a)*f(p)>0:
        a = p
      elif f(a)*f(p)<0:
        b = p
        #for i in range(N):
          #if abs(p-p[i-1]) < eps:
            #print(f"el cero es {p}")
            #break
          #elif abs(p - p[i-1])/abs((p)) < eps:
            #print(f"el cero es {p}")
            #break
      if abs(f(p)) < eps:
        print(f"el cero es {p}")
        break

      i = i+1
  return p

# %%
def newton_raphson2(f,df,x0,eps,Nmax):
  #aplicarle derivada con simpy
  i = 0
  while i<Nmax:
  #while(abs(f(x0)) < eps):
    p = x0 - (f(x0)/df(x0))
    #p_n = p[i-1] -(f(p[i-1])/df(p[i-1]))

    if abs(p-x0)<eps:
      break

    x0 = p
    i=i+1



    return p

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import optimize

F_2 = lambda x: 2/np.exp(x) + (np.pi*np.cos(np.exp(x) -  2))/np.exp(x)
DF_2 = lambda x: ((-np.pi*np.exp(2*x)*np.sin(np.exp(x) - 2) - np.pi*np.exp(x)*np.cos(np.exp(x) - 2))/np.exp(2*x)) - 2*np.exp(-x)

#optimize.bisect(F_2,1.4,1.6)
biseccion(f= lambda x: 2/np.exp(x) + (np.pi*np.cos(np.exp(x) -  2))/np.exp(x),a=1.4,b=1.6,N=100,eps=1e-7)
# Out:
# 0 1.5 -0.1075530868329857
# 1 1.45 -0.0012554179075667249
# 2 1.4249999999999998 0.06248859098990056
# 3 1.4375 0.029800772611835835
# 4 1.44375 0.01406358948934816
# 5 1.446875 0.006351175709674861
# 6 1.4484374999999998 0.0025345718782596727
# 7 1.44921875 0.0006362403092238789
# 8 1.449609375 -0.0003104242071365615
# 9 1.4494140625 0.00016269935386881151
# 10 1.4495117187500002 -7.391462028311091e-05
# 11 1.449462890625 4.4379320800258526e-05
# 12 1.4494873046875 -1.4770911541950316e-05
# 13 1.44947509765625 1.4803389216389018e-05
# 14 1.4494812011718752 1.6034979177792508e-08
# el cero es 1.4494812011718752
# 1.4494812011718752

# %%
import numpy as np
import matplotlib.pyplot as plt
f_a = lambda b,x: 2/np.exp(x) + (b*np.cos(np.exp(x) -  2))/np.exp(x)
b = np.pi
x = np.linspace(1.42,1.5,100)
plt.figure()
plt.plot(x,f_a(b,x), label= f_a)
plt.legend()

# %%
newton_raphson2(F_2,DF_2,x0 = 1.45,eps = 1e-8,Nmax = 1000)
# Out:
# 1.4494805976361855

# %%
optimize.bisect(F_2,1.4,1.6),optimize.newton(F_2,1.4,DF_2)
# Out:
# (1.449481207791541, 1.4494812077904422)
