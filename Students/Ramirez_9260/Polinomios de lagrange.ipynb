# %%
import numpy as np
import sympy as sp

xp = np.array([2,5,6])
f = np.array([4,1,2 ])
fx=sp.Symbol("fx")
x = sp.Symbol("x")
j=0
xj=4

def productoria(xp):
  Lin=1
  for i in range(len(xp)):
    Li=(x-xp[i])/(xj-xp[i])
    Lin=Li*Lin
  return(Lin)

# %%
productoria(xp)
# Out:
# (3 - x/2)*(5 - x)*(x/2 - 1)

# %%
x = sp.Symbol("x")
def Polino(xp,f):
  Pi=0
  for i in range(len(xp)):
    print(i)
    Pi+=f[i]*productoria(xp)
    return(Pi)

# %%
Polino(xp,f)
# Out:
# 0
# 4*(3 - x/2)*(5 - x)*(x/2 - 1)
