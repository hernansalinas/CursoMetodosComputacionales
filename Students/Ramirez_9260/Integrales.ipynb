# %%
import scipy
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

a=0
b=10
N=10000000
X=np.linspace(a,b,N)

# %%
def f(x):
  return 3*x**2

# %%
dx=(b-a)/N
fin=dx*(f(X+1)+f(X).sum())
plt.plot(X,fin)
print("El area es: ",fin[0])
# Out:
# El area es:  1000.000053000005

# %%
print("El area con la formula es : ", fin[0])
inte=scipy.integrate.trapezoid(f(X),X)
print("El area con scipy es: ", inte)
e=np.absolute(inte-fin[0])
print("El el error ente ambos metodos es: ", e )
# Out:
# El area con la formula es :  1000.000053000005
# El area con scipy es:  1000.0000000000044
# El el error ente ambos metodos es:  5.300000054830889e-05
