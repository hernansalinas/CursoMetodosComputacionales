# %%
import scipy
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

epsi=0.1
a=2
X=np.linspace(0,np.pi,100)

# %%
def fun(x):
  return np.sin(x)
def cos(x):
  return np.cos(x)

# %%
Resu=scipy.misc.derivative(fun,X,dx=1E-8)
h=00000.1
fp=(1/(2*h))*(fun(X+h)-fun(X-h))
h2=1
fp2=(1/(2*h2))*(fun(X+h2)-fun(X-h2))
h3=2
fp3=(1/(2*h3))*(fun(X+h3)-fun(X-h3))
# Out:
# <ipython-input-3-3aae08d3d7c4>:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   Resu=scipy.misc.derivative(fun,X,dx=1E-8)

# %%
plt.plot(X,fp,label="Deri") #Metodo nuevo con h
plt.plot(X,fp2,label="Derih2") #Metodo nuevo con h2
plt.plot(X,fp3,label="Derih3") #Metodo nuevo con h3
plt.plot(X,cos(X),label="Cosx") #Metodo Scipy
plt.plot(X,fun(X),label="Senx") #Funcion original
plt.legend()
plt.grid()
