# %% [markdown]
# # **Métodos computacionales: Tarea 03.**
#
# **Por:** Juan Esteban Ospina Holguín y Mariana Toro Escobar.

# %% [markdown]
# # Problema 1.
#
# Usando el set `PS4_1.csv`, convertir la serie `Date` en el indice (serie de tiempo) y eliminar la serie `Unnamed: 1` (generado por pandas), retornar en una lista y en el siguiente orden:
#
# * cantidad de columnas
# * Nombre de las columnas
# * número de registros no NaN de cada columna
# * cantidad total de memoria usada para cargar el set en el computador ,( df.memory_usage() )
# * Estadistica basica para cada columna, media, desviacion estandar, maximo
# * Remplazar los NaN por None
#
#
# # Problema 2
#
# Realizar la lectura del data frame "Crimes_-_2019.csv" asociado a los crimenes que se presentaron en Chicago en el 2019.
#
#
# 1. Ver la estadistica general del data frame.
# 2. Dejar las columnas PrimaryType, y Date.
# 3. Transformar la columna Date que es tipo string en una tipo Fecha, use el siguiente metodo de pandaspd.to_datetime(df.Date,format="%m/%d/%Y %I:%M:%S %p").
# 4. Mostrar los casos totales para cada tipo de crimen de forma ascendente, emplee:
#    df.groupby(columna).Date.count()
#
#    sort_values()
# 5. Ordenar los valores por orden alfabetico de Primary type
# 6. Mostrar de la fila 100 a la 120
# 6. Realizar una visualización de los datos anteriores.Emplee la libreria  seaborn con un grafico tipo barplot. Ej.
#    ax = sns.barplot(x = "contador", y="Primary Type", data = datos)
#
#
#
#
# # Problema 3
#
# 1. Leer el dataset country_vaccinations.csv  y filtrar los datos para Colombia
# 2. Crear un csv con los datos para colombia
# 3. Realizar una comparacion con los paises latinoamericanos.
# 4. A traves de mascaras determinar el numero de vacunados en el intervalo  [1.5E6, 2.0E6]

# %%
import pandas as pd
import numpy as np
import statistics as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""Este código retorna una lista con información sobre el DataFrame PS4_1"""
path = "https://docs.google.com/spreadsheets/d/e/2PACX-1vStmeMc4ccgj-rEejEGmCvi6QJfPmI3sMEiIZwin4DwCeS2eVqd-DDKF7u3KDLd4w/pub?output=csv"
df1 = pd.read_csv(path)
del df1['Unnamed: 1']
df1
# Out:
#            Date  Berri1  Maisonneuve_1  Maisonneuve_2  Brebeuf
# 0    01/01/2009      29             20             35      NaN
# 1    02/01/2009      19              3             22      NaN
# 2    03/01/2009      24             12             22      NaN
# 3    04/01/2009      24              8             15      NaN
# 4    05/01/2009     120            111            141      NaN
# ..          ...     ...            ...            ...      ...
# 360  27/12/2009      66             29             52      0.0
# 361  28/12/2009      61             41             99      0.0
# 362  29/12/2009      89             52            115      0.0
# 363  30/12/2009      76             43            115      0.0
# 364  31/12/2009      53             46            112      0.0
#
# [365 rows x 5 columns]

# %%
def problema1(path):
  df = pd.read_csv(path)
  cantidad_columnas = len(df1.columns) #cantidad de columnas
  nombre = df1.columns #nombre de las columnas
  registros = len(df.axes[0])-df.isnull().sum() #registros no NaN de cada columna
  memoria = df1.memory_usage() #cantidad total de memoria usada
  estadistica = df1.describe() #estadística básica
  complete = df1.fillna('None') #reemplazo de NaN por None
  dic = {"1.Cantidad de columnas": cantidad_columnas, "2.Nombre de las columnas": nombre, "3.Número de registros no NaN de cada columna": registros, 
       "4.Cantidad total de memoria usada": memoria, "5.Estadística básica": estadistica, "6.Reemplazo de NaN por None": complete} #creación de diccionario
  return dic
problema1(path) #ejecución de la función
# Out:
# {'1.Cantidad de columnas': 5,
#  '2.Nombre de las columnas': Index(['Date', 'Berri1', 'Maisonneuve_1', 'Maisonneuve_2', 'Brebeuf'], dtype='object'),
#  '3.Número de registros no NaN de cada columna': Date             365
#  Unnamed: 1       365
#  Berri1           365
#  Maisonneuve_1    365
#  Maisonneuve_2    365
#  Brebeuf          178
#  dtype: int64,
#  '4.Cantidad total de memoria usada': Index             128
#  Date             2920
#  Berri1           2920
#  Maisonneuve_1    2920
#  Maisonneuve_2    2920
#  Brebeuf          2920
#  dtype: int64,
#  '5.Estadística básica':             Berri1  Maisonneuve_1  Maisonneuve_2      Brebeuf
#  count   365.000000     365.000000     365.000000   178.000000
#  mean   2032.200000    1060.252055    2093.169863  2576.359551
#  std    1878.879799    1079.533086    1854.368523  2484.004743
#  min       0.000000       0.000000       0.000000     0.000000
#  25%     194.000000      90.000000     228.000000     0.000000
# ...

# %%
"""Este código retorna información acerca del DataFrame Crimes_2019"""
path = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQu6gc-tIGJKMBTsWECK1egQvvz7GbmSDWblqyRsMSNX-vzNinqWc6M3OlcLuMRyDhfbsa2esOn1xrN/pub?output=csv"
df2 = pd.read_csv(path)
df2
# Out:
#      Unnamed: 0        Primary Type                    Date
# 0             0  DECEPTIVE PRACTICE   09/24/2019 8:00:00 AM
# 1             1               THEFT   10/13/2019 8:30:00 PM
# 2             2               THEFT   10/05/2019 6:30:00 PM
# 3             3     CRIMINAL DAMAGE   10/13/2019 7:00:00 PM
# 4             4             ASSAULT   10/13/2019 2:10:00 PM
# ..          ...                 ...                     ...
# 995         995       OTHER OFFENSE  10/14/2019 10:47:00 PM
# 996         996             BATTERY   10/14/2019 4:00:00 AM
# 997         997               THEFT  10/14/2019 10:25:00 AM
# 998         998               THEFT   10/14/2019 7:00:00 PM
# 999         999             ROBBERY   10/14/2019 4:10:00 PM
#
# [1000 rows x 3 columns]

# %%
Ndf = pd.DataFrame() #se define DataFrame para extraer las columnas PrimaryType, y Date
N1df = pd.DataFrame()
Ndf['Date'],Ndf['Primary Type'] = df2['Date'],df2['Primary Type'] #asignación de las series 
N1df['Primary Type'] = df2['Primary Type']
print("1. Estadistica general: \n",df2.describe(),"\n","\n", #estadística general del dataframe
    "2. columnas Date y PrimaryType.\n",Ndf,"\n","\n", #columnas PrimaryType, y Date
      "3.Convertir fechas","\n","\n",  pd.to_datetime(df2.Date,format="%m/%d/%Y %I:%M:%S %p"),"\n","\n", #transformar la columna Date que es tipo string en una tipo Fecha
      "4. casos totales para cada tipo de crimen \n", Ndf.groupby('Primary Type').Date.count().sort_values(), "\n","\n", #casos totales para cada tipo de crimen de forma ascendente
      "5. Primary type ordenado", N1df.sort_values(by=['Primary Type']),"\n","\n", #ordenar alfabéticamente de PrimaryType
      "6. Fila 100 - 120",Ndf.iloc[100:121]) #mostrar de la fila 100 a la 120

datos = df2.groupby("Primary Type").Date.count().sort_values(ascending=False) #visualización de los datos anteriores
datos = datos.reset_index()
datos = datos.rename(columns={"Date":"contador"})
ax = sns.barplot(x = "contador", y="Primary Type", data = datos)
# Out:
# 1. Estadistica general:
#          Unnamed: 0
# count  1000.000000
# mean    499.500000
# std     288.819436
# min       0.000000
# 25%     249.750000
# 50%     499.500000
# 75%     749.250000
# max     999.000000
#
#  2. columnas Date y PrimaryType.
#                         Date        Primary Type
# 0     09/24/2019 8:00:00 AM  DECEPTIVE PRACTICE
# 1     10/13/2019 8:30:00 PM               THEFT
# 2     10/05/2019 6:30:00 PM               THEFT
# 3     10/13/2019 7:00:00 PM     CRIMINAL DAMAGE
# 4     10/13/2019 2:10:00 PM             ASSAULT
# ..                      ...                 ...
# 995  10/14/2019 10:47:00 PM       OTHER OFFENSE
# 996   10/14/2019 4:00:00 AM             BATTERY
# 997  10/14/2019 10:25:00 AM               THEFT
# 998   10/14/2019 7:00:00 PM               THEFT
# 999   10/14/2019 4:10:00 PM             ROBBERY
#
# [1000 rows x 2 columns]
#
#  3.Convertir fechas
#
#  0     2019-09-24 08:00:00
# 1     2019-10-13 20:30:00
# 2     2019-10-05 18:30:00
# ...

# %%
"""Este código retorna información acerca del DataFrame country_vaccinations"""
path = "https://docs.google.com/spreadsheets/d/e/2PACX-1vSJ7bFjFQu-VmuwebbH0vrg8a3b168p6aTsglLbMISvmgYmg9yGT6mPdlAUVeBl1lU1Cxnj9wtNxghu/pub?output=csv"
df3 = pd.read_csv(path)
df3
# Out:
#           country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1     Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2     Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3     Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4     Afghanistan      AFG  2021-02-26                 NaN                NaN
# ...           ...      ...         ...                 ...                ...
# 9571     Zimbabwe      ZWE  2021-03-29             81610.0            69751.0
# 9572     Zimbabwe      ZWE  2021-03-30             85866.0            72944.0
# 9573     Zimbabwe      ZWE  2021-03-31             91880.0            76995.0
# 9574     Zimbabwe      ZWE  2021-04-01            105307.0            87791.0
# 9575     Zimbabwe      ZWE  2021-04-02            124753.0           103815.0
#
# ...

# %%
Colombia_ = df3.loc[df3.loc[:, 'country'] == 'Colombia'] #csv con los datos para Colombia
Colombia_
#print(Colombia_.to_csv()) imprime en formato csv
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 1841  Colombia      COL  2021-02-17                18.0                NaN
# 1842  Colombia      COL  2021-02-18              9935.0                NaN
# 1843  Colombia      COL  2021-02-19             21307.0                NaN
# 1844  Colombia      COL  2021-02-20             33140.0                NaN
# 1845  Colombia      COL  2021-02-21             39827.0                NaN
# 1846  Colombia      COL  2021-02-22             45166.0                NaN
# 1847  Colombia      COL  2021-02-23             48150.0                NaN
# 1848  Colombia      COL  2021-02-24             50524.0                NaN
# 1849  Colombia      COL  2021-02-25             66157.0                NaN
# 1850  Colombia      COL  2021-02-26             81333.0                NaN
# 1851  Colombia      COL  2021-02-27            114042.0                NaN
# ...

# %%
paises = ["Argentina","Bolivia","Chile","Colombia","Costa Rica","Ecuador","El Salvador","Guatemala","Honduras","Mexico","Panama",
                       "Paraguay","Peru","Dominican Republic","Uruguay","Venezuela"] #comparación de países latinoamericanos
datos = df3[["total_vaccinations","people_vaccinated","people_fully_vaccinated","daily_vaccinations_raw","daily_vaccinations",
                         "total_vaccinations_per_hundred","people_vaccinated_per_hundred","people_fully_vaccinated_per_hundred",
                         "daily_vaccinations_per_million"]]

lista1=[] #listas para cada conjunto de datos
lista2=[]
lista3=[]
lista4=[]
lista5=[]
lista6=[]
lista7=[]
lista8=[]
lista9=[]

#asignación de los valores iniciales para completar las listas 
for i in paises: 
  df = df3.loc[df3.loc[:, 'country'] == i]
  num = df["total_vaccinations"].max()
  lista1.append(num)

for i in paises:
  df = df3.loc[df3.loc[:, 'country'] == i]
  num = df["people_vaccinated"].max()
  lista2.append(num)

for i in paises:
  df = df3.loc[df3.loc[:, 'country'] == i]
  num = df["people_fully_vaccinated"].max()
  lista3.append(num)

for i in paises:
  df = df3.loc[df3.loc[:, 'country'] == i]
  num = df["daily_vaccinations_raw"].mean()
  lista4.append(num)

for i in paises:
  df = df3.loc[df3.loc[:, 'country'] == i]
  num = df["daily_vaccinations"].mean()
  lista5.append(num)

for i in paises:
  df = df3.loc[df3.loc[:, 'country'] == i]
  num = df["total_vaccinations_per_hundred"].mean()
  lista6.append(num)

for i in paises:
  df = df3.loc[df3.loc[:, 'country'] == i]
  num = df["people_vaccinated_per_hundred"].mean()
  lista7.append(num)

for i in paises:
  df = df3.loc[df3.loc[:, 'country'] == i]
  num = df["people_fully_vaccinated_per_hundred"].mean()
  lista8.append(num)

for i in paises:
  df = df3.loc[df3.loc[:, 'country'] == i]
  num = df["daily_vaccinations_per_million"].mean()
  lista9.append(num)

dic=[] #creación del DataFrame con la información de los países latinoamericanos
dataf=[]
for i in range(0,16,1): #se itera sobre el número total de países latinoamericanos
  dic={"total_vaccinations":lista1[i], "people_vaccinated":lista2[i], "people_fully_vaccinated":lista3[i], "daily_vaccinations_raw":lista4[i],
       "daily_vaccinations":lista5[i], "total_vaccinations_per_hundred":lista6[i], "people_vaccinated_per_hundred":lista7[i],
       "people_fully_vaccinated_per_hundred":lista8[i], "daily_vaccinations_per_million":lista9[i]}
  dataf.append(dic)
dataff = pd.DataFrame(dataf)
dataff.index = paises
print(dataff)

dataffintervalo1 = dataff[dataff["total_vaccinations"]>=(1.5*10**6)] #número de vacunados en el intervalo > 1.5E6
dataffintervalo2 = dataffintervalo1[dataffintervalo1["total_vaccinations"]<=(2*10**6)] #número de vacunados en el intervalo < 2.0E6
print("Los pais/paises con el numero de vacunados en el intervalo [1.5E6, 2.0E6] es/son:")
print(dataffintervalo2)
print("Ningún país latinoamericano cumple con la condición") #conclusión
# Out:
#                     total_vaccinations  people_vaccinated  \
# Argentina                    4178896.0          3495125.0
# Bolivia                       318115.0           203103.0
# Chile                       10784941.0          6939461.0
# Colombia                     2336144.0          1971891.0
# Costa Rica                    384355.0           224092.0
# Ecuador                       283106.0           204902.0
# El Salvador                   120476.0           120476.0
# Guatemala                     112751.0           111559.0
# Honduras                       43073.0            43073.0
# Mexico                       8987190.0          7903660.0
# Panama                        373491.0           247539.0
# Paraguay                       45494.0            43656.0
# Peru                          857493.0           573505.0
# Dominican Republic           1101528.0          1000000.0
# Uruguay                       784804.0           716835.0
# ...
