# %% [markdown]
# # Planteamiento del problema
#
# Considere dos osciladores acoplados, de masas idénticas y  conectadas mediante tres resortes de constantes elásticas $k_1, k_2, k_3$. Como se muestra en la figura.

# %% [markdown]
# Después de realizar un análisis detallado del problema, a través de las leyes de Newton ó empleando las ecuaciones de Euler-Lagrange, se puede mostrar que las ecuaciones de movimiento para el sistema vienen dadas por:
#
# \begin{equation}
# m_1 \frac{ \mathrm{d}^2 x_1 }{\mathrm{d}t^2} = -k_1 x_1 + k_2 (x_2-x_1)
# \end{equation}
#
#
#
# \begin{equation}
# m_2 \frac{ \mathrm{d}^2 x_2 }{\mathrm{d}t^2} = -k_3 x_2 - k_2 (x_2-x_1)
# \end{equation}
#
# De forma compacta,  la ecuacion anterior puede ser escrita como:
#
#
# \begin{equation}
# m_1 \ddot{x_1} = -k_1 x_1 + k_2 (x_2-x_1)
# \end{equation}
#
#
#
# \begin{equation}
# m_2  \ddot{x_2} = -k_3 x_2 - k_2 (x_2-x_1)
# \end{equation}
#
# donde $\ddot{x} =\frac{\mathrm{d^2}x}{\mathrm{d}t^2}$.
#
# Las ecuaciones anteriores, son ecuaciones diferenciales lineales de segundo orden y acopladas, que pueden ser escritas de forma matricial como $m\vec{\ddot{x}}= -A\vec{x}$, donde A, es una matriz simétrica:
#
# \begin{equation}
# m
# \begin{pmatrix}
# \ddot{x_1}  \\
# \ddot{x_2}
# \end{pmatrix}
# =-
# \begin{pmatrix}
# k_1 + k_2 & -k_2  \\
# -k_2       &  k_2+k_3  \\
# \end{pmatrix}
# \begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix}
# \end{equation}
#
#
# Para resolver el sistema de ecuaciones acopladas, se puede realizar una transformación, que permite desacoplar el sistema de ecuaciones diferenciales. Sea
#  $\vec{\eta}=S\vec{x}$, donde $\eta$ es una nueva variable en el sistema transformado y S una matriz que cumple que $SAS^{-1}=A_d$, siendo $A_d$ una matriz diagonal.
#
#  Se cumple que $\vec{\ddot {\eta}}=S\vec{\ddot{x}}$
#  y  $m\vec{\ddot{x}}=A\vec{x}$, multiplicando por una matriz S, a ambos lados de la ecuación $m\vec{\ddot{x}}=-A\vec{x}$ obtenemos:
#
# \begin{equation}
# mS\vec{\ddot{x}}=- S A\vec{x}
# \end{equation}
#
# \begin{equation}
# m \vec{\ddot{\eta}} = -S A S^{-1}S\vec{x}
# \end{equation}
#
#
# \begin{equation}
# m \vec{\ddot{\eta}} = -(S A S^{-1})\eta
# \end{equation}
#
#
# \begin{equation}
# m \vec{\ddot{\eta}} = -A_d\eta
# \end{equation}
#
# \begin{equation}
# m\begin{pmatrix}
# \ddot{\eta_1}\\
# \ddot{\eta_2}
# \end{pmatrix}
# =
# -\begin{pmatrix}
# \lambda_1 & 0\\
# 0          &\lambda_2
# \end{pmatrix}
# \begin{pmatrix}
# \eta_1\\
# \eta_2
# \end{pmatrix},
# \end{equation}
#
# donde $\lambda=m\omega^2$ son los autovalores de A. Notese que S es la matriz formada por los autovectores de A. La ecuacion anterior, tiene solución en términos de funciones armónicas.
#
#
# Basado en lo anterior, y resolviendo  el problema más sencillo en el que $k_1 = k_3 = k$, tenemos que:
#
#
# \begin{equation}
# \begin{pmatrix}
# \frac{k + k_2}{m}-\omega^2 & -\frac{k_2}{m}\\
#  -\frac{k_2}{m}          &\frac{k_2 + k}{m}-\omega^2
# \end{pmatrix}
# \begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix}
# =
# -\begin{pmatrix}
# 0\\
# 0
# \end{pmatrix}
# \end{equation}
#
#
# \begin{equation}
# det(A-\omega^2 I)= \left(\frac{k + k_2}{m}-\omega^2\right) \left(\frac{k_2+k}{m}-\omega^2\right )-\frac{k_2^2}{m^2}=0
# \end{equation}
#
# Resolviendo para $\omega^2$, tenemos que :
#
# \begin{equation}
# \omega^2_1=\frac{k+2k_2}{m}
# \end{equation}
#
#
# \begin{equation}
# \omega^2_2=\frac{k}{m},
# \end{equation}
#
#
# los autovecres vienen dados por:
#
# \begin{equation}
# \vec{v_1}=\frac{1}{\sqrt{2}}
# \begin{pmatrix}
# 1\\
# -1
# \end{pmatrix}
# \end{equation}
#
#
# \begin{equation}
# \vec{v_2}=\frac{1}{\sqrt{2}}
# \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix}
# \end{equation}
#
# y la matriz S, viene dada por:
#
#
# \begin{equation}
# S=\frac{1}{\sqrt{2}}
# \begin{pmatrix}
# 1 & -1\\
# 1 & 1
# \end{pmatrix}
# \end{equation}
#
# las variables $x_1,x_2$, en terminos de $\eta$ están dadas por:
#
# \begin{equation}
# x_1=\frac{1}{\sqrt{2}}(\eta_1+\eta_2)
# \end{equation}
#
#
# \begin{equation}
# x_2=\frac{1}{\sqrt{2}}(\eta_2+\eta_1)
# \end{equation}
#
# En conclusión el problema puede ser resuelto, si solucionamos la
# ecuaciones diferenciables desacopladas:
# \begin{equation}
# \ddot{\eta_1}+\omega_1\eta_1=0
# \end{equation}
#
# \begin{equation}
# \ddot{\eta_2}+\omega_2\eta_2=0
# \end{equation}
#
#  con:
#
#  \begin{equation}
# \omega^2_1=\frac{k+2k_2}{m}
# \end{equation}
#
#
# \begin{equation}
# \omega^2_2=\frac{k}{m}
# \end{equation}

# %%
import matplotlib.pylab as plt
import numpy as np 
from scipy import integrate # se usara integrate.odeint
from matplotlib import animation, rc
#from google.colab import files
#from IPython.display import Image
#uploaded = files.upload()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Su tarea será:
#
# 1. Considerar un sistema de dos osciladores acoplados, con constantes elásticas $k_1=k_3$,  $k_2$ y construir un programa que permita realizar los cálculos anteriores de forma sistemática. Es decir, se deberá resolver el problema de autovalores y autovectores, para encontrar las frecuencias de oscilación y la matriz diagonal. La ecuación diferencial  para $\eta$,  deberá ser resuelta  numéricamente y comparada con la solución análitica, la cual viene dada por:
#
#
# \begin{equation}
# \eta_1(t)=\eta_1(0)\cos(\omega_1t)+ \frac{\dot{\eta_1}(0)}{\omega_1}\sin(\omega_1t)
# \end{equation}
#
# \begin{equation}
# \eta_2(t)=\eta_2(0)\cos(\omega_2t)+ \frac{\dot{\eta_2}(0)}{\omega_2}\sin(\omega_1t)
# \end{equation}
#
# y empleando:
#
# \begin{equation}
# x_1=\frac{1}{\sqrt{2}}(\eta_1+\eta_2)
# \end{equation}
#
#
# \begin{equation}
# x_2=\frac{1}{\sqrt{2}}(\eta_2+\eta_1)
# \end{equation}
# tenemos que la solución exacta, al problema viene dada por:
#
# \begin{equation}
# x_1(t)=\frac{1}{2}(x_1(0)-x_2(0))\cos\omega_1 t+\frac{1}{2\omega_1}(\dot{x_1}(0)-\dot{x_2}(0))\sin\omega_1t+\\
# \frac{1}{2}(x_1(0)+x_2(0))\cos\omega_2 t+\frac{1}{2\omega_2}(\dot{x_1}(0)+\dot{x_2}(0))\sin\omega_2t
# \end{equation}
#
# \begin{equation}
# x_2(t)=\frac{1}{2}(x_2(0)-x_1(0))\cos\omega_1 t+\frac{1}{2\omega_1}(\dot{x_2}(0)-\dot{x_1}(0))\sin\omega_1t+\\
# \frac{1}{2}(x_1(0)+x_2(0))\cos\omega_2 t+\frac{1}{2\omega_2}(\dot{x_1}(0)+\dot{x_2}(0))\sin\omega_2t
# \end{equation}
#
#
# La ecuacion anterior tiene solución según las condiciones iniciales. Muestre que la solucion numérica coincide con la analíítica, para ello, realice graficas de ambas soluciones y comparelas, cuando considera  la evolución temporal de $x_1$, $x_2$ para las siguientes condiciones:
#
# - **Modo simétrico:** $x_1(0) = x_2(0) = A$, $\dot{x_1}(0)=\dot{x_2}(0) = 0$
# - **Modo antisimétrico:** $x_1(0)=-x_2(0) = A$, $\dot{x_1}(0)=\dot{x_2}(0) = 0$
# -  $x_1(0)=A, x_2(0) = 0$, $\dot{x_1}(0)=\dot{x_2}(0) = 0$
#
#
#
# 2. Para el última condición, suponga que el acoplamiento es debil, es decir $k_2<<k$. ¿Cómo es la evolucion temporal de $x_1$ y $x_2$ en este caso?.
#
# 3. ¿Qué puede concluir de sus resultados?
#
# 4.  Generalizar el problema, para constantes elásticas de los resortes $k_1, k_2, k_3$ y masas de $m_1, m_2, m_3$.
#
# 5. Realice una animación del movimiento de las particulas en el espacio, segun los resultados obtenidos.
#
#
#
#
# **RETO 1** Considere ahora, un sistema con amortiguamiento proporcional a la velocidad, las ecuaciones de movimiento,
# vienen dadas por:
#
# \begin{equation}
# m\ddot{y_1} + \gamma \dot{y_1} + (k +k_2) y_1 - k_2 y_2 = 0
# \end{equation}
#
#
# \begin{equation}
# m\ddot{y_2} + \gamma \dot{y_2} + (k +k_2) y2 - k_2 y_1 = 0
# \end{equation}
#
# Estudiar en este caso, la evolucion temporal de cada masa para diferentes condiciones.
#
# **RETO 2** Considere 10 osciladores acoplados, ¿Qué tipo de soluciones se pueden obtener este caso?

# %%
def ita1(itas, t):
  w1 = omegas[0]

  dxdt = itas[1]
  ita1_2prima = -w1**2 * itas[0]
  return [dxdt,ita1_2prima]

def ita2(itas, t):
  w2 = omegas[1]

  dxdt = itas[1]
  ita2_2prima = -w2**2 * itas[0]
  return [dxdt,ita2_2prima]  

def kilo(ks):
  k1 = ks[0]
  k2 = ks[1]
  k3 = ks[2]

  A = np.array([[k1 + k2 , -k2], [-k2, k2 + k3]])
  A_valores, A_vectores = np.linalg.eig(A) # A_vectores es la matris tal que (A_vectores @ A @ (A_vectores)**-1) 
  A_diag = (A_vectores @ A @ np.linalg.inv(A_vectores)) # matriz A diagonal 

  return A,A_valores,A_vectores,A_diag

# %%
# en este caso los k's son iguales y tomas las masas tambien iguales 
m1 = 1
m2 = 1
k1 = 1
k2 = 1
k3 = 1
ks = [k1, k2, k3]
A,A_valores,A_vectores,A_diag = kilo(ks)

# η = itaa
x0 = 0 #posicion inicial
x1 = 2 #velocidad inicial
itas = np.array([x0, x1]) 
omega1 = (k1 + 2*k2)/m1
omega2 = k1/m2
omegas = np.array([omega1, omega2]) # los omegas
t =np.linspace(0, 10, 500)    #tiempo de integracion

itacion1 = integrate.odeint(ita1, itas, t) # las soluciones, para las itas
itacion2 = integrate.odeint(ita2, itas, t) # las soluciones, para las itas

# %%
fig1=plt.figure(figsize=(10,8))
plt.subplot(211)
plt.plot(t, itacion1[:,0]) # la segunda derivada de itaa1 en funcion del tiempo ita[:, 0]
plt.xlabel("t", size = 15)    # nombre del eje x 
plt.ylabel("itaa1(t)", size = 15) # nombre del eje y
plt.grid()
plt.subplot(212)
plt.plot(t, itacion1[:,1], color="green")  # la segunda derivada de itaa2 en funcion del tiempo ita[:, 1]
plt.xlabel("t", size = 15)    # nombre del eje x
plt.ylabel("Derivada itaa2(t)", size = 15) # nombre del eje y
plt.grid()
plt.show()

# %%
fig1=plt.figure(figsize=(10,8))
plt.subplot(211)
plt.plot(t, itacion2[:,0]) # la segunda derivada de itaa1 en funcion del tiempo ita[:, 0]
plt.xlabel("t", size = 15)    # nombre del eje x 
plt.ylabel("itaa1(t)", size = 15) # nombre del eje y
plt.grid()
plt.subplot(212)
plt.plot(t, itacion2[:,1], color="green")  # la segunda derivada de itaa2 en funcion del tiempo ita[:, 1]
plt.xlabel("t", size = 15)    # nombre del eje x
plt.ylabel(" Derivada de itaa2(t)", size = 15) # nombre del eje y
plt.grid()
plt.show()

# %% [markdown]
# \begin{equation}
# x_1=\frac{1}{\sqrt{2}}(\eta_1+\eta_2)
# \end{equation}
#
#
# \begin{equation}
# x_2=\frac{1}{\sqrt{2}}(\eta_2+\eta_1)
# \end{equation}

# %%
def x(itacion1, itacion2):
  x_1 = 1/np.sqrt(2)*(itacion1[:,0] + itacion2[:,0])
  x_2 = 1/np.sqrt(2)*(itacion2[:,0] - itacion1[:,0])
  return x_1, x_2

x_1, x_2 = x(itacion1, itacion2) 

"""
No se podra hacer la comparacion con los x's analiticos, por el problema respecto a la x1(0)=x2(0)=A
"""
# Out:
# "\nNo se podra hacer la comparacion con los x's analiticos, por el problema respecto a la x1(0)=x2(0)=A\n"

# %% [markdown]
# \begin{equation}
# \eta_1(t)=\eta_1(0)\cos(\omega_1t)+ \frac{\dot{\eta_1}(0)}{\omega_1}\sin(\omega_1t)
# \end{equation}
#
# \begin{equation}
# \eta_2(t)=\eta_2(0)\cos(\omega_2t)+ \frac{\dot{\eta_2}(0)}{\omega_2}\sin(\omega_1t)
# \end{equation}

# %%
def l_itas(itas, t):
  itaa1 = itas[0] * np.cos(omega1 * t) + (itas[1]/omega1) * np.sin(omega1 * t)
  itaa2 = itas[0] * np.cos(omega2 * t) + (itas[1]/omega2) * np.sin(omega2 * t)
  return itaa1, itaa2

t = np.linspace(0, 10, 500)

itaa1, itaa2 = l_itas(itas, t)
print(itaa1[:20])
print("\n")
print(itacion1[:20,0])
print("\n")
print(itaa2[:20])
print("\n")
print(itacion2[:20,0])
# Out:
# [0.         0.04005602 0.0799673  0.11958964 0.15877985 0.19739634
#  0.23529956 0.27235256 0.30842146 0.34337591 0.37708963 0.4094408
#  0.4403125  0.4695932  0.4971771  0.52296452 0.54686228 0.56878403
#  0.58865057 0.6063901 ]
#
#
# [0.         0.04005603 0.07996731 0.11958965 0.15877987 0.19739636
#  0.23529957 0.27235257 0.30842146 0.34337592 0.37708964 0.4094408
#  0.4403125  0.4695932  0.49717709 0.52296451 0.54686227 0.56878402
#  0.58865056 0.60639009]
#
#
# [0.         0.04007748 0.08013886 0.12016806 0.160149   0.20006563
#  0.23990191 0.27964185 0.31926949 0.35876891 0.39812425 0.43731971
#  0.47633955 0.51516809 0.55378975 0.59218901 0.63035045 0.66825875
#  0.70589868 0.74325512]
#
#
# [0.         0.04007746 0.08013885 0.12016805 0.16014899 0.20006561
#  0.2399019  0.27964184 0.31926947 0.3587689  0.39812424 0.4373197
#  0.47633954 0.51516808 0.55378973 0.59218899 0.63035043 0.66825873
#  0.70589866 0.74325511]

# %%
plt.plot(t,abs(itaa1[:]-itacion1[:,0])) 
plt.xlabel("Diferencia de los resultados 1", size = 15)
plt.ylabel("A lo largo del tiempo", size = 15)
plt.grid()

# %%
plt.plot(t,abs(itaa2[:]-itacion2[:,0])) 
plt.xlabel("Diferencia de los resultados 2", size = 15)
plt.ylabel("A lo largo del tiempo", size = 15)
plt.grid()

# %%
def analitica(x11, x12, t):
  les_x1 = np.array([])
  les_x2 = np.array([])

  for i in t:
    x1_t = 0.5 * (x11 - x12) * np.cos(omega1 * i) + 1/(2 * omega1) * ( 0 - 0 ) * np.sin(omega1 * i) + 0.5 * ( x11 + x12) * np.cos(omega2 * i) + 1/(2* omega2) * (0 + 0) * np.sin(omega2 * i) 

    x2_t = 0.5 * (x12 - x11) * np.cos(omega1 * i) + 1/(2 * omega1) * ( 0 - 0 ) * np.sin(omega1 * i) + 0.5 * ( x11 + x12) * np.cos(omega2 * i) + 1/(2* omega2) * (0 + 0) * np.sin(omega2 * i) 
    
    les_x1 = np.append(les_x1, x1_t)
    les_x2 = np.append(les_x2, x2_t)
  return  les_x1, les_x2

"""
NO TIENE SENTIDO QUE PARA x1(0)=x2(0)=A PORQUE NO PODRE COMPARAR LAS SOLUCIONES ANALITICAS, CON LAS OBTENIDAS CON LAS CTES
"""

#vamos a ver la solucion que deberia dar en el modo simetrico 
t = np.linspace(0, 10, 500)
les_x1 = np.array([])
les_x2 = np.array([])
x11 = A
x12 = A

simetrico_x1, simetrixo_x2 = analitica(x11, x12, t)

#vamos a ver la solucion que deberia dar en el modo Antisimetrico 
las_x1 = np.array([])
las_x2 = np.array([])
x11 = A
x12 = -A

Antisimetrico_x1, Antisimetrixo_x2 = analitica(x11, x12, t)

#Camos a ver la solucion que deberia dar en el modo 3
los_x1 = np.array([])
los_x2 = np.array([])
x11 = A
x12 = 0

modo3_x1, modo3_x2 = analitica(x11, x12, t)
modo3_x1[:100]
# Out:
# array([ 2.        , -1.        , -1.        ,  2.        ,  1.99799253,
#        -0.99899626, -0.99899626,  1.99799253,  1.99197672, -0.99598836,
#        -0.99598836,  1.99197672,  1.98197237, -0.99098619, -0.99098619,
#         1.98197237,  1.96801242, -0.98400621, -0.98400621,  1.96801242,
#         1.95014279, -0.97507139, -0.97507139,  1.95014279,  1.92842225,
#        -0.96421113, -0.96421113,  1.92842225,  1.90292222, -0.95146111,
#        -0.95146111,  1.90292222,  1.87372646, -0.93686323, -0.93686323,
#         1.87372646,  1.84093085, -0.92046542, -0.92046542,  1.84093085,
#         1.80464296, -0.90232148, -0.90232148,  1.80464296,  1.76498175,
#        -0.88249087, -0.88249087,  1.76498175,  1.72207707, -0.86103853,
#        -0.86103853,  1.72207707,  1.67606925, -0.83803463, -0.83803463,
#         1.67606925,  1.62710859, -0.8135543 , -0.8135543 ,  1.62710859,
#         1.57535479, -0.7876774 , -0.7876774 ,  1.57535479,  1.52097642,
#        -0.76048821, -0.76048821,  1.52097642,  1.4641503 , -0.73207515,
#        -0.73207515,  1.4641503 ,  1.40506085, -0.70253042, -0.70253042,
#         1.40506085,  1.34389948, -0.67194974, -0.67194974,  1.34389948,
#         1.28086387, -0.64043194, -0.64043194,  1.28086387,  1.21615727,
#        -0.60807864, -0.60807864,  1.21615727,  1.14998779, -0.57499389,
#        -0.57499389,  1.14998779,  1.08256763, -0.54128381, -0.54128381,
#         1.08256763,  1.01411236, -0.50705618, -0.50705618,  1.01411236])

# %%
""" 
#NO DA EL PLOT POR QUE no se pueden mltiplicar la dimension de los array 
fig1=plt.figure(figsize=(10,8))
plt.subplot(211)
plt.plot(t, simetrico_x1) # la segunda derivada de itaa1 en funcion del tiempo ita[:, 0]
plt.xlabel("t")    # nombre del eje x 
plt.ylabel("itaa1(t)") # nombre del eje y
plt.subplot(212)
plt.plot(t, simetrixo_x2, color="green")  # la segunda derivada de itaa2 en funcion del tiempo ita[:, 1]
plt.xlabel("t")    # nombre del eje x
plt.ylabel("itaa2(t)") # nombre del eje y
plt.show()
"""
# Out:
# ' \n#NO DA EL PLOT POR QUE no se pueden mltiplicar la dimension de los array \nfig1=plt.figure(figsize=(10,8))\nplt.subplot(211)\nplt.plot(t, simetrico_x1) # la segunda derivada de itaa1 en funcion del tiempo ita[:, 0]\nplt.xlabel("t")    # nombre del eje x \nplt.ylabel("itaa1(t)") # nombre del eje y\nplt.subplot(212)\nplt.plot(t, simetrixo_x2, color="green")  # la segunda derivada de itaa2 en funcion del tiempo ita[:, 1]\nplt.xlabel("t")    # nombre del eje x\nplt.ylabel("itaa2(t)") # nombre del eje y\nplt.show()\n'

# %%
#2. para esto 
k1 = 1000 # y k1 = k3 
k2 = 5
A = np.array([[k1-k2, -k2],
              [-k2, 2 * k1]])
los_x1 = np.array([])
los_x2 = np.array([])
x11 = A
x12 = 0

modo31_x1, modo32_x2 = analitica(x11, x12, t)
modo31_x1[:100] # se puede observar que hay una clara disminucion de los valores
# Out:
# array([ 995.        ,   -5.        ,   -5.        , 2000.        ,
#         994.00128215,   -4.99498132,   -4.99498132, 1997.99252693,
#         991.00841647,   -4.97994179,   -4.97994179, 1991.97671653,
#         986.03125487,   -4.95493093,   -4.95493093, 1981.97237159,
#         979.08617801,   -4.92003105,   -4.92003105, 1968.01241811,
#         970.19603685,   -4.87535697,   -4.87535697, 1950.14278763,
#         959.39007089,   -4.82105563,   -4.82105563, 1928.42225304,
#         946.70380375,   -4.75730555,   -4.75730555, 1902.9222186 ,
#         932.17891619,   -4.68431616,   -4.68431616, 1873.72646471,
#         915.86309718,   -4.60232712,   -4.60232712, 1840.93084859,
#         897.80987348,   -4.5116074 ,   -4.5116074 , 1804.64296176,
#         878.07841846,   -4.41245436,   -4.41245436, 1764.98174564,
#         856.73334069,   -4.30519267,   -4.30519267, 1722.07706671,
#         833.84445317,   -4.19017313,   -4.19017313, 1676.0692526 ,
#         809.48652402,   -4.06777148,   -4.06777148, 1627.10859099,
#         783.73900949,   -3.93838698,   -3.93838698, 1575.35479295,
#         756.68577031,   -3.80244106,   -3.80244106, 1520.97642274,
#         728.41477235,   -3.66037574,   -3.66037574, 1464.15029618,
#         699.01777267,   -3.51265212,   -3.51265212, 1405.06084959,
#         668.58999219,   -3.3597487 ,   -3.3597487 , 1343.8994818 ,
#         637.22977603,   -3.20215968,   -3.20215968, 1280.86387142,
#         605.03824278,   -3.04039318,   -3.04039318, 1216.15727193,
#         572.11892406,   -2.87496947,   -2.87496947, 1149.98778706,
#         538.57739553,   -2.70641907,   -2.70641907, 1082.56762921,
#         504.52090081,   -2.53528091,   -2.53528091, 1014.11236344])

# %% [markdown]
# #3. R//
# Podemos observar que cuando se desacoplan las ecuaciones los osciladores actuan como osciladores normales, esto se puede en las graficas de las derivadas.

# %%
"""
SE SUPONE QUE ES PARA ANIMAR PERO NO SE MUY BIEN COMO FUNCIONA LA VERDAD
"""
def update(i):
  """
  #funcion que ni pta idea pa que es, la creo el profesor, y se que es necesaria para la animacion
  """
  ax.clear()
  ax.imshow(evol_temp[i], cmap="gray") # el "gray", es la escala de grices que se usan para ver la animacion 
  ax.axis("on") 
  return ax  

interval_ = 200
#interval_ = int(input(f"Deme el tiempo que va a haber entre una iteracion y otra la animacion en milisegundos: "))
t_max = 100
#t_max = int(input(f"Deme el numero de veces de iteraciones: "))
anchura = 8
altura = 8

evol_temp = itacion1# evol_temp es la variable de la cual se va a crear la animacion 

fig = plt.figure(figsize = (anchura,altura)) # tamaño de la figura
ax = plt.subplot(1,1,1)           # en que lugar va a a estar la animacion 
anim = animation.FuncAnimation(fig, update, frames = len(evol_temp), interval = interval_) # funcion para animar, Interval, es el tiempo de la animacion
plt.close() # para no mostrar lo en esta celda 

anim # muestra la animacion  #GUARDADO CHAVALES
