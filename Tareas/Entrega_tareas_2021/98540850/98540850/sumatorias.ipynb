# %% [markdown]
# ## Cancelación sustractiva
#
#
#
# **serieSn**. Un ejemplo de la cancelacion substractiva es en la suma de series alternantes. Considere la serie $\mathrm{S}_N$,  escrita  matematicamente de tres formas diferentes:
#
# -
# \begin{equation}
# \mathrm{S}_N^{(1)} = \sum_{n = 1}^{2N} (-1)^n \frac{n}{n+1}
# \end{equation}
#
# - Sumando números pares e impares.
#
# \begin{equation}
# \mathrm{S}_N^{(2)} = -\sum_{n = 1}^{N}\frac{2n-1}{2n} + \sum_{n=1}^{N} \frac{2n}{2n+1}
# \end{equation}
#
# - Combinando las series de una forma analítica
#
# \begin{equation}
# \mathrm{S}_N^{(3)} = \sum_{n = 1}^{N}\frac{1}{2n(2n+1)}
# \end{equation}
#
#
#
# Las tres sumas $\mathrm{S}_N^{(1)}$, $\mathrm{S}_N^{(2)}$ y $\mathrm{S}_N^{(3)}$ son matemáticamente iguales, pero los resultados  pueden tener resultados numéricos diferentes.
#
#
# - a) Escribir un programa que realice el cálculo de $\mathrm{S}_N^{(1)}$, $\mathrm{S}_N^{(2)}$ y $\mathrm{S}_N^{(3)}$
# - b) Estudiar la convergencia de la serie para los tres casos.
# - c) Considere  que $S_N^{(3)}$ es la solución exacta, realizar dos graficos log-log, del error relativo en función
# del número de términos ($\mathrm{Log_{10}} E$ VS $\mathrm{Log_{10}} N$), para $S_N^{(1)}$ y $S_N^{(2)}$. Donde,  $E = |(S_N^{(i)} - S_N^{(3)})/S_N^{(3)}|$, i = 1, 2. Considere valores de $N = 1\times 10^{6}$.
# - d) Analizar y discutir los resultados. Tenga en cuenta la discusión realizada sobre teoría de errores en la página
# 39 del libro del libro [Computational Physics. ](https://www.dropbox.com/s/n06ul2r4l65khl6/Computational%20Physics%20-%20Problem%20Solving%20with%20Computers%2C%203527406263.pdf?dl=0)

# %%
#importar librerias

import matplotlib.pylab as plt 
import numpy as np

#defino la primera serie 
def Sn_1(N): 
  S_n = 0
  for n in range(1,N):
    prod_1 = ((-1)**n)
    prod_2= n/(n+1)
    S_n = prod_1*prod_2
    
  return S_n

print("convergencia de la serie_1 para dos valores consecutivo")# el resutado debe ser parecido para dos valores consecutivos para que la serie converga
print()                                                       # de lo contrario la serie diverge
print("n:",Sn_1(1000),"   " ,"n+1:", Sn_1(1001)," la serie diverge, pues el signo cambia para dos valores consecutivos  ")
print("===================================================")   

#####################################################################################################################################


#defino la segunda serie 
#dividiré la serie en dos partes para operar mejor 
def Sn_11(N): 
  S_n = 0
  for n in range(1,2*N):
    prod_11 = -(2*n-1)/(2*n)# primer operando
    prod_21= (2*n)/(2*n+1)#segundo operando
    S_n1 = prod_11+prod_21# suma del pirmer operando y segundo operando
    
  return S_n1
print("convergencia de la serie_2 para dos valores consecutivo")# el resutado debe ser parecido para dos valores consecutivos para que la serie converga
print()                                                       # de lo contrario la serie diverge
print("n:",Sn_11(9999),"   ","n+1:",Sn_11(10000)," la serie converge ")#
print("===================================================")

#####################################################################################################################################


#defino la tercera serie 

def Sn_111(N): 
  S_n = 0
  for n in range(1,2*N):
    prod_111 = 1/(2*n*(2*n+1))
      
    
  return prod_111# retorno el prducto de la serie

print("convergencia de la serie_3 para dos valores consecutivo")# el resutado debe ser parecido para dos valores consecutivos para que la serie converga
print()                                                       # de lo contrario la serie diverge
print("n:",Sn_111(9999),"   ","n+1:",Sn_111(10000)," la serie converge ")#
print()
# Out:
# convergencia de la serie_1 para dos valores consecutivo
#
# n: -0.999     n+1: 0.999000999000999  la serie diverge, pues el signo cambia para dos valores consecutivos
# ...
# convergencia de la serie_2 para dos valores consecutivo
#
# n: 6.251719142369438e-10     n+1: 6.250469031243711e-10  la serie converge
# ...
# convergencia de la serie_3 para dos valores consecutivo
#
# n: 6.251719105534289e-10     n+1: 6.250468777345214e-10  la serie converge

# %% [markdown]
# \begin{equation}
# \mathrm{S}_N^{(2)} = -\sum_{n = 1}^{N}\frac{2n-1}{2n} + \sum_{n=1}^{N} \frac{2n}{2n+1}
# \end{equation}
# Esta serie converge por lo expuesto en el resultado anterior
#
#
# \begin{equation}
# \mathrm{S}_N^{(3)} = \sum_{n = 1}^{N}\frac{1}{2n(2n+1)}
# \end{equation}
# Esta serie converge por lo expuesto en el resultado anterior
#
# \begin{equation}
# \mathrm{S}_N^{(1)} = \sum_{n = 1}^{2N} (-1)^n \frac{n}{n+1}
# \end{equation}
# Esta serie diverge, pues los signos se altenan para valores consecutivos

# %%
log = np.arange(1000000,1000010,1)#arreglo para el formato log-log 
err = []#arreglo vacio
for i in log:
  abs = np.fabs(S1(i)-S3(i))/S3(i)#error dado 
  err.append(abs)

err_1 = []# repetire lo anterior 
for i in log:
  abs_1 = np.fabs(S2(i)-S3(i))/S3(i)
  err_1.append(abs_1)

#graficas
plt.figure(figsize=(20,5))
plt.subplots_adjust(hspace=2)
plt.suptitle("Graficos log-log")
# graficando el error relativo de la serie 1 
plt.subplot(1,2,1)
plt.title("Error relativo serie 1")
plt.loglog(log,err)
plt.xlabel("N")
plt.ylabel("ERROR_1")
plt.grid()
# graficando el error relativo de la serie 2
plt.subplot(1,2,2)
plt.title("Error relativo serie 2")
plt.loglog(log,err_1, color="g")
plt.xlabel("N")
plt.ylabel("ERROR_2")
plt.grid()
plt.show()

# %% [markdown]
# EN LA GRAFICA DEL ERROR RELATIVO DE LA SERIE 2 LA PENDIENTE ES CONTANTE, UN INDICATIVO DE LA SERIE CONVERGE, LA SERIE TIENE UN COMPORAMIENTO OSCILATORIO, UN PENDIENTE QUE CAMBIA ES INDICATIVO DE QUE LA SERIE 1 DIVERGE

# %% [markdown]
# ## **Errores de redondeo**. Caos numérico en un mapa logístico y errores de punto flotante (Errores de redondeo)
#
# > Un ejemplo clásico de caos,  es el comportamiento no lineal en las interaciones de un mapa logistico
#
# \begin{equation}
# x_{n+1}=f(x_n)=rx_n(1-x_n)
# \end{equation}
#
# > con $x\in (0,1)$ y $r\in(0,4)$ se pueden producir varios comportamientos sorprendentes.
#
#
# > ### Problema:
# Encontrar tres formas diferentes de expresar $f(x)$  y calcular la evolución de la misma condición inicial después de cientos de iteraciones. Para este problema, será extremadamente útil  ver sus resultados gráficamente; construya listas de números y llame la libreria matplotlib.
#
#
# >#### Hint: valores numéricos de r y x0 que puede tomar:
# ```python
#     >>> r = [1.9, 2.9, 3.1, 3.5, 3.9]
#
#     >>> x0 = 0.6 # any number in [0,1] will do here
#
#     >>> numpoints = 100
#        ```

# %%
lista_tasa = [1.9, 2.9, 3.1, 3.5, 3.9]

def todo(r):
  #Defino algunas variables
  size = 10
  xi = 0.6
  r = r
  repeticiones = 100 
  #Importante crear este arreglo para que no hayan errores por dimensiones mas adelante
  Nrep = np.arange(0, repeticiones, 1)

  
  def f1(x, r):#función de población original
    y = r * x * (1-x)
    return y

  def f2(x, r):#fforma 1
    y = r * (x**2) * (1/x - 1)
    return y

  def f3(x, r):#forma2
    y = (-1)*np.sqrt(x**2)*r*(x-1)
    return y
  
  def graficas(xi, r, repeticiones,Funcion):#forma 3
    f = Funcion
    ejey = np.zeros(repeticiones)
    for i in range(0, repeticiones):
      xn = f(xi, r)
      xi = xn
      ejey[i] = xn
    return ejey 

  #Grafico 1
  plt.figure(figsize=(22,5))
  y1 = graficas(xi, r, repeticiones,f1)
  plt.subplot(141)
  plt.xlabel("Repeticiones", fontsize=size)
  plt.ylabel("F(x)")
  plt.grid()
  plt.plot(Nrep, y1, label = '$r*x*(1-x)$') 
  plt.legend()
  #Grafico 1
  y2 = graficas(xi, r, repeticiones,f2)
  plt.subplot(142)
  plt.xlabel("Repeticiones", fontsize=size)
  plt.ylabel("F(x)")
  plt.grid()
  plt.plot(Nrep, y2, label = '$r*(x^2)*(1/x - 1)$') 
  plt.legend()
    #Grafico 3
  y3 = graficas(xi, r, repeticiones,f3)
  plt.subplot(143)
  plt.xlabel("Repeticiones", fontsize=size)
  plt.ylabel("F(x)")
  plt.grid()
  plt.plot(Nrep, y3,color = 'pink',label = '$(-1)r(x-1)((x^2)^(1/2))$') 
  plt.legend()
  
  plt.show()
for i in lista_tasa:
  print("Para una tasa de crecimiento (r), igual a {}, se obtienen las siguientes gràficas: ".format(i))
  print(todo(i))
# Out:
# Para una tasa de crecimiento (r), igual a 1.9, se obtienen las siguientes gràficas:
# None
# Para una tasa de crecimiento (r), igual a 2.9, se obtienen las siguientes gràficas:
# None
# Para una tasa de crecimiento (r), igual a 3.1, se obtienen las siguientes gràficas:
# None
# Para una tasa de crecimiento (r), igual a 3.5, se obtienen las siguientes gràficas:
# None
# Para una tasa de crecimiento (r), igual a 3.9, se obtienen las siguientes gràficas:
# None
