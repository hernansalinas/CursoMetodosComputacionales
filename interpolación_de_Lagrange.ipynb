# %% [markdown]
# <a href="https://colab.research.google.com/github/Elizajr/CursoMetodosComputacionales/blob/main/interpolaci%C3%B3n_de_Lagrange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
puntos=np.array([[2,4],[5,1],[6,2]])
plt.figure()
#plt.plot(puntos[:,0],puntos[:,1],"o")
plt.plot(puntos.T[0],puntos.T[1],"o", c="pink")
plt.show()

# %%
def L(puntos,j):
  n=len(puntos)
  def evaluar(x):
    resultado=1
    for i in range(n):
      if i != j:
        resultado*=(x-puntos[i][0])/(puntos[j][0]-puntos[i][0])
    return resultado

  return evaluar

# %%
L0=L(puntos,0)
L1=L(puntos,1)
L2=L(puntos,2)

# %%
Lsuprema=np.array([L0,L1,L2])
X=np.linspace(0,6)
plt.figure()
plt.plot(puntos.T[0],puntos.T[1],"o", c="pink")
for p in Lsuprema:
  Y=p(X)
  plt.plot(X,Y)
plt.show()

# %%
L0(6)
# Out:
# 0.0

# %%
puntos
# Out:
# array([[2, 4],
#        [5, 1],
#        [6, 2]])

# %%
puntos[0][1]
# Out:
# 4

# %%
def P(puntos,Lsuprema):
  n=len(puntos)
  def evaluar(x):
    salida=0
    for k in range(n):
      salida+=puntos[k][1]*Lsuprema[k](x)
    return salida
  return evaluar

# %%
plt.figure()
plt.plot(puntos.T[0],puntos.T[1],"o", c="pink")
Y=Pol(X)
plt.plot(X,Y,c="magenta",alpha=0.2)
plt.grid(linestyle="dotted")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolación de Lagrange")
plt.show()
